# %%
import scraper
import pickle
import matplotlib.pyplot as plt
from sklearn import preprocessing
import numpy as np
import sys
from datetime import datetime

# %%
itemPrices = scraper.loadItemPrices()

# %%
def checkDates(dates):
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    return repeats

# %%
data = {}
for item in itemPrices:
    print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)
# Out:
# Dragon_bones
# Iron_longsword
# Dragon_halberd
# Scythe_of_vitur_(uncharged)
# Holy_wraps
# Black_warlock
# Blue_wizard_robe_(g)
# Abyssal_whip
# Amethyst_arrowtips
# Blue_elegant_shirt
# Godsword_shard_1
# Dodgy_necklace
# Holy_symbol
# Desert_legs
# Empty_plant_pot
# Steel_full_helm_(g)
# Mist_battlestaff
# Steel_dagger(p)
# Bone_club
# Roast_rabbit
# Adamant_platebody
# Elf_camp_teleport
# Ogre_arrow_shaft
# New_crystal_bow
# Shrimps
# Magic_essence_mix(2)
# Steel_kiteshield
# Dragonfruit_tree_seed
# Adamant_shield_(h1)
# Rune_thrownaxe
# Cabbage
# Bandos_godsword_ornament_kit
# Black_full_helm_(t)
# Noose_wand
# Karil's_leathertop
# Anglerfish
# Jar_of_souls
# Chocolate_bomb
# Onyx_amulet
# Cabbage_seed
# Energy_mix(2)
# Cleaver
# Dragon_spear(p)
# Flax
# Malediction_shard_1
# Saradomin_d'hide_boots
# Bronze_platebody_(t)
# Easter_egg
# War_blessing
# Rune_longsword
# Leaf-bladed_sword
# Unblessed_symbol
# Dragon_knife(p+)
# Infinity_gloves
# Ensouled_aviansie_head
# Orange_dye
# Ankou_top
# Saltpetre
# Samurai_greaves
# Ancient_statuette
# Turquoise_robe_bottoms
# Dragon_dagger(p++)
# Mithril_axe
# Relicym's_balm(2)
# Jade_bolt_tips
# Dragon_arrow(p+)
# Oak_blackjack(o)
# Adamant_shield_(h5)
# Dwarf_weed
# Banana
# Longbow
# Stamina_potion(3)
# Mint_cake
# Marrentill
# Guthix_full_helm
# Red_d'hide_vamb
# Onyx
# Teak_clock
# 3rd_age_range_legs
# Oil_lamp
# Guthan's_armour_set
# Pestle_and_mortar
# Teleport_to_house
# Ruby_bolts
# Cream_robe_bottoms
# Air_rune
# Black_flowers
# Twisted_buckler
# Saradomin_full_helm
# Mahogany_logs
# Super_restore(2)
# Rune_warhammer
# Steel_platelegs
# Verac's_flail
# Broad_arrowheads
# Torstol_seed
# Stone_seal
# Ensouled_bloodveld_head
# Orange
# Bandos_robe_legs
# Jade
# Team-10_cape
# Silver_bar
# Rune_arrow(p++)
# Steel_studs
# Black_dagger
# Bronze_plateskirt_(g)
# Team-31_cape
# Dragon_bolts
# Iron_dagger(p+)
# Mystic_gloves_(dark)
# Lesser_demon_mask
# Rune_javelin(p+)
# Afro
# Dwarven_stout(m)
# Pearl_bolts_(e)
# Bolt_rack
# Revenant_ether
# Antifire_potion(2)
# Black_d'hide_shield
# Bronze_arrow(p++)
# Prayer_potion(3)
# Mithril_javelin(p)
# Bullseye_lantern_(unf)
# Tyrannical_ring
# Grey_robe_top
# Green_d'hide_chaps
# Teacher_wand
# Black_warhammer
# Dragon_platebody
# Bronze_gold-trimmed_set_(sk)
# Lobster
# Rune_helm_(h4)
# Mystic_robe_top_(dark)
# Needle
# Monk's_robe_top_(g)
# Fishing_rod
# Adamant_spear
# Zul-andra_teleport
# Silk
# Polar_kebbit_fur
# Mithril_pickaxe
# Magic_sapling
# Superantipoison(2)
# Ruby_bracelet
# Iron_warhammer
# Black_shield_(h3)
# Adamant_2h_sword
# Bronze_platelegs_(g)
# Cannonball
# Old_school_bond
# Kyatt_hat
# Dragon_javelin(p++)
# Steel_javelin_heads
# Gilded_kiteshield
# Adamant_cane
# Assorted_flowers
# Bagged_daffodils
# Defence_potion(2)
# Extended_super_antifire(3)
# Iron_dart
# Premade_s'y_crunch
# Ensouled_elf_head
# Gilded_platebody
# Kwuarm
# Mystic_boots_(light)
# Green_d'hide_body_(g)
# Sapphire_glacialis
# Blue_halloween_mask
# Dragon_legs/skirt_ornament_kit
# Bronze_pickaxe
# Ensouled_giant_head
# Amulet_of_magic
# Ancient_relic
# Earth_impling_jar
# Antidote++(4)
# Elysian_spirit_shield
# Super_attack(1)
# Palm_sapling
# Kitchen_knife
# Steel_knife(p)
# Amethyst_arrow(p+)
# Red_hat
# Armadyl_chaps
# Adamant_longsword
# Dragon_mace
# Dagannoth_hide
# Stale_baguette
# Guthix_balance(3)
# Bronze_gold-trimmed_set_(lg)
# Top_hat
# Black_desert_shirt
# Torn_prayer_scroll
# Onions(10)
# Super_antifire_potion(1)
# Black_salamander
# Saradomin_brew(4)
# Mystic_hat_(dark)
# Black_axe
# Adamant_hasta(p)
# Brass_necklace
# Black_d'hide_chaps_(t)
# Hydra_bones
# Dinh's_bulwark
# Steel_spear
# Mithril_trimmed_set_(lg)
# Adamant_helm_(h2)
# Adamant_full_helm
# Black_knife(p+)
# Serpentine_visage
# Green_elegant_shirt
# Grey_toy_horsey
# Lizardman_fang
# Red_dye
# Olive_oil(2)
# Green_d'hide_shield
# Green_firelighter
# Black_halberd
# Bastion_potion(1)
# Magic_potion(3)
# Large_teak_bed
# Unfired_pot_lid
# Golden_chef's_hat
# Bandos_dragonhide_set
# Amulet_of_glory_(t4)
# Grapes
# Black_med_helm
# Dwarf_cannon_set
# Tzhaar-ket-em
# Black_helm_(h1)
# Cooking_apple
# Orange_chunks
# Black_d'hide_vamb
# Hard_leather
# Raurg_bones
# Bananas(5)
# Marrentill_tar
# Dharok's_platelegs
# Adamant_gold-trimmed_set_(sk)
# Meat_pizza
# Steel_bolts_(unf)
# Iron_set_(sk)
# Beer_tankard
# Maple_bird_house
# Mithril_bar
# Godsword_shard_2
# Wool
# Dwarven_stout(4)
# Teal_gloves
# Steam_rune
# Black_toy_horsey
# Iron_kiteshield_(g)
# Adamant_full_helm_(g)
# Onyx_dragon_bolts_(e)
# Bread_dough
# Rock-shell_chunk
# Hunting_mix(1)
# Nasturtiums
# Willow_shield
# Ancient_d'hide
# Riyl_remains
# Black_shield_(h1)
# Tiara
# Gold_amulet
# Arceuus_banner
# Zamorak_page_1
# Iron_dagger(p++)
# Bandos_robe_top
# Runite_bolts
# Raw_shark
# Bronze_dart
# Bronze_platelegs
# Elder_chaos_robe
# Impling_jar
# Sapphire_bolt_tips
# Iron_dragon_mask
# Mahogany_seed
# Desert_camo_legs
# Mithril_spear(p)
# Dwarven_stout(m4)
# Kyatt_fur
# Gnomebowl_mould
# Nature_impling_jar
# Team-26_cape
# Slayer's_respite(m4)
# Superattack_mix(1)
# Trading_sticks
# Rock-climbing_boots
# Amulet_of_defence
# Mackerel
# Potato_with_cheese
# Guthix_dragonhide
# Plant_cure
# Yellow_dye
# Bat_bones
# Oak_roots
# Super_attack(3)
# Bronze_kiteshield_(t)
# Ancient_platelegs
# Amulet_of_chemistry
# Skull_piece
# Raw_salmon
# Fenkenstrain's_castle_teleport
# Iron_bolts_(unf)
# Water_battlestaff
# Sagacious_spectacles
# Cooked_rabbit
# Bottled_dragonbreath
# Iron_hasta(p)
# Mithril_dagger(p++)
# Mithril_2h_sword
# Disk_of_returning
# Combat_bracelet
# Rune_platebody_(g)
# Pot_of_cream
# Rune_platebody
# Bucket_of_milk
# Oak_shield
# Caviar
# Fremennik_cyan_cloak
# Orange_sapling
# Jar_of_swamp
# Pastry_dough
# Rune_dart_tip
# Iron_arrow(p+)
# Black_kiteshield_(t)
# Black_mask_(10)
# Holy_elixir
# Iron_hasta
# Mithril_knife(p+)
# Dragon_dagger
# Black_brutal
# Cooked_karambwan
# Mithril_arrow(p+)
# Chisel
# Bandos_page_1
# Tomatoes(5)
# Ballista_limbs
# Rosemary_seed
# Rune_javelin
# Pink_elegant_skirt
# Ring_of_forging
# Saradomin_sword
# Bird_nest
# Adamant_scimitar
# Adamant_kiteshield
# Purple_cape
# Fez
# Amulet_of_torture
# Black_dart(p++)
# Mystic_gloves
# Yew_stock
# Fremennik_skirt
# Kwuarm_potion_(unf)
# Adamant_spear(p)
# Mithril_javelin(p++)
# Beer_barrel
# Mithril_hasta(p)
# Worm_hole
# Jungle_demon_mask
# Ground_guam
# Diamond_necklace
# Cleaning_cloth
# Jungle_camo_top
# Rune_plateskirt_(g)
# Mushroom_pie
# Team-24_cape
# Pineapple_seed
# Adamant_dart(p)
# Black_mask
# Maple_pyre_logs
# Magic_staff
# Unicorn_horn
# Opal_bolt_tips
# Dragon_hasta(p+)
# Bracelet_of_slaughter
# Gold_seal
# Frog-leather_boots
# Hill_giant_club
# Zamorak_robe_legs
# Team-25_cape
# Jade_machete
# Sapphire_bolts
# Iron_javelin(p++)
# Rock-shell_splinter
# Red_d'hide_body
# Serum_207_(1)
# Mystic_lava_staff
# Steel_arrow
# Gadderhammer
# Nature_talisman
# Mud_battlestaff
# Kraken_tentacle
# Bagged_willow_tree
# Ale_of_the_gods
# Saradomin_d'hide
# Blue_elegant_legs
# Spork
# Zamorak_d'hide_boots
# Team-12_cape
# Adamant_sword
# Black_dart
# Ninja_impling_jar
# Warrior_ring
# Adamant_knife
# Dragon_armour_set_(sk)
# Magic_potion(1)
# Stripy_feather
# Guthix_rest(1)
# Uncharged_toxic_trident_(e)
# Cat_mask
# Adamant_shield_(h2)
# Iron_thrownaxe
# Raw_monkfish
# Monk's_robe_top
# Black_chinchompa
# Lumbridge_graveyard_teleport
# Dragon_defender_ornament_kit
# Avantoe_potion_(unf)
# Willow_shortbow
# Bandos_kiteshield
# Uncooked_egg
# Compost_potion(3)
# Slayer's_staff
# Purple_flowers
# Black_skirt_(t)
# Bronze_med_helm
# Axeman's_folly
# Black_plateskirt_(t)
# Onyx_dragon_bolts
# White_boots
# Monk's_robe_(g)
# Team-43_cape
# Cadantine_blood_potion_(unf)
# Snakeskin
# Team-37_cape
# White_chainbody
# Batta_tin
# Mithril_kiteshield
# Musketeer_pants
# Bronze_warhammer
# Torstol
# Dragonstone_bolts_(e)
# Saradomin_robe_legs
# Adamant_dart
# Orange_feather
# Goblin_mail
# Seers_ring
# Wooden_chair
# Antidote++(3)
# Golden_apron
# Seaweed_spore
# Gilded_dresser
# Diamond
# Empty_oil_lantern
# Amulet_of_power
# Guthix_page_3
# Mind_bomb(m4)
# Maple_blackjack
# Toktz-xil-ak
# Hunter_potion(4)
# Grey_gloves
# Smoke_battlestaff
# Guthan's_warspear_0
# Splitbark_boots
# Snapdragon_seed
# Pink_elegant_legs
# Extended_antifire_mix(2)
# Iron_claws
# Ancient_dragonhide_set
# Onyx_necklace
# Mithril_hasta
# Spice
# Cider_barrel
# Saradomin_kiteshield
# Tatty_graahk_fur
# Bronze_knife(p++)
# Half_full_wine_jug
# Potato_cactus_seed
# Necklace_of_anguish
# Red_cape
# Elder_maul
# Premade_choc_bomb
# Adamant_dart(p+)
# Sapphire_ring
# Black_dragon_leather
# Cosmic_tiara
# Fish_food
# Rune_plateskirt
# Sulliuscep_cap
# Ghrazi_rapier
# Grain
# Armadyl_coif
# Iron_dagger
# Mystic_hat
# Large_oak_bed
# Menaphite_red_robe
# Pegasian_crystal
# Iron_knife(p)
# Raw_oomlie
# Fishing_mix(2)
# Mahogany_pyre_log
# Calquat_keg
# Bookcase
# Earth_tiara
# Silver_bolts
# Curry_sapling
# Onion
# Ape_atoll_teleport
# Worm_batta
# Plain_pizza
# Cactus_spine
# Defence_mix(2)
# Menaphite_purple_robe
# Energy_potion(2)
# Blood_rune
# Guthan's_chainskirt
# Raw_beef
# Guthix_d'hide_boots
# Harralander_tar
# Bandos_platebody
# Blue_wizard_hat_(t)
# Adamant_plateskirt_(g)
# Mithril_platelegs_(t)
# Super_restore_mix(2)
# Asgarnian_ale(m4)
# Teak_wardrobe
# Super_energy_mix(2)
# Golden_scarab
# Unlit_torch
# Wolf_bones
# Stamina_potion(2)
# Snape_grass_seed
# Steel_scimitar
# Bronze_dagger
# Yew_roots
# Combat_potion(3)
# Leaf-bladed_battleaxe
# Pottery_statuette
# Steel_platebody
# Opal_bolts_(e)
# Egg_potato
# Enchant_ruby_or_topaz
# Grey_hat
# Machete
# Sapphire_necklace
# Empty_sack
# Bones_to_bananas
# Bracelet_of_clay
# Pat_of_butter
# Attack_potion(4)
# Bastion_potion(2)
# Thorny_hedge
# Amulet_of_glory
# Mithril_dagger(p)
# Steel_dart(p+)
# Onyx_bolts_(e)
# Fremennik_green_cloak
# Rune_dart
# Herring
# Blue_elegant_skirt
# Efh_salt
# Antidote+(3)
# Enchant_onyx
# Steel_battleaxe
# Blue_headband
# Fat_snail
# Zamorak_full_helm
# Blue_elegant_blouse
# Black_bead
# Black_dagger(p++)
# Timber_beam
# Gilded_scimitar
# Papaya_sapling
# Iron_gold-trimmed_set_(lg)
# Premade_fr't_batta
# Dragon_hasta(p++)
# Roast_beast_meat
# Serum_207_(4)
# Magic_mix(1)
# Mind_altar_teleport
# Black_pickaxe
# Mithril_dragon_mask
# Mithril_bolts_(p)
# 3rd_age_platelegs
# Jade_necklace
# Armadyl_d'hide_boots
# Circular_hide
# Mystic_boots_(dark)
# Minced_meat
# Dark_bow_tie
# Leather_chaps
# Curry
# Yellow_hat
# Pharaoh's_sceptre_(3)
# Tarromin_tar
# Sinister_key
# Pegasian_boots
# Mithril_mace
# Iron_full_helm
# Ahrim's_staff
# Larupia_hat
# Hunter_potion(2)
# Golovanova_fruit_top
# Bronze_dart(p)
# Steel_halberd
# Longbow_(u)
# Team-23_cape
# Willow_seed
# Light_tuxedo_cuffs
# Light_trousers
# Shade_robe
# Pitta_bread
# Farseer_helm
# Dragon_boots
# Wooden_spoon
# Rune_full_helm_(t)
# Jar_of_decay
# Amulet_of_the_damned_(full)
# Dragon_crossbow_(u)
# Red_robe_top
# Black_wizard_hat_(t)
# Rune_javelin_heads
# Mushroom_spore
# Grimy_cadantine
# Bronze_javelin_heads
# Adamant_claws
# Magic_pyre_logs
# Mithril_knife(p)
# Topaz_bracelet
# Mystic_gloves_(light)
# Team-36_cape
# Bronze_bar
# Guthix_armour_set_(sk)
# Robin_hood_hat
# Oak_cape_rack
# Ourg_bones
# Fur
# Watering_can
# Kebab_mix
# Merfolk_trident
# Mind_shield
# Apple_tree_seed
# 3rd_age_axe
# Beginner_wand
# Super_antifire_mix(1)
# Saradomin_platelegs
# Rune_gold-trimmed_set_(lg)
# Adamant_bolts(unf)
# Mithril_plateskirt_(t)
# Spined_gloves
# Xerician_hat
# Bronze_knife
# Crystal_key
# Black_dart(p+)
# Ensouled_imp_head
# Super_attack(4)
# Guam_leaf
# Verac's_plateskirt
# Spicy_crunchies
# Sapphire_bracelet
# Mole_skin
# Proselyte_harness_f
# Annakarl_teleport
# Barb-tail_harpoon
# Calquat_fruit
# Bullseye_lantern_(empty)
# Larupia_legs
# Fremennik_beige_shirt
# Uncut_onyx
# Bagged_marigolds
# Wrath_rune
# Dragonstone_amulet
# 3rd_age_mage_hat
# Iron_med_helm
# Yew_longbow_(u)
# Spectral_sigil
# Gardening_trowel
# Premade_blurb'_sp.
# Super_combat_potion(4)
# Mithril_platelegs_(g)
# Studded_body_(t)
# Gilded_med_helm
# Turquoise_boots
# Armadyl_kiteshield
# Teal_hat
# Flared_trousers
# Asyn_remains
# White_mace
# Dragon_cane
# Steel_trimmed_set_(lg)
# Zamorak_armour_set_(lg)
# Necklace_mould
# Zenyte_ring
# Super_strength(3)
# Stew
# Gout_tuber
# Woad_seed
# Red_d'hide_chaps
# Dragon_arrow
# Infinity_bottoms
# Potato_with_butter
# Adamant_platelegs_(t)
# Super_restore(1)
# Spicy_minced_meat
# Blue_beret
# Super_defence(1)
# Black_mace
# Rune_full_helm
# Cream_hat
# Skeletal_boots
# White_firelighter
# Steel_plateskirt_(t)
# Opal_dragon_bolts
# Tuna_potato
# Graahk_headdress
# White_platebody
# Bandos_rune_armour_set_(lg)
# Dorgeshuun_crossbow
# Spiked_boots
# Blamish_bark_shell
# Ranging_mix(2)
# Morrigan's_throwing_axe
# Runite_crossbow_(u)
# Piscarilius_banner
# Choc_saturday
# Teak_bird_house
# Ancient_kiteshield
# Potatoes(10)
# Obsidian_platelegs
# Dragonstone_bracelet
# Raw_bass
# Adamantite_limbs
# Black_gold-trimmed_set_(sk)
# Super_def._mix(2)
# Adamant_trimmed_set_(lg)
# Strawberries(5)
# Lean_snail_meat
# Adamant_javelin(p+)
# Adamant_hasta(p+)
# Papaya_tree_seed
# 3rd_age_full_helmet
# Four-poster_bed
# Arctic_pyre_logs
# Bandos_stole
# Achey_tree_logs
# Amulet_of_magic_(t)
# Topaz_bolts_(e)
# Katana
# Dust_battlestaff
# Shears
# Ball_of_wool
# Dragon_dart_tip
# Willow_blackjack(o)
# Ring_of_pursuit
# Magic_roots
# Team-16_cape
# Tortoise_shell
# Dragonfruit_sapling
# Hood_of_darkness
# Fremennik_brown_shirt
# Dragon_plateskirt
# Pizza_base
# Steel_thrownaxe
# Gilded_hasta
# Rune_dart(p++)
# Hat_eyepatch
# Limpwurt_root
# Super_defence(4)
# Berserker_necklace
# Pot_of_flour
# Small_fishing_net
# Rune_arrow
# Steel_knife
# Bronze_kiteshield_(g)
# Fremennik_purple_cloak
# Desert_devil_fur
# Carved_oak_table
# Spiny_helmet
# Dragonfruit
# Armadyl_dragonhide_set
# Uncut_jade
# Graahk_fur
# Ancient_crozier
# Iron_pickaxe
# Jar_of_stone
# Knife
# Mithril_arrow(p)
# Mithril_dart_tip
# Godsword_blade
# Anti-venom(2)
# Rolling_pin
# Cod
# Dark_tuxedo_shoes
# Bronze_spear(p)
# Grimy_snapdragon
# Dragon_kiteshield
# Grimy_tarromin
# Dwellberry_seed
# Fancy_hedge
# Adamant_knife(p)
# Rune_dagger(p)
# Saradomin_hilt
# Earth_orb
# Unfired_bowl
# Emerald_amulet
# Abyssal_dagger_(p++)
# Teak_fancy_dress_box
# Rope
# Bronze_platelegs_(t)
# Seaweed
# Oak_clock
# Guam_potion_(unf)
# Sacred_oil(1)
# Yew_longbow
# Raw_manta_ray
# Kodai_insignia
# Oak_fancy_dress_box
# Oak_longbow_(u)
# Red_spiders'_eggs
# Adamant_helm_(h4)
# Thin_snail
# Rainbow_fish
# Team-20_cape
# Obsidian_cape
# Dragon_longsword
# Tatty_larupia_fur
# Ensouled_chaos_druid_head
# White_beret
# Cowhide
# Purple_firelighter
# Adamant_kiteshield_(t)
# Extended_antifire(1)
# Goat_horn_dust
# Fedora
# Pineapple_ring
# Leaping_sturgeon
# Magic_seed
# Cannon_base
# Mushroom_potato
# Sliced_banana
# Redwood_sapling
# Kebbit_teeth
# Mystic_fire_staff
# Adamant_bolts_(p)
# Cornflour
# Soul_rune
# Mithril_platebody_(g)
# Steel_boots
# Black_dragon_mask
# Chef's_hat
# Green_dragon_mask
# Shield_right_half
# Cake_tin
# Basket
# Mahogany_plank
# Maple_seed
# Mithril_arrow(p++)
# Grimy_torstol
# Guthix_kiteshield
# Guthix_platelegs
# Snape_grass
# Rune_crossbow
# Karil's_leatherskirt
# Bronze_knife(p)
# Adamant_crossbow_(u)
# Orange_salamander
# Dragon_pickaxe_upgrade_kit
# White_med_helm
# Steel_arrow(p)
# Mithril_knife(p++)
# Adamant_arrow(p++)
# Black_wizard_robe_(t)
# Adamant_javelin(p++)
# Combat_mix(2)
# Green_dragon_leather
# Iron_arrowtips
# Green_dragonhide_set
# Silver_bolts_(p+)
# Bones_to_peaches
# Sapphire_dragon_bolts
# Dragon_bitter
# Zamorak_monk_top
# Death_rune
# Deerstalker
# Elemental_talisman
# Zamorak_platebody
# Dragon_boots_ornament_kit
# Ensouled_demon_head
# Edible_seaweed
# Skeletal_bottoms
# Shaman_mask
# Grimy_dwarf_weed
# Spirit_shield
# Yew_bird_house
# Emerald
# Graahk_legs
# Torag's_platebody
# Premade_worm_hole
# Unlit_bug_lantern
# Spectral_spirit_shield
# Bucket
# Iron_kiteshield
# Zamorak_mix(2)
# Staff_of_light
# Apples(5)
# Book_of_law_page_set
# Steel_claws
# Teak_kitchen_table
# Marrentill_potion_(unf)
# Zamorak_brew(2)
# Guthix_rest(4)
# Adamant_shield_(h4)
# Red_gloves
# Ankou_mask
# 3rd_age_pickaxe
# Super_def._mix(1)
# Blue_d'hide_chaps_(g)
# Saradomin_coif
# Saradomin_page_4
# Black_boater
# Chilli_con_carne
# Gilded_armour_set_(lg)
# Rune_dagger(p++)
# Halloween_mask_set
# Agility_potion(2)
# Jade_dragon_bolts_(e)
# Te_salt
# Raw_rat_meat
# Attack_potion(2)
# Grimy_kwuarm
# Black_platebody_(g)
# Rune_arrow(p+)
# Armadyl_page_1
# Grand_seed_pod
# Extended_antifire_mix(1)
# Steel_dagger(p++)
# Botanical_pie
# Ring_of_nature
# Lovakengj_hood
# Manta_ray
# Steel_dart_tip
# Soda_ash
# Team-29_cape
# Guthan's_platebody
# Javelin_shaft
# Enchant_sapphire_or_opal
# Rune_knife(p+)
# Lantadyme
# Adamant_platelegs
# Odium_ward
# Samurai_boots
# Pink_boater
# Dwarven_helmet
# Bronze_hasta
# Iron_limbs
# Premade_w'm_batta
# Red_boater
# Bronze_javelin(p)
# Magic_comp_bow
# Bounty_teleport_scroll
# Asgarnian_ale(4)
# Cyclops_head
# Zamorak_hilt
# Iron_spear(p)
# Kebab
# Hosidius_scarf
# Teak_dresser
# Guthix_stole
# Shayzien_banner
# Amulet_of_accuracy
# Rune_hasta(p+)
# Adamant_warhammer
# Iron_ore
# Jade_ring
# Lava_rune
# Adamantite_bar
# Dragon_thrownaxe
# Jangerberries
# Coal
# Granite_body
# Iron_platebody_(t)
# Steel_arrow(p++)
# Premade_ttl
# Desert_goat_horn
# Cadava_berries
# Vesta's_spear
# Ham_cloak
# Mithril_javelin_heads
# Fire_orb
# Rune_chainbody
# Black_robe
# M._treasure_chest
# Skills_necklace(6)
# Iron_halberd
# Oak_longbow
# Dragon_bolts_(p++)
# Imp_mask
# Mithril_set_(lg)
# Rune_kiteshield_(t)
# Mith_grapple_tip
# Skills_necklace
# Dragon_axe
# Unholy_symbol
# Iron_axe
# Black_headband
# Raw_summer_pie
# Rune_axe
# Gold_leaf
# Dragon_crossbow
# Ring_of_wealth_(5)
# Magic_bird_house
# Yew_sapling
# Dark_crab
# Super_restore(4)
# Chopped_tomato
# Emerald_bracelet
# Fruit_batta
# Sinew
# Uncut_diamond
# Ancient_chaps
# Oak_dining_table
# Zamorak_monk_bottom
# Red_d'hide_chaps_(g)
# Snapdragon
# Restore_potion(3)
# Tai_bwo_wannai_teleport
# Cooked_jubbly
# Blurberry_special
# Black_dagger(p+)
# Blue_robe_bottoms
# Rune_kiteshield_(g)
# Onyx_bolts
# Team-5_cape
# Adamant_crossbow
# Guthan's_warspear
# Clockwork
# Opal_amulet
# Black_spiky_vambs
# Proselyte_sallet
# Dragon_platebody_ornament_kit
# Golden_statuette
# Body_rune
# Uncut_dragonstone
# Raw_rainbow_fish
# Mith_crossbow
# Adamant_dagger
# Sanguinesti_staff_(uncharged)
# Saw
# Guthan's_helm
# Mos_le'harmless_teleport
# Saradomin_robe_top
# 3rd_age_longsword
# Bloody_bracer
# Mystic_air_staff
# Splitbark_legs
# Zamorak_brew(1)
# Ensouled_horror_head
# Dharok's_helm_0
# Iron_chainbody
# Blue_skirt_(t)
# Avantoe
# Ankou_gloves
# Curry_leaf
# Rune_dagger
# Pot_lid
# Fancy_teak_dresser
# Opal_necklace
# Book_of_darkness_page_set
# Mystic_steam_staff
# White_berries
# Mind_tiara
# Ham_logo
# Red_elegant_blouse
# Pottery_scarab
# Toy_doll
# Justiciar_chestguard
# Double_eye_patch
# Maple_longbow_(u)
# Citizen_shoes
# Expeditious_bracelet
# Armadyl_platebody
# Penguin_mask
# Bronze_set_(sk)
# Heavy_frame
# Tuna_and_corn
# Swamp_weed
# Shade_robe_top
# Rune_pickaxe
# Ensouled_bear_head
# Torag's_platelegs
# Torag's_armour_set
# Runite_bolts_(unf)
# Magic_stock
# Oak_pyre_logs
# Weeds
# Iron_javelin(p)
# Bronze_hasta(p)
# Mahogany_armchair
# Purple_elegant_shirt
# Mithril_bolts
# Opal_bracelet
# Mahogany_magic_wardrobe
# Oak_bed
# Yellow_dark_bow_paint
# Battlestaff
# Marigold_seed
# Ahrim's_robetop
# Wine_of_zamorak
# Earth_rune
# Magic_shortbow_(u)
# Rune_nails
# Toadflax_seed
# Spider_on_shaft
# Harralander_seed
# Left_eye_patch
# Purple_hat
# Raw_herring
# Chopped_garlic
# Dark_tuxedo_jacket
# Iron_bolts_(p++)
# Mahogany_table
# Occult_necklace
# Bandos_plateskirt
# Ruby_bolt_tips
# Dragon_metal_shard
# Odium_shard_3
# Camelot_teleport
# Vampyre_dust
# Flamtaer_hammer
# Dwarf_weed_potion_(unf)
# Restore_mix(2)
# Mystic_water_staff
# Silver_bolts_(p++)
# Magic_longbow
# Cake
# Armadyl_godsword_ornament_kit
# Bronze_full_helm_(g)
# Team-39_cape
# Black_leprechaun_hat
# Topaz_ring
# Ensouled_kalphite_head
# Adamant_hasta(p++)
# Mithril_platebody
# Grog
# Adamant_bolts_(p++)
# Molten_glass
# Guthix_plateskirt
# Teak_sapling
# Black_shield_(h4)
# Black_helm_(h4)
# Greenman's_ale(m)
# Extended_super_antifire(2)
# Zamorak_page_3
# Zenyte
# Raw_yak_meat
# Filled_plant_pot
# Pharaoh's_sceptre
# Bread
# Plank
# Tiara_mould
# Mithril_dart(p)
# Steel_nails
# Insect_repellent
# Lovakengj_scarf
# Mithril_bolts_(unf)
# Oak_treasure_chest
# Opal_amulet_(u)
# Rune_claws
# Black_platelegs_(t)
# Ogre_coffin_key
# Black_beret
# Empty_candle_lantern
# Black_spear(p)
# Yew_comp_bow
# Snake_hide
# Black_set_(sk)
# Rune_knife(p++)
# Relicym's_mix(1)
# Torture_ornament_kit
# Emerald_dragon_bolts
# Helm_of_neitiznot
# Armadyl_d'hide
# Mahogany_toy_box
# Adamant_arrow(p)
# Infinity_hat
# Bronze_set_(lg)
# Rock-shell_helm
# Jute_fibre
# Granite_legs
# Ruby_dragon_bolts_(e)
# Bandos_bracers
# Bronze_trimmed_set_(sk)
# Security_book
# Wild_pie
# Cannon_stand
# Lime_slices
# Super_energy_mix(1)
# Dragon_sq_shield_ornament_kit
# Rune_platelegs_(t)
# Ancient_page_1
# Black_plateskirt_(g)
# Bowl_wig
# Tormented_bracelet
# Steel_knife(p+)
# Zenyte_necklace
# Wood_camo_legs
# Iron_bolts_(p+)
# Brass_key
# Anti-venom+(2)
# Black_wizard_hat_(g)
# Unstrung_heavy_ballista
# Lemon_chunks
# Initiate_sallet
# Team-42_cape
# Irit_seed
# Gold_elegant_legs
# Oak_drawers
# Guthix_page_4
# Box_trap
# Leprechaun_hat
# Oak_sapling
# Hosidius_hood
# Samurai_kasa
# Curry_tree_seed
# Long_kebbit_bolts
# Steel_platelegs_(g)
# Enchanted_hat
# Steel_javelin
# Shortbow
# Bagged_yew_tree
# Axeman's_folly(4)
# Trout
# Topiary_hedge
# Mithril_arrow
# Fremennik_black_cloak
# Skeletal_visage
# Yellow_gloves
# Grimy_irit_leaf
# Black_trimmed_set_(lg)
# Bronze_dart_tip
# Ruby_harvest
# Adamant_gold-trimmed_set_(lg)
# Bronze_dart(p+)
# Tzhaar-ket-om
# Rock-shell_legs
# Red_elegant_skirt
# Ancient_page_4
# White_scimitar
# Bandos_hilt
# Bronze_chainbody
# Rock_thrownhammer
# Tarromin_potion_(unf)
# Rune_med_helm
# Fried_onions
# Prayer_mix(2)
# Bronze_kiteshield
# Mystic_robe_bottom_(dark)
# Guthix_mitre
# Adamant_pickaxe
# Red_topaz_machete
# Bronze_mace
# Mithril_scimitar
# Harralander_potion_(unf)
# Maple_sapling
# Santa_hat
# Limestone_brick
# Snakeskin_shield
# Guthix_bracers
# Pirate's_hat
# Waterskin(4)
# Chopped_ugthanki
# Black_boots
# Rune_hasta(p)
# Acorn
# Kebbit_claws
# Potato_seed
# Dragon_arrow(p++)
# Bronze_dagger(p+)
# Combat_bracelet(6)
# Steel_full_helm
# Abyssal_bracelet(5)
# Iron_scimitar
# Inoculation_bracelet
# Blue_hat
# Rune_full_helm_(g)
# Menaphite_purple_top
# Yellow_robe_bottoms
# Irit_potion_(unf)
# Bronze_thrownaxe
# Sleeping_cap
# Ardougne_teleport
# White_elegant_skirt
# Team-41_cape
# Mining_helmet
# Premade_veg_batta
# Krandorian_hops
# Relicym's_balm(1)
# Blue_skirt_(g)
# Dragon_chainbody
# Steel_javelin(p+)
# Gnome_goggles
# Team-18_cape
# Yellow_feather
# Compost
# Bandos_platelegs
# Combat_potion(4)
# Mithril_platebody_(t)
# Karil's_leatherskirt_0
# Studded_body
# Rune_armour_set_(sk)
# Yanillian_hops
# Amethyst_bolt_tips
# Iron_hasta(p++)
# Fishing_potion(3)
# Godsword_shard_3
# Bass
# Rune_essence
# Dark_fishing_bait
# Ankou's_leggings
# Malediction_shard_2
# Woad_leaf
# Bone_spear
# Purple_elegant_blouse
# Emerald_bolts_(e)
# Amylase_crystal
# Lockpick
# Olive_oil(4)
# Avantoe_seed
# Onyx_amulet_(u)
# Arcane_spirit_shield
# Dragon_bitter(4)
# Abyssal_dagger
# Ivory_comb
# Iron_dart(p)
# Lava_battlestaff
# Ancient_rune_armour_set_(sk)
# Steel_arrow(p+)
# Stone_statuette
# Opal_ring
# Toxic_staff_(uncharged)
# Defence_potion(1)
# Red_cavalier
# Pink_skirt
# Chilli_potato
# Raw_slimy_eel
# Redwood_logs
# Bronze_platebody
# Rune_mace
# Super_restore_mix(1)
# West_ardougne_teleport
# Watermelon
# Sacred_oil(4)
# Restore_mix(1)
# Olive_oil(1)
# Lava_dragon_mask
# Enchant_dragonstone
# Leather_gloves
# Pie_shell
# Malediction_shard_3
# Oak_shortbow_(u)
# Hair
# Limpwurt_seed
# Copper_ore
# Black_unicorn_mask
# Explorer_backpack
# Black_cape
# Shaving_stand
# Fried_mushrooms
# Yellow_boots
# Snakeskin_chaps
# Rune_sword
# Rune_arrowtips
# Guthix_balance(1)
# Adamant_arrow(p+)
# Topaz_bolts
# Mithril_ore
# Slayer_bell
# Sapphire_amulet
# Royal_gown_bottom
# Cooked_slimy_eel
# Mithril_full_helm
# Garlic
# Strength_potion(1)
# Studded_chaps_(t)
# Jug
# Bowl
# Rock-shell_boots
# Royal_gown_top
# Rune_scimitar
# Uncooked_dragonfruit_pie
# Kharyrll_teleport
# Loop_half_of_key
# Amulet_of_glory(6)
# Green_elegant_legs
# Crude_chair
# Maple_roots
# Ahrim's_armour_set
# Superantipoison(1)
# Crier_hat
# Earth_talisman
# Bronze_longsword
# Chaos_rune
# Defence_potion(3)
# Green_d'hide_body
# Emerald_dragon_bolts_(e)
# Doogle_leaves
# Pie_dish
# Holy_mould
# Twisted_bow
# Mithril_dart
# Fremennik_gloves
# Mithril_sq_shield
# Swamp_lizard
# Highwayman_mask
# Dragon_spear
# Pirate_hat_&_patch
# Ruby_dragon_bolts
# Zenyte_bracelet
# Ancient_rune_armour_set_(lg)
# Flattened_hide
# Black_cane
# Drift_net
# Charcoal
# Whiteberry_seed
# Nardah_teleport
# Steel_bolts_(p+)
# Adamant_dagger(p)
# Ranarr_potion_(unf)
# Green_d'hide_chaps_(g)
# Onyx_bolt_tips
# Butterfly_net
# Guthix_robe_top
# Toktz-mej-tal
# Butterfly_jar
# Mud_rune
# Marble_cape_rack
# Obsidian_cape_(r)
# Ensouled_dagannoth_head
# Ensouled_tzhaar_head
# Carved_oak_magic_wardrobe
# Maple_shield
# Superantipoison(4)
# Red_elegant_legs
# Holy_blessing
# Bucket_of_sap
# Black_claws
# Zuriel's_staff
# Ugthanki_kebab
# Dragon_harpoon
# Zamorakian_hasta
# Magic_logs
# Black_shield_(h2)
# Dragon_hasta
# Red_headband
# Small_box_hedge
# Seed_dibber
# Ogre_arrow
# Arcane_sigil
# Amulet_of_glory_(t)
# Casket
# Eternal_gem
# Briefcase
# Granite_clamp
# Willow_comp_bow
# Ancient_mitre
# Skeletal_helm
# Smoke_rune
# Wizard_boots
# Morrigan's_javelin
# Steel_dagger
# Black_elegant_legs
# Team-49_cape
# Amethyst_arrow
# Uncut_red_topaz
# Kodai_wand
# Toxic_blowpipe_(empty)
# Crystal_seed
# Iron_dart(p++)
# Sanfew_serum(4)
# Steel_trimmed_set_(sk)
# Uncharged_toxic_trident
# Super_combat_potion(1)
# Desert_top
# Rune_boots
# Black_helm_(h2)
# Bones
# Saradomin_brew(1)
# Grey_robe_bottoms
# Toad's_legs
# Ancient_totem
# Menaphite_red_kilt
# Battlemage_potion(4)
# White_headband
# Bagged_flower
# Menaphite_purple_hat
# Rune_shield_(h3)
# Gloves_of_silence
# Toy_doll_(wound)
# Bottle_of_wine
# Bagged_plant_1
# Berserker_ring
# Iron_gold-trimmed_set_(sk)
# Mithril_bolts_(p+)
# Red_halloween_mask
# Guthix_page_2
# Kitchen_table
# Bronze_hasta(p++)
# Chef's_delight(4)
# Revenant_cave_teleport
# Ahrim's_robetop_0
# Mage's_book
# Black_dart(p)
# Bucket_helm_(g)
# Adamant_dagger(p++)
# Mole_claw
# Black_tourmaline_core
# Emerald_ring
# Vesta's_longsword
# Dark_tuxedo_cuffs
# Dragonfire_ward
# Gloves_of_darkness
# Ham_boots
# Sliced_mushrooms
# Red_feather
# Raw_dark_crab
# Battlemage_potion(1)
# Oak_bench
# Spotted_cape
# Armadyl_plateskirt
# Cocktail_glass
# Dragon_med_helm
# Uncut_emerald
# Rune_dart(p+)
# Anti-venom(3)
# Fury_ornament_kit
# Redberry_seed
# Iron_spear(p++)
# Tomato_seed
# Black_dragonhide
# Body_talisman
# Bronze_battleaxe
# Barrows_teleport
# Red_partyhat
# Potato
# Zamorakian_spear
# Zamorak_godsword
# Blue_cape
# Uncooked_berry_pie
# Extended_super_antifire(4)
# Blue_spiky_vambs
# Steel_dart(p)
# Oak_wardrobe
# Bronze_axe
# Raw_ugthanki_meat
# Obsidian_platebody
# Dragon_javelin(p+)
# Blue_robe_top
# Dragonstone_amulet_(u)
# Ashes
# Torstol_potion_(unf)
# Ale_yeast
# Zenyte_amulet
# Death_tiara
# Red_d'hide_shield
# Fishing_mix(1)
# Lava_staff_upgrade_kit
# Pith_helmet
# Dragon_full_helm
# Dagannoth_bones
# Bronze_bolts_(p)
# Super_energy(3)
# Xerician_robe
# Frozen_whip_mix
# Rune_kiteshield
# Initiate_cuisse
# Giant_frog_legs
# Uncut_opal
# Raw_swordfish
# Vial_of_water
# Wrath_talisman
# Super_attack(2)
# Mithril_nails
# Strength_amulet_(t)
# Rune_helm_(h1)
# Ancestral_robe_top
# Gilded_plateskirt
# Pink_boots
# Bandos_chestplate
# Raw_beast_meat
# Polar_camo_top
# Varrock_teleport
# Green_d'hide_vamb
# Treasonous_ring
# Blue_wizard_robe_(t)
# Rune_helm_(h3)
# Grimy_harralander
# Black_dragonhide_set
# Cocktail_guide
# Pot_of_cornflour
# Elemental_helmet
# White_dark_bow_paint
# Iron_trimmed_set_(sk)
# Blue_d'hide_shield
# Zamorak_mix(1)
# Marble_magic_wardrobe
# Garden_pie
# Bastion_potion(4)
# Teak_table
# Eclectic_impling_jar
# Poison
# Book_of_balance_page_set
# Pumpkin
# Runite_bar
# Dragonfruit_pie
# Purple_sweets
# Serum_207_(3)
# Samurai_shirt
# Mystic_robe_bottom_(light)
# Brandy
# Magic_box
# Unicorn_horn_dust
# Apple_sapling
# Maple_blackjack(d)
# Pearl_dragon_bolts_(e)
# Bronze_crossbow_(u)
# Pineapple_pizza
# Teak_treasure_chest
# Fiyr_remains
# Team_cape_i
# Tuna
# Zamorak_chaps
# Bronze_plateskirt
# Adamant_dagger(p+)
# Bag_of_salt
# Bandos_crozier
# Agility_potion(4)
# Dragonstone_dragon_bolts_(e)
# Amulet_of_eternal_glory
# Iron_platelegs
# Black_helm_(h5)
# Dragon_scimitar_ornament_kit
# Cured_yak-hide
# Bagged_magic_tree
# Peaceful_blessing
# Coconut
# Diamond_amulet_(u)
# Cider
# Emerald_amulet_(u)
# Antidote++(2)
# Rangers'_tunic
# Greenmans_ale(m4)
# Relicym's_balm(4)
# Amethyst
# Cave_goblin_wire
# Cooked_sweetcorn
# Antifire_mix(1)
# Dragon_warhammer
# Olive_oil(3)
# Granite_helm
# Orange_cape
# Triangle_sandwich
# Ancient_robe_top
# Team-28_cape
# Pirate's_hook
# Blue_dragon_scale
# Monkfish
# Ankou_socks
# Amulet_mould
# Sacred_oil(3)
# Magic_potion(4)
# Axeman's_folly(m)
# Incomplete_light_ballista
# Adamant_platelegs_(g)
# Strength_potion(3)
# Rune_javelin(p)
# Amulet_of_glory_(t6)
# Green_dye
# Orange_tree_seed
# Water_tiara
# Super_antifire_potion(3)
# Steel_hasta(p+)
# Avernic_defender_hilt
# Mithril_thrownaxe
# Split_log
# Skills_necklace(4)
# Steam_battlestaff
# Games_necklace(8)
# Zamorak_page_4
# Dragonfire_shield
# Pineapple
# Rune_plateskirt_(t)
# Gianne's_cook_book
# Big_fishing_net
# White_boater
# Bronze_spear(p++)
# Hunter_potion(1)
# Iron_plateskirt_(g)
# Rabbit_snare
# Black_platebody
# Diamond_amulet
# Sapphire_dragon_bolts_(e)
# Ahrim's_hood_0
# Egg
# White_cavalier
# 3rd_age_kiteshield
# Pyrophosphite
# Calquat_sapling
# Light_bow_tie
# Saradomin_bracers
# Nunchaku
# Saradomin_mjolnir
# Light_orb
# Feldip_hills_teleport
# Beanie
# Elemental_shield
# Black_trimmed_set_(sk)
# Black_platelegs
# Rune_helm_(h2)
# Mature_cider
# Monocle
# Digsite_teleport
# Ancient_stole
# 3rd_age_cloak
# Unfired_pot
# Shoe_box
# Iron_plateskirt_(t)
# Crushed_nest
# Half_moon_spectacles
# Amulet_of_fury
# Zamorak_robe_top
# Zenyte_amulet_(u)
# Mithril_full_helm_(t)
# Uncooked_apple_pie
# Extended_antifire(3)
# Dragon_limbs
# Karil's_crossbow_0
# Water_talisman
# Ring_of_life
# Sandstone_(2kg)
# Mystic_robe_top
# Relicym's_mix(2)
# Dragon_bitter(m4)
# Essence_impling_jar
# Oak_armour_case
# Bronze_bolts
# Zamorak's_grapes
# Gnomish_firelighter
# Iron_arrow(p)
# Rock-shell_shard
# Rune_shield_(h5)
# Willow_branch
# Mummy's_legs
# Evil_chicken_wings
# Rock-shell_plate
# Jade_dragon_bolts
# Bob's_purple_shirt
# Teak_stock
# Raw_sardine
# Maple_longbow
# Sapphire
# Adamant_full_helm_(t)
# Amethyst_javelin(p)
# Roast_bird_meat
# Amethyst_broad_bolts
# Amulet_of_strength
# Mithril_arrowtips
# Sanfew_serum(1)
# Raw_trout
# Strength_potion(4)
# Stamina_mix(1)
# Opal_machete
# Saradomin_page_1
# Cadantine
# Mahogany_bookcase
# Magic_shortbow_scroll
# Lime_chunks
# Antifire_mix(2)
# Chocolate_cake
# Saradomin_crozier
# Team-3_cape
# Pyre_logs
# Dragon_metal_slice
# Bowl_of_water
# Raw_admiral_pie
# Citizen_top
# Jug_of_water
# Teak_armour_case
# Green_halloween_mask
# Gold_ore
# Mind_talisman
# Wyvern_bones
# Bowl_of_hot_water
# Barley_seed
# Rune_trimmed_set_(lg)
# Boots_of_darkness
# Crossbow
# Draynor_manor_teleport
# Abyssal_dagger_(p)
# Ancient_mace
# Necklace_of_passage(5)
# Super_defence(2)
# Black_shield_(h5)
# Kebbit_bolts
# Blue_firelighter
# Verac's_brassard_0
# Willow_blackjack(d)
# Fire_rune
# Cooked_meat
# Staff_of_earth
# Raw_wild_pie
# White_bead
# Dragon_dart(p++)
# Verac's_helm_0
# Calquat_tree_seed
# Stony_basalt
# Black_elegant_shirt
# Splitbark_gauntlets
# White_elegant_blouse
# Water_rune
# Blue_dragonhide_set
# Eternal_crystal
# Black_gold-trimmed_set_(lg)
# Right_eye_patch
# Ring_of_dueling(8)
# Mixed_flowers
# Diamond_bolt_tips
# Bucket_of_water
# Bandos_rune_armour_set_(sk)
# Incomplete_heavy_ballista
# Black_longsword
# Armadyl_page_3
# Banana_sapling
# Raw_rabbit
# Fremennik_blue_shirt
# Equa_leaves
# Infinity_top
# Rock_hammer
# 3rd_age_vambraces
# Bracelet_mould
# Abyssal_dagger_(p+)
# Maple_shortbow_(u)
# Studded_chaps
# Jute_seed
# Steel_platelegs_(t)
# Guthix_coif
# Mysterious_emblem
# Diamond_bolts
# Strawberry
# Blue_dark_bow_paint
# Hammer
# Initiate_harness_m
# Light_tuxedo_shoes
# Iron_bolts_(p)
# Saradomin_page_2
# New_crystal_shield
# Premade_dr'_dragon
# Bone_dagger_(p)
# Nature_tiara
# Runite_bolts_(p++)
# Fishing_potion(1)
# Rune_arrow(p)
# Dexterous_prayer_scroll
# Magic_potion(2)
# Iron_sq_shield
# Bronze_spear
# Bronze_limbs
# Ugthanki_&_onion
# Cannon_barrels
# Black_sq_shield
# Grape_seed
# Amethyst_javelin(p++)
# Guardian_boots
# Super_antifire_potion(2)
# Saradomin_godsword_ornament_kit
# Iron_sword
# Adamant_javelin_heads
# Willow_logs
# Proboscis
# Iron_platebody_(g)
# Adamantite_nails
# Yew_shortbow_(u)
# Spined_chaps
# Light_tuxedo_jacket
# Pearl_dragon_bolts
# Wildblood_hops
# Ancient_bracers
# Spotted_kebbit_fur
# Dragon_javelin
# Adamant_sq_shield
# Team-44_cape
# Lassar_teleport
# Seasoned_sardine
# Blue_d'hide_chaps_(t)
# Supercompost
# Rune_spear(p++)
# White_plateskirt
# Cavalier_mask
# Desert_boots
# Apple_mush
# Spatula
# Zamorak_d'hide
# Occult_ornament_kit
# A_powdered_wig
# Bagged_sunflower
# Superior_dragon_bones
# Crier_coat
# Bandos_godsword
# Spider_on_stick
# Uncut_sapphire
# Ruby_amulet_(u)
# Chef's_delight(m4)
# Purple_elegant_skirt
# Mystic_smoke_staff
# Sandstone_(5kg)
# Kyatt_top
# Oyster_pearls
# Burnt_bones
# Opal
# Fancy_tiara
# Vodka
# Vegetable_batta
# 3rd_age_range_top
# Magic_mix(2)
# Iron_spit
# Saradomin_armour_set_(sk)
# Ring_of_wealth_scroll
# Black_knife(p++)
# Harralander
# Guthix_mjolnir
# Antipoison_mix(2)
# Stretched_hide
# Topaz_necklace
# Proselyte_cuisse
# Rune_helm_(h5)
# Team_cape_zero
# White_magic_staff
# 3rd_age_robe_top
# Papaya_fruit
# Staff_of_water
# Asgarnian_ale
# Dynamite
# Ribcage_piece
# Steel_platebody_(g)
# Unholy_book_page_set
# Gold_bracelet
# Iron_dart_tip
# Premade_sgg
# Goblin_book
# Pink_cape
# Ancient_platebody
# Mort'ton_teleport
# Cosmic_rune
# Black_spear(p+)
# Bronze_arrow
# Silver_dust
# Cup_of_tea
# Torag's_hammers_0
# Bronze_dagger(p)
# Adamant_med_helm
# Runite_ore
# Iron_bar
# Air_orb
# Black_chainbody
# Ahrim's_hood
# Polar_camo_legs
# Graahk_top
# Iron_platelegs_(g)
# Energy_potion(3)
# 3rd_age_amulet
# Drake's_claw
# Desert_shirt
# Fibula_piece
# Bryophyta's_staff_(uncharged)
# Insulated_boots
# Red_dragon_mask
# Ruby_amulet
# Wooden_bed
# Black_helm_(h3)
# Rune_dart(p)
# White_apron
# Armadyl_page_2
# Yew_seed
# Cream_robe_top
# Guthix_dragonhide_set
# Cup_of_water
# Pineapple_sapling
# Larupia_top
# Energy_potion(4)
# Leather
# Oak_shaving_stand
# Willow_longbow_(u)
# Big_bones
# Malediction_ward
# Zombie_head
# Craw's_bow_(u)
# Zamorak_brew(4)
# Willow_roots
# Ward_upgrade_kit
# Earmuffs
# Oak_blackjack(d)
# Arceuus_scarf
# Elysian_sigil
# Marigolds
# Red_beret
# Tanzanite_fang
# Headless_arrow
# Green_cape
# Cooked_crab_meat
# King_worm
# Linen
# Enchant_emerald_or_jade
# Purple_boater
# Slayer's_respite(m)
# Opulent_table
# Lumbridge_teleport
# Iron_platelegs_(t)
# Saradomin_brew(2)
# Bark
# Diamond_bolts_(e)
# Adamant_helm_(h1)
# Barb_bolttips
# Ruby_ring
# Jade_amulet_(u)
# Spiky_vambraces
# Ancestral_hat
# Oyster
# Tooth_half_of_key
# Fremennik_boots
# Blue_boater
# Anchovies
# Shield_left_half
# Yew_logs
# Raw_sea_turtle
# Ancient_crystal
# Red_spiky_vambs
# Magic_essence_mix(1)
# Light_ballista
# Jar_of_sand
# Paddewwa_teleport
# Zenyte_shard
# 3rd_age_robe
# Yellow_partyhat
# Toad_crunchies
# Attack_potion(1)
# Mummy's_body
# Swamp_toad
# Redberries
# Amethyst_arrow(p++)
# Green_elegant_blouse
# Black_platelegs_(g)
# Ranging_mix(1)
# White_longsword
# Turquoise_hat
# Fire_battlestaff
# Onyx_bracelet
# Air_battlestaff
# Rune_2h_sword
# Fremennik_grey_shirt
# Iron_trimmed_set_(lg)
# Odium_shard_2
# Black_set_(lg)
# Mithril_dart(p++)
# Bandos_tassets
# Guthix_armour_set_(lg)
# Bob's_green_shirt
# Christmas_cracker
# Super_combat_potion(2)
# Gold_elegant_shirt
# Teak_logs
# Guthix_rest(2)
# Prayer_mix(1)
# Steel_gold-trimmed_set_(lg)
# Dragon_spear(p+)
# Air_talisman
# Mummy's_hands
# Adamant_thrownaxe
# Green_dark_bow_paint
# Pink_hat
# Carved_teak_magic_wardrobe
# Dragon_2h_sword
# Admiral_pie
# Dark_cavalier
# Team-2_cape
# Bronze_sq_shield
# Bronze_full_helm_(t)
# Brown_headband
# Empty_fishbowl
# Verac's_brassard
# Team-15_cape
# Anti-poison_supermix(2)
# Steel_2h_sword
# Premade_t'd_batta
# Ancient_full_helm
# Blue_flowers
# Adamant_javelin
# Ranging_potion(3)
# Crier_bell
# Dragon_dagger(p)
# Fremennik_robe
# Mithril_seeds
# Body_tiara
# White_gloves
# Antipoison(4)
# Arena_book
# Bandos_page_2
# Runite_bolts_(p+)
# Purple_elegant_legs
# Ensouled_abyssal_head
# Dust_rune
# Hunter_potion(3)
# Jar_of_miasma
# Gilded_boots
# Gilded_sq_shield
# Green_partyhat
# Premade_wiz_blz'd
# Wood_dining_table
# Dragon_sq_shield
# Adamant_boots
# Zamorak_plateskirt
# Team-19_cape
# White_lily_seed
# Karambwan_vessel
# Magic_shield
# Torag's_platelegs_0
# Dragonstone_ring
# Enchanted_robe
# Mahogany_bench
# Red_bead
# Pirate_boots
# Wrapped_oomlie
# Frog-leather_chaps
# Odium_shard_1
# Iron_bolts
# Vial_of_blood
# Attack_mix(1)
# Premade_veg_ball
# Lobster_pot
# Staff_of_air
# Phrin_remains
# Studded_body_(g)
# Bronze_javelin
# Dareeyak_teleport
# Crushed_superior_dragon_bones
# Cream_boots
# Iron_nails
# Lean_snail
# Ranger_boots
# Ancient_plateskirt
# Steel_spear(p)
# Ensouled_dragon_head
# Grimy_marrentill
# Greater_demon_mask
# Thammaron's_sceptre_(u)
# Ancestral_robe_bottom
# Pink_headband
# Binding_necklace
# Antipoison_mix(1)
# Yanillian_seed
# Wizard_hat
# Dharok's_greataxe
# Mithril_chainbody
# Grimy_ranarr_weed
# Topaz_dragon_bolts_(e)
# Premade_c+t_batta
# Oil_lantern_frame
# Gilded_2h_sword
# Adamant_platebody_(g)
# Skewer
# Ham_robe
# Polished_buttons
# Ballista_spring
# Musketeer_hat
# Black_nails
# Dragon_javelin(p)
# Guthix_cloak
# Bronze_2h_sword
# Strange_fruit
# Steel_set_(lg)
# Diamond_dragon_bolts_(e)
# Steel_crossbow_(u)
# Red_d'hide_chaps_(t)
# Jar_of_dirt
# Rune_knife(p)
# Oak_logs
# Ham_hood
# Ancient_d'hide_boots
# Guthix_balance(2)
# Splitbark_helm
# White_partyhat
# Emerald_necklace
# Mithril_claws
# Big_pirate_hat
# Snapdragon_potion_(unf)
# Super_kebab
# Sapphire_amulet_(u)
# Amethyst_javelin_heads
# White_toy_horsey
# Steel_arrowtips
# Desert_robe
# Green_boater
# Mind_rune
# Zamorak_platelegs
# Ensouled_minotaur_head
# Regen_bracelet
# Blue_dragon_leather
# Nice_hedge
# Bronze_halberd
# White_2h_sword
# Evil_chicken_head
# Magic_string
# Armadyl_platelegs
# Raw_lobster
# Jade_amulet
# Oak_shortbow
# Mort_myre_fungus
# Adamant_knife(p++)
# Dragon_javelin_heads
# Bronze_arrow(p+)
# Redwood_pyre_logs
# Drake's_tooth
# Ancient_effigy
# Unstrung_light_ballista
# Premade_ch'_crunch
# Teak_magic_wardrobe
# Steel_brutal
# Bronze_dagger(p++)
# Mummy's_head
# Mithril_set_(sk)
# Bagged_bluebells
# Larupia_fur
# Mithril_sword
# Dragon_claws
# Wizard_blizzard
# Pink_elegant_blouse
# Musketeer_tabard
# Dwellberries
# Black_skirt
# Clay
# Steel_med_helm
# White_flowers
# Saradomin_mitre
# Adamant_spear(p+)
# Mithril_hasta(p+)
# Oak_dresser
# Dragon_metal_lump
# Snakeskin_boots
# Veg_ball
# Spined_helm
# Grey_wolf_fur
# Super_antifire_mix(2)
# Belladonna_seed
# Rune_battleaxe
# Rake
# Saradomin_chaps
# Guthix_chaps
# Keg_of_beer
# Blue_d'hide_body_(g)
# Flamtaer_bracelet
# Guam_seed
# Carved_teak_bench
# Orange_flowers
# Strawberry_seed
# Grimy_lantadyme
# Staff
# Volcanic_ash
# Nose_peg
# Greenman's_ale
# Snakeskin_vambraces
# Raw_pike
# Druid's_robe
# Gold_amulet_(u)
# Super_antifire_potion(4)
# Egg_and_tomato
# Snakeskin_body
# Premade_fr'_blast
# Toy_soldier_(wound)
# Mahogany_cape_rack
# Uncut_ruby
# Guthix_balance(4)
# Fremennik_teal_cloak
# Basalt
# Royal_crown
# Barrel
# Dragon_battleaxe
# Lovakengj_banner
# Archery_ticket
# Jade_bracelet
# Team-48_cape
# Gold_ring
# Hunting_mix(2)
# Obsidian_helmet
# Arrow_shaft
# Charge_dragonstone_jewellery_scroll
# Bronze_crossbow
# Rabbit_foot
# Blue_d'hide_body_(t)
# Zamorak_mjolnir
# Toy_mouse
# Super_energy(1)
# Mithril_trimmed_set_(sk)
# Combat_mix(1)
# Partyhat_&_specs
# Bronze_knife(p+)
# Lantern_lens
# Adamant_hasta
# Karil's_coif_0
# Steel_bolts
# Attack_potion(3)
# Desert_robes
# Pot
# Enchanted_top
# Thatch_spar_med
# Teak_drawers
# Steel_kiteshield_(g)
# Mithril_kiteshield_(g)
# Tinderbox
# Ancient_wyvern_shield
# Willow_blackjack
# Hardleather_body
# Blessed_spirit_shield
# Mummy's_feet
# Granite_ring
# Ruby
# Irit_leaf
# Tatty_kyatt_fur
# Oak_magic_wardrobe
# Opal_bolts
# Black_d'hide_chaps
# Sanfew_serum(2)
# Team-11_cape
# Dragon_bolts_(unf)
# Cheese
# Mystic_mud_staff
# Apprentice_wand
# Dashing_kebbit_fur
# Jungle_camo_legs
# Shrunk_ogleroot
# Pineapple_punch
# Uncut_zenyte
# Super_energy(2)
# Gnomeball
# Moonlight_mead(m4)
# Mithril_knife
# Iron_dagger(p)
# White_sword
# Gilded_platelegs
# Slayer's_enchantment
# Bronze_wire
# Orange_slices
# Orange_boater
# Broad_bolts
# Bronze_scimitar
# Saradomin_dragonhide_set
# Mind_bomb(4)
# Leaping_salmon
# Armadyl_godsword
# Black_dagger(p)
# Extended_super_antifire(1)
# Harpoon
# Goblin_mask
# Leather_body
# Guam_tar
# White_platelegs
# Unfired_pie_dish
# Verac's_helm
# Zulrah's_scales
# Snowy_knight
# Tan_cavalier
# Armadyl_crozier
# Broken_bark_snelm
# Cider(4)
# Guthan's_helm_0
# Sapphire_bolts_(e)
# Ham_gloves
# Bone_dagger
# Silver_ore
# Dragon_bitter(m)
# Staff_of_fire
# White_kiteshield
# Tall_box_hedge
# Initiate_hauberk
# Green_headband
# White_claws
# Willow_shortbow_(u)
# Armadyl_page_4
# Rune_brutal
# Karil's_leathertop_0
# Tarromin
# Purple_robe_bottoms
# Skeletal_gloves
# Steel_pickaxe
# Chaos_talisman
# Armadyl_helmet
# Adamant_battleaxe
# Lava_scale_shard
# Dragon_hunter_lance
# Ranarr_weed
# Weapon_poison(+)
# Amulet_of_glory(4)
# Thin_snail_meat
# Steel_knife(p++)
# Team-45_cape
# Ensouled_monkey_head
# Fremennik_brown_cloak
# Enchant_diamond
# Cheese+tom_batta
# Lumberyard_teleport
# Hammerstone_seed
# Bottomless_compost_bucket
# Black_cavalier
# Chocchip_crunchies
# Soft_clay
# Menaphite_red_top
# Chocolate_dust
# Dragon_pickaxe
# Poison_chalice
# Leather_boots
# Strength_mix(1)
# Bronze_dragon_mask
# Black_spear
# Elder_chaos_top
# Sanfew_serum(3)
# Team-21_cape
# Fremennik_blue_cloak
# Guthix_robe_legs
# Arceuus_hood
# Rune_cane
# Raw_shrimps
# Steam_staff_upgrade_kit
# Rune_platelegs
# Cannon_furnace
# Watermelon_seed
# Rune_halberd
# Red_boots
# Ranging_potion(1)
# Steel_kiteshield_(t)
# Coif
# Adamant_dart_tip
# Energy_mix(1)
# Rune_shield_(h2)
# Mithril_bolts_(p++)
# Superantipoison(3)
# Empty_cup
# Dwarven_stout
# Team-9_cape
# Mahogany_stock
# Steel_bolts_(p++)
# Iron_hasta(p+)
# Guthix_crozier
# Teak_cape_rack
# Dragonstone_dragon_bolts
# Steel_bolts_(p)
# Adamant_shield_(h3)
# Saradomin's_light
# Bucket_helm
# Pantaloons
# Adamant_arrowtips
# Watchtower_teleport
# Ensouled_scorpion_head
# Energy_potion(1)
# Mahogany_bird_house
# Shark
# Vial
# Dragon_impling_jar
# Black_full_helm_(g)
# Prayer_potion(4)
# Steel_spear(p++)
# Waterskin(0)
# 3rd_age_range_coif
# Granite_shield
# Willow_stock
# Shayzien_scarf
# Wooden_bench
# Torag's_helm
# Dragon_armour_set_(lg)
# Dragon_necklace
# Restore_potion(4)
# Pie_recipe_book
# Saradomin_plateskirt
# Rune_knife
# Snakeskin_bandana
# Empty_oil_lamp
# Agility_potion(1)
# Black_d'hide_body_(t)
# Pike
# Ring_of_the_gods
# Kebbit_spike
# Bronze_plateskirt_(t)
# White_dagger(p)
# Willow_sapling
# Raw_jubbly
# Silver_sickle
# Dragon_dart
# Black_battleaxe
# Master_wand
# Frying_pan
# Anti-venom(1)
# Lime
# Lantadyme_potion_(unf)
# Mystic_robe_bottom
# Adamant_arrow
# Maple_blackjack(o)
# Monkey_nuts
# Black_d'hide_body_(g)
# Greenmans_ale(4)
# Mithril_kiteshield_(t)
# Anti-venom+(1)
# Zamorak_cloak
# Summer_pie
# Rune_javelin(p++)
# Banana_stew
# Feather
# Mithril_spear(p+)
# Granite_(5kg)
# Skeletal_top
# Maple_logs
# Nail_beast_nails
# Crunchy_tray
# Sweetcorn
# Poison_ivy_seed
# Turquoise_robe_top
# Ring_mould
# Wyrm_bones
# Black_spear(p++)
# Pink_robe_bottoms
# Mystic_robe_top_(light)
# Gilded_four-poster
# Fine_cloth
# Raw_mud_pie
# Silver_bolts_(unf)
# Ring_of_wealth
# Red_salamander
# Steel_warhammer
# Saradomin_stole
# Bandos_page_4
# Saradomin_cloak
# Anguish_ornament_kit
# Moonlight_mead(4)
# Ranarr_seed
# Zamorak_crozier
# Karil's_coif
# Red_topaz
# Iron_boots
# Fish_pie
# Adamant_helm_(h5)
# Clue_box
# Spinach_roll
# Ahrim's_robeskirt_0
# Mort_myre_pear
# Dragonstone_bolt_tips
# Rune_trimmed_set_(sk)
# Ancient_robe_legs
# Asgarnian_hops
# Oak_armchair
# Hosidius_banner
# Strung_rabbit_foot
# Premade_choc_s'dy
# Teak_bed
# Leaping_trout
# Adamant_platebody_(t)
# Ham_shirt
# Serum_207_(2)
# Bob's_black_shirt
# Granite_maul
# Secateurs
# Bird_snare
# Iron_brutal
# Staff_of_the_dead
# Ensouled_ogre_head
# Wooden_stock
# Babydragon_bones
# Berserker_helm
# Oak_bird_house
# Unfinished_broad_bolts
# Saradomin_platebody
# Shayzien_hood
# Toktz-xil-ek
# Dragon_platelegs
# Shortbow_(u)
# Topaz_bolt_tips
# Teak_dining_bench
# Thatch_spar_dense
# Diamond_bracelet
# Green_boots
# Zamorak_armour_set_(sk)
# Ahrim's_staff_0
# Wood_camo_top
# Iron_kiteshield_(t)
# Tome_of_fire_(empty)
# Black_demon_mask
# Bandos_boots
# Battlemage_potion(3)
# Dragon_hasta(p)
# Archers_ring
# Asgarnian_seed
# Zogre_bones
# Tangled_toad's_legs
# Adamant_bolts_(p+)
# Blue_d'hide_vamb
# Black_plateskirt
# Blue_d'hide_chaps
# Adamant_dart(p++)
# Glassblowing_pipe
# Arctic_pine_logs
# Green_robe_top
# Guthix_page_1
# Baked_potato
# Roe
# Rune_shield_(h1)
# Druid's_robe_top
# Adamant_chainbody
# Gilded_bench
# Raw_anchovies
# Bronze_spear(p+)
# Swamp_paste
# Bronze_arrow(p)
# Steel_sq_shield
# Mithril_halberd
# Locust_meat
# Meat_pie
# Teak_seed
# Pineapple_chunks
# Attack_mix(2)
# Marrentill_seed
# Super_potion_set
# Spicy_tomato
# Diamond_dragon_bolts
# Robe_bottom_of_darkness
# Jar_of_darkness
# Bone_dagger_(p+)
# Chaos_tiara
# Gold_headband
# Dark_infinity_colour_kit
# Bob's_blue_shirt
# Skewer_stick
# Bronze_javelin(p++)
# Hammerstone_hops
# Teal_robe_top
# Granite_boots
# Dharok's_greataxe_0
# Lemon
# Dharok's_platebody_0
# Armadyl_mitre
# Lunar_isle_teleport
# Pest_control_teleport
# Fremennik_pink_cloak
# Team-13_cape
# Lemon_slices
# Dragon_hunter_crossbow
# Master_scroll_book_(empty)
# Adamant_halberd
# Team-34_cape
# Shantay_pass
# Redberry_pie
# Combat_potion_set
# Salmon
# Muddy_key
# Menaphite_purple_kilt
# Mahogany_sapling
# Cemetery_teleport
# Team-30_cape
# Magic_shortbow
# Defence_potion(4)
# Bagged_nice_tree
# Sickle_mould
# Adamant_plateskirt
# Red_d'hide_body_(t)
# Team-17_cape
# Bagged_plant_3
# Premade_t'd_crunch
# Green_elegant_skirt
# Rune_hasta(p++)
# Unpowered_orb
# Steel_limbs
# Rune_spear(p)
# Team-33_cape
# Fishing_potion(2)
# Ensouled_troll_head
# Granite_gloves
# Loar_remains
# Super_defence(3)
# Honourable_blessing
# Guthix_rest(3)
# Spicy_sauce
# Gold_elegant_skirt
# Iron_spear(p+)
# Airtight_pot
# Blacksmith's_helm
# Burning_amulet(5)
# Pure_essence
# Raw_cave_eel
# Steel_hasta(p++)
# Serpentine_helm_(uncharged)
# Dwarf_weed_seed
# Iron_mace
# Yak-hide
# Death_talisman
# Ruby_necklace
# Unfinished_potion
# Adamant_spear(p++)
# Bastion_potion(3)
# Monkey_bar
# Bandos_mitre
# Bagged_oak_tree
# Zamorak_bracers
# Tall_fancy_hedge
# Iron_arrow
# Combat_potion(1)
# Menaphite_red_hat
# Bucket_of_sand
# Raw_mackerel
# Iron_full_helm_(t)
# Bronze_bolts_(p++)
# Arcane_prayer_scroll
# Antifire_potion(3)
# Choc-ice
# Raw_chompy
# Compost_potion(2)
# Emerald_bolts
# Tarromin_seed
# Bracelet_of_ethereum_(uncharged)
# Iron_2h_sword
# Extended_antifire(4)
# Rune_dagger(p+)
# Evil_chicken_feet
# Dharok's_platelegs_0
# Armadyl_robe_legs
# Necklace_of_faith
# Adamant_helm_(h3)
# Bronze_boots
# Phoenix_necklace
# Amethyst_javelin
# Bob's_red_shirt
# Steel_axe
# Iron_plateskirt
# Adamant_brutal
# Yellow_cape
# Brine_sabre
# Raw_garden_pie
# Elder_chaos_hood
# Oak_toy_box
# Seercull
# Sardine
# Leather_cowl
# Fremennik_grey_cloak
# Bryophyta's_essence
# Mithril_hasta(p++)
# Monkey_bones
# Cosmic_talisman
# Topaz_dragon_bolts
# Teasing_stick
# Bear_fur
# Ultracompost
# Bolt_mould
# Iron_javelin(p+)
# Dragon_scimitar
# Sandworms
# Redwood_shield
# Iron_spear
# Grimy_toadflax
# Piscarilius_scarf
# Super_restore(3)
# Watermelon_slice
# Limestone
# Partyhat_set
# Weapon_poison(++)
# Stamina_mix(2)
# Bronze_platebody_(g)
# Saradomin_godsword
# Wildblood_seed
# Ranger_gloves
# Logs
# Gianne_dough
# Ring_of_suffering
# White_warhammer
# Gilded_clock
# Fremennik_red_cloak
# Book_of_war_page_set
# Onyx_ring
# Mithril_gold-trimmed_set_(sk)
# Ancient_cloak
# Grimy_guam_leaf
# Amethyst_arrow(p)
# Red_elegant_shirt
# Iron_dart(p+)
# Dragon_kiteshield_ornament_kit
# Bronze_trimmed_set_(lg)
# Grey_boots
# Black_kiteshield_(g)
# Sandstone_(10kg)
# Piscatoris_teleport
# Mithril_spear(p++)
# Opal_dragon_bolts_(e)
# Silver_bolts_(p)
# Raw_fish_pie
# Steel_mace
# Cabbage_round_shield
# Light_frame
# Nature_rune
# Proselyte_hauberk
# Super_combat_potion(3)
# Air_tiara
# Giant_seaweed
# Vyrewatch_shoes
# Hunters'_crossbow
# Amethyst_javelin(p+)
# Magic_cape_rack
# Moonlight_mead
# Jogre_bones
# Mithril_gold-trimmed_set_(lg)
# Antipoison(3)
# White_sq_shield
# Salve_graveyard_teleport
# Nasturtium_seed
# 3rd_age_platebody
# Dragonstone
# Krandorian_seed
# Iron_platebody
# Gilded_armour_set_(sk)
# Raw_anglerfish
# Red_flowers
# Studded_chaps_(g)
# Raw_tuna
# Chef's_delight
# Sacred_oil(2)
# Beer_glass
# Bronze_bolts_(unf)
# Diamond_ring
# Blue_dragonhide
# Apple_pie
# Maple_stock
# Dragon_dart(p+)
# Papyrus
# Pink_elegant_shirt
# Black_sword
# Mystic_earth_staff
# Holy_sandals
# Iron_set_(lg)
# Dragon_chainbody_ornament_kit
# Uncharged_trident
# Ring_of_stone
# Extended_super_antifire_mix(1)
# Coconut_milk
# Monk's_robe
# Potato_cactus
# Dragon_arrow(p)
# Bandit's_brew
# Team-7_cape
# White_dagger
# Bone_dagger_(p++)
# Mahogany_wardrobe
# Ring_of_coins
# Team-1_cape
# Black_full_helm
# Superattack_mix(2)
# Leather_vambraces
# Black_d'hide_chaps_(g)
# Steel_longsword
# Iron_crossbow_(u)
# Combat_potion(2)
# Samurai_gloves
# Mithril_longsword
# Mystic_dust_staff
# Chinchompa
# Karil's_crossbow
# Purple_gloves
# Toadflax_potion_(unf)
# Ancient_blessing
# Infinity_boots
# Strength_mix(2)
# Bronze_bolts_(p+)
# Water_orb
# Burnt_page
# Black_desert_robe
# Ranging_potion(2)
# Gin
# Cooked_oomlie_wrap
# Old_demon_mask
# Dragon_knife
# Eternal_boots
# Green_d'hide_body_(t)
# Monkey_tail
# Purple_dye
# Mirror_shield
# Spade
# Verac's_plateskirt_0
# Gardening_boots
# Team-50_cape
# Toy_mouse_(wound)
# Imbued_heart
# Fayrg_bones
# Dragon_dart(p)
# Steel_dart
# Ancient_emblem
# Adamant_plateskirt_(t)
# Wrath_tiara
# Adamant_trimmed_set_(sk)
# Lava_dragon_bones
# Mithril_javelin(p+)
# Wooden_cat
# Cactus_seed
# Cadantine_seed
# Armadyl_cloak
# Antifire_potion(4)
# Bandos_chaps
# Piscarilius_hood
# Red_dragon_leather
# Thread
# White_dagger(p+)
# Bronze_nails
# Young_impling_jar
# Team-22_cape
# Redwood_bird_house
# Gilded_magic_wardrobe
# Unstrung_symbol
# Uncharged_trident_(e)
# Common_kebbit_fur
# Gilded_chainbody
# Mind_helmet
# Ahrim's_robeskirt
# Ranging_potion(4)
# Agility_mix(2)
# Grimy_avantoe
# Oak_stock
# Iron_javelin_heads
# Magpie_impling_jar
# Senntisten_teleport
# Extended_antifire(2)
# Unholy_blessing
# Rune_spear
# Amulet_of_bounty
# Zamorak_coif
# Armadyl_robe_top
# Toktz-xil-ul
# Iron_full_helm_(g)
# Flighted_ogre_arrow
# Top_hat_&_monocle
# Damaged_monkey_tail
# Cave_eel
# Carved_oak_bench
# Evil_chicken_legs
# Scrambled_egg
# Primordial_crystal
# Verac's_armour_set
# Poison_ivy_berries
# Fire_tiara
# Red_d'hide_body_(g)
# Meat_tenderiser
# Mithril_med_helm
# Asgarnian_ale(m)
# Bandos_cloak
# Gnome_scarf
# Super_strength(4)
# Green_spiky_vambs
# Dark_kebbit_fur
# Agility_mix(1)
# Bronze_javelin(p+)
# Lantadyme_seed
# Bandos_full_helm
# Cup_of_hot_water
# Smouldering_stone
# Purple_robe_top
# Dharok's_helm
# Primordial_boots
# Ensouled_dog_head
# Saradomin's_tear
# Granite_hammer
# Abyssal_bludgeon
# Dragon_spear(p++)
# Law_rune
# Dragon_dagger(p+)
# Dragonbone_necklace
# Iron_knife(p++)
# Zamorak_stole
# Battlemage_potion(2)
# Slayer's_respite
# Bucket_of_wax
# Bronze_arrowtips
# Granite_(2kg)
# Volcanic_whip_mix
# Black_kiteshield
# Dragon_bolts_(p)
# Adamantite_ore
# Mithril_battleaxe
# Adamant_javelin(p)
# Ancient_medallion
# Bottled_dragonbreath_(unpowered)
# Shaikahan_bones
# Rock-shell_gloves
# Dragon_bolts_(p+)
# Statius's_warhammer
# Pearl_bolts
# Icy_basalt
# Super_strength(1)
# Team-4_cape
# Celastrus_sapling
# Premade_p'_punch
# Chef's_delight(m)
# Toy_soldier
# Dark_bow
# Justiciar_armour_set
# White_battleaxe
# Justiciar_legguards
# Blue_dragon_mask
# Gilded_cape_rack
# Yellow_flowers
# Kebbit_teeth_dust
# Prayer_potion(2)
# Axeman's_folly(m4)
# Stone_scarab
# Fish_offcuts
# Mithril_limbs
# Steel_plateskirt_(g)
# Blue_d'hide_body
# Blue_partyhat
# Dharok's_armour_set
# Team-40_cape
# Stamina_potion(1)
# Uncooked_botanical_pie
# Dragon_hasta(kp)
# Antidote+(4)
# Anti-venom+(3)
# Willow_bird_house
# Blue_dye
# Fake_beard
# Teak_pyre_logs
# Warrior_helm
# Bagged_dead_tree
# Navy_cavalier
# Drake_bones
# Super_str._mix(2)
# Egg_whisk
# Light_infinity_colour_kit
# Kyatt_legs
# Bird_house
# Guthix_platebody
# Antipoison(1)
# Crossbow_string
# Garlic_powder
# Torag's_platebody_0
# Bandos_coif
# Steel_dragon_mask
# Mithril_plateskirt
# Heavy_ballista
# Adamant_kiteshield_(g)
# Cocktail_shaker
# Barbed_bolts
# Team-47_cape
# Proselyte_tasset
# Runite_limbs
# Bow_string
# Gold_bar
# Armadyl_hilt
# Steel_plateskirt
# Blue_wizard_robe
# Wolfbone_arrowtips
# Adamant_mace
# Bronze_hasta(p+)
# Cadantine_potion_(unf)
# Mahogany_armour_case
# Dark_trousers
# Oak_chair
# Castle_wars_bracelet(3)
# Saradomin_armour_set_(lg)
# Team-6_cape
# Gilded_wardrobe
# Anti-dragon_shield
# Toktz-ket-xil
# Maple_shortbow
# Fruit_blast
# Red_dragonhide
# Anchovy_pizza
# Fremennik_red_shirt
# Anti-poison_supermix(1)
# Zamorak_page_2
# Ancient_staff
# Marble_block
# Raw_cod
# Kharidian_headpiece
# Oyster_pearl
# Bolt_of_cloth
# Armadyl_chestplate
# Desert_camo_top
# Stamina_potion(4)
# Eye_of_newt
# Mahogany_fancy_dress_box
# Anti-venom(4)
# Magic_stone
# Mort_myre_stem
# Antipoison(2)
# Xerician_top
# Robe_top_of_darkness
# Teak_plank
# Green_robe_bottoms
# Green_hat
# Iron_battleaxe
# Torag's_hammers
# Armadyl_bracers
# Mithril_dagger
# Steel_set_(sk)
# Sea_turtle
# Mahogany_dresser
# Palm_tree_seed
# Vyrewatch_top
# Willow_pyre_logs
# White_unicorn_mask
# Fishing_potion(4)
# Compost_potion(1)
# Ghorrock_teleport
# Oak_kitchen_table
# Super_energy(4)
# Armadyl_chainskirt
# 3rd_age_bow
# Antidote+(1)
# Rune_gold-trimmed_set_(sk)
# Sandstone_(1kg)
# Short_green_guy
# Team-35_cape
# Raw_karambwan
# Prayer_potion(1)
# Blue_wizard_hat_(g)
# Toy_cat
# Fire_talisman
# Royal_sceptre
# Ancient_coif
# Rune_armour_set_(lg)
# Zamorak_dragonhide_set
# Swordfish
# Black_wizard_robe_(g)
# Climbing_boots
# Defence_mix(1)
# Justiciar_faceguard
# Unstrung_comp_bow
# Team-14_cape
# Chopped_tuna
# Mithril_dart(p+)
# Jug_of_wine
# Fly_fishing_rod
# Mushroom_&_onion
# Carrallangar_teleport
# Green_d'hide_chaps_(t)
# Antidote++(1)
# Jangerberry_seed
# White_halberd
# Fishing_bait
# Rune_spear(p+)
# Ugthanki_&_tomato
# Rune_hasta
# Cooked_chicken
# Vyrewatch_legs
# Mithril_full_helm_(g)
# Dragon_knife(p)
# Steel_platebody_(t)
# Efaritay's_aid
# Barley_malt
# Steel_sword
# Team-38_cape
# Lava_scale
# Wyvern_visage
# Steel_hasta
# Blue_feather
# Relicym's_balm(3)
# Comp_ogre_bow
# Chocolate_bar
# Raw_bird_meat
# Steel_crossbow
# Raw_bear_meat
# Bronze_dart(p++)
# Dragonstone_bolts
# Team-8_cape
# Numulite
# Redwood_tree_seed
# Splitbark_body
# Spined_boots
# Armadyl_rune_armour_set_(lg)
# Tin_ore
# Bagged_maple_tree
# Strength_potion(2)
# Tomato
# Onion_seed
# Candle
# Extended_super_antifire_mix(2)
# Mithril_platelegs
# Bullseye_lantern
# Ugthanki_meat
# Iron_knife
# Mystic_mist_staff
# Mithril_crossbow_(u)
# Slayer's_respite(4)
# Cadavaberry_seed
# Fremennik_hat
# Armadyl_stole
# Beer
# Raw_chicken
# Red_robe_bottoms
# Iron_javelin
# Oil_lantern
# Mithril_boots
# Steel_hasta(p)
# Karidian_disguise
# Black_scimitar
# Yew_pyre_logs
# Gold_necklace
# Rocking_chair
# Chopped_onion
# Rosemary
# Onion_&_tomato
# Calcite
# Oranges(5)
# Spider_carcass
# Dharok's_platebody
# Wooden_shield_(g)
# Iron_crossbow
# Teal_robe_bottoms
# Ship_ticket
# Wizard's_mind_bomb
# Adamant_set_(sk)
# Adamant_axe
# Oak_plank
# Tyras_helm
# Ring_of_recoil
# Super_str._mix(1)
# Saradomin_page_3
# Baby_impling_jar
# Iron_arrow(p++)
# Mithril_plateskirt_(g)
# Steel_gold-trimmed_set_(sk)
# Green_dragonhide
# Trident_of_the_seas_(full)
# Armadyl_rune_armour_set_(sk)
# Swamp_tar
# Sweetcorn_seed
# Antidote+(2)
# Bandos_d'hide
# Cider(m4)
# Restore_potion(2)
# Topaz_amulet_(u)
# Steel_dart(p++)
# Granite_(500g)
# Steel_dagger(p+)
# Pearl_bolt_tips
# Astral_rune
# Zamorak_brew(3)
# Pink_robe_top
# Black_knife
# Runite_bolts_(p)
# Mithril_brutal
# Blue_boots
# Topaz_amulet
# Facemask
# Long_kebbit_spike
# Earth_battlestaff
# Worm_crunchies
# Dragon_full_helm_ornament_kit
# Bronze_full_helm
# Compost_potion(4)
# Team-27_cape
# Team-32_cape
# Steel_bar
# Harmony_island_teleport
# Restore_potion(1)
# Bronze_claws
# Dragon_scale_dust
# Unstrung_emblem
# Red_chinchompa
# Steel_javelin(p++)
# Armadyl_full_helm
# Bandos_page_3
# Guthan's_chainskirt_0
# Steel_chainbody
# Ensouled_goblin_head
# Mith_grapple
# Steel_spear(p+)
# Dragon_knife(p++)
# Uncooked_meat_pie
# White_full_helm
# Mature_wmb
# Ancient_page_2
# Adamant_bolts
# Magic_fang
# Obsidian_armour_set
# Ruby_bolts_(e)
# Willow_longbow
# Citizen_trousers
# Blue_skirt
# Ancient_page_3
# Purple_boots
# Rune_shield_(h4)
# Gnome_spice
# Purple_partyhat
# Mithril_spear
# Black_skirt_(g)
# Ring_of_returning(5)
# Urt_salt
# Adamant_set_(lg)
# Saradomin_brew(3)
# Mithril_javelin
# Black_platebody_(t)
# Iron_knife(p+)
# Team_cape_x
# Armadyl_crossbow
# Mithril_warhammer
# Steel_full_helm_(t)
# Unfired_plant_pot
# Mystic_hat_(light)
# Black_knife(p)
# Bronze_sword
# Banana_tree_seed
# Agility_potion(3)
# Yew_shield
# Blue_wizard_hat
# Dragon_arrowtips
# Stronghold_notes
# Mushroom
# Rune_platelegs_(g)
# Gold_elegant_blouse
# Mystic_boots
# Magic_longbow_(u)
# Proselyte_harness_m
# Ancestral_robes_set
# Falador_teleport
# Karil's_armour_set
# Brown_apron
# Uncooked_mushroom_pie
# Guthan's_platebody_0
# Hard_leather_shield
# Archer_helm
# Mithril_dagger(p+)
# Weapon_poison
# Yellow_robe_top
# Drunk_dragon
# Oak_bookcase
# Toad_batta
# Combat_bracelet(4)
# Teak_toy_box
# Holy_book_page_set
# Emerald_bolt_tips
# Mud_pie
# Feldip_weasel_fur
# Toadflax
# Teak_armchair
# Moonlight_mead(m)
# Viggora's_chainmace_(u)
# Premade_w'm_crun'
# Xerician_fabric
# Torag's_helm_0
# Bagged_roses
# Yew_shortbow
# Dragon_sword
# Fat_snail_meat
# Yak-hide_armour
# Bagged_plant_2
# Fremennik_yellow_cloak
# Spottier_cape
# Mist_rune
# Thatch_spar_light
# Antifire_potion(1)
# Bandos_d'hide_boots
# Adamant_knife(p+)
# Gilded_full_helm
# Draconic_visage
# Zamorak_kiteshield
# Bronze_brutal
# Anti-venom+(4)
# Teal_boots
# Gourmet_impling_jar
# Unpowered_symbol
# Wooden_shield
# Cabbages(10)
# Barley
# Red_firelighter
# Rune_sq_shield
# Zamorak_godsword_ornament_kit
# Spined_body
# Black_2h_sword
# Black_d'hide_body
# Brown_toy_horsey
# Yellow_bead
# Zamorak_mitre
# Kwuarm_seed
# Bone_bolts
# Frog-leather_body
# Cooked_chompy
# Steel_javelin(p)
# Amulet_of_avarice
# Whisky
# Ensouled_unicorn_head
# White_dagger(p++)
# Pile_of_salt
# Granite_longsword
# 3rd_age_wand
# Rune_platebody_(t)
# Carved_teak_table
# Team-46_cape
# Super_strength(2)
# Verac's_flail_0

# %%
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))

# %%
data['Dragon_bones']
# Out:
# []

# %%
print(itemPrices['Dragon_bones'][414:417])
# Out:
# [(1463961600, 3175, -1), (1464048000, 3143, -1), (1464134400, 3139, -1)]

# %%
# fix duplicate dates
for item in itemPrices:
    print(item)
    dates = [a[0] for a in itemPrices[item]]
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    for index in sorted(repeats, reverse=True):
        del itemPrices[item][index]
# Out:
# Dragon_bones
# Iron_longsword
# Dragon_halberd
# Scythe_of_vitur_(uncharged)
# Holy_wraps
# Black_warlock
# Blue_wizard_robe_(g)
# Abyssal_whip
# Amethyst_arrowtips
# Blue_elegant_shirt
# Godsword_shard_1
# Dodgy_necklace
# Holy_symbol
# Desert_legs
# Empty_plant_pot
# Steel_full_helm_(g)
# Mist_battlestaff
# Steel_dagger(p)
# Bone_club
# Roast_rabbit
# Adamant_platebody
# Elf_camp_teleport
# Ogre_arrow_shaft
# New_crystal_bow
# Shrimps
# Magic_essence_mix(2)
# Steel_kiteshield
# Dragonfruit_tree_seed
# Adamant_shield_(h1)
# Rune_thrownaxe
# Cabbage
# Bandos_godsword_ornament_kit
# Black_full_helm_(t)
# Noose_wand
# Karil's_leathertop
# Anglerfish
# Jar_of_souls
# Chocolate_bomb
# Onyx_amulet
# Cabbage_seed
# Energy_mix(2)
# Cleaver
# Dragon_spear(p)
# Flax
# Malediction_shard_1
# Saradomin_d'hide_boots
# Bronze_platebody_(t)
# Easter_egg
# War_blessing
# Rune_longsword
# Leaf-bladed_sword
# Unblessed_symbol
# Dragon_knife(p+)
# Infinity_gloves
# Ensouled_aviansie_head
# Orange_dye
# Ankou_top
# Saltpetre
# Samurai_greaves
# Ancient_statuette
# Turquoise_robe_bottoms
# Dragon_dagger(p++)
# Mithril_axe
# Relicym's_balm(2)
# Jade_bolt_tips
# Dragon_arrow(p+)
# Oak_blackjack(o)
# Adamant_shield_(h5)
# Dwarf_weed
# Banana
# Longbow
# Stamina_potion(3)
# Mint_cake
# Marrentill
# Guthix_full_helm
# Red_d'hide_vamb
# Onyx
# Teak_clock
# 3rd_age_range_legs
# Oil_lamp
# Guthan's_armour_set
# Pestle_and_mortar
# Teleport_to_house
# Ruby_bolts
# Cream_robe_bottoms
# Air_rune
# Black_flowers
# Twisted_buckler
# Saradomin_full_helm
# Mahogany_logs
# Super_restore(2)
# Rune_warhammer
# Steel_platelegs
# Verac's_flail
# Broad_arrowheads
# Torstol_seed
# Stone_seal
# Ensouled_bloodveld_head
# Orange
# Bandos_robe_legs
# Jade
# Team-10_cape
# Silver_bar
# Rune_arrow(p++)
# Steel_studs
# Black_dagger
# Bronze_plateskirt_(g)
# Team-31_cape
# Dragon_bolts
# Iron_dagger(p+)
# Mystic_gloves_(dark)
# Lesser_demon_mask
# Rune_javelin(p+)
# Afro
# Dwarven_stout(m)
# Pearl_bolts_(e)
# Bolt_rack
# Revenant_ether
# Antifire_potion(2)
# Black_d'hide_shield
# Bronze_arrow(p++)
# Prayer_potion(3)
# Mithril_javelin(p)
# Bullseye_lantern_(unf)
# Tyrannical_ring
# Grey_robe_top
# Green_d'hide_chaps
# Teacher_wand
# Black_warhammer
# Dragon_platebody
# Bronze_gold-trimmed_set_(sk)
# Lobster
# Rune_helm_(h4)
# Mystic_robe_top_(dark)
# Needle
# Monk's_robe_top_(g)
# Fishing_rod
# Adamant_spear
# Zul-andra_teleport
# Silk
# Polar_kebbit_fur
# Mithril_pickaxe
# Magic_sapling
# Superantipoison(2)
# Ruby_bracelet
# Iron_warhammer
# Black_shield_(h3)
# Adamant_2h_sword
# Bronze_platelegs_(g)
# Cannonball
# Old_school_bond
# Kyatt_hat
# Dragon_javelin(p++)
# Steel_javelin_heads
# Gilded_kiteshield
# Adamant_cane
# Assorted_flowers
# Bagged_daffodils
# Defence_potion(2)
# Extended_super_antifire(3)
# Iron_dart
# Premade_s'y_crunch
# Ensouled_elf_head
# Gilded_platebody
# Kwuarm
# Mystic_boots_(light)
# Green_d'hide_body_(g)
# Sapphire_glacialis
# Blue_halloween_mask
# Dragon_legs/skirt_ornament_kit
# Bronze_pickaxe
# Ensouled_giant_head
# Amulet_of_magic
# Ancient_relic
# Earth_impling_jar
# Antidote++(4)
# Elysian_spirit_shield
# Super_attack(1)
# Palm_sapling
# Kitchen_knife
# Steel_knife(p)
# Amethyst_arrow(p+)
# Red_hat
# Armadyl_chaps
# Adamant_longsword
# Dragon_mace
# Dagannoth_hide
# Stale_baguette
# Guthix_balance(3)
# Bronze_gold-trimmed_set_(lg)
# Top_hat
# Black_desert_shirt
# Torn_prayer_scroll
# Onions(10)
# Super_antifire_potion(1)
# Black_salamander
# Saradomin_brew(4)
# Mystic_hat_(dark)
# Black_axe
# Adamant_hasta(p)
# Brass_necklace
# Black_d'hide_chaps_(t)
# Hydra_bones
# Dinh's_bulwark
# Steel_spear
# Mithril_trimmed_set_(lg)
# Adamant_helm_(h2)
# Adamant_full_helm
# Black_knife(p+)
# Serpentine_visage
# Green_elegant_shirt
# Grey_toy_horsey
# Lizardman_fang
# Red_dye
# Olive_oil(2)
# Green_d'hide_shield
# Green_firelighter
# Black_halberd
# Bastion_potion(1)
# Magic_potion(3)
# Large_teak_bed
# Unfired_pot_lid
# Golden_chef's_hat
# Bandos_dragonhide_set
# Amulet_of_glory_(t4)
# Grapes
# Black_med_helm
# Dwarf_cannon_set
# Tzhaar-ket-em
# Black_helm_(h1)
# Cooking_apple
# Orange_chunks
# Black_d'hide_vamb
# Hard_leather
# Raurg_bones
# Bananas(5)
# Marrentill_tar
# Dharok's_platelegs
# Adamant_gold-trimmed_set_(sk)
# Meat_pizza
# Steel_bolts_(unf)
# Iron_set_(sk)
# Beer_tankard
# Maple_bird_house
# Mithril_bar
# Godsword_shard_2
# Wool
# Dwarven_stout(4)
# Teal_gloves
# Steam_rune
# Black_toy_horsey
# Iron_kiteshield_(g)
# Adamant_full_helm_(g)
# Onyx_dragon_bolts_(e)
# Bread_dough
# Rock-shell_chunk
# Hunting_mix(1)
# Nasturtiums
# Willow_shield
# Ancient_d'hide
# Riyl_remains
# Black_shield_(h1)
# Tiara
# Gold_amulet
# Arceuus_banner
# Zamorak_page_1
# Iron_dagger(p++)
# Bandos_robe_top
# Runite_bolts
# Raw_shark
# Bronze_dart
# Bronze_platelegs
# Elder_chaos_robe
# Impling_jar
# Sapphire_bolt_tips
# Iron_dragon_mask
# Mahogany_seed
# Desert_camo_legs
# Mithril_spear(p)
# Dwarven_stout(m4)
# Kyatt_fur
# Gnomebowl_mould
# Nature_impling_jar
# Team-26_cape
# Slayer's_respite(m4)
# Superattack_mix(1)
# Trading_sticks
# Rock-climbing_boots
# Amulet_of_defence
# Mackerel
# Potato_with_cheese
# Guthix_dragonhide
# Plant_cure
# Yellow_dye
# Bat_bones
# Oak_roots
# Super_attack(3)
# Bronze_kiteshield_(t)
# Ancient_platelegs
# Amulet_of_chemistry
# Skull_piece
# Raw_salmon
# Fenkenstrain's_castle_teleport
# Iron_bolts_(unf)
# Water_battlestaff
# Sagacious_spectacles
# Cooked_rabbit
# Bottled_dragonbreath
# Iron_hasta(p)
# Mithril_dagger(p++)
# Mithril_2h_sword
# Disk_of_returning
# Combat_bracelet
# Rune_platebody_(g)
# Pot_of_cream
# Rune_platebody
# Bucket_of_milk
# Oak_shield
# Caviar
# Fremennik_cyan_cloak
# Orange_sapling
# Jar_of_swamp
# Pastry_dough
# Rune_dart_tip
# Iron_arrow(p+)
# Black_kiteshield_(t)
# Black_mask_(10)
# Holy_elixir
# Iron_hasta
# Mithril_knife(p+)
# Dragon_dagger
# Black_brutal
# Cooked_karambwan
# Mithril_arrow(p+)
# Chisel
# Bandos_page_1
# Tomatoes(5)
# Ballista_limbs
# Rosemary_seed
# Rune_javelin
# Pink_elegant_skirt
# Ring_of_forging
# Saradomin_sword
# Bird_nest
# Adamant_scimitar
# Adamant_kiteshield
# Purple_cape
# Fez
# Amulet_of_torture
# Black_dart(p++)
# Mystic_gloves
# Yew_stock
# Fremennik_skirt
# Kwuarm_potion_(unf)
# Adamant_spear(p)
# Mithril_javelin(p++)
# Beer_barrel
# Mithril_hasta(p)
# Worm_hole
# Jungle_demon_mask
# Ground_guam
# Diamond_necklace
# Cleaning_cloth
# Jungle_camo_top
# Rune_plateskirt_(g)
# Mushroom_pie
# Team-24_cape
# Pineapple_seed
# Adamant_dart(p)
# Black_mask
# Maple_pyre_logs
# Magic_staff
# Unicorn_horn
# Opal_bolt_tips
# Dragon_hasta(p+)
# Bracelet_of_slaughter
# Gold_seal
# Frog-leather_boots
# Hill_giant_club
# Zamorak_robe_legs
# Team-25_cape
# Jade_machete
# Sapphire_bolts
# Iron_javelin(p++)
# Rock-shell_splinter
# Red_d'hide_body
# Serum_207_(1)
# Mystic_lava_staff
# Steel_arrow
# Gadderhammer
# Nature_talisman
# Mud_battlestaff
# Kraken_tentacle
# Bagged_willow_tree
# Ale_of_the_gods
# Saradomin_d'hide
# Blue_elegant_legs
# Spork
# Zamorak_d'hide_boots
# Team-12_cape
# Adamant_sword
# Black_dart
# Ninja_impling_jar
# Warrior_ring
# Adamant_knife
# Dragon_armour_set_(sk)
# Magic_potion(1)
# Stripy_feather
# Guthix_rest(1)
# Uncharged_toxic_trident_(e)
# Cat_mask
# Adamant_shield_(h2)
# Iron_thrownaxe
# Raw_monkfish
# Monk's_robe_top
# Black_chinchompa
# Lumbridge_graveyard_teleport
# Dragon_defender_ornament_kit
# Avantoe_potion_(unf)
# Willow_shortbow
# Bandos_kiteshield
# Uncooked_egg
# Compost_potion(3)
# Slayer's_staff
# Purple_flowers
# Black_skirt_(t)
# Bronze_med_helm
# Axeman's_folly
# Black_plateskirt_(t)
# Onyx_dragon_bolts
# White_boots
# Monk's_robe_(g)
# Team-43_cape
# Cadantine_blood_potion_(unf)
# Snakeskin
# Team-37_cape
# White_chainbody
# Batta_tin
# Mithril_kiteshield
# Musketeer_pants
# Bronze_warhammer
# Torstol
# Dragonstone_bolts_(e)
# Saradomin_robe_legs
# Adamant_dart
# Orange_feather
# Goblin_mail
# Seers_ring
# Wooden_chair
# Antidote++(3)
# Golden_apron
# Seaweed_spore
# Gilded_dresser
# Diamond
# Empty_oil_lantern
# Amulet_of_power
# Guthix_page_3
# Mind_bomb(m4)
# Maple_blackjack
# Toktz-xil-ak
# Hunter_potion(4)
# Grey_gloves
# Smoke_battlestaff
# Guthan's_warspear_0
# Splitbark_boots
# Snapdragon_seed
# Pink_elegant_legs
# Extended_antifire_mix(2)
# Iron_claws
# Ancient_dragonhide_set
# Onyx_necklace
# Mithril_hasta
# Spice
# Cider_barrel
# Saradomin_kiteshield
# Tatty_graahk_fur
# Bronze_knife(p++)
# Half_full_wine_jug
# Potato_cactus_seed
# Necklace_of_anguish
# Red_cape
# Elder_maul
# Premade_choc_bomb
# Adamant_dart(p+)
# Sapphire_ring
# Black_dragon_leather
# Cosmic_tiara
# Fish_food
# Rune_plateskirt
# Sulliuscep_cap
# Ghrazi_rapier
# Grain
# Armadyl_coif
# Iron_dagger
# Mystic_hat
# Large_oak_bed
# Menaphite_red_robe
# Pegasian_crystal
# Iron_knife(p)
# Raw_oomlie
# Fishing_mix(2)
# Mahogany_pyre_log
# Calquat_keg
# Bookcase
# Earth_tiara
# Silver_bolts
# Curry_sapling
# Onion
# Ape_atoll_teleport
# Worm_batta
# Plain_pizza
# Cactus_spine
# Defence_mix(2)
# Menaphite_purple_robe
# Energy_potion(2)
# Blood_rune
# Guthan's_chainskirt
# Raw_beef
# Guthix_d'hide_boots
# Harralander_tar
# Bandos_platebody
# Blue_wizard_hat_(t)
# Adamant_plateskirt_(g)
# Mithril_platelegs_(t)
# Super_restore_mix(2)
# Asgarnian_ale(m4)
# Teak_wardrobe
# Super_energy_mix(2)
# Golden_scarab
# Unlit_torch
# Wolf_bones
# Stamina_potion(2)
# Snape_grass_seed
# Steel_scimitar
# Bronze_dagger
# Yew_roots
# Combat_potion(3)
# Leaf-bladed_battleaxe
# Pottery_statuette
# Steel_platebody
# Opal_bolts_(e)
# Egg_potato
# Enchant_ruby_or_topaz
# Grey_hat
# Machete
# Sapphire_necklace
# Empty_sack
# Bones_to_bananas
# Bracelet_of_clay
# Pat_of_butter
# Attack_potion(4)
# Bastion_potion(2)
# Thorny_hedge
# Amulet_of_glory
# Mithril_dagger(p)
# Steel_dart(p+)
# Onyx_bolts_(e)
# Fremennik_green_cloak
# Rune_dart
# Herring
# Blue_elegant_skirt
# Efh_salt
# Antidote+(3)
# Enchant_onyx
# Steel_battleaxe
# Blue_headband
# Fat_snail
# Zamorak_full_helm
# Blue_elegant_blouse
# Black_bead
# Black_dagger(p++)
# Timber_beam
# Gilded_scimitar
# Papaya_sapling
# Iron_gold-trimmed_set_(lg)
# Premade_fr't_batta
# Dragon_hasta(p++)
# Roast_beast_meat
# Serum_207_(4)
# Magic_mix(1)
# Mind_altar_teleport
# Black_pickaxe
# Mithril_dragon_mask
# Mithril_bolts_(p)
# 3rd_age_platelegs
# Jade_necklace
# Armadyl_d'hide_boots
# Circular_hide
# Mystic_boots_(dark)
# Minced_meat
# Dark_bow_tie
# Leather_chaps
# Curry
# Yellow_hat
# Pharaoh's_sceptre_(3)
# Tarromin_tar
# Sinister_key
# Pegasian_boots
# Mithril_mace
# Iron_full_helm
# Ahrim's_staff
# Larupia_hat
# Hunter_potion(2)
# Golovanova_fruit_top
# Bronze_dart(p)
# Steel_halberd
# Longbow_(u)
# Team-23_cape
# Willow_seed
# Light_tuxedo_cuffs
# Light_trousers
# Shade_robe
# Pitta_bread
# Farseer_helm
# Dragon_boots
# Wooden_spoon
# Rune_full_helm_(t)
# Jar_of_decay
# Amulet_of_the_damned_(full)
# Dragon_crossbow_(u)
# Red_robe_top
# Black_wizard_hat_(t)
# Rune_javelin_heads
# Mushroom_spore
# Grimy_cadantine
# Bronze_javelin_heads
# Adamant_claws
# Magic_pyre_logs
# Mithril_knife(p)
# Topaz_bracelet
# Mystic_gloves_(light)
# Team-36_cape
# Bronze_bar
# Guthix_armour_set_(sk)
# Robin_hood_hat
# Oak_cape_rack
# Ourg_bones
# Fur
# Watering_can
# Kebab_mix
# Merfolk_trident
# Mind_shield
# Apple_tree_seed
# 3rd_age_axe
# Beginner_wand
# Super_antifire_mix(1)
# Saradomin_platelegs
# Rune_gold-trimmed_set_(lg)
# Adamant_bolts(unf)
# Mithril_plateskirt_(t)
# Spined_gloves
# Xerician_hat
# Bronze_knife
# Crystal_key
# Black_dart(p+)
# Ensouled_imp_head
# Super_attack(4)
# Guam_leaf
# Verac's_plateskirt
# Spicy_crunchies
# Sapphire_bracelet
# Mole_skin
# Proselyte_harness_f
# Annakarl_teleport
# Barb-tail_harpoon
# Calquat_fruit
# Bullseye_lantern_(empty)
# Larupia_legs
# Fremennik_beige_shirt
# Uncut_onyx
# Bagged_marigolds
# Wrath_rune
# Dragonstone_amulet
# 3rd_age_mage_hat
# Iron_med_helm
# Yew_longbow_(u)
# Spectral_sigil
# Gardening_trowel
# Premade_blurb'_sp.
# Super_combat_potion(4)
# Mithril_platelegs_(g)
# Studded_body_(t)
# Gilded_med_helm
# Turquoise_boots
# Armadyl_kiteshield
# Teal_hat
# Flared_trousers
# Asyn_remains
# White_mace
# Dragon_cane
# Steel_trimmed_set_(lg)
# Zamorak_armour_set_(lg)
# Necklace_mould
# Zenyte_ring
# Super_strength(3)
# Stew
# Gout_tuber
# Woad_seed
# Red_d'hide_chaps
# Dragon_arrow
# Infinity_bottoms
# Potato_with_butter
# Adamant_platelegs_(t)
# Super_restore(1)
# Spicy_minced_meat
# Blue_beret
# Super_defence(1)
# Black_mace
# Rune_full_helm
# Cream_hat
# Skeletal_boots
# White_firelighter
# Steel_plateskirt_(t)
# Opal_dragon_bolts
# Tuna_potato
# Graahk_headdress
# White_platebody
# Bandos_rune_armour_set_(lg)
# Dorgeshuun_crossbow
# Spiked_boots
# Blamish_bark_shell
# Ranging_mix(2)
# Morrigan's_throwing_axe
# Runite_crossbow_(u)
# Piscarilius_banner
# Choc_saturday
# Teak_bird_house
# Ancient_kiteshield
# Potatoes(10)
# Obsidian_platelegs
# Dragonstone_bracelet
# Raw_bass
# Adamantite_limbs
# Black_gold-trimmed_set_(sk)
# Super_def._mix(2)
# Adamant_trimmed_set_(lg)
# Strawberries(5)
# Lean_snail_meat
# Adamant_javelin(p+)
# Adamant_hasta(p+)
# Papaya_tree_seed
# 3rd_age_full_helmet
# Four-poster_bed
# Arctic_pyre_logs
# Bandos_stole
# Achey_tree_logs
# Amulet_of_magic_(t)
# Topaz_bolts_(e)
# Katana
# Dust_battlestaff
# Shears
# Ball_of_wool
# Dragon_dart_tip
# Willow_blackjack(o)
# Ring_of_pursuit
# Magic_roots
# Team-16_cape
# Tortoise_shell
# Dragonfruit_sapling
# Hood_of_darkness
# Fremennik_brown_shirt
# Dragon_plateskirt
# Pizza_base
# Steel_thrownaxe
# Gilded_hasta
# Rune_dart(p++)
# Hat_eyepatch
# Limpwurt_root
# Super_defence(4)
# Berserker_necklace
# Pot_of_flour
# Small_fishing_net
# Rune_arrow
# Steel_knife
# Bronze_kiteshield_(g)
# Fremennik_purple_cloak
# Desert_devil_fur
# Carved_oak_table
# Spiny_helmet
# Dragonfruit
# Armadyl_dragonhide_set
# Uncut_jade
# Graahk_fur
# Ancient_crozier
# Iron_pickaxe
# Jar_of_stone
# Knife
# Mithril_arrow(p)
# Mithril_dart_tip
# Godsword_blade
# Anti-venom(2)
# Rolling_pin
# Cod
# Dark_tuxedo_shoes
# Bronze_spear(p)
# Grimy_snapdragon
# Dragon_kiteshield
# Grimy_tarromin
# Dwellberry_seed
# Fancy_hedge
# Adamant_knife(p)
# Rune_dagger(p)
# Saradomin_hilt
# Earth_orb
# Unfired_bowl
# Emerald_amulet
# Abyssal_dagger_(p++)
# Teak_fancy_dress_box
# Rope
# Bronze_platelegs_(t)
# Seaweed
# Oak_clock
# Guam_potion_(unf)
# Sacred_oil(1)
# Yew_longbow
# Raw_manta_ray
# Kodai_insignia
# Oak_fancy_dress_box
# Oak_longbow_(u)
# Red_spiders'_eggs
# Adamant_helm_(h4)
# Thin_snail
# Rainbow_fish
# Team-20_cape
# Obsidian_cape
# Dragon_longsword
# Tatty_larupia_fur
# Ensouled_chaos_druid_head
# White_beret
# Cowhide
# Purple_firelighter
# Adamant_kiteshield_(t)
# Extended_antifire(1)
# Goat_horn_dust
# Fedora
# Pineapple_ring
# Leaping_sturgeon
# Magic_seed
# Cannon_base
# Mushroom_potato
# Sliced_banana
# Redwood_sapling
# Kebbit_teeth
# Mystic_fire_staff
# Adamant_bolts_(p)
# Cornflour
# Soul_rune
# Mithril_platebody_(g)
# Steel_boots
# Black_dragon_mask
# Chef's_hat
# Green_dragon_mask
# Shield_right_half
# Cake_tin
# Basket
# Mahogany_plank
# Maple_seed
# Mithril_arrow(p++)
# Grimy_torstol
# Guthix_kiteshield
# Guthix_platelegs
# Snape_grass
# Rune_crossbow
# Karil's_leatherskirt
# Bronze_knife(p)
# Adamant_crossbow_(u)
# Orange_salamander
# Dragon_pickaxe_upgrade_kit
# White_med_helm
# Steel_arrow(p)
# Mithril_knife(p++)
# Adamant_arrow(p++)
# Black_wizard_robe_(t)
# Adamant_javelin(p++)
# Combat_mix(2)
# Green_dragon_leather
# Iron_arrowtips
# Green_dragonhide_set
# Silver_bolts_(p+)
# Bones_to_peaches
# Sapphire_dragon_bolts
# Dragon_bitter
# Zamorak_monk_top
# Death_rune
# Deerstalker
# Elemental_talisman
# Zamorak_platebody
# Dragon_boots_ornament_kit
# Ensouled_demon_head
# Edible_seaweed
# Skeletal_bottoms
# Shaman_mask
# Grimy_dwarf_weed
# Spirit_shield
# Yew_bird_house
# Emerald
# Graahk_legs
# Torag's_platebody
# Premade_worm_hole
# Unlit_bug_lantern
# Spectral_spirit_shield
# Bucket
# Iron_kiteshield
# Zamorak_mix(2)
# Staff_of_light
# Apples(5)
# Book_of_law_page_set
# Steel_claws
# Teak_kitchen_table
# Marrentill_potion_(unf)
# Zamorak_brew(2)
# Guthix_rest(4)
# Adamant_shield_(h4)
# Red_gloves
# Ankou_mask
# 3rd_age_pickaxe
# Super_def._mix(1)
# Blue_d'hide_chaps_(g)
# Saradomin_coif
# Saradomin_page_4
# Black_boater
# Chilli_con_carne
# Gilded_armour_set_(lg)
# Rune_dagger(p++)
# Halloween_mask_set
# Agility_potion(2)
# Jade_dragon_bolts_(e)
# Te_salt
# Raw_rat_meat
# Attack_potion(2)
# Grimy_kwuarm
# Black_platebody_(g)
# Rune_arrow(p+)
# Armadyl_page_1
# Grand_seed_pod
# Extended_antifire_mix(1)
# Steel_dagger(p++)
# Botanical_pie
# Ring_of_nature
# Lovakengj_hood
# Manta_ray
# Steel_dart_tip
# Soda_ash
# Team-29_cape
# Guthan's_platebody
# Javelin_shaft
# Enchant_sapphire_or_opal
# Rune_knife(p+)
# Lantadyme
# Adamant_platelegs
# Odium_ward
# Samurai_boots
# Pink_boater
# Dwarven_helmet
# Bronze_hasta
# Iron_limbs
# Premade_w'm_batta
# Red_boater
# Bronze_javelin(p)
# Magic_comp_bow
# Bounty_teleport_scroll
# Asgarnian_ale(4)
# Cyclops_head
# Zamorak_hilt
# Iron_spear(p)
# Kebab
# Hosidius_scarf
# Teak_dresser
# Guthix_stole
# Shayzien_banner
# Amulet_of_accuracy
# Rune_hasta(p+)
# Adamant_warhammer
# Iron_ore
# Jade_ring
# Lava_rune
# Adamantite_bar
# Dragon_thrownaxe
# Jangerberries
# Coal
# Granite_body
# Iron_platebody_(t)
# Steel_arrow(p++)
# Premade_ttl
# Desert_goat_horn
# Cadava_berries
# Vesta's_spear
# Ham_cloak
# Mithril_javelin_heads
# Fire_orb
# Rune_chainbody
# Black_robe
# M._treasure_chest
# Skills_necklace(6)
# Iron_halberd
# Oak_longbow
# Dragon_bolts_(p++)
# Imp_mask
# Mithril_set_(lg)
# Rune_kiteshield_(t)
# Mith_grapple_tip
# Skills_necklace
# Dragon_axe
# Unholy_symbol
# Iron_axe
# Black_headband
# Raw_summer_pie
# Rune_axe
# Gold_leaf
# Dragon_crossbow
# Ring_of_wealth_(5)
# Magic_bird_house
# Yew_sapling
# Dark_crab
# Super_restore(4)
# Chopped_tomato
# Emerald_bracelet
# Fruit_batta
# Sinew
# Uncut_diamond
# Ancient_chaps
# Oak_dining_table
# Zamorak_monk_bottom
# Red_d'hide_chaps_(g)
# Snapdragon
# Restore_potion(3)
# Tai_bwo_wannai_teleport
# Cooked_jubbly
# Blurberry_special
# Black_dagger(p+)
# Blue_robe_bottoms
# Rune_kiteshield_(g)
# Onyx_bolts
# Team-5_cape
# Adamant_crossbow
# Guthan's_warspear
# Clockwork
# Opal_amulet
# Black_spiky_vambs
# Proselyte_sallet
# Dragon_platebody_ornament_kit
# Golden_statuette
# Body_rune
# Uncut_dragonstone
# Raw_rainbow_fish
# Mith_crossbow
# Adamant_dagger
# Sanguinesti_staff_(uncharged)
# Saw
# Guthan's_helm
# Mos_le'harmless_teleport
# Saradomin_robe_top
# 3rd_age_longsword
# Bloody_bracer
# Mystic_air_staff
# Splitbark_legs
# Zamorak_brew(1)
# Ensouled_horror_head
# Dharok's_helm_0
# Iron_chainbody
# Blue_skirt_(t)
# Avantoe
# Ankou_gloves
# Curry_leaf
# Rune_dagger
# Pot_lid
# Fancy_teak_dresser
# Opal_necklace
# Book_of_darkness_page_set
# Mystic_steam_staff
# White_berries
# Mind_tiara
# Ham_logo
# Red_elegant_blouse
# Pottery_scarab
# Toy_doll
# Justiciar_chestguard
# Double_eye_patch
# Maple_longbow_(u)
# Citizen_shoes
# Expeditious_bracelet
# Armadyl_platebody
# Penguin_mask
# Bronze_set_(sk)
# Heavy_frame
# Tuna_and_corn
# Swamp_weed
# Shade_robe_top
# Rune_pickaxe
# Ensouled_bear_head
# Torag's_platelegs
# Torag's_armour_set
# Runite_bolts_(unf)
# Magic_stock
# Oak_pyre_logs
# Weeds
# Iron_javelin(p)
# Bronze_hasta(p)
# Mahogany_armchair
# Purple_elegant_shirt
# Mithril_bolts
# Opal_bracelet
# Mahogany_magic_wardrobe
# Oak_bed
# Yellow_dark_bow_paint
# Battlestaff
# Marigold_seed
# Ahrim's_robetop
# Wine_of_zamorak
# Earth_rune
# Magic_shortbow_(u)
# Rune_nails
# Toadflax_seed
# Spider_on_shaft
# Harralander_seed
# Left_eye_patch
# Purple_hat
# Raw_herring
# Chopped_garlic
# Dark_tuxedo_jacket
# Iron_bolts_(p++)
# Mahogany_table
# Occult_necklace
# Bandos_plateskirt
# Ruby_bolt_tips
# Dragon_metal_shard
# Odium_shard_3
# Camelot_teleport
# Vampyre_dust
# Flamtaer_hammer
# Dwarf_weed_potion_(unf)
# Restore_mix(2)
# Mystic_water_staff
# Silver_bolts_(p++)
# Magic_longbow
# Cake
# Armadyl_godsword_ornament_kit
# Bronze_full_helm_(g)
# Team-39_cape
# Black_leprechaun_hat
# Topaz_ring
# Ensouled_kalphite_head
# Adamant_hasta(p++)
# Mithril_platebody
# Grog
# Adamant_bolts_(p++)
# Molten_glass
# Guthix_plateskirt
# Teak_sapling
# Black_shield_(h4)
# Black_helm_(h4)
# Greenman's_ale(m)
# Extended_super_antifire(2)
# Zamorak_page_3
# Zenyte
# Raw_yak_meat
# Filled_plant_pot
# Pharaoh's_sceptre
# Bread
# Plank
# Tiara_mould
# Mithril_dart(p)
# Steel_nails
# Insect_repellent
# Lovakengj_scarf
# Mithril_bolts_(unf)
# Oak_treasure_chest
# Opal_amulet_(u)
# Rune_claws
# Black_platelegs_(t)
# Ogre_coffin_key
# Black_beret
# Empty_candle_lantern
# Black_spear(p)
# Yew_comp_bow
# Snake_hide
# Black_set_(sk)
# Rune_knife(p++)
# Relicym's_mix(1)
# Torture_ornament_kit
# Emerald_dragon_bolts
# Helm_of_neitiznot
# Armadyl_d'hide
# Mahogany_toy_box
# Adamant_arrow(p)
# Infinity_hat
# Bronze_set_(lg)
# Rock-shell_helm
# Jute_fibre
# Granite_legs
# Ruby_dragon_bolts_(e)
# Bandos_bracers
# Bronze_trimmed_set_(sk)
# Security_book
# Wild_pie
# Cannon_stand
# Lime_slices
# Super_energy_mix(1)
# Dragon_sq_shield_ornament_kit
# Rune_platelegs_(t)
# Ancient_page_1
# Black_plateskirt_(g)
# Bowl_wig
# Tormented_bracelet
# Steel_knife(p+)
# Zenyte_necklace
# Wood_camo_legs
# Iron_bolts_(p+)
# Brass_key
# Anti-venom+(2)
# Black_wizard_hat_(g)
# Unstrung_heavy_ballista
# Lemon_chunks
# Initiate_sallet
# Team-42_cape
# Irit_seed
# Gold_elegant_legs
# Oak_drawers
# Guthix_page_4
# Box_trap
# Leprechaun_hat
# Oak_sapling
# Hosidius_hood
# Samurai_kasa
# Curry_tree_seed
# Long_kebbit_bolts
# Steel_platelegs_(g)
# Enchanted_hat
# Steel_javelin
# Shortbow
# Bagged_yew_tree
# Axeman's_folly(4)
# Trout
# Topiary_hedge
# Mithril_arrow
# Fremennik_black_cloak
# Skeletal_visage
# Yellow_gloves
# Grimy_irit_leaf
# Black_trimmed_set_(lg)
# Bronze_dart_tip
# Ruby_harvest
# Adamant_gold-trimmed_set_(lg)
# Bronze_dart(p+)
# Tzhaar-ket-om
# Rock-shell_legs
# Red_elegant_skirt
# Ancient_page_4
# White_scimitar
# Bandos_hilt
# Bronze_chainbody
# Rock_thrownhammer
# Tarromin_potion_(unf)
# Rune_med_helm
# Fried_onions
# Prayer_mix(2)
# Bronze_kiteshield
# Mystic_robe_bottom_(dark)
# Guthix_mitre
# Adamant_pickaxe
# Red_topaz_machete
# Bronze_mace
# Mithril_scimitar
# Harralander_potion_(unf)
# Maple_sapling
# Santa_hat
# Limestone_brick
# Snakeskin_shield
# Guthix_bracers
# Pirate's_hat
# Waterskin(4)
# Chopped_ugthanki
# Black_boots
# Rune_hasta(p)
# Acorn
# Kebbit_claws
# Potato_seed
# Dragon_arrow(p++)
# Bronze_dagger(p+)
# Combat_bracelet(6)
# Steel_full_helm
# Abyssal_bracelet(5)
# Iron_scimitar
# Inoculation_bracelet
# Blue_hat
# Rune_full_helm_(g)
# Menaphite_purple_top
# Yellow_robe_bottoms
# Irit_potion_(unf)
# Bronze_thrownaxe
# Sleeping_cap
# Ardougne_teleport
# White_elegant_skirt
# Team-41_cape
# Mining_helmet
# Premade_veg_batta
# Krandorian_hops
# Relicym's_balm(1)
# Blue_skirt_(g)
# Dragon_chainbody
# Steel_javelin(p+)
# Gnome_goggles
# Team-18_cape
# Yellow_feather
# Compost
# Bandos_platelegs
# Combat_potion(4)
# Mithril_platebody_(t)
# Karil's_leatherskirt_0
# Studded_body
# Rune_armour_set_(sk)
# Yanillian_hops
# Amethyst_bolt_tips
# Iron_hasta(p++)
# Fishing_potion(3)
# Godsword_shard_3
# Bass
# Rune_essence
# Dark_fishing_bait
# Ankou's_leggings
# Malediction_shard_2
# Woad_leaf
# Bone_spear
# Purple_elegant_blouse
# Emerald_bolts_(e)
# Amylase_crystal
# Lockpick
# Olive_oil(4)
# Avantoe_seed
# Onyx_amulet_(u)
# Arcane_spirit_shield
# Dragon_bitter(4)
# Abyssal_dagger
# Ivory_comb
# Iron_dart(p)
# Lava_battlestaff
# Ancient_rune_armour_set_(sk)
# Steel_arrow(p+)
# Stone_statuette
# Opal_ring
# Toxic_staff_(uncharged)
# Defence_potion(1)
# Red_cavalier
# Pink_skirt
# Chilli_potato
# Raw_slimy_eel
# Redwood_logs
# Bronze_platebody
# Rune_mace
# Super_restore_mix(1)
# West_ardougne_teleport
# Watermelon
# Sacred_oil(4)
# Restore_mix(1)
# Olive_oil(1)
# Lava_dragon_mask
# Enchant_dragonstone
# Leather_gloves
# Pie_shell
# Malediction_shard_3
# Oak_shortbow_(u)
# Hair
# Limpwurt_seed
# Copper_ore
# Black_unicorn_mask
# Explorer_backpack
# Black_cape
# Shaving_stand
# Fried_mushrooms
# Yellow_boots
# Snakeskin_chaps
# Rune_sword
# Rune_arrowtips
# Guthix_balance(1)
# Adamant_arrow(p+)
# Topaz_bolts
# Mithril_ore
# Slayer_bell
# Sapphire_amulet
# Royal_gown_bottom
# Cooked_slimy_eel
# Mithril_full_helm
# Garlic
# Strength_potion(1)
# Studded_chaps_(t)
# Jug
# Bowl
# Rock-shell_boots
# Royal_gown_top
# Rune_scimitar
# Uncooked_dragonfruit_pie
# Kharyrll_teleport
# Loop_half_of_key
# Amulet_of_glory(6)
# Green_elegant_legs
# Crude_chair
# Maple_roots
# Ahrim's_armour_set
# Superantipoison(1)
# Crier_hat
# Earth_talisman
# Bronze_longsword
# Chaos_rune
# Defence_potion(3)
# Green_d'hide_body
# Emerald_dragon_bolts_(e)
# Doogle_leaves
# Pie_dish
# Holy_mould
# Twisted_bow
# Mithril_dart
# Fremennik_gloves
# Mithril_sq_shield
# Swamp_lizard
# Highwayman_mask
# Dragon_spear
# Pirate_hat_&_patch
# Ruby_dragon_bolts
# Zenyte_bracelet
# Ancient_rune_armour_set_(lg)
# Flattened_hide
# Black_cane
# Drift_net
# Charcoal
# Whiteberry_seed
# Nardah_teleport
# Steel_bolts_(p+)
# Adamant_dagger(p)
# Ranarr_potion_(unf)
# Green_d'hide_chaps_(g)
# Onyx_bolt_tips
# Butterfly_net
# Guthix_robe_top
# Toktz-mej-tal
# Butterfly_jar
# Mud_rune
# Marble_cape_rack
# Obsidian_cape_(r)
# Ensouled_dagannoth_head
# Ensouled_tzhaar_head
# Carved_oak_magic_wardrobe
# Maple_shield
# Superantipoison(4)
# Red_elegant_legs
# Holy_blessing
# Bucket_of_sap
# Black_claws
# Zuriel's_staff
# Ugthanki_kebab
# Dragon_harpoon
# Zamorakian_hasta
# Magic_logs
# Black_shield_(h2)
# Dragon_hasta
# Red_headband
# Small_box_hedge
# Seed_dibber
# Ogre_arrow
# Arcane_sigil
# Amulet_of_glory_(t)
# Casket
# Eternal_gem
# Briefcase
# Granite_clamp
# Willow_comp_bow
# Ancient_mitre
# Skeletal_helm
# Smoke_rune
# Wizard_boots
# Morrigan's_javelin
# Steel_dagger
# Black_elegant_legs
# Team-49_cape
# Amethyst_arrow
# Uncut_red_topaz
# Kodai_wand
# Toxic_blowpipe_(empty)
# Crystal_seed
# Iron_dart(p++)
# Sanfew_serum(4)
# Steel_trimmed_set_(sk)
# Uncharged_toxic_trident
# Super_combat_potion(1)
# Desert_top
# Rune_boots
# Black_helm_(h2)
# Bones
# Saradomin_brew(1)
# Grey_robe_bottoms
# Toad's_legs
# Ancient_totem
# Menaphite_red_kilt
# Battlemage_potion(4)
# White_headband
# Bagged_flower
# Menaphite_purple_hat
# Rune_shield_(h3)
# Gloves_of_silence
# Toy_doll_(wound)
# Bottle_of_wine
# Bagged_plant_1
# Berserker_ring
# Iron_gold-trimmed_set_(sk)
# Mithril_bolts_(p+)
# Red_halloween_mask
# Guthix_page_2
# Kitchen_table
# Bronze_hasta(p++)
# Chef's_delight(4)
# Revenant_cave_teleport
# Ahrim's_robetop_0
# Mage's_book
# Black_dart(p)
# Bucket_helm_(g)
# Adamant_dagger(p++)
# Mole_claw
# Black_tourmaline_core
# Emerald_ring
# Vesta's_longsword
# Dark_tuxedo_cuffs
# Dragonfire_ward
# Gloves_of_darkness
# Ham_boots
# Sliced_mushrooms
# Red_feather
# Raw_dark_crab
# Battlemage_potion(1)
# Oak_bench
# Spotted_cape
# Armadyl_plateskirt
# Cocktail_glass
# Dragon_med_helm
# Uncut_emerald
# Rune_dart(p+)
# Anti-venom(3)
# Fury_ornament_kit
# Redberry_seed
# Iron_spear(p++)
# Tomato_seed
# Black_dragonhide
# Body_talisman
# Bronze_battleaxe
# Barrows_teleport
# Red_partyhat
# Potato
# Zamorakian_spear
# Zamorak_godsword
# Blue_cape
# Uncooked_berry_pie
# Extended_super_antifire(4)
# Blue_spiky_vambs
# Steel_dart(p)
# Oak_wardrobe
# Bronze_axe
# Raw_ugthanki_meat
# Obsidian_platebody
# Dragon_javelin(p+)
# Blue_robe_top
# Dragonstone_amulet_(u)
# Ashes
# Torstol_potion_(unf)
# Ale_yeast
# Zenyte_amulet
# Death_tiara
# Red_d'hide_shield
# Fishing_mix(1)
# Lava_staff_upgrade_kit
# Pith_helmet
# Dragon_full_helm
# Dagannoth_bones
# Bronze_bolts_(p)
# Super_energy(3)
# Xerician_robe
# Frozen_whip_mix
# Rune_kiteshield
# Initiate_cuisse
# Giant_frog_legs
# Uncut_opal
# Raw_swordfish
# Vial_of_water
# Wrath_talisman
# Super_attack(2)
# Mithril_nails
# Strength_amulet_(t)
# Rune_helm_(h1)
# Ancestral_robe_top
# Gilded_plateskirt
# Pink_boots
# Bandos_chestplate
# Raw_beast_meat
# Polar_camo_top
# Varrock_teleport
# Green_d'hide_vamb
# Treasonous_ring
# Blue_wizard_robe_(t)
# Rune_helm_(h3)
# Grimy_harralander
# Black_dragonhide_set
# Cocktail_guide
# Pot_of_cornflour
# Elemental_helmet
# White_dark_bow_paint
# Iron_trimmed_set_(sk)
# Blue_d'hide_shield
# Zamorak_mix(1)
# Marble_magic_wardrobe
# Garden_pie
# Bastion_potion(4)
# Teak_table
# Eclectic_impling_jar
# Poison
# Book_of_balance_page_set
# Pumpkin
# Runite_bar
# Dragonfruit_pie
# Purple_sweets
# Serum_207_(3)
# Samurai_shirt
# Mystic_robe_bottom_(light)
# Brandy
# Magic_box
# Unicorn_horn_dust
# Apple_sapling
# Maple_blackjack(d)
# Pearl_dragon_bolts_(e)
# Bronze_crossbow_(u)
# Pineapple_pizza
# Teak_treasure_chest
# Fiyr_remains
# Team_cape_i
# Tuna
# Zamorak_chaps
# Bronze_plateskirt
# Adamant_dagger(p+)
# Bag_of_salt
# Bandos_crozier
# Agility_potion(4)
# Dragonstone_dragon_bolts_(e)
# Amulet_of_eternal_glory
# Iron_platelegs
# Black_helm_(h5)
# Dragon_scimitar_ornament_kit
# Cured_yak-hide
# Bagged_magic_tree
# Peaceful_blessing
# Coconut
# Diamond_amulet_(u)
# Cider
# Emerald_amulet_(u)
# Antidote++(2)
# Rangers'_tunic
# Greenmans_ale(m4)
# Relicym's_balm(4)
# Amethyst
# Cave_goblin_wire
# Cooked_sweetcorn
# Antifire_mix(1)
# Dragon_warhammer
# Olive_oil(3)
# Granite_helm
# Orange_cape
# Triangle_sandwich
# Ancient_robe_top
# Team-28_cape
# Pirate's_hook
# Blue_dragon_scale
# Monkfish
# Ankou_socks
# Amulet_mould
# Sacred_oil(3)
# Magic_potion(4)
# Axeman's_folly(m)
# Incomplete_light_ballista
# Adamant_platelegs_(g)
# Strength_potion(3)
# Rune_javelin(p)
# Amulet_of_glory_(t6)
# Green_dye
# Orange_tree_seed
# Water_tiara
# Super_antifire_potion(3)
# Steel_hasta(p+)
# Avernic_defender_hilt
# Mithril_thrownaxe
# Split_log
# Skills_necklace(4)
# Steam_battlestaff
# Games_necklace(8)
# Zamorak_page_4
# Dragonfire_shield
# Pineapple
# Rune_plateskirt_(t)
# Gianne's_cook_book
# Big_fishing_net
# White_boater
# Bronze_spear(p++)
# Hunter_potion(1)
# Iron_plateskirt_(g)
# Rabbit_snare
# Black_platebody
# Diamond_amulet
# Sapphire_dragon_bolts_(e)
# Ahrim's_hood_0
# Egg
# White_cavalier
# 3rd_age_kiteshield
# Pyrophosphite
# Calquat_sapling
# Light_bow_tie
# Saradomin_bracers
# Nunchaku
# Saradomin_mjolnir
# Light_orb
# Feldip_hills_teleport
# Beanie
# Elemental_shield
# Black_trimmed_set_(sk)
# Black_platelegs
# Rune_helm_(h2)
# Mature_cider
# Monocle
# Digsite_teleport
# Ancient_stole
# 3rd_age_cloak
# Unfired_pot
# Shoe_box
# Iron_plateskirt_(t)
# Crushed_nest
# Half_moon_spectacles
# Amulet_of_fury
# Zamorak_robe_top
# Zenyte_amulet_(u)
# Mithril_full_helm_(t)
# Uncooked_apple_pie
# Extended_antifire(3)
# Dragon_limbs
# Karil's_crossbow_0
# Water_talisman
# Ring_of_life
# Sandstone_(2kg)
# Mystic_robe_top
# Relicym's_mix(2)
# Dragon_bitter(m4)
# Essence_impling_jar
# Oak_armour_case
# Bronze_bolts
# Zamorak's_grapes
# Gnomish_firelighter
# Iron_arrow(p)
# Rock-shell_shard
# Rune_shield_(h5)
# Willow_branch
# Mummy's_legs
# Evil_chicken_wings
# Rock-shell_plate
# Jade_dragon_bolts
# Bob's_purple_shirt
# Teak_stock
# Raw_sardine
# Maple_longbow
# Sapphire
# Adamant_full_helm_(t)
# Amethyst_javelin(p)
# Roast_bird_meat
# Amethyst_broad_bolts
# Amulet_of_strength
# Mithril_arrowtips
# Sanfew_serum(1)
# Raw_trout
# Strength_potion(4)
# Stamina_mix(1)
# Opal_machete
# Saradomin_page_1
# Cadantine
# Mahogany_bookcase
# Magic_shortbow_scroll
# Lime_chunks
# Antifire_mix(2)
# Chocolate_cake
# Saradomin_crozier
# Team-3_cape
# Pyre_logs
# Dragon_metal_slice
# Bowl_of_water
# Raw_admiral_pie
# Citizen_top
# Jug_of_water
# Teak_armour_case
# Green_halloween_mask
# Gold_ore
# Mind_talisman
# Wyvern_bones
# Bowl_of_hot_water
# Barley_seed
# Rune_trimmed_set_(lg)
# Boots_of_darkness
# Crossbow
# Draynor_manor_teleport
# Abyssal_dagger_(p)
# Ancient_mace
# Necklace_of_passage(5)
# Super_defence(2)
# Black_shield_(h5)
# Kebbit_bolts
# Blue_firelighter
# Verac's_brassard_0
# Willow_blackjack(d)
# Fire_rune
# Cooked_meat
# Staff_of_earth
# Raw_wild_pie
# White_bead
# Dragon_dart(p++)
# Verac's_helm_0
# Calquat_tree_seed
# Stony_basalt
# Black_elegant_shirt
# Splitbark_gauntlets
# White_elegant_blouse
# Water_rune
# Blue_dragonhide_set
# Eternal_crystal
# Black_gold-trimmed_set_(lg)
# Right_eye_patch
# Ring_of_dueling(8)
# Mixed_flowers
# Diamond_bolt_tips
# Bucket_of_water
# Bandos_rune_armour_set_(sk)
# Incomplete_heavy_ballista
# Black_longsword
# Armadyl_page_3
# Banana_sapling
# Raw_rabbit
# Fremennik_blue_shirt
# Equa_leaves
# Infinity_top
# Rock_hammer
# 3rd_age_vambraces
# Bracelet_mould
# Abyssal_dagger_(p+)
# Maple_shortbow_(u)
# Studded_chaps
# Jute_seed
# Steel_platelegs_(t)
# Guthix_coif
# Mysterious_emblem
# Diamond_bolts
# Strawberry
# Blue_dark_bow_paint
# Hammer
# Initiate_harness_m
# Light_tuxedo_shoes
# Iron_bolts_(p)
# Saradomin_page_2
# New_crystal_shield
# Premade_dr'_dragon
# Bone_dagger_(p)
# Nature_tiara
# Runite_bolts_(p++)
# Fishing_potion(1)
# Rune_arrow(p)
# Dexterous_prayer_scroll
# Magic_potion(2)
# Iron_sq_shield
# Bronze_spear
# Bronze_limbs
# Ugthanki_&_onion
# Cannon_barrels
# Black_sq_shield
# Grape_seed
# Amethyst_javelin(p++)
# Guardian_boots
# Super_antifire_potion(2)
# Saradomin_godsword_ornament_kit
# Iron_sword
# Adamant_javelin_heads
# Willow_logs
# Proboscis
# Iron_platebody_(g)
# Adamantite_nails
# Yew_shortbow_(u)
# Spined_chaps
# Light_tuxedo_jacket
# Pearl_dragon_bolts
# Wildblood_hops
# Ancient_bracers
# Spotted_kebbit_fur
# Dragon_javelin
# Adamant_sq_shield
# Team-44_cape
# Lassar_teleport
# Seasoned_sardine
# Blue_d'hide_chaps_(t)
# Supercompost
# Rune_spear(p++)
# White_plateskirt
# Cavalier_mask
# Desert_boots
# Apple_mush
# Spatula
# Zamorak_d'hide
# Occult_ornament_kit
# A_powdered_wig
# Bagged_sunflower
# Superior_dragon_bones
# Crier_coat
# Bandos_godsword
# Spider_on_stick
# Uncut_sapphire
# Ruby_amulet_(u)
# Chef's_delight(m4)
# Purple_elegant_skirt
# Mystic_smoke_staff
# Sandstone_(5kg)
# Kyatt_top
# Oyster_pearls
# Burnt_bones
# Opal
# Fancy_tiara
# Vodka
# Vegetable_batta
# 3rd_age_range_top
# Magic_mix(2)
# Iron_spit
# Saradomin_armour_set_(sk)
# Ring_of_wealth_scroll
# Black_knife(p++)
# Harralander
# Guthix_mjolnir
# Antipoison_mix(2)
# Stretched_hide
# Topaz_necklace
# Proselyte_cuisse
# Rune_helm_(h5)
# Team_cape_zero
# White_magic_staff
# 3rd_age_robe_top
# Papaya_fruit
# Staff_of_water
# Asgarnian_ale
# Dynamite
# Ribcage_piece
# Steel_platebody_(g)
# Unholy_book_page_set
# Gold_bracelet
# Iron_dart_tip
# Premade_sgg
# Goblin_book
# Pink_cape
# Ancient_platebody
# Mort'ton_teleport
# Cosmic_rune
# Black_spear(p+)
# Bronze_arrow
# Silver_dust
# Cup_of_tea
# Torag's_hammers_0
# Bronze_dagger(p)
# Adamant_med_helm
# Runite_ore
# Iron_bar
# Air_orb
# Black_chainbody
# Ahrim's_hood
# Polar_camo_legs
# Graahk_top
# Iron_platelegs_(g)
# Energy_potion(3)
# 3rd_age_amulet
# Drake's_claw
# Desert_shirt
# Fibula_piece
# Bryophyta's_staff_(uncharged)
# Insulated_boots
# Red_dragon_mask
# Ruby_amulet
# Wooden_bed
# Black_helm_(h3)
# Rune_dart(p)
# White_apron
# Armadyl_page_2
# Yew_seed
# Cream_robe_top
# Guthix_dragonhide_set
# Cup_of_water
# Pineapple_sapling
# Larupia_top
# Energy_potion(4)
# Leather
# Oak_shaving_stand
# Willow_longbow_(u)
# Big_bones
# Malediction_ward
# Zombie_head
# Craw's_bow_(u)
# Zamorak_brew(4)
# Willow_roots
# Ward_upgrade_kit
# Earmuffs
# Oak_blackjack(d)
# Arceuus_scarf
# Elysian_sigil
# Marigolds
# Red_beret
# Tanzanite_fang
# Headless_arrow
# Green_cape
# Cooked_crab_meat
# King_worm
# Linen
# Enchant_emerald_or_jade
# Purple_boater
# Slayer's_respite(m)
# Opulent_table
# Lumbridge_teleport
# Iron_platelegs_(t)
# Saradomin_brew(2)
# Bark
# Diamond_bolts_(e)
# Adamant_helm_(h1)
# Barb_bolttips
# Ruby_ring
# Jade_amulet_(u)
# Spiky_vambraces
# Ancestral_hat
# Oyster
# Tooth_half_of_key
# Fremennik_boots
# Blue_boater
# Anchovies
# Shield_left_half
# Yew_logs
# Raw_sea_turtle
# Ancient_crystal
# Red_spiky_vambs
# Magic_essence_mix(1)
# Light_ballista
# Jar_of_sand
# Paddewwa_teleport
# Zenyte_shard
# 3rd_age_robe
# Yellow_partyhat
# Toad_crunchies
# Attack_potion(1)
# Mummy's_body
# Swamp_toad
# Redberries
# Amethyst_arrow(p++)
# Green_elegant_blouse
# Black_platelegs_(g)
# Ranging_mix(1)
# White_longsword
# Turquoise_hat
# Fire_battlestaff
# Onyx_bracelet
# Air_battlestaff
# Rune_2h_sword
# Fremennik_grey_shirt
# Iron_trimmed_set_(lg)
# Odium_shard_2
# Black_set_(lg)
# Mithril_dart(p++)
# Bandos_tassets
# Guthix_armour_set_(lg)
# Bob's_green_shirt
# Christmas_cracker
# Super_combat_potion(2)
# Gold_elegant_shirt
# Teak_logs
# Guthix_rest(2)
# Prayer_mix(1)
# Steel_gold-trimmed_set_(lg)
# Dragon_spear(p+)
# Air_talisman
# Mummy's_hands
# Adamant_thrownaxe
# Green_dark_bow_paint
# Pink_hat
# Carved_teak_magic_wardrobe
# Dragon_2h_sword
# Admiral_pie
# Dark_cavalier
# Team-2_cape
# Bronze_sq_shield
# Bronze_full_helm_(t)
# Brown_headband
# Empty_fishbowl
# Verac's_brassard
# Team-15_cape
# Anti-poison_supermix(2)
# Steel_2h_sword
# Premade_t'd_batta
# Ancient_full_helm
# Blue_flowers
# Adamant_javelin
# Ranging_potion(3)
# Crier_bell
# Dragon_dagger(p)
# Fremennik_robe
# Mithril_seeds
# Body_tiara
# White_gloves
# Antipoison(4)
# Arena_book
# Bandos_page_2
# Runite_bolts_(p+)
# Purple_elegant_legs
# Ensouled_abyssal_head
# Dust_rune
# Hunter_potion(3)
# Jar_of_miasma
# Gilded_boots
# Gilded_sq_shield
# Green_partyhat
# Premade_wiz_blz'd
# Wood_dining_table
# Dragon_sq_shield
# Adamant_boots
# Zamorak_plateskirt
# Team-19_cape
# White_lily_seed
# Karambwan_vessel
# Magic_shield
# Torag's_platelegs_0
# Dragonstone_ring
# Enchanted_robe
# Mahogany_bench
# Red_bead
# Pirate_boots
# Wrapped_oomlie
# Frog-leather_chaps
# Odium_shard_1
# Iron_bolts
# Vial_of_blood
# Attack_mix(1)
# Premade_veg_ball
# Lobster_pot
# Staff_of_air
# Phrin_remains
# Studded_body_(g)
# Bronze_javelin
# Dareeyak_teleport
# Crushed_superior_dragon_bones
# Cream_boots
# Iron_nails
# Lean_snail
# Ranger_boots
# Ancient_plateskirt
# Steel_spear(p)
# Ensouled_dragon_head
# Grimy_marrentill
# Greater_demon_mask
# Thammaron's_sceptre_(u)
# Ancestral_robe_bottom
# Pink_headband
# Binding_necklace
# Antipoison_mix(1)
# Yanillian_seed
# Wizard_hat
# Dharok's_greataxe
# Mithril_chainbody
# Grimy_ranarr_weed
# Topaz_dragon_bolts_(e)
# Premade_c+t_batta
# Oil_lantern_frame
# Gilded_2h_sword
# Adamant_platebody_(g)
# Skewer
# Ham_robe
# Polished_buttons
# Ballista_spring
# Musketeer_hat
# Black_nails
# Dragon_javelin(p)
# Guthix_cloak
# Bronze_2h_sword
# Strange_fruit
# Steel_set_(lg)
# Diamond_dragon_bolts_(e)
# Steel_crossbow_(u)
# Red_d'hide_chaps_(t)
# Jar_of_dirt
# Rune_knife(p)
# Oak_logs
# Ham_hood
# Ancient_d'hide_boots
# Guthix_balance(2)
# Splitbark_helm
# White_partyhat
# Emerald_necklace
# Mithril_claws
# Big_pirate_hat
# Snapdragon_potion_(unf)
# Super_kebab
# Sapphire_amulet_(u)
# Amethyst_javelin_heads
# White_toy_horsey
# Steel_arrowtips
# Desert_robe
# Green_boater
# Mind_rune
# Zamorak_platelegs
# Ensouled_minotaur_head
# Regen_bracelet
# Blue_dragon_leather
# Nice_hedge
# Bronze_halberd
# White_2h_sword
# Evil_chicken_head
# Magic_string
# Armadyl_platelegs
# Raw_lobster
# Jade_amulet
# Oak_shortbow
# Mort_myre_fungus
# Adamant_knife(p++)
# Dragon_javelin_heads
# Bronze_arrow(p+)
# Redwood_pyre_logs
# Drake's_tooth
# Ancient_effigy
# Unstrung_light_ballista
# Premade_ch'_crunch
# Teak_magic_wardrobe
# Steel_brutal
# Bronze_dagger(p++)
# Mummy's_head
# Mithril_set_(sk)
# Bagged_bluebells
# Larupia_fur
# Mithril_sword
# Dragon_claws
# Wizard_blizzard
# Pink_elegant_blouse
# Musketeer_tabard
# Dwellberries
# Black_skirt
# Clay
# Steel_med_helm
# White_flowers
# Saradomin_mitre
# Adamant_spear(p+)
# Mithril_hasta(p+)
# Oak_dresser
# Dragon_metal_lump
# Snakeskin_boots
# Veg_ball
# Spined_helm
# Grey_wolf_fur
# Super_antifire_mix(2)
# Belladonna_seed
# Rune_battleaxe
# Rake
# Saradomin_chaps
# Guthix_chaps
# Keg_of_beer
# Blue_d'hide_body_(g)
# Flamtaer_bracelet
# Guam_seed
# Carved_teak_bench
# Orange_flowers
# Strawberry_seed
# Grimy_lantadyme
# Staff
# Volcanic_ash
# Nose_peg
# Greenman's_ale
# Snakeskin_vambraces
# Raw_pike
# Druid's_robe
# Gold_amulet_(u)
# Super_antifire_potion(4)
# Egg_and_tomato
# Snakeskin_body
# Premade_fr'_blast
# Toy_soldier_(wound)
# Mahogany_cape_rack
# Uncut_ruby
# Guthix_balance(4)
# Fremennik_teal_cloak
# Basalt
# Royal_crown
# Barrel
# Dragon_battleaxe
# Lovakengj_banner
# Archery_ticket
# Jade_bracelet
# Team-48_cape
# Gold_ring
# Hunting_mix(2)
# Obsidian_helmet
# Arrow_shaft
# Charge_dragonstone_jewellery_scroll
# Bronze_crossbow
# Rabbit_foot
# Blue_d'hide_body_(t)
# Zamorak_mjolnir
# Toy_mouse
# Super_energy(1)
# Mithril_trimmed_set_(sk)
# Combat_mix(1)
# Partyhat_&_specs
# Bronze_knife(p+)
# Lantern_lens
# Adamant_hasta
# Karil's_coif_0
# Steel_bolts
# Attack_potion(3)
# Desert_robes
# Pot
# Enchanted_top
# Thatch_spar_med
# Teak_drawers
# Steel_kiteshield_(g)
# Mithril_kiteshield_(g)
# Tinderbox
# Ancient_wyvern_shield
# Willow_blackjack
# Hardleather_body
# Blessed_spirit_shield
# Mummy's_feet
# Granite_ring
# Ruby
# Irit_leaf
# Tatty_kyatt_fur
# Oak_magic_wardrobe
# Opal_bolts
# Black_d'hide_chaps
# Sanfew_serum(2)
# Team-11_cape
# Dragon_bolts_(unf)
# Cheese
# Mystic_mud_staff
# Apprentice_wand
# Dashing_kebbit_fur
# Jungle_camo_legs
# Shrunk_ogleroot
# Pineapple_punch
# Uncut_zenyte
# Super_energy(2)
# Gnomeball
# Moonlight_mead(m4)
# Mithril_knife
# Iron_dagger(p)
# White_sword
# Gilded_platelegs
# Slayer's_enchantment
# Bronze_wire
# Orange_slices
# Orange_boater
# Broad_bolts
# Bronze_scimitar
# Saradomin_dragonhide_set
# Mind_bomb(4)
# Leaping_salmon
# Armadyl_godsword
# Black_dagger(p)
# Extended_super_antifire(1)
# Harpoon
# Goblin_mask
# Leather_body
# Guam_tar
# White_platelegs
# Unfired_pie_dish
# Verac's_helm
# Zulrah's_scales
# Snowy_knight
# Tan_cavalier
# Armadyl_crozier
# Broken_bark_snelm
# Cider(4)
# Guthan's_helm_0
# Sapphire_bolts_(e)
# Ham_gloves
# Bone_dagger
# Silver_ore
# Dragon_bitter(m)
# Staff_of_fire
# White_kiteshield
# Tall_box_hedge
# Initiate_hauberk
# Green_headband
# White_claws
# Willow_shortbow_(u)
# Armadyl_page_4
# Rune_brutal
# Karil's_leathertop_0
# Tarromin
# Purple_robe_bottoms
# Skeletal_gloves
# Steel_pickaxe
# Chaos_talisman
# Armadyl_helmet
# Adamant_battleaxe
# Lava_scale_shard
# Dragon_hunter_lance
# Ranarr_weed
# Weapon_poison(+)
# Amulet_of_glory(4)
# Thin_snail_meat
# Steel_knife(p++)
# Team-45_cape
# Ensouled_monkey_head
# Fremennik_brown_cloak
# Enchant_diamond
# Cheese+tom_batta
# Lumberyard_teleport
# Hammerstone_seed
# Bottomless_compost_bucket
# Black_cavalier
# Chocchip_crunchies
# Soft_clay
# Menaphite_red_top
# Chocolate_dust
# Dragon_pickaxe
# Poison_chalice
# Leather_boots
# Strength_mix(1)
# Bronze_dragon_mask
# Black_spear
# Elder_chaos_top
# Sanfew_serum(3)
# Team-21_cape
# Fremennik_blue_cloak
# Guthix_robe_legs
# Arceuus_hood
# Rune_cane
# Raw_shrimps
# Steam_staff_upgrade_kit
# Rune_platelegs
# Cannon_furnace
# Watermelon_seed
# Rune_halberd
# Red_boots
# Ranging_potion(1)
# Steel_kiteshield_(t)
# Coif
# Adamant_dart_tip
# Energy_mix(1)
# Rune_shield_(h2)
# Mithril_bolts_(p++)
# Superantipoison(3)
# Empty_cup
# Dwarven_stout
# Team-9_cape
# Mahogany_stock
# Steel_bolts_(p++)
# Iron_hasta(p+)
# Guthix_crozier
# Teak_cape_rack
# Dragonstone_dragon_bolts
# Steel_bolts_(p)
# Adamant_shield_(h3)
# Saradomin's_light
# Bucket_helm
# Pantaloons
# Adamant_arrowtips
# Watchtower_teleport
# Ensouled_scorpion_head
# Energy_potion(1)
# Mahogany_bird_house
# Shark
# Vial
# Dragon_impling_jar
# Black_full_helm_(g)
# Prayer_potion(4)
# Steel_spear(p++)
# Waterskin(0)
# 3rd_age_range_coif
# Granite_shield
# Willow_stock
# Shayzien_scarf
# Wooden_bench
# Torag's_helm
# Dragon_armour_set_(lg)
# Dragon_necklace
# Restore_potion(4)
# Pie_recipe_book
# Saradomin_plateskirt
# Rune_knife
# Snakeskin_bandana
# Empty_oil_lamp
# Agility_potion(1)
# Black_d'hide_body_(t)
# Pike
# Ring_of_the_gods
# Kebbit_spike
# Bronze_plateskirt_(t)
# White_dagger(p)
# Willow_sapling
# Raw_jubbly
# Silver_sickle
# Dragon_dart
# Black_battleaxe
# Master_wand
# Frying_pan
# Anti-venom(1)
# Lime
# Lantadyme_potion_(unf)
# Mystic_robe_bottom
# Adamant_arrow
# Maple_blackjack(o)
# Monkey_nuts
# Black_d'hide_body_(g)
# Greenmans_ale(4)
# Mithril_kiteshield_(t)
# Anti-venom+(1)
# Zamorak_cloak
# Summer_pie
# Rune_javelin(p++)
# Banana_stew
# Feather
# Mithril_spear(p+)
# Granite_(5kg)
# Skeletal_top
# Maple_logs
# Nail_beast_nails
# Crunchy_tray
# Sweetcorn
# Poison_ivy_seed
# Turquoise_robe_top
# Ring_mould
# Wyrm_bones
# Black_spear(p++)
# Pink_robe_bottoms
# Mystic_robe_top_(light)
# Gilded_four-poster
# Fine_cloth
# Raw_mud_pie
# Silver_bolts_(unf)
# Ring_of_wealth
# Red_salamander
# Steel_warhammer
# Saradomin_stole
# Bandos_page_4
# Saradomin_cloak
# Anguish_ornament_kit
# Moonlight_mead(4)
# Ranarr_seed
# Zamorak_crozier
# Karil's_coif
# Red_topaz
# Iron_boots
# Fish_pie
# Adamant_helm_(h5)
# Clue_box
# Spinach_roll
# Ahrim's_robeskirt_0
# Mort_myre_pear
# Dragonstone_bolt_tips
# Rune_trimmed_set_(sk)
# Ancient_robe_legs
# Asgarnian_hops
# Oak_armchair
# Hosidius_banner
# Strung_rabbit_foot
# Premade_choc_s'dy
# Teak_bed
# Leaping_trout
# Adamant_platebody_(t)
# Ham_shirt
# Serum_207_(2)
# Bob's_black_shirt
# Granite_maul
# Secateurs
# Bird_snare
# Iron_brutal
# Staff_of_the_dead
# Ensouled_ogre_head
# Wooden_stock
# Babydragon_bones
# Berserker_helm
# Oak_bird_house
# Unfinished_broad_bolts
# Saradomin_platebody
# Shayzien_hood
# Toktz-xil-ek
# Dragon_platelegs
# Shortbow_(u)
# Topaz_bolt_tips
# Teak_dining_bench
# Thatch_spar_dense
# Diamond_bracelet
# Green_boots
# Zamorak_armour_set_(sk)
# Ahrim's_staff_0
# Wood_camo_top
# Iron_kiteshield_(t)
# Tome_of_fire_(empty)
# Black_demon_mask
# Bandos_boots
# Battlemage_potion(3)
# Dragon_hasta(p)
# Archers_ring
# Asgarnian_seed
# Zogre_bones
# Tangled_toad's_legs
# Adamant_bolts_(p+)
# Blue_d'hide_vamb
# Black_plateskirt
# Blue_d'hide_chaps
# Adamant_dart(p++)
# Glassblowing_pipe
# Arctic_pine_logs
# Green_robe_top
# Guthix_page_1
# Baked_potato
# Roe
# Rune_shield_(h1)
# Druid's_robe_top
# Adamant_chainbody
# Gilded_bench
# Raw_anchovies
# Bronze_spear(p+)
# Swamp_paste
# Bronze_arrow(p)
# Steel_sq_shield
# Mithril_halberd
# Locust_meat
# Meat_pie
# Teak_seed
# Pineapple_chunks
# Attack_mix(2)
# Marrentill_seed
# Super_potion_set
# Spicy_tomato
# Diamond_dragon_bolts
# Robe_bottom_of_darkness
# Jar_of_darkness
# Bone_dagger_(p+)
# Chaos_tiara
# Gold_headband
# Dark_infinity_colour_kit
# Bob's_blue_shirt
# Skewer_stick
# Bronze_javelin(p++)
# Hammerstone_hops
# Teal_robe_top
# Granite_boots
# Dharok's_greataxe_0
# Lemon
# Dharok's_platebody_0
# Armadyl_mitre
# Lunar_isle_teleport
# Pest_control_teleport
# Fremennik_pink_cloak
# Team-13_cape
# Lemon_slices
# Dragon_hunter_crossbow
# Master_scroll_book_(empty)
# Adamant_halberd
# Team-34_cape
# Shantay_pass
# Redberry_pie
# Combat_potion_set
# Salmon
# Muddy_key
# Menaphite_purple_kilt
# Mahogany_sapling
# Cemetery_teleport
# Team-30_cape
# Magic_shortbow
# Defence_potion(4)
# Bagged_nice_tree
# Sickle_mould
# Adamant_plateskirt
# Red_d'hide_body_(t)
# Team-17_cape
# Bagged_plant_3
# Premade_t'd_crunch
# Green_elegant_skirt
# Rune_hasta(p++)
# Unpowered_orb
# Steel_limbs
# Rune_spear(p)
# Team-33_cape
# Fishing_potion(2)
# Ensouled_troll_head
# Granite_gloves
# Loar_remains
# Super_defence(3)
# Honourable_blessing
# Guthix_rest(3)
# Spicy_sauce
# Gold_elegant_skirt
# Iron_spear(p+)
# Airtight_pot
# Blacksmith's_helm
# Burning_amulet(5)
# Pure_essence
# Raw_cave_eel
# Steel_hasta(p++)
# Serpentine_helm_(uncharged)
# Dwarf_weed_seed
# Iron_mace
# Yak-hide
# Death_talisman
# Ruby_necklace
# Unfinished_potion
# Adamant_spear(p++)
# Bastion_potion(3)
# Monkey_bar
# Bandos_mitre
# Bagged_oak_tree
# Zamorak_bracers
# Tall_fancy_hedge
# Iron_arrow
# Combat_potion(1)
# Menaphite_red_hat
# Bucket_of_sand
# Raw_mackerel
# Iron_full_helm_(t)
# Bronze_bolts_(p++)
# Arcane_prayer_scroll
# Antifire_potion(3)
# Choc-ice
# Raw_chompy
# Compost_potion(2)
# Emerald_bolts
# Tarromin_seed
# Bracelet_of_ethereum_(uncharged)
# Iron_2h_sword
# Extended_antifire(4)
# Rune_dagger(p+)
# Evil_chicken_feet
# Dharok's_platelegs_0
# Armadyl_robe_legs
# Necklace_of_faith
# Adamant_helm_(h3)
# Bronze_boots
# Phoenix_necklace
# Amethyst_javelin
# Bob's_red_shirt
# Steel_axe
# Iron_plateskirt
# Adamant_brutal
# Yellow_cape
# Brine_sabre
# Raw_garden_pie
# Elder_chaos_hood
# Oak_toy_box
# Seercull
# Sardine
# Leather_cowl
# Fremennik_grey_cloak
# Bryophyta's_essence
# Mithril_hasta(p++)
# Monkey_bones
# Cosmic_talisman
# Topaz_dragon_bolts
# Teasing_stick
# Bear_fur
# Ultracompost
# Bolt_mould
# Iron_javelin(p+)
# Dragon_scimitar
# Sandworms
# Redwood_shield
# Iron_spear
# Grimy_toadflax
# Piscarilius_scarf
# Super_restore(3)
# Watermelon_slice
# Limestone
# Partyhat_set
# Weapon_poison(++)
# Stamina_mix(2)
# Bronze_platebody_(g)
# Saradomin_godsword
# Wildblood_seed
# Ranger_gloves
# Logs
# Gianne_dough
# Ring_of_suffering
# White_warhammer
# Gilded_clock
# Fremennik_red_cloak
# Book_of_war_page_set
# Onyx_ring
# Mithril_gold-trimmed_set_(sk)
# Ancient_cloak
# Grimy_guam_leaf
# Amethyst_arrow(p)
# Red_elegant_shirt
# Iron_dart(p+)
# Dragon_kiteshield_ornament_kit
# Bronze_trimmed_set_(lg)
# Grey_boots
# Black_kiteshield_(g)
# Sandstone_(10kg)
# Piscatoris_teleport
# Mithril_spear(p++)
# Opal_dragon_bolts_(e)
# Silver_bolts_(p)
# Raw_fish_pie
# Steel_mace
# Cabbage_round_shield
# Light_frame
# Nature_rune
# Proselyte_hauberk
# Super_combat_potion(3)
# Air_tiara
# Giant_seaweed
# Vyrewatch_shoes
# Hunters'_crossbow
# Amethyst_javelin(p+)
# Magic_cape_rack
# Moonlight_mead
# Jogre_bones
# Mithril_gold-trimmed_set_(lg)
# Antipoison(3)
# White_sq_shield
# Salve_graveyard_teleport
# Nasturtium_seed
# 3rd_age_platebody
# Dragonstone
# Krandorian_seed
# Iron_platebody
# Gilded_armour_set_(sk)
# Raw_anglerfish
# Red_flowers
# Studded_chaps_(g)
# Raw_tuna
# Chef's_delight
# Sacred_oil(2)
# Beer_glass
# Bronze_bolts_(unf)
# Diamond_ring
# Blue_dragonhide
# Apple_pie
# Maple_stock
# Dragon_dart(p+)
# Papyrus
# Pink_elegant_shirt
# Black_sword
# Mystic_earth_staff
# Holy_sandals
# Iron_set_(lg)
# Dragon_chainbody_ornament_kit
# Uncharged_trident
# Ring_of_stone
# Extended_super_antifire_mix(1)
# Coconut_milk
# Monk's_robe
# Potato_cactus
# Dragon_arrow(p)
# Bandit's_brew
# Team-7_cape
# White_dagger
# Bone_dagger_(p++)
# Mahogany_wardrobe
# Ring_of_coins
# Team-1_cape
# Black_full_helm
# Superattack_mix(2)
# Leather_vambraces
# Black_d'hide_chaps_(g)
# Steel_longsword
# Iron_crossbow_(u)
# Combat_potion(2)
# Samurai_gloves
# Mithril_longsword
# Mystic_dust_staff
# Chinchompa
# Karil's_crossbow
# Purple_gloves
# Toadflax_potion_(unf)
# Ancient_blessing
# Infinity_boots
# Strength_mix(2)
# Bronze_bolts_(p+)
# Water_orb
# Burnt_page
# Black_desert_robe
# Ranging_potion(2)
# Gin
# Cooked_oomlie_wrap
# Old_demon_mask
# Dragon_knife
# Eternal_boots
# Green_d'hide_body_(t)
# Monkey_tail
# Purple_dye
# Mirror_shield
# Spade
# Verac's_plateskirt_0
# Gardening_boots
# Team-50_cape
# Toy_mouse_(wound)
# Imbued_heart
# Fayrg_bones
# Dragon_dart(p)
# Steel_dart
# Ancient_emblem
# Adamant_plateskirt_(t)
# Wrath_tiara
# Adamant_trimmed_set_(sk)
# Lava_dragon_bones
# Mithril_javelin(p+)
# Wooden_cat
# Cactus_seed
# Cadantine_seed
# Armadyl_cloak
# Antifire_potion(4)
# Bandos_chaps
# Piscarilius_hood
# Red_dragon_leather
# Thread
# White_dagger(p+)
# Bronze_nails
# Young_impling_jar
# Team-22_cape
# Redwood_bird_house
# Gilded_magic_wardrobe
# Unstrung_symbol
# Uncharged_trident_(e)
# Common_kebbit_fur
# Gilded_chainbody
# Mind_helmet
# Ahrim's_robeskirt
# Ranging_potion(4)
# Agility_mix(2)
# Grimy_avantoe
# Oak_stock
# Iron_javelin_heads
# Magpie_impling_jar
# Senntisten_teleport
# Extended_antifire(2)
# Unholy_blessing
# Rune_spear
# Amulet_of_bounty
# Zamorak_coif
# Armadyl_robe_top
# Toktz-xil-ul
# Iron_full_helm_(g)
# Flighted_ogre_arrow
# Top_hat_&_monocle
# Damaged_monkey_tail
# Cave_eel
# Carved_oak_bench
# Evil_chicken_legs
# Scrambled_egg
# Primordial_crystal
# Verac's_armour_set
# Poison_ivy_berries
# Fire_tiara
# Red_d'hide_body_(g)
# Meat_tenderiser
# Mithril_med_helm
# Asgarnian_ale(m)
# Bandos_cloak
# Gnome_scarf
# Super_strength(4)
# Green_spiky_vambs
# Dark_kebbit_fur
# Agility_mix(1)
# Bronze_javelin(p+)
# Lantadyme_seed
# Bandos_full_helm
# Cup_of_hot_water
# Smouldering_stone
# Purple_robe_top
# Dharok's_helm
# Primordial_boots
# Ensouled_dog_head
# Saradomin's_tear
# Granite_hammer
# Abyssal_bludgeon
# Dragon_spear(p++)
# Law_rune
# Dragon_dagger(p+)
# Dragonbone_necklace
# Iron_knife(p++)
# Zamorak_stole
# Battlemage_potion(2)
# Slayer's_respite
# Bucket_of_wax
# Bronze_arrowtips
# Granite_(2kg)
# Volcanic_whip_mix
# Black_kiteshield
# Dragon_bolts_(p)
# Adamantite_ore
# Mithril_battleaxe
# Adamant_javelin(p)
# Ancient_medallion
# Bottled_dragonbreath_(unpowered)
# Shaikahan_bones
# Rock-shell_gloves
# Dragon_bolts_(p+)
# Statius's_warhammer
# Pearl_bolts
# Icy_basalt
# Super_strength(1)
# Team-4_cape
# Celastrus_sapling
# Premade_p'_punch
# Chef's_delight(m)
# Toy_soldier
# Dark_bow
# Justiciar_armour_set
# White_battleaxe
# Justiciar_legguards
# Blue_dragon_mask
# Gilded_cape_rack
# Yellow_flowers
# Kebbit_teeth_dust
# Prayer_potion(2)
# Axeman's_folly(m4)
# Stone_scarab
# Fish_offcuts
# Mithril_limbs
# Steel_plateskirt_(g)
# Blue_d'hide_body
# Blue_partyhat
# Dharok's_armour_set
# Team-40_cape
# Stamina_potion(1)
# Uncooked_botanical_pie
# Dragon_hasta(kp)
# Antidote+(4)
# Anti-venom+(3)
# Willow_bird_house
# Blue_dye
# Fake_beard
# Teak_pyre_logs
# Warrior_helm
# Bagged_dead_tree
# Navy_cavalier
# Drake_bones
# Super_str._mix(2)
# Egg_whisk
# Light_infinity_colour_kit
# Kyatt_legs
# Bird_house
# Guthix_platebody
# Antipoison(1)
# Crossbow_string
# Garlic_powder
# Torag's_platebody_0
# Bandos_coif
# Steel_dragon_mask
# Mithril_plateskirt
# Heavy_ballista
# Adamant_kiteshield_(g)
# Cocktail_shaker
# Barbed_bolts
# Team-47_cape
# Proselyte_tasset
# Runite_limbs
# Bow_string
# Gold_bar
# Armadyl_hilt
# Steel_plateskirt
# Blue_wizard_robe
# Wolfbone_arrowtips
# Adamant_mace
# Bronze_hasta(p+)
# Cadantine_potion_(unf)
# Mahogany_armour_case
# Dark_trousers
# Oak_chair
# Castle_wars_bracelet(3)
# Saradomin_armour_set_(lg)
# Team-6_cape
# Gilded_wardrobe
# Anti-dragon_shield
# Toktz-ket-xil
# Maple_shortbow
# Fruit_blast
# Red_dragonhide
# Anchovy_pizza
# Fremennik_red_shirt
# Anti-poison_supermix(1)
# Zamorak_page_2
# Ancient_staff
# Marble_block
# Raw_cod
# Kharidian_headpiece
# Oyster_pearl
# Bolt_of_cloth
# Armadyl_chestplate
# Desert_camo_top
# Stamina_potion(4)
# Eye_of_newt
# Mahogany_fancy_dress_box
# Anti-venom(4)
# Magic_stone
# Mort_myre_stem
# Antipoison(2)
# Xerician_top
# Robe_top_of_darkness
# Teak_plank
# Green_robe_bottoms
# Green_hat
# Iron_battleaxe
# Torag's_hammers
# Armadyl_bracers
# Mithril_dagger
# Steel_set_(sk)
# Sea_turtle
# Mahogany_dresser
# Palm_tree_seed
# Vyrewatch_top
# Willow_pyre_logs
# White_unicorn_mask
# Fishing_potion(4)
# Compost_potion(1)
# Ghorrock_teleport
# Oak_kitchen_table
# Super_energy(4)
# Armadyl_chainskirt
# 3rd_age_bow
# Antidote+(1)
# Rune_gold-trimmed_set_(sk)
# Sandstone_(1kg)
# Short_green_guy
# Team-35_cape
# Raw_karambwan
# Prayer_potion(1)
# Blue_wizard_hat_(g)
# Toy_cat
# Fire_talisman
# Royal_sceptre
# Ancient_coif
# Rune_armour_set_(lg)
# Zamorak_dragonhide_set
# Swordfish
# Black_wizard_robe_(g)
# Climbing_boots
# Defence_mix(1)
# Justiciar_faceguard
# Unstrung_comp_bow
# Team-14_cape
# Chopped_tuna
# Mithril_dart(p+)
# Jug_of_wine
# Fly_fishing_rod
# Mushroom_&_onion
# Carrallangar_teleport
# Green_d'hide_chaps_(t)
# Antidote++(1)
# Jangerberry_seed
# White_halberd
# Fishing_bait
# Rune_spear(p+)
# Ugthanki_&_tomato
# Rune_hasta
# Cooked_chicken
# Vyrewatch_legs
# Mithril_full_helm_(g)
# Dragon_knife(p)
# Steel_platebody_(t)
# Efaritay's_aid
# Barley_malt
# Steel_sword
# Team-38_cape
# Lava_scale
# Wyvern_visage
# Steel_hasta
# Blue_feather
# Relicym's_balm(3)
# Comp_ogre_bow
# Chocolate_bar
# Raw_bird_meat
# Steel_crossbow
# Raw_bear_meat
# Bronze_dart(p++)
# Dragonstone_bolts
# Team-8_cape
# Numulite
# Redwood_tree_seed
# Splitbark_body
# Spined_boots
# Armadyl_rune_armour_set_(lg)
# Tin_ore
# Bagged_maple_tree
# Strength_potion(2)
# Tomato
# Onion_seed
# Candle
# Extended_super_antifire_mix(2)
# Mithril_platelegs
# Bullseye_lantern
# Ugthanki_meat
# Iron_knife
# Mystic_mist_staff
# Mithril_crossbow_(u)
# Slayer's_respite(4)
# Cadavaberry_seed
# Fremennik_hat
# Armadyl_stole
# Beer
# Raw_chicken
# Red_robe_bottoms
# Iron_javelin
# Oil_lantern
# Mithril_boots
# Steel_hasta(p)
# Karidian_disguise
# Black_scimitar
# Yew_pyre_logs
# Gold_necklace
# Rocking_chair
# Chopped_onion
# Rosemary
# Onion_&_tomato
# Calcite
# Oranges(5)
# Spider_carcass
# Dharok's_platebody
# Wooden_shield_(g)
# Iron_crossbow
# Teal_robe_bottoms
# Ship_ticket
# Wizard's_mind_bomb
# Adamant_set_(sk)
# Adamant_axe
# Oak_plank
# Tyras_helm
# Ring_of_recoil
# Super_str._mix(1)
# Saradomin_page_3
# Baby_impling_jar
# Iron_arrow(p++)
# Mithril_plateskirt_(g)
# Steel_gold-trimmed_set_(sk)
# Green_dragonhide
# Trident_of_the_seas_(full)
# Armadyl_rune_armour_set_(sk)
# Swamp_tar
# Sweetcorn_seed
# Antidote+(2)
# Bandos_d'hide
# Cider(m4)
# Restore_potion(2)
# Topaz_amulet_(u)
# Steel_dart(p++)
# Granite_(500g)
# Steel_dagger(p+)
# Pearl_bolt_tips
# Astral_rune
# Zamorak_brew(3)
# Pink_robe_top
# Black_knife
# Runite_bolts_(p)
# Mithril_brutal
# Blue_boots
# Topaz_amulet
# Facemask
# Long_kebbit_spike
# Earth_battlestaff
# Worm_crunchies
# Dragon_full_helm_ornament_kit
# Bronze_full_helm
# Compost_potion(4)
# Team-27_cape
# Team-32_cape
# Steel_bar
# Harmony_island_teleport
# Restore_potion(1)
# Bronze_claws
# Dragon_scale_dust
# Unstrung_emblem
# Red_chinchompa
# Steel_javelin(p++)
# Armadyl_full_helm
# Bandos_page_3
# Guthan's_chainskirt_0
# Steel_chainbody
# Ensouled_goblin_head
# Mith_grapple
# Steel_spear(p+)
# Dragon_knife(p++)
# Uncooked_meat_pie
# White_full_helm
# Mature_wmb
# Ancient_page_2
# Adamant_bolts
# Magic_fang
# Obsidian_armour_set
# Ruby_bolts_(e)
# Willow_longbow
# Citizen_trousers
# Blue_skirt
# Ancient_page_3
# Purple_boots
# Rune_shield_(h4)
# Gnome_spice
# Purple_partyhat
# Mithril_spear
# Black_skirt_(g)
# Ring_of_returning(5)
# Urt_salt
# Adamant_set_(lg)
# Saradomin_brew(3)
# Mithril_javelin
# Black_platebody_(t)
# Iron_knife(p+)
# Team_cape_x
# Armadyl_crossbow
# Mithril_warhammer
# Steel_full_helm_(t)
# Unfired_plant_pot
# Mystic_hat_(light)
# Black_knife(p)
# Bronze_sword
# Banana_tree_seed
# Agility_potion(3)
# Yew_shield
# Blue_wizard_hat
# Dragon_arrowtips
# Stronghold_notes
# Mushroom
# Rune_platelegs_(g)
# Gold_elegant_blouse
# Mystic_boots
# Magic_longbow_(u)
# Proselyte_harness_m
# Ancestral_robes_set
# Falador_teleport
# Karil's_armour_set
# Brown_apron
# Uncooked_mushroom_pie
# Guthan's_platebody_0
# Hard_leather_shield
# Archer_helm
# Mithril_dagger(p+)
# Weapon_poison
# Yellow_robe_top
# Drunk_dragon
# Oak_bookcase
# Toad_batta
# Combat_bracelet(4)
# Teak_toy_box
# Holy_book_page_set
# Emerald_bolt_tips
# Mud_pie
# Feldip_weasel_fur
# Toadflax
# Teak_armchair
# Moonlight_mead(m)
# Viggora's_chainmace_(u)
# Premade_w'm_crun'
# Xerician_fabric
# Torag's_helm_0
# Bagged_roses
# Yew_shortbow
# Dragon_sword
# Fat_snail_meat
# Yak-hide_armour
# Bagged_plant_2
# Fremennik_yellow_cloak
# Spottier_cape
# Mist_rune
# Thatch_spar_light
# Antifire_potion(1)
# Bandos_d'hide_boots
# Adamant_knife(p+)
# Gilded_full_helm
# Draconic_visage
# Zamorak_kiteshield
# Bronze_brutal
# Anti-venom+(4)
# Teal_boots
# Gourmet_impling_jar
# Unpowered_symbol
# Wooden_shield
# Cabbages(10)
# Barley
# Red_firelighter
# Rune_sq_shield
# Zamorak_godsword_ornament_kit
# Spined_body
# Black_2h_sword
# Black_d'hide_body
# Brown_toy_horsey
# Yellow_bead
# Zamorak_mitre
# Kwuarm_seed
# Bone_bolts
# Frog-leather_body
# Cooked_chompy
# Steel_javelin(p)
# Amulet_of_avarice
# Whisky
# Ensouled_unicorn_head
# White_dagger(p++)
# Pile_of_salt
# Granite_longsword
# 3rd_age_wand
# Rune_platebody_(t)
# Carved_teak_table
# Team-46_cape
# Super_strength(2)
# Verac's_flail_0

# %%
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check if it worked

data = {}
for item in itemPrices:
    print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))
# Out:
# Dragon_bones
# Iron_longsword
# Dragon_halberd
# Scythe_of_vitur_(uncharged)
# Holy_wraps
# Black_warlock
# Blue_wizard_robe_(g)
# Abyssal_whip
# Amethyst_arrowtips
# Blue_elegant_shirt
# Godsword_shard_1
# Dodgy_necklace
# Holy_symbol
# Desert_legs
# Empty_plant_pot
# Steel_full_helm_(g)
# Mist_battlestaff
# Steel_dagger(p)
# Bone_club
# Roast_rabbit
# Adamant_platebody
# Elf_camp_teleport
# Ogre_arrow_shaft
# New_crystal_bow
# Shrimps
# Magic_essence_mix(2)
# Steel_kiteshield
# Dragonfruit_tree_seed
# Adamant_shield_(h1)
# Rune_thrownaxe
# Cabbage
# Bandos_godsword_ornament_kit
# Black_full_helm_(t)
# Noose_wand
# Karil's_leathertop
# Anglerfish
# Jar_of_souls
# Chocolate_bomb
# Onyx_amulet
# Cabbage_seed
# Energy_mix(2)
# Cleaver
# Dragon_spear(p)
# Flax
# Malediction_shard_1
# Saradomin_d'hide_boots
# Bronze_platebody_(t)
# Easter_egg
# War_blessing
# Rune_longsword
# Leaf-bladed_sword
# Unblessed_symbol
# Dragon_knife(p+)
# Infinity_gloves
# Ensouled_aviansie_head
# Orange_dye
# Ankou_top
# Saltpetre
# Samurai_greaves
# Ancient_statuette
# Turquoise_robe_bottoms
# Dragon_dagger(p++)
# Mithril_axe
# Relicym's_balm(2)
# Jade_bolt_tips
# Dragon_arrow(p+)
# Oak_blackjack(o)
# Adamant_shield_(h5)
# Dwarf_weed
# Banana
# Longbow
# Stamina_potion(3)
# Mint_cake
# Marrentill
# Guthix_full_helm
# Red_d'hide_vamb
# Onyx
# Teak_clock
# 3rd_age_range_legs
# Oil_lamp
# Guthan's_armour_set
# Pestle_and_mortar
# Teleport_to_house
# Ruby_bolts
# Cream_robe_bottoms
# Air_rune
# Black_flowers
# Twisted_buckler
# Saradomin_full_helm
# Mahogany_logs
# Super_restore(2)
# Rune_warhammer
# Steel_platelegs
# Verac's_flail
# Broad_arrowheads
# Torstol_seed
# Stone_seal
# Ensouled_bloodveld_head
# Orange
# Bandos_robe_legs
# Jade
# Team-10_cape
# Silver_bar
# Rune_arrow(p++)
# Steel_studs
# Black_dagger
# Bronze_plateskirt_(g)
# Team-31_cape
# Dragon_bolts
# Iron_dagger(p+)
# Mystic_gloves_(dark)
# Lesser_demon_mask
# Rune_javelin(p+)
# Afro
# Dwarven_stout(m)
# Pearl_bolts_(e)
# Bolt_rack
# Revenant_ether
# Antifire_potion(2)
# Black_d'hide_shield
# Bronze_arrow(p++)
# Prayer_potion(3)
# Mithril_javelin(p)
# Bullseye_lantern_(unf)
# Tyrannical_ring
# Grey_robe_top
# Green_d'hide_chaps
# Teacher_wand
# Black_warhammer
# Dragon_platebody
# Bronze_gold-trimmed_set_(sk)
# Lobster
# Rune_helm_(h4)
# Mystic_robe_top_(dark)
# Needle
# Monk's_robe_top_(g)
# Fishing_rod
# Adamant_spear
# Zul-andra_teleport
# Silk
# Polar_kebbit_fur
# Mithril_pickaxe
# Magic_sapling
# Superantipoison(2)
# Ruby_bracelet
# Iron_warhammer
# Black_shield_(h3)
# Adamant_2h_sword
# Bronze_platelegs_(g)
# Cannonball
# Old_school_bond
# Kyatt_hat
# Dragon_javelin(p++)
# Steel_javelin_heads
# Gilded_kiteshield
# Adamant_cane
# Assorted_flowers
# Bagged_daffodils
# Defence_potion(2)
# Extended_super_antifire(3)
# Iron_dart
# Premade_s'y_crunch
# Ensouled_elf_head
# Gilded_platebody
# Kwuarm
# Mystic_boots_(light)
# Green_d'hide_body_(g)
# Sapphire_glacialis
# Blue_halloween_mask
# Dragon_legs/skirt_ornament_kit
# Bronze_pickaxe
# Ensouled_giant_head
# Amulet_of_magic
# Ancient_relic
# Earth_impling_jar
# Antidote++(4)
# Elysian_spirit_shield
# Super_attack(1)
# Palm_sapling
# Kitchen_knife
# Steel_knife(p)
# Amethyst_arrow(p+)
# Red_hat
# Armadyl_chaps
# Adamant_longsword
# Dragon_mace
# Dagannoth_hide
# Stale_baguette
# Guthix_balance(3)
# Bronze_gold-trimmed_set_(lg)
# Top_hat
# Black_desert_shirt
# Torn_prayer_scroll
# Onions(10)
# Super_antifire_potion(1)
# Black_salamander
# Saradomin_brew(4)
# Mystic_hat_(dark)
# Black_axe
# Adamant_hasta(p)
# Brass_necklace
# Black_d'hide_chaps_(t)
# Hydra_bones
# Dinh's_bulwark
# Steel_spear
# Mithril_trimmed_set_(lg)
# Adamant_helm_(h2)
# Adamant_full_helm
# Black_knife(p+)
# Serpentine_visage
# Green_elegant_shirt
# Grey_toy_horsey
# Lizardman_fang
# Red_dye
# Olive_oil(2)
# Green_d'hide_shield
# Green_firelighter
# Black_halberd
# Bastion_potion(1)
# Magic_potion(3)
# Large_teak_bed
# Unfired_pot_lid
# Golden_chef's_hat
# Bandos_dragonhide_set
# Amulet_of_glory_(t4)
# Grapes
# Black_med_helm
# Dwarf_cannon_set
# Tzhaar-ket-em
# Black_helm_(h1)
# Cooking_apple
# Orange_chunks
# Black_d'hide_vamb
# Hard_leather
# Raurg_bones
# Bananas(5)
# Marrentill_tar
# Dharok's_platelegs
# Adamant_gold-trimmed_set_(sk)
# Meat_pizza
# Steel_bolts_(unf)
# Iron_set_(sk)
# Beer_tankard
# Maple_bird_house
# Mithril_bar
# Godsword_shard_2
# Wool
# Dwarven_stout(4)
# Teal_gloves
# Steam_rune
# Black_toy_horsey
# Iron_kiteshield_(g)
# Adamant_full_helm_(g)
# Onyx_dragon_bolts_(e)
# Bread_dough
# Rock-shell_chunk
# Hunting_mix(1)
# Nasturtiums
# Willow_shield
# Ancient_d'hide
# Riyl_remains
# Black_shield_(h1)
# Tiara
# Gold_amulet
# Arceuus_banner
# Zamorak_page_1
# Iron_dagger(p++)
# Bandos_robe_top
# Runite_bolts
# Raw_shark
# Bronze_dart
# Bronze_platelegs
# Elder_chaos_robe
# Impling_jar
# Sapphire_bolt_tips
# Iron_dragon_mask
# Mahogany_seed
# Desert_camo_legs
# Mithril_spear(p)
# Dwarven_stout(m4)
# Kyatt_fur
# Gnomebowl_mould
# Nature_impling_jar
# Team-26_cape
# Slayer's_respite(m4)
# Superattack_mix(1)
# Trading_sticks
# Rock-climbing_boots
# Amulet_of_defence
# Mackerel
# Potato_with_cheese
# Guthix_dragonhide
# Plant_cure
# Yellow_dye
# Bat_bones
# Oak_roots
# Super_attack(3)
# Bronze_kiteshield_(t)
# Ancient_platelegs
# Amulet_of_chemistry
# Skull_piece
# Raw_salmon
# Fenkenstrain's_castle_teleport
# Iron_bolts_(unf)
# Water_battlestaff
# Sagacious_spectacles
# Cooked_rabbit
# Bottled_dragonbreath
# Iron_hasta(p)
# Mithril_dagger(p++)
# Mithril_2h_sword
# Disk_of_returning
# Combat_bracelet
# Rune_platebody_(g)
# Pot_of_cream
# Rune_platebody
# Bucket_of_milk
# Oak_shield
# Caviar
# Fremennik_cyan_cloak
# Orange_sapling
# Jar_of_swamp
# Pastry_dough
# Rune_dart_tip
# Iron_arrow(p+)
# Black_kiteshield_(t)
# Black_mask_(10)
# Holy_elixir
# Iron_hasta
# Mithril_knife(p+)
# Dragon_dagger
# Black_brutal
# Cooked_karambwan
# Mithril_arrow(p+)
# Chisel
# Bandos_page_1
# Tomatoes(5)
# Ballista_limbs
# Rosemary_seed
# Rune_javelin
# Pink_elegant_skirt
# Ring_of_forging
# Saradomin_sword
# Bird_nest
# Adamant_scimitar
# Adamant_kiteshield
# Purple_cape
# Fez
# Amulet_of_torture
# Black_dart(p++)
# Mystic_gloves
# Yew_stock
# Fremennik_skirt
# Kwuarm_potion_(unf)
# Adamant_spear(p)
# Mithril_javelin(p++)
# Beer_barrel
# Mithril_hasta(p)
# Worm_hole
# Jungle_demon_mask
# Ground_guam
# Diamond_necklace
# Cleaning_cloth
# Jungle_camo_top
# Rune_plateskirt_(g)
# Mushroom_pie
# Team-24_cape
# Pineapple_seed
# Adamant_dart(p)
# Black_mask
# Maple_pyre_logs
# Magic_staff
# Unicorn_horn
# Opal_bolt_tips
# Dragon_hasta(p+)
# Bracelet_of_slaughter
# Gold_seal
# Frog-leather_boots
# Hill_giant_club
# Zamorak_robe_legs
# Team-25_cape
# Jade_machete
# Sapphire_bolts
# Iron_javelin(p++)
# Rock-shell_splinter
# Red_d'hide_body
# Serum_207_(1)
# Mystic_lava_staff
# Steel_arrow
# Gadderhammer
# Nature_talisman
# Mud_battlestaff
# Kraken_tentacle
# Bagged_willow_tree
# Ale_of_the_gods
# Saradomin_d'hide
# Blue_elegant_legs
# Spork
# Zamorak_d'hide_boots
# Team-12_cape
# Adamant_sword
# Black_dart
# Ninja_impling_jar
# Warrior_ring
# Adamant_knife
# Dragon_armour_set_(sk)
# Magic_potion(1)
# Stripy_feather
# Guthix_rest(1)
# Uncharged_toxic_trident_(e)
# Cat_mask
# Adamant_shield_(h2)
# Iron_thrownaxe
# Raw_monkfish
# Monk's_robe_top
# Black_chinchompa
# Lumbridge_graveyard_teleport
# Dragon_defender_ornament_kit
# Avantoe_potion_(unf)
# Willow_shortbow
# Bandos_kiteshield
# Uncooked_egg
# Compost_potion(3)
# Slayer's_staff
# Purple_flowers
# Black_skirt_(t)
# Bronze_med_helm
# Axeman's_folly
# Black_plateskirt_(t)
# Onyx_dragon_bolts
# White_boots
# Monk's_robe_(g)
# Team-43_cape
# Cadantine_blood_potion_(unf)
# Snakeskin
# Team-37_cape
# White_chainbody
# Batta_tin
# Mithril_kiteshield
# Musketeer_pants
# Bronze_warhammer
# Torstol
# Dragonstone_bolts_(e)
# Saradomin_robe_legs
# Adamant_dart
# Orange_feather
# Goblin_mail
# Seers_ring
# Wooden_chair
# Antidote++(3)
# Golden_apron
# Seaweed_spore
# Gilded_dresser
# Diamond
# Empty_oil_lantern
# Amulet_of_power
# Guthix_page_3
# Mind_bomb(m4)
# Maple_blackjack
# Toktz-xil-ak
# Hunter_potion(4)
# Grey_gloves
# Smoke_battlestaff
# Guthan's_warspear_0
# Splitbark_boots
# Snapdragon_seed
# Pink_elegant_legs
# Extended_antifire_mix(2)
# Iron_claws
# Ancient_dragonhide_set
# Onyx_necklace
# Mithril_hasta
# Spice
# Cider_barrel
# Saradomin_kiteshield
# Tatty_graahk_fur
# Bronze_knife(p++)
# Half_full_wine_jug
# Potato_cactus_seed
# Necklace_of_anguish
# Red_cape
# Elder_maul
# Premade_choc_bomb
# Adamant_dart(p+)
# Sapphire_ring
# Black_dragon_leather
# Cosmic_tiara
# Fish_food
# Rune_plateskirt
# Sulliuscep_cap
# Ghrazi_rapier
# Grain
# Armadyl_coif
# Iron_dagger
# Mystic_hat
# Large_oak_bed
# Menaphite_red_robe
# Pegasian_crystal
# Iron_knife(p)
# Raw_oomlie
# Fishing_mix(2)
# Mahogany_pyre_log
# Calquat_keg
# Bookcase
# Earth_tiara
# Silver_bolts
# Curry_sapling
# Onion
# Ape_atoll_teleport
# Worm_batta
# Plain_pizza
# Cactus_spine
# Defence_mix(2)
# Menaphite_purple_robe
# Energy_potion(2)
# Blood_rune
# Guthan's_chainskirt
# Raw_beef
# Guthix_d'hide_boots
# Harralander_tar
# Bandos_platebody
# Blue_wizard_hat_(t)
# Adamant_plateskirt_(g)
# Mithril_platelegs_(t)
# Super_restore_mix(2)
# Asgarnian_ale(m4)
# Teak_wardrobe
# Super_energy_mix(2)
# Golden_scarab
# Unlit_torch
# Wolf_bones
# Stamina_potion(2)
# Snape_grass_seed
# Steel_scimitar
# Bronze_dagger
# Yew_roots
# Combat_potion(3)
# Leaf-bladed_battleaxe
# Pottery_statuette
# Steel_platebody
# Opal_bolts_(e)
# Egg_potato
# Enchant_ruby_or_topaz
# Grey_hat
# Machete
# Sapphire_necklace
# Empty_sack
# Bones_to_bananas
# Bracelet_of_clay
# Pat_of_butter
# Attack_potion(4)
# Bastion_potion(2)
# Thorny_hedge
# Amulet_of_glory
# Mithril_dagger(p)
# Steel_dart(p+)
# Onyx_bolts_(e)
# Fremennik_green_cloak
# Rune_dart
# Herring
# Blue_elegant_skirt
# Efh_salt
# Antidote+(3)
# Enchant_onyx
# Steel_battleaxe
# Blue_headband
# Fat_snail
# Zamorak_full_helm
# Blue_elegant_blouse
# Black_bead
# Black_dagger(p++)
# Timber_beam
# Gilded_scimitar
# Papaya_sapling
# Iron_gold-trimmed_set_(lg)
# Premade_fr't_batta
# Dragon_hasta(p++)
# Roast_beast_meat
# Serum_207_(4)
# Magic_mix(1)
# Mind_altar_teleport
# Black_pickaxe
# Mithril_dragon_mask
# Mithril_bolts_(p)
# 3rd_age_platelegs
# Jade_necklace
# Armadyl_d'hide_boots
# Circular_hide
# Mystic_boots_(dark)
# Minced_meat
# Dark_bow_tie
# Leather_chaps
# Curry
# Yellow_hat
# Pharaoh's_sceptre_(3)
# Tarromin_tar
# Sinister_key
# Pegasian_boots
# Mithril_mace
# Iron_full_helm
# Ahrim's_staff
# Larupia_hat
# Hunter_potion(2)
# Golovanova_fruit_top
# Bronze_dart(p)
# Steel_halberd
# Longbow_(u)
# Team-23_cape
# Willow_seed
# Light_tuxedo_cuffs
# Light_trousers
# Shade_robe
# Pitta_bread
# Farseer_helm
# Dragon_boots
# Wooden_spoon
# Rune_full_helm_(t)
# Jar_of_decay
# Amulet_of_the_damned_(full)
# Dragon_crossbow_(u)
# Red_robe_top
# Black_wizard_hat_(t)
# Rune_javelin_heads
# Mushroom_spore
# Grimy_cadantine
# Bronze_javelin_heads
# Adamant_claws
# Magic_pyre_logs
# Mithril_knife(p)
# Topaz_bracelet
# Mystic_gloves_(light)
# Team-36_cape
# Bronze_bar
# Guthix_armour_set_(sk)
# Robin_hood_hat
# Oak_cape_rack
# Ourg_bones
# Fur
# Watering_can
# Kebab_mix
# Merfolk_trident
# Mind_shield
# Apple_tree_seed
# 3rd_age_axe
# Beginner_wand
# Super_antifire_mix(1)
# Saradomin_platelegs
# Rune_gold-trimmed_set_(lg)
# Adamant_bolts(unf)
# Mithril_plateskirt_(t)
# Spined_gloves
# Xerician_hat
# Bronze_knife
# Crystal_key
# Black_dart(p+)
# Ensouled_imp_head
# Super_attack(4)
# Guam_leaf
# Verac's_plateskirt
# Spicy_crunchies
# Sapphire_bracelet
# Mole_skin
# Proselyte_harness_f
# Annakarl_teleport
# Barb-tail_harpoon
# Calquat_fruit
# Bullseye_lantern_(empty)
# Larupia_legs
# Fremennik_beige_shirt
# Uncut_onyx
# Bagged_marigolds
# Wrath_rune
# Dragonstone_amulet
# 3rd_age_mage_hat
# Iron_med_helm
# Yew_longbow_(u)
# Spectral_sigil
# Gardening_trowel
# Premade_blurb'_sp.
# Super_combat_potion(4)
# Mithril_platelegs_(g)
# Studded_body_(t)
# Gilded_med_helm
# Turquoise_boots
# Armadyl_kiteshield
# Teal_hat
# Flared_trousers
# Asyn_remains
# White_mace
# Dragon_cane
# Steel_trimmed_set_(lg)
# Zamorak_armour_set_(lg)
# Necklace_mould
# Zenyte_ring
# Super_strength(3)
# Stew
# Gout_tuber
# Woad_seed
# Red_d'hide_chaps
# Dragon_arrow
# Infinity_bottoms
# Potato_with_butter
# Adamant_platelegs_(t)
# Super_restore(1)
# Spicy_minced_meat
# Blue_beret
# Super_defence(1)
# Black_mace
# Rune_full_helm
# Cream_hat
# Skeletal_boots
# White_firelighter
# Steel_plateskirt_(t)
# Opal_dragon_bolts
# Tuna_potato
# Graahk_headdress
# White_platebody
# Bandos_rune_armour_set_(lg)
# Dorgeshuun_crossbow
# Spiked_boots
# Blamish_bark_shell
# Ranging_mix(2)
# Morrigan's_throwing_axe
# Runite_crossbow_(u)
# Piscarilius_banner
# Choc_saturday
# Teak_bird_house
# Ancient_kiteshield
# Potatoes(10)
# Obsidian_platelegs
# Dragonstone_bracelet
# Raw_bass
# Adamantite_limbs
# Black_gold-trimmed_set_(sk)
# Super_def._mix(2)
# Adamant_trimmed_set_(lg)
# Strawberries(5)
# Lean_snail_meat
# Adamant_javelin(p+)
# Adamant_hasta(p+)
# Papaya_tree_seed
# 3rd_age_full_helmet
# Four-poster_bed
# Arctic_pyre_logs
# Bandos_stole
# Achey_tree_logs
# Amulet_of_magic_(t)
# Topaz_bolts_(e)
# Katana
# Dust_battlestaff
# Shears
# Ball_of_wool
# Dragon_dart_tip
# Willow_blackjack(o)
# Ring_of_pursuit
# Magic_roots
# Team-16_cape
# Tortoise_shell
# Dragonfruit_sapling
# Hood_of_darkness
# Fremennik_brown_shirt
# Dragon_plateskirt
# Pizza_base
# Steel_thrownaxe
# Gilded_hasta
# Rune_dart(p++)
# Hat_eyepatch
# Limpwurt_root
# Super_defence(4)
# Berserker_necklace
# Pot_of_flour
# Small_fishing_net
# Rune_arrow
# Steel_knife
# Bronze_kiteshield_(g)
# Fremennik_purple_cloak
# Desert_devil_fur
# Carved_oak_table
# Spiny_helmet
# Dragonfruit
# Armadyl_dragonhide_set
# Uncut_jade
# Graahk_fur
# Ancient_crozier
# Iron_pickaxe
# Jar_of_stone
# Knife
# Mithril_arrow(p)
# Mithril_dart_tip
# Godsword_blade
# Anti-venom(2)
# Rolling_pin
# Cod
# Dark_tuxedo_shoes
# Bronze_spear(p)
# Grimy_snapdragon
# Dragon_kiteshield
# Grimy_tarromin
# Dwellberry_seed
# Fancy_hedge
# Adamant_knife(p)
# Rune_dagger(p)
# Saradomin_hilt
# Earth_orb
# Unfired_bowl
# Emerald_amulet
# Abyssal_dagger_(p++)
# Teak_fancy_dress_box
# Rope
# Bronze_platelegs_(t)
# Seaweed
# Oak_clock
# Guam_potion_(unf)
# Sacred_oil(1)
# Yew_longbow
# Raw_manta_ray
# Kodai_insignia
# Oak_fancy_dress_box
# Oak_longbow_(u)
# Red_spiders'_eggs
# Adamant_helm_(h4)
# Thin_snail
# Rainbow_fish
# Team-20_cape
# Obsidian_cape
# Dragon_longsword
# Tatty_larupia_fur
# Ensouled_chaos_druid_head
# White_beret
# Cowhide
# Purple_firelighter
# Adamant_kiteshield_(t)
# Extended_antifire(1)
# Goat_horn_dust
# Fedora
# Pineapple_ring
# Leaping_sturgeon
# Magic_seed
# Cannon_base
# Mushroom_potato
# Sliced_banana
# Redwood_sapling
# Kebbit_teeth
# Mystic_fire_staff
# Adamant_bolts_(p)
# Cornflour
# Soul_rune
# Mithril_platebody_(g)
# Steel_boots
# Black_dragon_mask
# Chef's_hat
# Green_dragon_mask
# Shield_right_half
# Cake_tin
# Basket
# Mahogany_plank
# Maple_seed
# Mithril_arrow(p++)
# Grimy_torstol
# Guthix_kiteshield
# Guthix_platelegs
# Snape_grass
# Rune_crossbow
# Karil's_leatherskirt
# Bronze_knife(p)
# Adamant_crossbow_(u)
# Orange_salamander
# Dragon_pickaxe_upgrade_kit
# White_med_helm
# Steel_arrow(p)
# Mithril_knife(p++)
# Adamant_arrow(p++)
# Black_wizard_robe_(t)
# Adamant_javelin(p++)
# Combat_mix(2)
# Green_dragon_leather
# Iron_arrowtips
# Green_dragonhide_set
# Silver_bolts_(p+)
# Bones_to_peaches
# Sapphire_dragon_bolts
# Dragon_bitter
# Zamorak_monk_top
# Death_rune
# Deerstalker
# Elemental_talisman
# Zamorak_platebody
# Dragon_boots_ornament_kit
# Ensouled_demon_head
# Edible_seaweed
# Skeletal_bottoms
# Shaman_mask
# Grimy_dwarf_weed
# Spirit_shield
# Yew_bird_house
# Emerald
# Graahk_legs
# Torag's_platebody
# Premade_worm_hole
# Unlit_bug_lantern
# Spectral_spirit_shield
# Bucket
# Iron_kiteshield
# Zamorak_mix(2)
# Staff_of_light
# Apples(5)
# Book_of_law_page_set
# Steel_claws
# Teak_kitchen_table
# Marrentill_potion_(unf)
# Zamorak_brew(2)
# Guthix_rest(4)
# Adamant_shield_(h4)
# Red_gloves
# Ankou_mask
# 3rd_age_pickaxe
# Super_def._mix(1)
# Blue_d'hide_chaps_(g)
# Saradomin_coif
# Saradomin_page_4
# Black_boater
# Chilli_con_carne
# Gilded_armour_set_(lg)
# Rune_dagger(p++)
# Halloween_mask_set
# Agility_potion(2)
# Jade_dragon_bolts_(e)
# Te_salt
# Raw_rat_meat
# Attack_potion(2)
# Grimy_kwuarm
# Black_platebody_(g)
# Rune_arrow(p+)
# Armadyl_page_1
# Grand_seed_pod
# Extended_antifire_mix(1)
# Steel_dagger(p++)
# Botanical_pie
# Ring_of_nature
# Lovakengj_hood
# Manta_ray
# Steel_dart_tip
# Soda_ash
# Team-29_cape
# Guthan's_platebody
# Javelin_shaft
# Enchant_sapphire_or_opal
# Rune_knife(p+)
# Lantadyme
# Adamant_platelegs
# Odium_ward
# Samurai_boots
# Pink_boater
# Dwarven_helmet
# Bronze_hasta
# Iron_limbs
# Premade_w'm_batta
# Red_boater
# Bronze_javelin(p)
# Magic_comp_bow
# Bounty_teleport_scroll
# Asgarnian_ale(4)
# Cyclops_head
# Zamorak_hilt
# Iron_spear(p)
# Kebab
# Hosidius_scarf
# Teak_dresser
# Guthix_stole
# Shayzien_banner
# Amulet_of_accuracy
# Rune_hasta(p+)
# Adamant_warhammer
# Iron_ore
# Jade_ring
# Lava_rune
# Adamantite_bar
# Dragon_thrownaxe
# Jangerberries
# Coal
# Granite_body
# Iron_platebody_(t)
# Steel_arrow(p++)
# Premade_ttl
# Desert_goat_horn
# Cadava_berries
# Vesta's_spear
# Ham_cloak
# Mithril_javelin_heads
# Fire_orb
# Rune_chainbody
# Black_robe
# M._treasure_chest
# Skills_necklace(6)
# Iron_halberd
# Oak_longbow
# Dragon_bolts_(p++)
# Imp_mask
# Mithril_set_(lg)
# Rune_kiteshield_(t)
# Mith_grapple_tip
# Skills_necklace
# Dragon_axe
# Unholy_symbol
# Iron_axe
# Black_headband
# Raw_summer_pie
# Rune_axe
# Gold_leaf
# Dragon_crossbow
# Ring_of_wealth_(5)
# Magic_bird_house
# Yew_sapling
# Dark_crab
# Super_restore(4)
# Chopped_tomato
# Emerald_bracelet
# Fruit_batta
# Sinew
# Uncut_diamond
# Ancient_chaps
# Oak_dining_table
# Zamorak_monk_bottom
# Red_d'hide_chaps_(g)
# Snapdragon
# Restore_potion(3)
# Tai_bwo_wannai_teleport
# Cooked_jubbly
# Blurberry_special
# Black_dagger(p+)
# Blue_robe_bottoms
# Rune_kiteshield_(g)
# Onyx_bolts
# Team-5_cape
# Adamant_crossbow
# Guthan's_warspear
# Clockwork
# Opal_amulet
# Black_spiky_vambs
# Proselyte_sallet
# Dragon_platebody_ornament_kit
# Golden_statuette
# Body_rune
# Uncut_dragonstone
# Raw_rainbow_fish
# Mith_crossbow
# Adamant_dagger
# Sanguinesti_staff_(uncharged)
# Saw
# Guthan's_helm
# Mos_le'harmless_teleport
# Saradomin_robe_top
# 3rd_age_longsword
# Bloody_bracer
# Mystic_air_staff
# Splitbark_legs
# Zamorak_brew(1)
# Ensouled_horror_head
# Dharok's_helm_0
# Iron_chainbody
# Blue_skirt_(t)
# Avantoe
# Ankou_gloves
# Curry_leaf
# Rune_dagger
# Pot_lid
# Fancy_teak_dresser
# Opal_necklace
# Book_of_darkness_page_set
# Mystic_steam_staff
# White_berries
# Mind_tiara
# Ham_logo
# Red_elegant_blouse
# Pottery_scarab
# Toy_doll
# Justiciar_chestguard
# Double_eye_patch
# Maple_longbow_(u)
# Citizen_shoes
# Expeditious_bracelet
# Armadyl_platebody
# Penguin_mask
# Bronze_set_(sk)
# Heavy_frame
# Tuna_and_corn
# Swamp_weed
# Shade_robe_top
# Rune_pickaxe
# Ensouled_bear_head
# Torag's_platelegs
# Torag's_armour_set
# Runite_bolts_(unf)
# Magic_stock
# Oak_pyre_logs
# Weeds
# Iron_javelin(p)
# Bronze_hasta(p)
# Mahogany_armchair
# Purple_elegant_shirt
# Mithril_bolts
# Opal_bracelet
# Mahogany_magic_wardrobe
# Oak_bed
# Yellow_dark_bow_paint
# Battlestaff
# Marigold_seed
# Ahrim's_robetop
# Wine_of_zamorak
# Earth_rune
# Magic_shortbow_(u)
# Rune_nails
# Toadflax_seed
# Spider_on_shaft
# Harralander_seed
# Left_eye_patch
# Purple_hat
# Raw_herring
# Chopped_garlic
# Dark_tuxedo_jacket
# Iron_bolts_(p++)
# Mahogany_table
# Occult_necklace
# Bandos_plateskirt
# Ruby_bolt_tips
# Dragon_metal_shard
# Odium_shard_3
# Camelot_teleport
# Vampyre_dust
# Flamtaer_hammer
# Dwarf_weed_potion_(unf)
# Restore_mix(2)
# Mystic_water_staff
# Silver_bolts_(p++)
# Magic_longbow
# Cake
# Armadyl_godsword_ornament_kit
# Bronze_full_helm_(g)
# Team-39_cape
# Black_leprechaun_hat
# Topaz_ring
# Ensouled_kalphite_head
# Adamant_hasta(p++)
# Mithril_platebody
# Grog
# Adamant_bolts_(p++)
# Molten_glass
# Guthix_plateskirt
# Teak_sapling
# Black_shield_(h4)
# Black_helm_(h4)
# Greenman's_ale(m)
# Extended_super_antifire(2)
# Zamorak_page_3
# Zenyte
# Raw_yak_meat
# Filled_plant_pot
# Pharaoh's_sceptre
# Bread
# Plank
# Tiara_mould
# Mithril_dart(p)
# Steel_nails
# Insect_repellent
# Lovakengj_scarf
# Mithril_bolts_(unf)
# Oak_treasure_chest
# Opal_amulet_(u)
# Rune_claws
# Black_platelegs_(t)
# Ogre_coffin_key
# Black_beret
# Empty_candle_lantern
# Black_spear(p)
# Yew_comp_bow
# Snake_hide
# Black_set_(sk)
# Rune_knife(p++)
# Relicym's_mix(1)
# Torture_ornament_kit
# Emerald_dragon_bolts
# Helm_of_neitiznot
# Armadyl_d'hide
# Mahogany_toy_box
# Adamant_arrow(p)
# Infinity_hat
# Bronze_set_(lg)
# Rock-shell_helm
# Jute_fibre
# Granite_legs
# Ruby_dragon_bolts_(e)
# Bandos_bracers
# Bronze_trimmed_set_(sk)
# Security_book
# Wild_pie
# Cannon_stand
# Lime_slices
# Super_energy_mix(1)
# Dragon_sq_shield_ornament_kit
# Rune_platelegs_(t)
# Ancient_page_1
# Black_plateskirt_(g)
# Bowl_wig
# Tormented_bracelet
# Steel_knife(p+)
# Zenyte_necklace
# Wood_camo_legs
# Iron_bolts_(p+)
# Brass_key
# Anti-venom+(2)
# Black_wizard_hat_(g)
# Unstrung_heavy_ballista
# Lemon_chunks
# Initiate_sallet
# Team-42_cape
# Irit_seed
# Gold_elegant_legs
# Oak_drawers
# Guthix_page_4
# Box_trap
# Leprechaun_hat
# Oak_sapling
# Hosidius_hood
# Samurai_kasa
# Curry_tree_seed
# Long_kebbit_bolts
# Steel_platelegs_(g)
# Enchanted_hat
# Steel_javelin
# Shortbow
# Bagged_yew_tree
# Axeman's_folly(4)
# Trout
# Topiary_hedge
# Mithril_arrow
# Fremennik_black_cloak
# Skeletal_visage
# Yellow_gloves
# Grimy_irit_leaf
# Black_trimmed_set_(lg)
# Bronze_dart_tip
# Ruby_harvest
# Adamant_gold-trimmed_set_(lg)
# Bronze_dart(p+)
# Tzhaar-ket-om
# Rock-shell_legs
# Red_elegant_skirt
# Ancient_page_4
# White_scimitar
# Bandos_hilt
# Bronze_chainbody
# Rock_thrownhammer
# Tarromin_potion_(unf)
# Rune_med_helm
# Fried_onions
# Prayer_mix(2)
# Bronze_kiteshield
# Mystic_robe_bottom_(dark)
# Guthix_mitre
# Adamant_pickaxe
# Red_topaz_machete
# Bronze_mace
# Mithril_scimitar
# Harralander_potion_(unf)
# Maple_sapling
# Santa_hat
# Limestone_brick
# Snakeskin_shield
# Guthix_bracers
# Pirate's_hat
# Waterskin(4)
# Chopped_ugthanki
# Black_boots
# Rune_hasta(p)
# Acorn
# Kebbit_claws
# Potato_seed
# Dragon_arrow(p++)
# Bronze_dagger(p+)
# Combat_bracelet(6)
# Steel_full_helm
# Abyssal_bracelet(5)
# Iron_scimitar
# Inoculation_bracelet
# Blue_hat
# Rune_full_helm_(g)
# Menaphite_purple_top
# Yellow_robe_bottoms
# Irit_potion_(unf)
# Bronze_thrownaxe
# Sleeping_cap
# Ardougne_teleport
# White_elegant_skirt
# Team-41_cape
# Mining_helmet
# Premade_veg_batta
# Krandorian_hops
# Relicym's_balm(1)
# Blue_skirt_(g)
# Dragon_chainbody
# Steel_javelin(p+)
# Gnome_goggles
# Team-18_cape
# Yellow_feather
# Compost
# Bandos_platelegs
# Combat_potion(4)
# Mithril_platebody_(t)
# Karil's_leatherskirt_0
# Studded_body
# Rune_armour_set_(sk)
# Yanillian_hops
# Amethyst_bolt_tips
# Iron_hasta(p++)
# Fishing_potion(3)
# Godsword_shard_3
# Bass
# Rune_essence
# Dark_fishing_bait
# Ankou's_leggings
# Malediction_shard_2
# Woad_leaf
# Bone_spear
# Purple_elegant_blouse
# Emerald_bolts_(e)
# Amylase_crystal
# Lockpick
# Olive_oil(4)
# Avantoe_seed
# Onyx_amulet_(u)
# Arcane_spirit_shield
# Dragon_bitter(4)
# Abyssal_dagger
# Ivory_comb
# Iron_dart(p)
# Lava_battlestaff
# Ancient_rune_armour_set_(sk)
# Steel_arrow(p+)
# Stone_statuette
# Opal_ring
# Toxic_staff_(uncharged)
# Defence_potion(1)
# Red_cavalier
# Pink_skirt
# Chilli_potato
# Raw_slimy_eel
# Redwood_logs
# Bronze_platebody
# Rune_mace
# Super_restore_mix(1)
# West_ardougne_teleport
# Watermelon
# Sacred_oil(4)
# Restore_mix(1)
# Olive_oil(1)
# Lava_dragon_mask
# Enchant_dragonstone
# Leather_gloves
# Pie_shell
# Malediction_shard_3
# Oak_shortbow_(u)
# Hair
# Limpwurt_seed
# Copper_ore
# Black_unicorn_mask
# Explorer_backpack
# Black_cape
# Shaving_stand
# Fried_mushrooms
# Yellow_boots
# Snakeskin_chaps
# Rune_sword
# Rune_arrowtips
# Guthix_balance(1)
# Adamant_arrow(p+)
# Topaz_bolts
# Mithril_ore
# Slayer_bell
# Sapphire_amulet
# Royal_gown_bottom
# Cooked_slimy_eel
# Mithril_full_helm
# Garlic
# Strength_potion(1)
# Studded_chaps_(t)
# Jug
# Bowl
# Rock-shell_boots
# Royal_gown_top
# Rune_scimitar
# Uncooked_dragonfruit_pie
# Kharyrll_teleport
# Loop_half_of_key
# Amulet_of_glory(6)
# Green_elegant_legs
# Crude_chair
# Maple_roots
# Ahrim's_armour_set
# Superantipoison(1)
# Crier_hat
# Earth_talisman
# Bronze_longsword
# Chaos_rune
# Defence_potion(3)
# Green_d'hide_body
# Emerald_dragon_bolts_(e)
# Doogle_leaves
# Pie_dish
# Holy_mould
# Twisted_bow
# Mithril_dart
# Fremennik_gloves
# Mithril_sq_shield
# Swamp_lizard
# Highwayman_mask
# Dragon_spear
# Pirate_hat_&_patch
# Ruby_dragon_bolts
# Zenyte_bracelet
# Ancient_rune_armour_set_(lg)
# Flattened_hide
# Black_cane
# Drift_net
# Charcoal
# Whiteberry_seed
# Nardah_teleport
# Steel_bolts_(p+)
# Adamant_dagger(p)
# Ranarr_potion_(unf)
# Green_d'hide_chaps_(g)
# Onyx_bolt_tips
# Butterfly_net
# Guthix_robe_top
# Toktz-mej-tal
# Butterfly_jar
# Mud_rune
# Marble_cape_rack
# Obsidian_cape_(r)
# Ensouled_dagannoth_head
# Ensouled_tzhaar_head
# Carved_oak_magic_wardrobe
# Maple_shield
# Superantipoison(4)
# Red_elegant_legs
# Holy_blessing
# Bucket_of_sap
# Black_claws
# Zuriel's_staff
# Ugthanki_kebab
# Dragon_harpoon
# Zamorakian_hasta
# Magic_logs
# Black_shield_(h2)
# Dragon_hasta
# Red_headband
# Small_box_hedge
# Seed_dibber
# Ogre_arrow
# Arcane_sigil
# Amulet_of_glory_(t)
# Casket
# Eternal_gem
# Briefcase
# Granite_clamp
# Willow_comp_bow
# Ancient_mitre
# Skeletal_helm
# Smoke_rune
# Wizard_boots
# Morrigan's_javelin
# Steel_dagger
# Black_elegant_legs
# Team-49_cape
# Amethyst_arrow
# Uncut_red_topaz
# Kodai_wand
# Toxic_blowpipe_(empty)
# Crystal_seed
# Iron_dart(p++)
# Sanfew_serum(4)
# Steel_trimmed_set_(sk)
# Uncharged_toxic_trident
# Super_combat_potion(1)
# Desert_top
# Rune_boots
# Black_helm_(h2)
# Bones
# Saradomin_brew(1)
# Grey_robe_bottoms
# Toad's_legs
# Ancient_totem
# Menaphite_red_kilt
# Battlemage_potion(4)
# White_headband
# Bagged_flower
# Menaphite_purple_hat
# Rune_shield_(h3)
# Gloves_of_silence
# Toy_doll_(wound)
# Bottle_of_wine
# Bagged_plant_1
# Berserker_ring
# Iron_gold-trimmed_set_(sk)
# Mithril_bolts_(p+)
# Red_halloween_mask
# Guthix_page_2
# Kitchen_table
# Bronze_hasta(p++)
# Chef's_delight(4)
# Revenant_cave_teleport
# Ahrim's_robetop_0
# Mage's_book
# Black_dart(p)
# Bucket_helm_(g)
# Adamant_dagger(p++)
# Mole_claw
# Black_tourmaline_core
# Emerald_ring
# Vesta's_longsword
# Dark_tuxedo_cuffs
# Dragonfire_ward
# Gloves_of_darkness
# Ham_boots
# Sliced_mushrooms
# Red_feather
# Raw_dark_crab
# Battlemage_potion(1)
# Oak_bench
# Spotted_cape
# Armadyl_plateskirt
# Cocktail_glass
# Dragon_med_helm
# Uncut_emerald
# Rune_dart(p+)
# Anti-venom(3)
# Fury_ornament_kit
# Redberry_seed
# Iron_spear(p++)
# Tomato_seed
# Black_dragonhide
# Body_talisman
# Bronze_battleaxe
# Barrows_teleport
# Red_partyhat
# Potato
# Zamorakian_spear
# Zamorak_godsword
# Blue_cape
# Uncooked_berry_pie
# Extended_super_antifire(4)
# Blue_spiky_vambs
# Steel_dart(p)
# Oak_wardrobe
# Bronze_axe
# Raw_ugthanki_meat
# Obsidian_platebody
# Dragon_javelin(p+)
# Blue_robe_top
# Dragonstone_amulet_(u)
# Ashes
# Torstol_potion_(unf)
# Ale_yeast
# Zenyte_amulet
# Death_tiara
# Red_d'hide_shield
# Fishing_mix(1)
# Lava_staff_upgrade_kit
# Pith_helmet
# Dragon_full_helm
# Dagannoth_bones
# Bronze_bolts_(p)
# Super_energy(3)
# Xerician_robe
# Frozen_whip_mix
# Rune_kiteshield
# Initiate_cuisse
# Giant_frog_legs
# Uncut_opal
# Raw_swordfish
# Vial_of_water
# Wrath_talisman
# Super_attack(2)
# Mithril_nails
# Strength_amulet_(t)
# Rune_helm_(h1)
# Ancestral_robe_top
# Gilded_plateskirt
# Pink_boots
# Bandos_chestplate
# Raw_beast_meat
# Polar_camo_top
# Varrock_teleport
# Green_d'hide_vamb
# Treasonous_ring
# Blue_wizard_robe_(t)
# Rune_helm_(h3)
# Grimy_harralander
# Black_dragonhide_set
# Cocktail_guide
# Pot_of_cornflour
# Elemental_helmet
# White_dark_bow_paint
# Iron_trimmed_set_(sk)
# Blue_d'hide_shield
# Zamorak_mix(1)
# Marble_magic_wardrobe
# Garden_pie
# Bastion_potion(4)
# Teak_table
# Eclectic_impling_jar
# Poison
# Book_of_balance_page_set
# Pumpkin
# Runite_bar
# Dragonfruit_pie
# Purple_sweets
# Serum_207_(3)
# Samurai_shirt
# Mystic_robe_bottom_(light)
# Brandy
# Magic_box
# Unicorn_horn_dust
# Apple_sapling
# Maple_blackjack(d)
# Pearl_dragon_bolts_(e)
# Bronze_crossbow_(u)
# Pineapple_pizza
# Teak_treasure_chest
# Fiyr_remains
# Team_cape_i
# Tuna
# Zamorak_chaps
# Bronze_plateskirt
# Adamant_dagger(p+)
# Bag_of_salt
# Bandos_crozier
# Agility_potion(4)
# Dragonstone_dragon_bolts_(e)
# Amulet_of_eternal_glory
# Iron_platelegs
# Black_helm_(h5)
# Dragon_scimitar_ornament_kit
# Cured_yak-hide
# Bagged_magic_tree
# Peaceful_blessing
# Coconut
# Diamond_amulet_(u)
# Cider
# Emerald_amulet_(u)
# Antidote++(2)
# Rangers'_tunic
# Greenmans_ale(m4)
# Relicym's_balm(4)
# Amethyst
# Cave_goblin_wire
# Cooked_sweetcorn
# Antifire_mix(1)
# Dragon_warhammer
# Olive_oil(3)
# Granite_helm
# Orange_cape
# Triangle_sandwich
# Ancient_robe_top
# Team-28_cape
# Pirate's_hook
# Blue_dragon_scale
# Monkfish
# Ankou_socks
# Amulet_mould
# Sacred_oil(3)
# Magic_potion(4)
# Axeman's_folly(m)
# Incomplete_light_ballista
# Adamant_platelegs_(g)
# Strength_potion(3)
# Rune_javelin(p)
# Amulet_of_glory_(t6)
# Green_dye
# Orange_tree_seed
# Water_tiara
# Super_antifire_potion(3)
# Steel_hasta(p+)
# Avernic_defender_hilt
# Mithril_thrownaxe
# Split_log
# Skills_necklace(4)
# Steam_battlestaff
# Games_necklace(8)
# Zamorak_page_4
# Dragonfire_shield
# Pineapple
# Rune_plateskirt_(t)
# Gianne's_cook_book
# Big_fishing_net
# White_boater
# Bronze_spear(p++)
# Hunter_potion(1)
# Iron_plateskirt_(g)
# Rabbit_snare
# Black_platebody
# Diamond_amulet
# Sapphire_dragon_bolts_(e)
# Ahrim's_hood_0
# Egg
# White_cavalier
# 3rd_age_kiteshield
# Pyrophosphite
# Calquat_sapling
# Light_bow_tie
# Saradomin_bracers
# Nunchaku
# Saradomin_mjolnir
# Light_orb
# Feldip_hills_teleport
# Beanie
# Elemental_shield
# Black_trimmed_set_(sk)
# Black_platelegs
# Rune_helm_(h2)
# Mature_cider
# Monocle
# Digsite_teleport
# Ancient_stole
# 3rd_age_cloak
# Unfired_pot
# Shoe_box
# Iron_plateskirt_(t)
# Crushed_nest
# Half_moon_spectacles
# Amulet_of_fury
# Zamorak_robe_top
# Zenyte_amulet_(u)
# Mithril_full_helm_(t)
# Uncooked_apple_pie
# Extended_antifire(3)
# Dragon_limbs
# Karil's_crossbow_0
# Water_talisman
# Ring_of_life
# Sandstone_(2kg)
# Mystic_robe_top
# Relicym's_mix(2)
# Dragon_bitter(m4)
# Essence_impling_jar
# Oak_armour_case
# Bronze_bolts
# Zamorak's_grapes
# Gnomish_firelighter
# Iron_arrow(p)
# Rock-shell_shard
# Rune_shield_(h5)
# Willow_branch
# Mummy's_legs
# Evil_chicken_wings
# Rock-shell_plate
# Jade_dragon_bolts
# Bob's_purple_shirt
# Teak_stock
# Raw_sardine
# Maple_longbow
# Sapphire
# Adamant_full_helm_(t)
# Amethyst_javelin(p)
# Roast_bird_meat
# Amethyst_broad_bolts
# Amulet_of_strength
# Mithril_arrowtips
# Sanfew_serum(1)
# Raw_trout
# Strength_potion(4)
# Stamina_mix(1)
# Opal_machete
# Saradomin_page_1
# Cadantine
# Mahogany_bookcase
# Magic_shortbow_scroll
# Lime_chunks
# Antifire_mix(2)
# Chocolate_cake
# Saradomin_crozier
# Team-3_cape
# Pyre_logs
# Dragon_metal_slice
# Bowl_of_water
# Raw_admiral_pie
# Citizen_top
# Jug_of_water
# Teak_armour_case
# Green_halloween_mask
# Gold_ore
# Mind_talisman
# Wyvern_bones
# Bowl_of_hot_water
# Barley_seed
# Rune_trimmed_set_(lg)
# Boots_of_darkness
# Crossbow
# Draynor_manor_teleport
# Abyssal_dagger_(p)
# Ancient_mace
# Necklace_of_passage(5)
# Super_defence(2)
# Black_shield_(h5)
# Kebbit_bolts
# Blue_firelighter
# Verac's_brassard_0
# Willow_blackjack(d)
# Fire_rune
# Cooked_meat
# Staff_of_earth
# Raw_wild_pie
# White_bead
# Dragon_dart(p++)
# Verac's_helm_0
# Calquat_tree_seed
# Stony_basalt
# Black_elegant_shirt
# Splitbark_gauntlets
# White_elegant_blouse
# Water_rune
# Blue_dragonhide_set
# Eternal_crystal
# Black_gold-trimmed_set_(lg)
# Right_eye_patch
# Ring_of_dueling(8)
# Mixed_flowers
# Diamond_bolt_tips
# Bucket_of_water
# Bandos_rune_armour_set_(sk)
# Incomplete_heavy_ballista
# Black_longsword
# Armadyl_page_3
# Banana_sapling
# Raw_rabbit
# Fremennik_blue_shirt
# Equa_leaves
# Infinity_top
# Rock_hammer
# 3rd_age_vambraces
# Bracelet_mould
# Abyssal_dagger_(p+)
# Maple_shortbow_(u)
# Studded_chaps
# Jute_seed
# Steel_platelegs_(t)
# Guthix_coif
# Mysterious_emblem
# Diamond_bolts
# Strawberry
# Blue_dark_bow_paint
# Hammer
# Initiate_harness_m
# Light_tuxedo_shoes
# Iron_bolts_(p)
# Saradomin_page_2
# New_crystal_shield
# Premade_dr'_dragon
# Bone_dagger_(p)
# Nature_tiara
# Runite_bolts_(p++)
# Fishing_potion(1)
# Rune_arrow(p)
# Dexterous_prayer_scroll
# Magic_potion(2)
# Iron_sq_shield
# Bronze_spear
# Bronze_limbs
# Ugthanki_&_onion
# Cannon_barrels
# Black_sq_shield
# Grape_seed
# Amethyst_javelin(p++)
# Guardian_boots
# Super_antifire_potion(2)
# Saradomin_godsword_ornament_kit
# Iron_sword
# Adamant_javelin_heads
# Willow_logs
# Proboscis
# Iron_platebody_(g)
# Adamantite_nails
# Yew_shortbow_(u)
# Spined_chaps
# Light_tuxedo_jacket
# Pearl_dragon_bolts
# Wildblood_hops
# Ancient_bracers
# Spotted_kebbit_fur
# Dragon_javelin
# Adamant_sq_shield
# Team-44_cape
# Lassar_teleport
# Seasoned_sardine
# Blue_d'hide_chaps_(t)
# Supercompost
# Rune_spear(p++)
# White_plateskirt
# Cavalier_mask
# Desert_boots
# Apple_mush
# Spatula
# Zamorak_d'hide
# Occult_ornament_kit
# A_powdered_wig
# Bagged_sunflower
# Superior_dragon_bones
# Crier_coat
# Bandos_godsword
# Spider_on_stick
# Uncut_sapphire
# Ruby_amulet_(u)
# Chef's_delight(m4)
# Purple_elegant_skirt
# Mystic_smoke_staff
# Sandstone_(5kg)
# Kyatt_top
# Oyster_pearls
# Burnt_bones
# Opal
# Fancy_tiara
# Vodka
# Vegetable_batta
# 3rd_age_range_top
# Magic_mix(2)
# Iron_spit
# Saradomin_armour_set_(sk)
# Ring_of_wealth_scroll
# Black_knife(p++)
# Harralander
# Guthix_mjolnir
# Antipoison_mix(2)
# Stretched_hide
# Topaz_necklace
# Proselyte_cuisse
# Rune_helm_(h5)
# Team_cape_zero
# White_magic_staff
# 3rd_age_robe_top
# Papaya_fruit
# Staff_of_water
# Asgarnian_ale
# Dynamite
# Ribcage_piece
# Steel_platebody_(g)
# Unholy_book_page_set
# Gold_bracelet
# Iron_dart_tip
# Premade_sgg
# Goblin_book
# Pink_cape
# Ancient_platebody
# Mort'ton_teleport
# Cosmic_rune
# Black_spear(p+)
# Bronze_arrow
# Silver_dust
# Cup_of_tea
# Torag's_hammers_0
# Bronze_dagger(p)
# Adamant_med_helm
# Runite_ore
# Iron_bar
# Air_orb
# Black_chainbody
# Ahrim's_hood
# Polar_camo_legs
# Graahk_top
# Iron_platelegs_(g)
# Energy_potion(3)
# 3rd_age_amulet
# Drake's_claw
# Desert_shirt
# Fibula_piece
# Bryophyta's_staff_(uncharged)
# Insulated_boots
# Red_dragon_mask
# Ruby_amulet
# Wooden_bed
# Black_helm_(h3)
# Rune_dart(p)
# White_apron
# Armadyl_page_2
# Yew_seed
# Cream_robe_top
# Guthix_dragonhide_set
# Cup_of_water
# Pineapple_sapling
# Larupia_top
# Energy_potion(4)
# Leather
# Oak_shaving_stand
# Willow_longbow_(u)
# Big_bones
# Malediction_ward
# Zombie_head
# Craw's_bow_(u)
# Zamorak_brew(4)
# Willow_roots
# Ward_upgrade_kit
# Earmuffs
# Oak_blackjack(d)
# Arceuus_scarf
# Elysian_sigil
# Marigolds
# Red_beret
# Tanzanite_fang
# Headless_arrow
# Green_cape
# Cooked_crab_meat
# King_worm
# Linen
# Enchant_emerald_or_jade
# Purple_boater
# Slayer's_respite(m)
# Opulent_table
# Lumbridge_teleport
# Iron_platelegs_(t)
# Saradomin_brew(2)
# Bark
# Diamond_bolts_(e)
# Adamant_helm_(h1)
# Barb_bolttips
# Ruby_ring
# Jade_amulet_(u)
# Spiky_vambraces
# Ancestral_hat
# Oyster
# Tooth_half_of_key
# Fremennik_boots
# Blue_boater
# Anchovies
# Shield_left_half
# Yew_logs
# Raw_sea_turtle
# Ancient_crystal
# Red_spiky_vambs
# Magic_essence_mix(1)
# Light_ballista
# Jar_of_sand
# Paddewwa_teleport
# Zenyte_shard
# 3rd_age_robe
# Yellow_partyhat
# Toad_crunchies
# Attack_potion(1)
# Mummy's_body
# Swamp_toad
# Redberries
# Amethyst_arrow(p++)
# Green_elegant_blouse
# Black_platelegs_(g)
# Ranging_mix(1)
# White_longsword
# Turquoise_hat
# Fire_battlestaff
# Onyx_bracelet
# Air_battlestaff
# Rune_2h_sword
# Fremennik_grey_shirt
# Iron_trimmed_set_(lg)
# Odium_shard_2
# Black_set_(lg)
# Mithril_dart(p++)
# Bandos_tassets
# Guthix_armour_set_(lg)
# Bob's_green_shirt
# Christmas_cracker
# Super_combat_potion(2)
# Gold_elegant_shirt
# Teak_logs
# Guthix_rest(2)
# Prayer_mix(1)
# Steel_gold-trimmed_set_(lg)
# Dragon_spear(p+)
# Air_talisman
# Mummy's_hands
# Adamant_thrownaxe
# Green_dark_bow_paint
# Pink_hat
# Carved_teak_magic_wardrobe
# Dragon_2h_sword
# Admiral_pie
# Dark_cavalier
# Team-2_cape
# Bronze_sq_shield
# Bronze_full_helm_(t)
# Brown_headband
# Empty_fishbowl
# Verac's_brassard
# Team-15_cape
# Anti-poison_supermix(2)
# Steel_2h_sword
# Premade_t'd_batta
# Ancient_full_helm
# Blue_flowers
# Adamant_javelin
# Ranging_potion(3)
# Crier_bell
# Dragon_dagger(p)
# Fremennik_robe
# Mithril_seeds
# Body_tiara
# White_gloves
# Antipoison(4)
# Arena_book
# Bandos_page_2
# Runite_bolts_(p+)
# Purple_elegant_legs
# Ensouled_abyssal_head
# Dust_rune
# Hunter_potion(3)
# Jar_of_miasma
# Gilded_boots
# Gilded_sq_shield
# Green_partyhat
# Premade_wiz_blz'd
# Wood_dining_table
# Dragon_sq_shield
# Adamant_boots
# Zamorak_plateskirt
# Team-19_cape
# White_lily_seed
# Karambwan_vessel
# Magic_shield
# Torag's_platelegs_0
# Dragonstone_ring
# Enchanted_robe
# Mahogany_bench
# Red_bead
# Pirate_boots
# Wrapped_oomlie
# Frog-leather_chaps
# Odium_shard_1
# Iron_bolts
# Vial_of_blood
# Attack_mix(1)
# Premade_veg_ball
# Lobster_pot
# Staff_of_air
# Phrin_remains
# Studded_body_(g)
# Bronze_javelin
# Dareeyak_teleport
# Crushed_superior_dragon_bones
# Cream_boots
# Iron_nails
# Lean_snail
# Ranger_boots
# Ancient_plateskirt
# Steel_spear(p)
# Ensouled_dragon_head
# Grimy_marrentill
# Greater_demon_mask
# Thammaron's_sceptre_(u)
# Ancestral_robe_bottom
# Pink_headband
# Binding_necklace
# Antipoison_mix(1)
# Yanillian_seed
# Wizard_hat
# Dharok's_greataxe
# Mithril_chainbody
# Grimy_ranarr_weed
# Topaz_dragon_bolts_(e)
# Premade_c+t_batta
# Oil_lantern_frame
# Gilded_2h_sword
# Adamant_platebody_(g)
# Skewer
# Ham_robe
# Polished_buttons
# Ballista_spring
# Musketeer_hat
# Black_nails
# Dragon_javelin(p)
# Guthix_cloak
# Bronze_2h_sword
# Strange_fruit
# Steel_set_(lg)
# Diamond_dragon_bolts_(e)
# Steel_crossbow_(u)
# Red_d'hide_chaps_(t)
# Jar_of_dirt
# Rune_knife(p)
# Oak_logs
# Ham_hood
# Ancient_d'hide_boots
# Guthix_balance(2)
# Splitbark_helm
# White_partyhat
# Emerald_necklace
# Mithril_claws
# Big_pirate_hat
# Snapdragon_potion_(unf)
# Super_kebab
# Sapphire_amulet_(u)
# Amethyst_javelin_heads
# White_toy_horsey
# Steel_arrowtips
# Desert_robe
# Green_boater
# Mind_rune
# Zamorak_platelegs
# Ensouled_minotaur_head
# Regen_bracelet
# Blue_dragon_leather
# Nice_hedge
# Bronze_halberd
# White_2h_sword
# Evil_chicken_head
# Magic_string
# Armadyl_platelegs
# Raw_lobster
# Jade_amulet
# Oak_shortbow
# Mort_myre_fungus
# Adamant_knife(p++)
# Dragon_javelin_heads
# Bronze_arrow(p+)
# Redwood_pyre_logs
# Drake's_tooth
# Ancient_effigy
# Unstrung_light_ballista
# Premade_ch'_crunch
# Teak_magic_wardrobe
# Steel_brutal
# Bronze_dagger(p++)
# Mummy's_head
# Mithril_set_(sk)
# Bagged_bluebells
# Larupia_fur
# Mithril_sword
# Dragon_claws
# Wizard_blizzard
# Pink_elegant_blouse
# Musketeer_tabard
# Dwellberries
# Black_skirt
# Clay
# Steel_med_helm
# White_flowers
# Saradomin_mitre
# Adamant_spear(p+)
# Mithril_hasta(p+)
# Oak_dresser
# Dragon_metal_lump
# Snakeskin_boots
# Veg_ball
# Spined_helm
# Grey_wolf_fur
# Super_antifire_mix(2)
# Belladonna_seed
# Rune_battleaxe
# Rake
# Saradomin_chaps
# Guthix_chaps
# Keg_of_beer
# Blue_d'hide_body_(g)
# Flamtaer_bracelet
# Guam_seed
# Carved_teak_bench
# Orange_flowers
# Strawberry_seed
# Grimy_lantadyme
# Staff
# Volcanic_ash
# Nose_peg
# Greenman's_ale
# Snakeskin_vambraces
# Raw_pike
# Druid's_robe
# Gold_amulet_(u)
# Super_antifire_potion(4)
# Egg_and_tomato
# Snakeskin_body
# Premade_fr'_blast
# Toy_soldier_(wound)
# Mahogany_cape_rack
# Uncut_ruby
# Guthix_balance(4)
# Fremennik_teal_cloak
# Basalt
# Royal_crown
# Barrel
# Dragon_battleaxe
# Lovakengj_banner
# Archery_ticket
# Jade_bracelet
# Team-48_cape
# Gold_ring
# Hunting_mix(2)
# Obsidian_helmet
# Arrow_shaft
# Charge_dragonstone_jewellery_scroll
# Bronze_crossbow
# Rabbit_foot
# Blue_d'hide_body_(t)
# Zamorak_mjolnir
# Toy_mouse
# Super_energy(1)
# Mithril_trimmed_set_(sk)
# Combat_mix(1)
# Partyhat_&_specs
# Bronze_knife(p+)
# Lantern_lens
# Adamant_hasta
# Karil's_coif_0
# Steel_bolts
# Attack_potion(3)
# Desert_robes
# Pot
# Enchanted_top
# Thatch_spar_med
# Teak_drawers
# Steel_kiteshield_(g)
# Mithril_kiteshield_(g)
# Tinderbox
# Ancient_wyvern_shield
# Willow_blackjack
# Hardleather_body
# Blessed_spirit_shield
# Mummy's_feet
# Granite_ring
# Ruby
# Irit_leaf
# Tatty_kyatt_fur
# Oak_magic_wardrobe
# Opal_bolts
# Black_d'hide_chaps
# Sanfew_serum(2)
# Team-11_cape
# Dragon_bolts_(unf)
# Cheese
# Mystic_mud_staff
# Apprentice_wand
# Dashing_kebbit_fur
# Jungle_camo_legs
# Shrunk_ogleroot
# Pineapple_punch
# Uncut_zenyte
# Super_energy(2)
# Gnomeball
# Moonlight_mead(m4)
# Mithril_knife
# Iron_dagger(p)
# White_sword
# Gilded_platelegs
# Slayer's_enchantment
# Bronze_wire
# Orange_slices
# Orange_boater
# Broad_bolts
# Bronze_scimitar
# Saradomin_dragonhide_set
# Mind_bomb(4)
# Leaping_salmon
# Armadyl_godsword
# Black_dagger(p)
# Extended_super_antifire(1)
# Harpoon
# Goblin_mask
# Leather_body
# Guam_tar
# White_platelegs
# Unfired_pie_dish
# Verac's_helm
# Zulrah's_scales
# Snowy_knight
# Tan_cavalier
# Armadyl_crozier
# Broken_bark_snelm
# Cider(4)
# Guthan's_helm_0
# Sapphire_bolts_(e)
# Ham_gloves
# Bone_dagger
# Silver_ore
# Dragon_bitter(m)
# Staff_of_fire
# White_kiteshield
# Tall_box_hedge
# Initiate_hauberk
# Green_headband
# White_claws
# Willow_shortbow_(u)
# Armadyl_page_4
# Rune_brutal
# Karil's_leathertop_0
# Tarromin
# Purple_robe_bottoms
# Skeletal_gloves
# Steel_pickaxe
# Chaos_talisman
# Armadyl_helmet
# Adamant_battleaxe
# Lava_scale_shard
# Dragon_hunter_lance
# Ranarr_weed
# Weapon_poison(+)
# Amulet_of_glory(4)
# Thin_snail_meat
# Steel_knife(p++)
# Team-45_cape
# Ensouled_monkey_head
# Fremennik_brown_cloak
# Enchant_diamond
# Cheese+tom_batta
# Lumberyard_teleport
# Hammerstone_seed
# Bottomless_compost_bucket
# Black_cavalier
# Chocchip_crunchies
# Soft_clay
# Menaphite_red_top
# Chocolate_dust
# Dragon_pickaxe
# Poison_chalice
# Leather_boots
# Strength_mix(1)
# Bronze_dragon_mask
# Black_spear
# Elder_chaos_top
# Sanfew_serum(3)
# Team-21_cape
# Fremennik_blue_cloak
# Guthix_robe_legs
# Arceuus_hood
# Rune_cane
# Raw_shrimps
# Steam_staff_upgrade_kit
# Rune_platelegs
# Cannon_furnace
# Watermelon_seed
# Rune_halberd
# Red_boots
# Ranging_potion(1)
# Steel_kiteshield_(t)
# Coif
# Adamant_dart_tip
# Energy_mix(1)
# Rune_shield_(h2)
# Mithril_bolts_(p++)
# Superantipoison(3)
# Empty_cup
# Dwarven_stout
# Team-9_cape
# Mahogany_stock
# Steel_bolts_(p++)
# Iron_hasta(p+)
# Guthix_crozier
# Teak_cape_rack
# Dragonstone_dragon_bolts
# Steel_bolts_(p)
# Adamant_shield_(h3)
# Saradomin's_light
# Bucket_helm
# Pantaloons
# Adamant_arrowtips
# Watchtower_teleport
# Ensouled_scorpion_head
# Energy_potion(1)
# Mahogany_bird_house
# Shark
# Vial
# Dragon_impling_jar
# Black_full_helm_(g)
# Prayer_potion(4)
# Steel_spear(p++)
# Waterskin(0)
# 3rd_age_range_coif
# Granite_shield
# Willow_stock
# Shayzien_scarf
# Wooden_bench
# Torag's_helm
# Dragon_armour_set_(lg)
# Dragon_necklace
# Restore_potion(4)
# Pie_recipe_book
# Saradomin_plateskirt
# Rune_knife
# Snakeskin_bandana
# Empty_oil_lamp
# Agility_potion(1)
# Black_d'hide_body_(t)
# Pike
# Ring_of_the_gods
# Kebbit_spike
# Bronze_plateskirt_(t)
# White_dagger(p)
# Willow_sapling
# Raw_jubbly
# Silver_sickle
# Dragon_dart
# Black_battleaxe
# Master_wand
# Frying_pan
# Anti-venom(1)
# Lime
# Lantadyme_potion_(unf)
# Mystic_robe_bottom
# Adamant_arrow
# Maple_blackjack(o)
# Monkey_nuts
# Black_d'hide_body_(g)
# Greenmans_ale(4)
# Mithril_kiteshield_(t)
# Anti-venom+(1)
# Zamorak_cloak
# Summer_pie
# Rune_javelin(p++)
# Banana_stew
# Feather
# Mithril_spear(p+)
# Granite_(5kg)
# Skeletal_top
# Maple_logs
# Nail_beast_nails
# Crunchy_tray
# Sweetcorn
# Poison_ivy_seed
# Turquoise_robe_top
# Ring_mould
# Wyrm_bones
# Black_spear(p++)
# Pink_robe_bottoms
# Mystic_robe_top_(light)
# Gilded_four-poster
# Fine_cloth
# Raw_mud_pie
# Silver_bolts_(unf)
# Ring_of_wealth
# Red_salamander
# Steel_warhammer
# Saradomin_stole
# Bandos_page_4
# Saradomin_cloak
# Anguish_ornament_kit
# Moonlight_mead(4)
# Ranarr_seed
# Zamorak_crozier
# Karil's_coif
# Red_topaz
# Iron_boots
# Fish_pie
# Adamant_helm_(h5)
# Clue_box
# Spinach_roll
# Ahrim's_robeskirt_0
# Mort_myre_pear
# Dragonstone_bolt_tips
# Rune_trimmed_set_(sk)
# Ancient_robe_legs
# Asgarnian_hops
# Oak_armchair
# Hosidius_banner
# Strung_rabbit_foot
# Premade_choc_s'dy
# Teak_bed
# Leaping_trout
# Adamant_platebody_(t)
# Ham_shirt
# Serum_207_(2)
# Bob's_black_shirt
# Granite_maul
# Secateurs
# Bird_snare
# Iron_brutal
# Staff_of_the_dead
# Ensouled_ogre_head
# Wooden_stock
# Babydragon_bones
# Berserker_helm
# Oak_bird_house
# Unfinished_broad_bolts
# Saradomin_platebody
# Shayzien_hood
# Toktz-xil-ek
# Dragon_platelegs
# Shortbow_(u)
# Topaz_bolt_tips
# Teak_dining_bench
# Thatch_spar_dense
# Diamond_bracelet
# Green_boots
# Zamorak_armour_set_(sk)
# Ahrim's_staff_0
# Wood_camo_top
# Iron_kiteshield_(t)
# Tome_of_fire_(empty)
# Black_demon_mask
# Bandos_boots
# Battlemage_potion(3)
# Dragon_hasta(p)
# Archers_ring
# Asgarnian_seed
# Zogre_bones
# Tangled_toad's_legs
# Adamant_bolts_(p+)
# Blue_d'hide_vamb
# Black_plateskirt
# Blue_d'hide_chaps
# Adamant_dart(p++)
# Glassblowing_pipe
# Arctic_pine_logs
# Green_robe_top
# Guthix_page_1
# Baked_potato
# Roe
# Rune_shield_(h1)
# Druid's_robe_top
# Adamant_chainbody
# Gilded_bench
# Raw_anchovies
# Bronze_spear(p+)
# Swamp_paste
# Bronze_arrow(p)
# Steel_sq_shield
# Mithril_halberd
# Locust_meat
# Meat_pie
# Teak_seed
# Pineapple_chunks
# Attack_mix(2)
# Marrentill_seed
# Super_potion_set
# Spicy_tomato
# Diamond_dragon_bolts
# Robe_bottom_of_darkness
# Jar_of_darkness
# Bone_dagger_(p+)
# Chaos_tiara
# Gold_headband
# Dark_infinity_colour_kit
# Bob's_blue_shirt
# Skewer_stick
# Bronze_javelin(p++)
# Hammerstone_hops
# Teal_robe_top
# Granite_boots
# Dharok's_greataxe_0
# Lemon
# Dharok's_platebody_0
# Armadyl_mitre
# Lunar_isle_teleport
# Pest_control_teleport
# Fremennik_pink_cloak
# Team-13_cape
# Lemon_slices
# Dragon_hunter_crossbow
# Master_scroll_book_(empty)
# Adamant_halberd
# Team-34_cape
# Shantay_pass
# Redberry_pie
# Combat_potion_set
# Salmon
# Muddy_key
# Menaphite_purple_kilt
# Mahogany_sapling
# Cemetery_teleport
# Team-30_cape
# Magic_shortbow
# Defence_potion(4)
# Bagged_nice_tree
# Sickle_mould
# Adamant_plateskirt
# Red_d'hide_body_(t)
# Team-17_cape
# Bagged_plant_3
# Premade_t'd_crunch
# Green_elegant_skirt
# Rune_hasta(p++)
# Unpowered_orb
# Steel_limbs
# Rune_spear(p)
# Team-33_cape
# Fishing_potion(2)
# Ensouled_troll_head
# Granite_gloves
# Loar_remains
# Super_defence(3)
# Honourable_blessing
# Guthix_rest(3)
# Spicy_sauce
# Gold_elegant_skirt
# Iron_spear(p+)
# Airtight_pot
# Blacksmith's_helm
# Burning_amulet(5)
# Pure_essence
# Raw_cave_eel
# Steel_hasta(p++)
# Serpentine_helm_(uncharged)
# Dwarf_weed_seed
# Iron_mace
# Yak-hide
# Death_talisman
# Ruby_necklace
# Unfinished_potion
# Adamant_spear(p++)
# Bastion_potion(3)
# Monkey_bar
# Bandos_mitre
# Bagged_oak_tree
# Zamorak_bracers
# Tall_fancy_hedge
# Iron_arrow
# Combat_potion(1)
# Menaphite_red_hat
# Bucket_of_sand
# Raw_mackerel
# Iron_full_helm_(t)
# Bronze_bolts_(p++)
# Arcane_prayer_scroll
# Antifire_potion(3)
# Choc-ice
# Raw_chompy
# Compost_potion(2)
# Emerald_bolts
# Tarromin_seed
# Bracelet_of_ethereum_(uncharged)
# Iron_2h_sword
# Extended_antifire(4)
# Rune_dagger(p+)
# Evil_chicken_feet
# Dharok's_platelegs_0
# Armadyl_robe_legs
# Necklace_of_faith
# Adamant_helm_(h3)
# Bronze_boots
# Phoenix_necklace
# Amethyst_javelin
# Bob's_red_shirt
# Steel_axe
# Iron_plateskirt
# Adamant_brutal
# Yellow_cape
# Brine_sabre
# Raw_garden_pie
# Elder_chaos_hood
# Oak_toy_box
# Seercull
# Sardine
# Leather_cowl
# Fremennik_grey_cloak
# Bryophyta's_essence
# Mithril_hasta(p++)
# Monkey_bones
# Cosmic_talisman
# Topaz_dragon_bolts
# Teasing_stick
# Bear_fur
# Ultracompost
# Bolt_mould
# Iron_javelin(p+)
# Dragon_scimitar
# Sandworms
# Redwood_shield
# Iron_spear
# Grimy_toadflax
# Piscarilius_scarf
# Super_restore(3)
# Watermelon_slice
# Limestone
# Partyhat_set
# Weapon_poison(++)
# Stamina_mix(2)
# Bronze_platebody_(g)
# Saradomin_godsword
# Wildblood_seed
# Ranger_gloves
# Logs
# Gianne_dough
# Ring_of_suffering
# White_warhammer
# Gilded_clock
# Fremennik_red_cloak
# Book_of_war_page_set
# Onyx_ring
# Mithril_gold-trimmed_set_(sk)
# Ancient_cloak
# Grimy_guam_leaf
# Amethyst_arrow(p)
# Red_elegant_shirt
# Iron_dart(p+)
# Dragon_kiteshield_ornament_kit
# Bronze_trimmed_set_(lg)
# Grey_boots
# Black_kiteshield_(g)
# Sandstone_(10kg)
# Piscatoris_teleport
# Mithril_spear(p++)
# Opal_dragon_bolts_(e)
# Silver_bolts_(p)
# Raw_fish_pie
# Steel_mace
# Cabbage_round_shield
# Light_frame
# Nature_rune
# Proselyte_hauberk
# Super_combat_potion(3)
# Air_tiara
# Giant_seaweed
# Vyrewatch_shoes
# Hunters'_crossbow
# Amethyst_javelin(p+)
# Magic_cape_rack
# Moonlight_mead
# Jogre_bones
# Mithril_gold-trimmed_set_(lg)
# Antipoison(3)
# White_sq_shield
# Salve_graveyard_teleport
# Nasturtium_seed
# 3rd_age_platebody
# Dragonstone
# Krandorian_seed
# Iron_platebody
# Gilded_armour_set_(sk)
# Raw_anglerfish
# Red_flowers
# Studded_chaps_(g)
# Raw_tuna
# Chef's_delight
# Sacred_oil(2)
# Beer_glass
# Bronze_bolts_(unf)
# Diamond_ring
# Blue_dragonhide
# Apple_pie
# Maple_stock
# Dragon_dart(p+)
# Papyrus
# Pink_elegant_shirt
# Black_sword
# Mystic_earth_staff
# Holy_sandals
# Iron_set_(lg)
# Dragon_chainbody_ornament_kit
# Uncharged_trident
# Ring_of_stone
# Extended_super_antifire_mix(1)
# Coconut_milk
# Monk's_robe
# Potato_cactus
# Dragon_arrow(p)
# Bandit's_brew
# Team-7_cape
# White_dagger
# Bone_dagger_(p++)
# Mahogany_wardrobe
# Ring_of_coins
# Team-1_cape
# Black_full_helm
# Superattack_mix(2)
# Leather_vambraces
# Black_d'hide_chaps_(g)
# Steel_longsword
# Iron_crossbow_(u)
# Combat_potion(2)
# Samurai_gloves
# Mithril_longsword
# Mystic_dust_staff
# Chinchompa
# Karil's_crossbow
# Purple_gloves
# Toadflax_potion_(unf)
# Ancient_blessing
# Infinity_boots
# Strength_mix(2)
# Bronze_bolts_(p+)
# Water_orb
# Burnt_page
# Black_desert_robe
# Ranging_potion(2)
# Gin
# Cooked_oomlie_wrap
# Old_demon_mask
# Dragon_knife
# Eternal_boots
# Green_d'hide_body_(t)
# Monkey_tail
# Purple_dye
# Mirror_shield
# Spade
# Verac's_plateskirt_0
# Gardening_boots
# Team-50_cape
# Toy_mouse_(wound)
# Imbued_heart
# Fayrg_bones
# Dragon_dart(p)
# Steel_dart
# Ancient_emblem
# Adamant_plateskirt_(t)
# Wrath_tiara
# Adamant_trimmed_set_(sk)
# Lava_dragon_bones
# Mithril_javelin(p+)
# Wooden_cat
# Cactus_seed
# Cadantine_seed
# Armadyl_cloak
# Antifire_potion(4)
# Bandos_chaps
# Piscarilius_hood
# Red_dragon_leather
# Thread
# White_dagger(p+)
# Bronze_nails
# Young_impling_jar
# Team-22_cape
# Redwood_bird_house
# Gilded_magic_wardrobe
# Unstrung_symbol
# Uncharged_trident_(e)
# Common_kebbit_fur
# Gilded_chainbody
# Mind_helmet
# Ahrim's_robeskirt
# Ranging_potion(4)
# Agility_mix(2)
# Grimy_avantoe
# Oak_stock
# Iron_javelin_heads
# Magpie_impling_jar
# Senntisten_teleport
# Extended_antifire(2)
# Unholy_blessing
# Rune_spear
# Amulet_of_bounty
# Zamorak_coif
# Armadyl_robe_top
# Toktz-xil-ul
# Iron_full_helm_(g)
# Flighted_ogre_arrow
# Top_hat_&_monocle
# Damaged_monkey_tail
# Cave_eel
# Carved_oak_bench
# Evil_chicken_legs
# Scrambled_egg
# Primordial_crystal
# Verac's_armour_set
# Poison_ivy_berries
# Fire_tiara
# Red_d'hide_body_(g)
# Meat_tenderiser
# Mithril_med_helm
# Asgarnian_ale(m)
# Bandos_cloak
# Gnome_scarf
# Super_strength(4)
# Green_spiky_vambs
# Dark_kebbit_fur
# Agility_mix(1)
# Bronze_javelin(p+)
# Lantadyme_seed
# Bandos_full_helm
# Cup_of_hot_water
# Smouldering_stone
# Purple_robe_top
# Dharok's_helm
# Primordial_boots
# Ensouled_dog_head
# Saradomin's_tear
# Granite_hammer
# Abyssal_bludgeon
# Dragon_spear(p++)
# Law_rune
# Dragon_dagger(p+)
# Dragonbone_necklace
# Iron_knife(p++)
# Zamorak_stole
# Battlemage_potion(2)
# Slayer's_respite
# Bucket_of_wax
# Bronze_arrowtips
# Granite_(2kg)
# Volcanic_whip_mix
# Black_kiteshield
# Dragon_bolts_(p)
# Adamantite_ore
# Mithril_battleaxe
# Adamant_javelin(p)
# Ancient_medallion
# Bottled_dragonbreath_(unpowered)
# Shaikahan_bones
# Rock-shell_gloves
# Dragon_bolts_(p+)
# Statius's_warhammer
# Pearl_bolts
# Icy_basalt
# Super_strength(1)
# Team-4_cape
# Celastrus_sapling
# Premade_p'_punch
# Chef's_delight(m)
# Toy_soldier
# Dark_bow
# Justiciar_armour_set
# White_battleaxe
# Justiciar_legguards
# Blue_dragon_mask
# Gilded_cape_rack
# Yellow_flowers
# Kebbit_teeth_dust
# Prayer_potion(2)
# Axeman's_folly(m4)
# Stone_scarab
# Fish_offcuts
# Mithril_limbs
# Steel_plateskirt_(g)
# Blue_d'hide_body
# Blue_partyhat
# Dharok's_armour_set
# Team-40_cape
# Stamina_potion(1)
# Uncooked_botanical_pie
# Dragon_hasta(kp)
# Antidote+(4)
# Anti-venom+(3)
# Willow_bird_house
# Blue_dye
# Fake_beard
# Teak_pyre_logs
# Warrior_helm
# Bagged_dead_tree
# Navy_cavalier
# Drake_bones
# Super_str._mix(2)
# Egg_whisk
# Light_infinity_colour_kit
# Kyatt_legs
# Bird_house
# Guthix_platebody
# Antipoison(1)
# Crossbow_string
# Garlic_powder
# Torag's_platebody_0
# Bandos_coif
# Steel_dragon_mask
# Mithril_plateskirt
# Heavy_ballista
# Adamant_kiteshield_(g)
# Cocktail_shaker
# Barbed_bolts
# Team-47_cape
# Proselyte_tasset
# Runite_limbs
# Bow_string
# Gold_bar
# Armadyl_hilt
# Steel_plateskirt
# Blue_wizard_robe
# Wolfbone_arrowtips
# Adamant_mace
# Bronze_hasta(p+)
# Cadantine_potion_(unf)
# Mahogany_armour_case
# Dark_trousers
# Oak_chair
# Castle_wars_bracelet(3)
# Saradomin_armour_set_(lg)
# Team-6_cape
# Gilded_wardrobe
# Anti-dragon_shield
# Toktz-ket-xil
# Maple_shortbow
# Fruit_blast
# Red_dragonhide
# Anchovy_pizza
# Fremennik_red_shirt
# Anti-poison_supermix(1)
# Zamorak_page_2
# Ancient_staff
# Marble_block
# Raw_cod
# Kharidian_headpiece
# Oyster_pearl
# Bolt_of_cloth
# Armadyl_chestplate
# Desert_camo_top
# Stamina_potion(4)
# Eye_of_newt
# Mahogany_fancy_dress_box
# Anti-venom(4)
# Magic_stone
# Mort_myre_stem
# Antipoison(2)
# Xerician_top
# Robe_top_of_darkness
# Teak_plank
# Green_robe_bottoms
# Green_hat
# Iron_battleaxe
# Torag's_hammers
# Armadyl_bracers
# Mithril_dagger
# Steel_set_(sk)
# Sea_turtle
# Mahogany_dresser
# Palm_tree_seed
# Vyrewatch_top
# Willow_pyre_logs
# White_unicorn_mask
# Fishing_potion(4)
# Compost_potion(1)
# Ghorrock_teleport
# Oak_kitchen_table
# Super_energy(4)
# Armadyl_chainskirt
# 3rd_age_bow
# Antidote+(1)
# Rune_gold-trimmed_set_(sk)
# Sandstone_(1kg)
# Short_green_guy
# Team-35_cape
# Raw_karambwan
# Prayer_potion(1)
# Blue_wizard_hat_(g)
# Toy_cat
# Fire_talisman
# Royal_sceptre
# Ancient_coif
# Rune_armour_set_(lg)
# Zamorak_dragonhide_set
# Swordfish
# Black_wizard_robe_(g)
# Climbing_boots
# Defence_mix(1)
# Justiciar_faceguard
# Unstrung_comp_bow
# Team-14_cape
# Chopped_tuna
# Mithril_dart(p+)
# Jug_of_wine
# Fly_fishing_rod
# Mushroom_&_onion
# Carrallangar_teleport
# Green_d'hide_chaps_(t)
# Antidote++(1)
# Jangerberry_seed
# White_halberd
# Fishing_bait
# Rune_spear(p+)
# Ugthanki_&_tomato
# Rune_hasta
# Cooked_chicken
# Vyrewatch_legs
# Mithril_full_helm_(g)
# Dragon_knife(p)
# Steel_platebody_(t)
# Efaritay's_aid
# Barley_malt
# Steel_sword
# Team-38_cape
# Lava_scale
# Wyvern_visage
# Steel_hasta
# Blue_feather
# Relicym's_balm(3)
# Comp_ogre_bow
# Chocolate_bar
# Raw_bird_meat
# Steel_crossbow
# Raw_bear_meat
# Bronze_dart(p++)
# Dragonstone_bolts
# Team-8_cape
# Numulite
# Redwood_tree_seed
# Splitbark_body
# Spined_boots
# Armadyl_rune_armour_set_(lg)
# Tin_ore
# Bagged_maple_tree
# Strength_potion(2)
# Tomato
# Onion_seed
# Candle
# Extended_super_antifire_mix(2)
# Mithril_platelegs
# Bullseye_lantern
# Ugthanki_meat
# Iron_knife
# Mystic_mist_staff
# Mithril_crossbow_(u)
# Slayer's_respite(4)
# Cadavaberry_seed
# Fremennik_hat
# Armadyl_stole
# Beer
# Raw_chicken
# Red_robe_bottoms
# Iron_javelin
# Oil_lantern
# Mithril_boots
# Steel_hasta(p)
# Karidian_disguise
# Black_scimitar
# Yew_pyre_logs
# Gold_necklace
# Rocking_chair
# Chopped_onion
# Rosemary
# Onion_&_tomato
# Calcite
# Oranges(5)
# Spider_carcass
# Dharok's_platebody
# Wooden_shield_(g)
# Iron_crossbow
# Teal_robe_bottoms
# Ship_ticket
# Wizard's_mind_bomb
# Adamant_set_(sk)
# Adamant_axe
# Oak_plank
# Tyras_helm
# Ring_of_recoil
# Super_str._mix(1)
# Saradomin_page_3
# Baby_impling_jar
# Iron_arrow(p++)
# Mithril_plateskirt_(g)
# Steel_gold-trimmed_set_(sk)
# Green_dragonhide
# Trident_of_the_seas_(full)
# Armadyl_rune_armour_set_(sk)
# Swamp_tar
# Sweetcorn_seed
# Antidote+(2)
# Bandos_d'hide
# Cider(m4)
# Restore_potion(2)
# Topaz_amulet_(u)
# Steel_dart(p++)
# Granite_(500g)
# Steel_dagger(p+)
# Pearl_bolt_tips
# Astral_rune
# Zamorak_brew(3)
# Pink_robe_top
# Black_knife
# Runite_bolts_(p)
# Mithril_brutal
# Blue_boots
# Topaz_amulet
# Facemask
# Long_kebbit_spike
# Earth_battlestaff
# Worm_crunchies
# Dragon_full_helm_ornament_kit
# Bronze_full_helm
# Compost_potion(4)
# Team-27_cape
# Team-32_cape
# Steel_bar
# Harmony_island_teleport
# Restore_potion(1)
# Bronze_claws
# Dragon_scale_dust
# Unstrung_emblem
# Red_chinchompa
# Steel_javelin(p++)
# Armadyl_full_helm
# Bandos_page_3
# Guthan's_chainskirt_0
# Steel_chainbody
# Ensouled_goblin_head
# Mith_grapple
# Steel_spear(p+)
# Dragon_knife(p++)
# Uncooked_meat_pie
# White_full_helm
# Mature_wmb
# Ancient_page_2
# Adamant_bolts
# Magic_fang
# Obsidian_armour_set
# Ruby_bolts_(e)
# Willow_longbow
# Citizen_trousers
# Blue_skirt
# Ancient_page_3
# Purple_boots
# Rune_shield_(h4)
# Gnome_spice
# Purple_partyhat
# Mithril_spear
# Black_skirt_(g)
# Ring_of_returning(5)
# Urt_salt
# Adamant_set_(lg)
# Saradomin_brew(3)
# Mithril_javelin
# Black_platebody_(t)
# Iron_knife(p+)
# Team_cape_x
# Armadyl_crossbow
# Mithril_warhammer
# Steel_full_helm_(t)
# Unfired_plant_pot
# Mystic_hat_(light)
# Black_knife(p)
# Bronze_sword
# Banana_tree_seed
# Agility_potion(3)
# Yew_shield
# Blue_wizard_hat
# Dragon_arrowtips
# Stronghold_notes
# Mushroom
# Rune_platelegs_(g)
# Gold_elegant_blouse
# Mystic_boots
# Magic_longbow_(u)
# Proselyte_harness_m
# Ancestral_robes_set
# Falador_teleport
# Karil's_armour_set
# Brown_apron
# Uncooked_mushroom_pie
# Guthan's_platebody_0
# Hard_leather_shield
# Archer_helm
# Mithril_dagger(p+)
# Weapon_poison
# Yellow_robe_top
# Drunk_dragon
# Oak_bookcase
# Toad_batta
# Combat_bracelet(4)
# Teak_toy_box
# Holy_book_page_set
# Emerald_bolt_tips
# Mud_pie
# Feldip_weasel_fur
# Toadflax
# Teak_armchair
# Moonlight_mead(m)
# Viggora's_chainmace_(u)
# Premade_w'm_crun'
# Xerician_fabric
# Torag's_helm_0
# Bagged_roses
# Yew_shortbow
# Dragon_sword
# Fat_snail_meat
# Yak-hide_armour
# Bagged_plant_2
# Fremennik_yellow_cloak
# Spottier_cape
# Mist_rune
# Thatch_spar_light
# Antifire_potion(1)
# Bandos_d'hide_boots
# Adamant_knife(p+)
# Gilded_full_helm
# Draconic_visage
# Zamorak_kiteshield
# Bronze_brutal
# Anti-venom+(4)
# Teal_boots
# Gourmet_impling_jar
# Unpowered_symbol
# Wooden_shield
# Cabbages(10)
# Barley
# Red_firelighter
# Rune_sq_shield
# Zamorak_godsword_ornament_kit
# Spined_body
# Black_2h_sword
# Black_d'hide_body
# Brown_toy_horsey
# Yellow_bead
# Zamorak_mitre
# Kwuarm_seed
# Bone_bolts
# Frog-leather_body
# Cooked_chompy
# Steel_javelin(p)
# Amulet_of_avarice
# Whisky
# Ensouled_unicorn_head
# White_dagger(p++)
# Pile_of_salt
# Granite_longsword
# 3rd_age_wand
# Rune_platebody_(t)
# Carved_teak_table
# Team-46_cape
# Super_strength(2)
# Verac's_flail_0

# %%
itemPrices = scraper.loadItemPrices()
# just throw out first 90 days of data?
for item in itemPrices:
    itemPrices[item] = itemPrices[item][90:]

# %%
# Find missing dates
item = 'Dragon_legs/skirt_ornament_kit'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
# Out:
# 89 5232.0 2015-09-22 00:00:00
# 113 72.0 2016-05-20 00:00:00
# 171 120.0 2016-07-19 00:00:00
# 206 48.0 2016-08-27 00:00:00
# 207 72.0 2016-08-29 00:00:00
# 284 528.0 2016-11-16 00:00:00
# 332 96.0 2017-01-24 00:00:00
# 353 48.0 2017-02-17 00:00:00
# 399 192.0 2017-04-05 00:00:00
# 487 120.0 2017-07-09 00:00:00
# 512 72.0 2017-08-07 00:00:00
# 536 48.0 2017-09-02 00:00:00
# 679 48.0 2018-01-24 00:00:00
# 732 48.0 2018-03-19 00:00:00
# 734 48.0 2018-03-22 00:00:00
# 774 48.0 2018-05-02 00:00:00
# 777 48.0 2018-05-06 00:00:00
# 875 48.0 2018-08-13 00:00:00
# 876 48.0 2018-08-15 00:00:00
# 954 48.0 2018-11-02 00:00:00
# 981 48.0 2018-11-30 00:00:00
# 984 48.0 2018-12-04 00:00:00
# 985 48.0 2018-12-06 00:00:00
# 986 48.0 2018-12-08 00:00:00
# 1015 48.0 2019-01-07 00:00:00
# 1016 48.0 2019-01-09 00:00:00
# 0.27113702623906705

# %%
# Find missing dates
total = []
for item in itemPrices:
    if len(itemPrices[item])>0:
        dates = [a[0] for a in itemPrices[item]]
        day = 86400
        hour = 3600
        missing = 0
        for i in range(len(dates)-1):
            diff = dates[i+1]-dates[i]
            if diff<23*hour or diff>25*hour:
                #print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
                missing += int(diff/day)-1
        missRate = missing/len(itemPrices[item])
        total.append(missRate)
        if missing/len(itemPrices[item])>.1:
            print(item,missRate)
# Out:
# Dragon_legs/skirt_ornament_kit 0.27113702623906705

# %%
print(len(total),max(total),min(total),np.mean(total),np.std(total))
# Out:
# 3369 0.27113702623906705 0.0 0.05997011739669579 0.011076035014857169

# %%
plt.hist(total,30)
# Out:
# (array([3.000e+00, 0.000e+00, 2.300e+01, 4.500e+01, 2.030e+02, 7.600e+02,
#         1.105e+03, 6.690e+02, 5.500e+02, 9.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.        , 0.0090379 , 0.0180758 , 0.0271137 , 0.0361516 ,
#         0.0451895 , 0.05422741, 0.06326531, 0.07230321, 0.08134111,
#         0.09037901, 0.09941691, 0.10845481, 0.11749271, 0.12653061,
#         0.13556851, 0.14460641, 0.15364431, 0.16268222, 0.17172012,
#         0.18075802, 0.18979592, 0.19883382, 0.20787172, 0.21690962,
#         0.22594752, 0.23498542, 0.24402332, 0.25306122, 0.26209913,
#         0.27113703]),
#  <a list of 30 Patch objects>)

# %%
itemPrices.pop('Dragon_legs/skirt_ornament_kit',None)

# %%
item = 'Abyssal_whip'
prices = [a[1] for a in itemPrices[item]]
plt.plot(prices)

# %%
def interPolateMissingDates(info):
    dates = [a[0] for a in info]
    prices = [a[1] for a in info]
    quants = [a[2] for a in info]
    fixed = []
    for i in range(len(dates)-1):
        fixed.append(info[i])
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            daysToAdd = int(diff/day)-1
            d = []
            p = []
            q = []
            pToAdd = (prices[i+1]-prices[i])/(daysToAdd+1)
            qToAdd = (quants[i+1]-quants[i])/(daysToAdd+1)
            for j in range(daysToAdd):
                d.append(dates[i]+day*(j+1))
                p.append(prices[i]+(j+1)*pToAdd)
                q.append(quants[i]+(j+1)*qToAdd)
            for j in range(daysToAdd):
                fixed.append((d[j],p[j],q[j]))
    return fixed

# %%
# interpolate dates, prices, and quantities
#for item in itemPrices:
item = 'Abyssal_whip'
dates = [a[0] for a in itemPrices[item]]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("Before:",total)
interPolateMissingDates(itemPrices[item])
dates = [a[0] for a in fixed]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("After:",total)
prices = [a[1] for a in fixed]
plt.plot(prices)
# Out:
# Before: 55
# After: 0

# %%
# fix all items
for item in itemPrices:
    itemPrices[item] = interPolateMissingDates(itemPrices[item])

# %%
for item in itemPrices:
    dates = [a[0] for a in itemPrices[item]]
    total = 0
    for i in range(len(dates)-1):
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            total += int(diff/day)-1
    if total>0:
        print(item,total)

# %%
def checkOutliers(prices):
    outliers = []
    manualAdjust = []
    for i in range(len(prices)-2):
        diff1 = abs(prices[i+1]-prices[i])
        diff2 = abs(prices[i+2]-prices[i+1])
        if diff1>100 and diff2>100 and diff1>prices[i]*0.15 and diff2>prices[i+1]*0.15:
            outliers.append(i+1)
        if diff1>100 and diff2>100 and diff1>prices[i]*0.17 and diff2<prices[i+1]*0.15:
            manualAdjust.append(i+1)
    return outliers,manualAdjust

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
# Out:
# 122
# 8

# %%
print(outlier)
#print(adjust)
# Out:
# {'Turquoise_robe_bottoms': [91], 'Cream_robe_bottoms': [91], 'Lesser_demon_mask': [178, 179, 180, 181, 182], 'Prayer_potion(3)': [91], 'Superantipoison(2)': [91], 'Defence_potion(2)': [91], 'Blue_halloween_mask': [91], 'Super_attack(1)': [91], 'Arceuus_banner': [179, 180, 181, 182], 'Super_attack(3)': [91], 'Iron_hasta(p)': [675, 676, 677, 678], 'Purple_cape': [91], 'Jungle_demon_mask': [180, 181, 182], "Monk's_robe_top": [90], 'Empty_oil_lantern': [675, 676, 677, 678, 679], 'Bones_to_bananas': [655, 656, 657], 'Mithril_dagger(p)': [973], 'Enchant_onyx': [657], 'Turquoise_boots': [91], 'Super_strength(3)': [91], 'Super_defence(1)': [91], 'Cream_hat': [91], 'Piscarilius_banner': [178, 179, 180, 181, 182], 'Gilded_hasta': [181, 182], 'Zamorak_monk_top': [91], 'Zamorak_brew(2)': [91], 'Attack_potion(2)': [91], 'Lovakengj_hood': [179, 180, 181, 182], 'Samurai_boots': [180, 181, 182], 'Cyclops_head': [166, 167], 'Hosidius_scarf': [178, 179, 180, 181, 182], 'Shayzien_banner': [177, 178, 179, 180, 181], 'Black_robe': [91], 'Mith_grapple_tip': [653, 654, 655, 656, 657], 'Restore_potion(3)': [91], 'Blue_robe_bottoms': [91], 'Zamorak_brew(1)': [91], 'Spider_on_shaft': [654, 655, 656, 657], 'Left_eye_patch': [178, 179, 180, 181, 182], 'Restore_mix(2)': [1284], 'Lovakengj_scarf': [178, 179, 180, 181, 182], 'Bowl_wig': [178, 179, 180, 181, 182], 'Hosidius_hood': [179, 180, 181, 182], 'Blue_hat': [91], 'Iron_hasta(p++)': [674, 675, 676, 677, 678], 'Fishing_potion(3)': [91], 'Restore_mix(1)': [1282, 1283, 1284], 'Black_cape': [91], 'Superantipoison(1)': [91], 'Red_halloween_mask': [91], 'Bucket_helm_(g)': [181, 182], 'Gloves_of_darkness': [179, 180, 181, 182], 'Blue_cape': [91], 'Blue_robe_top': [91], 'Super_attack(2)': [91], 'Pink_boots': [91], 'Orange_cape': [91], 'Incomplete_light_ballista': [242, 243, 244, 245], "Mummy's_legs": [180, 181, 182], 'Strength_potion(4)': [91], 'Green_halloween_mask': [91], 'Boots_of_darkness': [177, 178, 179, 180, 181], 'Super_defence(2)': [91], 'Incomplete_heavy_ballista': [241, 242, 243, 244, 245], 'Fishing_potion(1)': [91], 'Spider_on_stick': [654, 655, 656, 657], 'Cream_robe_top': [91], 'Zombie_head': [178, 179, 180, 181], 'Arceuus_scarf': [178, 179, 180, 181, 182], 'Enchant_emerald_or_jade': [655, 656, 657], "Mummy's_body": [180, 181, 182], 'Turquoise_hat': [91], "Mummy's_hands": [180, 181, 182], 'Pink_hat': [91], 'Ranging_potion(3)': [91], 'Cream_boots': [91], 'Greater_demon_mask': [179, 180, 181, 182], 'Wizard_hat': [91], 'Unstrung_light_ballista': [242, 243, 244], "Mummy's_head": [181, 182], 'Lovakengj_banner': [178, 179, 180, 181, 182], 'Attack_potion(3)': [91], "Mummy's_feet": [180, 181, 182], 'Enchant_diamond': [654, 655, 656, 657], 'Strength_mix(1)': [1284], 'Arceuus_hood': [179, 180, 181, 182], 'Ranging_potion(1)': [91], 'Iron_hasta(p+)': [674, 675, 676, 677, 678], 'Dragon_impling_jar': [1043], 'Turquoise_robe_top': [91], 'Pink_robe_bottoms': [91], 'Hosidius_banner': [178, 179, 180, 181, 182], 'Shayzien_hood': [180, 181], 'Green_boots': [91], 'Green_robe_top': [91], 'Robe_bottom_of_darkness': [180, 181, 182], 'Fishing_potion(2)': [91, 1285], 'Super_defence(3)': [91], "Blacksmith's_helm": [179, 180, 181, 182], 'Yellow_cape': [91], 'Piscarilius_scarf': [178, 179, 180, 181, 182], 'Antipoison(3)': [91], "Monk's_robe": [90], 'Ranging_potion(2)': [91], 'Old_demon_mask': [181, 182], 'Monkey_tail': [244, 245], 'Piscarilius_hood': [178, 179, 180, 181, 182], 'Prayer_potion(2)': [91], 'Mithril_limbs': [655, 656, 657], 'Antipoison(1)': [91], 'Blue_wizard_robe': [91], 'Antipoison(2)': [91], 'Robe_top_of_darkness': [181, 182], 'Green_robe_bottoms': [91], 'Green_hat': [91], 'Prayer_potion(1)': [91], 'Restore_potion(2)': [91], 'Zamorak_brew(3)': [91], 'Pink_robe_top': [91], 'Blue_boots': [91], 'Restore_potion(1)': [91], 'Super_strength(2)': [91]}

# %%
item = 'Fishing_potion(1)'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [91]
# [1228, 1228, 1228, 54, 1228, 1228.0, 1228.0]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# adjust items that were revalued on 2017-04-11
week = 7 * 86400
checkPoint = 1491868800
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Lesser_demon_mask
# Arceuus_banner
# Iron_hasta(p)
# Jungle_demon_mask
# Empty_oil_lantern
# Bones_to_bananas
# Enchant_onyx
# Piscarilius_banner
# Gilded_hasta
# Lovakengj_hood
# Samurai_boots
# Cyclops_head
# Hosidius_scarf
# Shayzien_banner
# Mith_grapple_tip
# Spider_on_shaft
# Left_eye_patch
# Lovakengj_scarf
# Bowl_wig
# Hosidius_hood
# Iron_hasta(p++)
# Bucket_helm_(g)
# Gloves_of_darkness
# Incomplete_light_ballista
# Mummy's_legs
# Boots_of_darkness
# Incomplete_heavy_ballista
# Spider_on_stick
# Zombie_head
# Arceuus_scarf
# Enchant_emerald_or_jade
# Mummy's_body
# Mummy's_hands
# Greater_demon_mask
# Unstrung_light_ballista
# Mummy's_head
# Lovakengj_banner
# Mummy's_feet
# Enchant_diamond
# Arceuus_hood
# Iron_hasta(p+)
# Hosidius_banner
# Shayzien_hood
# Robe_bottom_of_darkness
# Blacksmith's_helm
# Piscarilius_scarf
# Old_demon_mask
# Monkey_tail
# Piscarilius_hood
# Mithril_limbs
# Robe_top_of_darkness

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 71
# 8
# {'Turquoise_robe_bottoms': [91], 'Cream_robe_bottoms': [91], 'Prayer_potion(3)': [91], 'Superantipoison(2)': [91], 'Defence_potion(2)': [91], 'Blue_halloween_mask': [91], 'Super_attack(1)': [91], 'Super_attack(3)': [91], 'Purple_cape': [91], "Monk's_robe_top": [90], 'Mithril_dagger(p)': [973], 'Turquoise_boots': [91], 'Super_strength(3)': [91], 'Super_defence(1)': [91], 'Cream_hat': [91], 'Zamorak_monk_top': [91], 'Zamorak_brew(2)': [91], 'Attack_potion(2)': [91], 'Black_robe': [91], 'Restore_potion(3)': [91], 'Blue_robe_bottoms': [91], 'Zamorak_brew(1)': [91], 'Restore_mix(2)': [1284], 'Blue_hat': [91], 'Fishing_potion(3)': [91], 'Restore_mix(1)': [1282, 1283, 1284], 'Black_cape': [91], 'Superantipoison(1)': [91], 'Red_halloween_mask': [91], 'Blue_cape': [91], 'Blue_robe_top': [91], 'Super_attack(2)': [91], 'Pink_boots': [91], 'Orange_cape': [91], 'Strength_potion(4)': [91], 'Green_halloween_mask': [91], 'Super_defence(2)': [91], 'Fishing_potion(1)': [91], 'Cream_robe_top': [91], 'Turquoise_hat': [91], 'Pink_hat': [91], 'Ranging_potion(3)': [91], 'Cream_boots': [91], 'Wizard_hat': [91], 'Attack_potion(3)': [91], 'Strength_mix(1)': [1284], 'Ranging_potion(1)': [91], 'Dragon_impling_jar': [1043], 'Turquoise_robe_top': [91], 'Pink_robe_bottoms': [91], 'Green_boots': [91], 'Green_robe_top': [91], 'Fishing_potion(2)': [91, 1285], 'Super_defence(3)': [91], 'Yellow_cape': [91], 'Antipoison(3)': [91], "Monk's_robe": [90], 'Ranging_potion(2)': [91], 'Prayer_potion(2)': [91], 'Antipoison(1)': [91], 'Blue_wizard_robe': [91], 'Antipoison(2)': [91], 'Green_robe_bottoms': [91], 'Green_hat': [91], 'Prayer_potion(1)': [91], 'Restore_potion(2)': [91], 'Zamorak_brew(3)': [91], 'Pink_robe_top': [91], 'Blue_boots': [91], 'Restore_potion(1)': [91], 'Super_strength(2)': [91]}

# %%
item = 'Turquoise_robe_bottoms'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [91]
# [2865, 2865, 2865, 83, 2865, 2837.2, 2809.4]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# fix outliers caused by misread on 2015-09-02 00:00:00
week = 7 * 86400
checkPoint = 1441152000
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Turquoise_robe_bottoms
# Cream_robe_bottoms
# Prayer_potion(3)
# Superantipoison(2)
# Defence_potion(2)
# Blue_halloween_mask
# Super_attack(1)
# Super_attack(3)
# Purple_cape
# Monk's_robe_top
# Turquoise_boots
# Super_strength(3)
# Super_defence(1)
# Cream_hat
# Zamorak_monk_top
# Zamorak_brew(2)
# Attack_potion(2)
# Black_robe
# Restore_potion(3)
# Blue_robe_bottoms
# Zamorak_brew(1)
# Blue_hat
# Fishing_potion(3)
# Black_cape
# Superantipoison(1)
# Red_halloween_mask
# Blue_cape
# Blue_robe_top
# Super_attack(2)
# Pink_boots
# Orange_cape
# Strength_potion(4)
# Green_halloween_mask
# Super_defence(2)
# Fishing_potion(1)
# Cream_robe_top
# Turquoise_hat
# Pink_hat
# Ranging_potion(3)
# Cream_boots
# Wizard_hat
# Attack_potion(3)
# Ranging_potion(1)
# Turquoise_robe_top
# Pink_robe_bottoms
# Green_boots
# Green_robe_top
# Fishing_potion(2)
# Super_defence(3)
# Yellow_cape
# Antipoison(3)
# Monk's_robe
# Ranging_potion(2)
# Prayer_potion(2)
# Antipoison(1)
# Blue_wizard_robe
# Antipoison(2)
# Green_robe_bottoms
# Green_hat
# Prayer_potion(1)
# Restore_potion(2)
# Zamorak_brew(3)
# Pink_robe_top
# Blue_boots
# Restore_potion(1)
# Super_strength(2)

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 6
# 4
# {'Mithril_dagger(p)': [973], 'Restore_mix(2)': [1284], 'Restore_mix(1)': [1282, 1283, 1284], 'Strength_mix(1)': [1284], 'Dragon_impling_jar': [1043], 'Fishing_potion(2)': [1187]}

# %%
for item in outlier:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Mithril_dagger(p)
# Restore_mix(2)
# Restore_mix(1)
# Strength_mix(1)
# Dragon_impling_jar
# Fishing_potion(2)

# %%
# guess I'll just get rid of these ones
for item in outlier:
    itemPrices.pop(item,None)

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 0
# 3
# {}

# %%
for item in adjust:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Disk_of_returning
# Dragon_harpoon
# Dragon_sword

# %%
# noticed that dragon sword price was changed after an update on january 10th
# and that information was stored on its wiki page, should probably scrape that as well

# %%
# normalization
item = 'Abyssal_whip'
x = np.array([a[1] for a in itemPrices[item]])
plt.plot(x)

# %%
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
# Out:
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
plt.hist(x_scaled,20)
# Out:
# (array([ 24., 120., 129., 131., 116.,  47.,  78., 101., 108.,  74.,  58.,
#          43.,  52.,  53.,  39.,  64.,   9.,   2.,   2.,   3.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <a list of 20 Patch objects>)

# %%
diff_x = [0] * (len(x)-1)
for i in range(len(x)-1):
    diff_x[i] = x[i+1]-x[i]
minX = min(diff_x)
diff_x = np.array([a+abs(minX)+.01 for a in diff_x])
log_x = np.log(diff_x)
x_diff_scaled = scaler.fit_transform(diff_x.reshape(-1, 1))
x_log_scaled = scaler.fit_transform(log_x.reshape(-1, 1))

# %%
plt.hist(x_diff_scaled,20)
plt.show()

# %%
plt.hist(x_log_scaled,20)
plt.show()

# %%
def scalePrices(x):
    diff_x = [0] * (len(x)-1)
    for i in range(len(x)-1):
        diff_x[i] = x[i+1]-x[i]
    minX = min(diff_x)
    diff_x = np.array([a+abs(minX)+.01 for a in diff_x])
    x_diff_scaled = scaler.fit_transform(diff_x.reshape(-1, 1))
    return x_diff_scaled

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1336: 2
# 1329: 256
# 1328: 509
# 1327: 34
# 1307: 1925
# 1306: 94
# 1231: 62
# 1230: 3
# 1113: 5
# 1112: 1
# 1020: 6
# 1019: 25
# 1018: 1
# 1003: 1
# 969: 1
# 896: 1
# 895: 19
# 894: 11
# 888: 9
# 887: 1
# 873: 2
# 872: 2
# 866: 2
# 853: 1
# 838: 1
# 833: 1
# 832: 61
# 831: 20
# 830: 6
# 829: 1
# 819: 6
# 807: 1
# 801: 1
# 755: 1
# 752: 1
# 748: 2
# 747: 4
# 732: 1
# 724: 1
# 701: 1
# 648: 3
# 647: 18
# 646: 20
# 645: 14
# 644: 9
# 643: 1
# 637: 3
# 634: 1
# 627: 1
# 623: 2
# 621: 24
# 620: 1
# 613: 1
# 592: 1
# 553: 1
# 530: 1
# 499: 3
# 498: 1
# 486: 13
# 458: 1
# 411: 6
# 410: 15
# 409: 3
# 363: 5
# 361: 1
# 355: 1
# 334: 5
# 332: 2
# 318: 1
# 292: 1
# 291: 8
# 290: 26
# 289: 6
# 288: 10
# 275: 3
# 274: 1
# 273: 1
# 272: 1
# 269: 9
# 264: 2
# 263: 1
# 262: 2
# 261: 2
# 260: 3
# 258: 5
# 254: 2
# 253: 1
# 174: 2
# 151: 1
# 137: 18
# 101: 1
# 86: 3
# 85: 1
# 43: 7
# 42: 3
# 41: 2
# 0: 28

# %%
# probably 1228
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
scaled = []
for item in itemPrices:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    scaled = scaled + list(scalePrices(prices))
plt.hist(scaled,20)
plt.show()
# Out:
# Dragon_bones
# Iron_longsword
# Dragon_halberd
# Scythe_of_vitur_(uncharged)
# Holy_wraps
# Black_warlock
# Blue_wizard_robe_(g)
# Abyssal_whip
# Amethyst_arrowtips
# Blue_elegant_shirt
# Godsword_shard_1
# Dodgy_necklace
# Holy_symbol
# Desert_legs
# Empty_plant_pot
# Steel_full_helm_(g)
# Mist_battlestaff
# Steel_dagger(p)
# Bone_club
# Roast_rabbit
# Adamant_platebody
# Elf_camp_teleport
# Gilded_platebody
# New_crystal_bow
# Shrimps
# Magic_essence_mix(2)
# Steel_kiteshield
# Dragonfruit_tree_seed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-219-3f120c0dcf05> in <module>()
#       3     print(item)
#       4     prices = [a[1] for a in itemPrices[item]]
# ----> 5     scaled = scaled + list(scalePrices(prices))
#       6 plt.hist(scaled,20)
#       7 plt.show()
#
# <ipython-input-216-eabb4c6eec93> in scalePrices(x)
#       3     for i in range(len(x)-1):
#       4         diff_x[i] = x[i+1]-x[i]
# ----> 5     minX = min(diff_x)
#       6     diff_x = np.array([a+abs(minX)+.01 for a in diff_x])
#       7     x_diff_scaled = scaler.fit_transform(diff_x.reshape(-1, 1))
#
# ValueError: min() arg is an empty sequence

# %%
itemPrices['Dragonfruit_tree_seed']
# Out:
# []
