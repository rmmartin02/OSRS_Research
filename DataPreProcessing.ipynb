# %%
import pickle
import matplotlib.pyplot as plt
from sklearn import preprocessing
import numpy as np
import sys
from datetime import datetime

# %%
import sys
import os
address = (os.sep).join(os.getcwd().split(os.sep)[:-2])
print(address)
sys.path.append(address)
print(sys.path)
import util.items as items
# Out:
# C:\Users\Martin
# ['C:\\Users\\Martin\\Projects\\OSRS_Research', 'c:\\users\\martin\\appdata\\local\\programs\\python\\python37\\python37.zip', 'c:\\users\\martin\\appdata\\local\\programs\\python\\python37\\DLLs', 'c:\\users\\martin\\appdata\\local\\programs\\python\\python37\\lib', 'c:\\users\\martin\\appdata\\local\\programs\\python\\python37', '', 'c:\\users\\martin\\appdata\\local\\programs\\python\\python37\\lib\\site-packages', 'c:\\users\\martin\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Martin\\.ipython', 'C:\\Users\\Martin']

# %%
with open('Data/itemPricesOriginal.pickle','rb') as f:
    itemPrices = pickle.load(f)

# %%
def checkDates(dates):
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    return repeats

# %%
data = {}
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)

# %%
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))
# Out:
# Ham_shirt 6
# Book_of_law_page_set 6
# Saradomin_chaps 7
# Topaz_amulet 5
# Oak_roots 6
# Amethyst_arrowtips 4
# Dragonstone_amulet 6
# Ankou_socks 5
# Black_axe 6
# Gilded_four-poster 8
# Steel_bolts_(p++) 8
# Silver_ore 8
# Adamant_dagger(p+) 5
# Ancient_coif 5
# Dragon_spear(p+) 7
# Dragon_boots 6
# Red_d'hide_shield 5
# Gourmet_impling_jar 7
# Zamorak_cloak 8
# Armadyl_crozier 6
# Sandstone_(5kg) 9
# Gilded_armour_set_(lg) 6
# Raw_slimy_eel 8
# Dragon_warhammer 6
# Steel_dagger(p+) 9
# Elysian_sigil 6
# Oak_shield 5
# Uncut_ruby 7
# Relicym's_mix(2) 7
# Mithril_thrownaxe 6
# Black_wizard_hat_(g) 6
# Watering_can 7
# Kodai_insignia 5
# Circular_hide 6
# Gold_elegant_legs 6
# Maple_blackjack 6
# Desert_top 6
# Relicym's_balm(4) 8
# Mahogany_fancy_dress_box 8
# Fly_fishing_rod 6
# Granite_ring 5
# Steel_spear(p+) 9
# Bronze_longsword 6
# Dark_kebbit_fur 6
# Black_platebody_(g) 6
# Insulated_boots 6
# Obsidian_cape_(r) 5
# Teak_logs 8
# Spined_boots 8
# Lizardman_fang 6
# Flamtaer_bracelet 5
# Steel_dagger(p++) 9
# Egg_potato 6
# Seaweed 9
# Chopped_ugthanki 7
# Anti-venom+(3) 7
# Snakeskin_bandana 8
# Extended_antifire_mix(1) 7
# Grey_toy_horsey 7
# Rune_helm_(h5) 6
# Premade_s'y_crunch 7
# Bronze_dart(p) 7
# Purple_partyhat 7
# Harpoon 6
# Riyl_remains 7
# White_bead 7
# Tuna 8
# Toadflax_seed 9
# Oak_blackjack(d) 7
# Extended_super_antifire(1) 5
# Stony_basalt 4
# Willow_branch 7
# Guthan's_warspear_0 7
# Ultracompost 5
# Mystic_dust_staff 5
# Mahogany_plank 6
# Steel_dart(p++) 9
# Team-41_cape 9
# Harralander_potion_(unf) 6
# Basalt 4
# Adamant_helm_(h2) 4
# Energy_potion(1) 7
# Cave_eel 6
# Superattack_mix(2) 8
# Blue_wizard_robe 7
# Wyvern_bones 7
# Green_dye 6
# Hair 6
# Rosemary 7
# Guthix_d'hide_boots 5
# Frozen_whip_mix 6
# Burning_amulet(5) 5
# Grimy_toadflax 7
# 3rd_age_robe 5
# Uncut_dragonstone 8
# Magic_sapling 6
# White_kiteshield 7
# Bullseye_lantern_(empty) 6
# Rune_plateskirt_(g) 7
# Mithril_hasta(p) 7
# Torag's_platebody_0 9
# Berserker_necklace 6
# Rune_longsword 9
# Dragon_armour_set_(sk) 5
# Dwarven_stout 6
# Bronze_dagger(p+) 7
# Blue_dragonhide_set 6
# Golden_statuette 6
# Silver_bolts 8
# Purple_gloves 8
# Black_boots 6
# Rune_hasta(p++) 8
# Arcane_sigil 6
# Green_d'hide_body_(t) 6
# Rune_javelin(p) 7
# Torag's_helm_0 8
# Frog-leather_boots 6
# Arena_book 8
# Fremennik_purple_cloak 7
# Water_talisman 7
# Tatty_graahk_fur 8
# Wyrm_bones 1
# Armadyl_helmet 6
# Amulet_of_glory_(t) 5
# Staff_of_the_dead 8
# Maple_pyre_logs 6
# Saradomin_brew(4) 8
# Warrior_helm 7
# Restore_mix(1) 8
# Adamant_kiteshield 4
# Half_moon_spectacles 5
# Feldip_weasel_fur 6
# Team_cape_i 7
# Anchovies 5
# Zuriel's_staff 3
# Iron_javelin(p++) 7
# Big_fishing_net 6
# Grey_gloves 7
# Opal_bolt_tips 6
# Jade_dragon_bolts_(e) 5
# Bronze_mace 6
# Oak_kitchen_table 8
# Team-43_cape 9
# Sinister_key 8
# Dinh's_bulwark 5
# Craw's_bow_(u) 4
# Pink_cape 8
# Teak_treasure_chest 10
# Fish_offcuts 6
# Defence_potion(2) 7
# Oak_bench 8
# Black_dragon_mask 6
# Helm_of_neitiznot 6
# Gilded_kiteshield 6
# Bastion_potion(2) 4
# Calquat_sapling 6
# Clue_box 6
# Adamant_platelegs_(g) 4
# Adamant_scimitar 4
# Amulet_of_chemistry 4
# Teak_wardrobe 10
# Golovanova_fruit_top 5
# Water_tiara 7
# Monk's_robe_top 8
# Cooked_chompy 6
# Rock-shell_chunk 7
# Black_d'hide_chaps 6
# Unfired_plant_pot 7
# Mithril_bolts_(p+) 8
# Antidote+(1) 7
# Enchanted_hat 6
# Death_tiara 6
# Stamina_mix(1) 9
# Yew_logs 8
# Grimy_marrentill 6
# Arctic_pine_logs 6
# Rune_javelin_heads 7
# Torag's_platelegs_0 9
# Rune_sword 7
# Mithril_full_helm 6
# Enchanted_top 6
# Air_tiara 5
# Body_rune 6
# Skills_necklace 8
# Antifire_potion(3) 7
# Steel_sq_shield 8
# Yellow_dark_bow_paint 8
# Necklace_of_anguish 6
# Lockpick 6
# Rock-shell_splinter 7
# Harralander_seed 7
# Toy_cat 8
# Oak_shortbow_(u) 7
# Ankou's_leggings 5
# Ring_of_coins 6
# Equa_leaves 6
# Headless_arrow 5
# Pot_of_cornflour 6
# Mithril_dagger(p++) 7
# Occult_ornament_kit 4
# Diamond_dragon_bolts_(e) 5
# Sea_turtle 6
# Ugthanki_&_onion 9
# Bounty_teleport_scroll 6
# Armadyl_rune_armour_set_(sk) 6
# Antidote++(2) 7
# Torstol 8
# New_crystal_shield 7
# Shayzien_banner 5
# Rune_kiteshield_(g) 7
# Dwellberries 6
# Willow_sapling 7
# Disk_of_returning 6
# Wooden_cat 7
# Raw_anchovies 7
# Gilded_sq_shield 5
# Bronze_plateskirt 7
# Sapphire_dragon_bolts_(e) 5
# Dragon_hasta(p++) 1
# Team-27_cape 9
# Dragon_sq_shield_ornament_kit 7
# Topaz_necklace 5
# Amethyst_javelin(p+) 4
# Death_talisman 6
# Spined_body 8
# Pink_elegant_shirt 6
# Bowl_of_hot_water 6
# Mummy's_feet 5
# Yew_stock 8
# Cheese 6
# Royal_gown_bottom 7
# Snapdragon_seed 9
# Uncharged_trident_(e) 5
# Magic_box 5
# Mithril_med_helm 6
# White_med_helm 7
# Pharaoh's_sceptre 5
# Guthix_page_1 6
# Snake_hide 8
# Pie_recipe_book 5
# Kitchen_knife 6
# Green_boater 6
# Team-44_cape 9
# Bandos_kiteshield 6
# Stronghold_notes 8
# Energy_potion(3) 7
# Cider(4) 7
# 3rd_age_pickaxe 5
# Dragon_cane 6
# Rune_dagger(p+) 9
# Chocchip_crunchies 6
# Minced_meat 8
# Orange 6
# Dragonfruit_pie 1
# Oak_fancy_dress_box 8
# Studded_body_(t) 8
# Ensouled_elf_head 6
# Bronze_dragon_mask 6
# Xerician_top 8
# Zamorak_robe_legs 8
# Yellow_partyhat 8
# Asgarnian_hops 6
# Energy_mix(1) 7
# Steel_2h_sword 8
# Rune_shield_(h4) 7
# Stamina_potion(4) 9
# Barley_malt 6
# Numulite 4
# Sickle_mould 8
# Adamant_crossbow_(u) 4
# Slayer's_enchantment 5
# Zulrah's_scales 8
# Bronze_bolts_(p) 7
# Black_dragonhide 6
# Adamant_helm_(h5) 4
# Gold_seal 6
# Opal_amulet_(u) 5
# Guthix_rest(1) 7
# Essence_impling_jar 7
# Yellow_cape 9
# Gin 6
# Earth_talisman 6
# Earth_tiara 6
# Piscarilius_hood 5
# Iron_kiteshield_(g) 6
# Golden_chef's_hat 5
# Ancient_bracers 5
# Jar_of_darkness 4
# White_boots 7
# Antifire_potion(2) 7
# Armadyl_d'hide 6
# Swordfish 7
# Rune_thrownaxe 7
# Dwarven_stout(m4) 7
# Karil's_armour_set 6
# Rune_dagger(p) 7
# Iron_bolts_(p+) 8
# Prayer_mix(1) 7
# Fishing_potion(1) 7
# Ale_of_the_gods 4
# Potato_with_cheese 6
# Bagged_bluebells 8
# Guthan's_helm 5
# Steel_bolts_(p) 10
# Watermelon 7
# Strength_potion(2) 9
# Adamant_chainbody 4
# Ensouled_demon_head 6
# Black_nails 6
# Wizard_hat 8
# Blue_partyhat 6
# Watermelon_seed 8
# Jar_of_stone 5
# Rune_javelin(p++) 8
# Dragon_thrownaxe 6
# Olive_oil(2) 7
# Onyx_bolts_(e) 7
# Bronze_spear 6
# Enchant_ruby_or_topaz 6
# Bronze_javelin_heads 6
# Potatoes(10) 7
# Bagged_roses 8
# Dragon_arrow 6
# Sacred_oil(2) 8
# Unpowered_symbol 7
# Smoke_battlestaff 8
# Snakeskin_vambraces 8
# Super_antifire_potion(3) 5
# Turquoise_boots 9
# Verac's_armour_set 7
# Zamorak_mix(1) 9
# Adamant_pickaxe 4
# Tall_fancy_hedge 10
# Empty_plant_pot 7
# Toxic_blowpipe_(empty) 9
# Avantoe_potion_(unf) 6
# Zamorak_armour_set_(sk) 7
# Toktz-xil-ak 8
# Proboscis 7
# Team-26_cape 9
# Bronze_dart(p+) 7
# Iron_bolts_(p++) 8
# Rock-shell_boots 7
# Spined_chaps 8
# Carved_teak_magic_wardrobe 8
# Teak_toy_box 10
# Sapphire_ring 7
# Odium_shard_3 6
# Dragon_spear(p) 7
# Dragon_bitter(m) 7
# Shantay_pass 8
# Guthix_armour_set_(lg) 6
# Red_d'hide_chaps_(t) 7
# Mystic_hat_(dark) 7
# Red_feather 7
# Steel_spear 8
# Pineapple_pizza 6
# Ancient_page_4 5
# Super_str._mix(2) 9
# Giant_seaweed 6
# Anti-venom+(1) 7
# Cooked_crab_meat 6
# Guthan's_chainskirt 6
# Black_dagger 6
# Black_dagger(p) 7
# Graahk_fur 6
# Dragonstone_amulet_(u) 7
# Adamant_set_(lg) 4
# Rune_helm_(h2) 7
# Mithril_2h_sword 6
# Mithril_spear(p++) 7
# Fat_snail 6
# Bronze_arrow 6
# Torn_prayer_scroll 6
# Black_platebody 6
# Gilded_chainbody 5
# Earth_impling_jar 6
# Rake 6
# Zamorak_page_2 8
# Cadantine_blood_potion_(unf) 4
# Dodgy_necklace 5
# Staff_of_fire 7
# Zenyte_amulet 9
# Unstrung_symbol 7
# Anti-dragon_shield 6
# Black_flowers 7
# Vegetable_batta 7
# Magic_essence_mix(2) 7
# Thread 8
# Flamtaer_hammer 7
# Bone_dagger_(p+) 8
# Grimy_dwarf_weed 6
# Cabbage 6
# Unlit_bug_lantern 9
# Amethyst_broad_bolts 4
# Dareeyak_teleport 6
# Ancient_wyvern_shield 5
# Super_attack(2) 9
# Adamant_sword 4
# White_magic_staff 7
# Blue_d'hide_body_(t) 6
# Ahrim's_robeskirt 5
# Zamorak_mjolnir 8
# Zogre_bones 8
# Knife 6
# Cemetery_teleport 6
# Apple_tree_seed 7
# Black_wizard_robe_(t) 6
# Cooked_chicken 6
# Basket 6
# Sardine 7
# Lovakengj_banner 5
# Earth_battlestaff 6
# Book_of_balance_page_set 6
# Jug_of_wine 6
# Noose_wand 6
# Mind_shield 6
# Elf_camp_teleport 6
# Teak_bed 10
# Wool 7
# Iron_med_helm 6
# Iron_spear(p+) 7
# Ninja_impling_jar 6
# Spider_on_stick 8
# Black_wizard_hat_(t) 6
# Teal_robe_bottoms 9
# Zamorak_armour_set_(lg) 8
# Studded_chaps_(g) 8
# Initiate_harness_m 5
# Bucket_of_sand 6
# Oak_treasure_chest 7
# Magic_longbow 6
# Green_halloween_mask 7
# Toy_soldier_(wound) 10
# Dragonstone 6
# Grimy_irit_leaf 7
# Menaphite_purple_top 7
# Choc_saturday 6
# Mithril_knife(p++) 7
# Bucket_of_milk 6
# Lean_snail_meat 6
# Wooden_stock 7
# Ensouled_imp_head 6
# Bucket_of_sap 6
# Bob's_red_shirt 6
# Shoe_box 10
# Rune_dart(p++) 8
# Rune_mace 8
# Adamant_javelin 4
# Adamant_hasta(p+) 5
# Fremennik_blue_cloak 7
# Teal_robe_top 9
# Sapphire 7
# Toktz-xil-ul 7
# Iron_platebody_(t) 6
# Iron_mace 5
# Iron_full_helm_(g) 6
# Avernic_defender_hilt 4
# Topaz_amulet_(u) 5
# Bandos_platebody 6
# Saradomin_page_1 7
# Egg_and_tomato 6
# Vyrewatch_legs 7
# Steel_nails 8
# Grey_boots 7
# Zamorak_brew(3) 8
# Skull_piece 8
# Uncooked_meat_pie 8
# Blue_wizard_hat_(t) 6
# Water_rune 7
# Teak_plank 8
# Grog 6
# Wood_dining_table 9
# Amulet_of_bounty 4
# Ahrim's_robetop 5
# Holy_wraps 5
# Black_cane 6
# Black_knife 6
# Bone_bolts 6
# Attack_potion(4) 7
# Sapphire_amulet_(u) 7
# Team-47_cape 8
# Cider(m4) 7
# Cowhide 6
# Dragon_hasta 1
# Bronze_claws 6
# Jungle_demon_mask 5
# Cannon_barrels 6
# Swamp_tar 8
# Zamorak_kiteshield 8
# Ruby_ring 7
# Pegasian_crystal 5
# Bat_bones 6
# Slayer's_respite(4) 9
# Muddy_key 6
# Oil_lantern 7
# Pink_hat 7
# Compost_potion(3) 7
# Leather_boots 6
# Malediction_shard_1 6
# Dharok's_helm_0 7
# Steel_full_helm 8
# Cosmic_rune 6
# Maple_logs 5
# Emerald_bolt_tips 6
# Apple_pie 6
# Ring_of_stone 7
# Mithril_trimmed_set_(sk) 6
# Steel_trimmed_set_(lg) 7
# Diamond_necklace 6
# Red_d'hide_body_(g) 7
# Steel_plateskirt 7
# Saradomin_mjolnir 7
# Potato 5
# Relicym's_balm(1) 8
# Steel_halberd 8
# Lava_scale 6
# Avantoe 6
# Rabbit_snare 7
# Dragon_knife 1
# Adamant_javelin(p) 5
# Dragonfire_shield 6
# Pyre_logs 7
# Beginner_wand 6
# Iron_platebody_(g) 6
# Black_robe 7
# Sapphire_dragon_bolts 5
# Steel_javelin(p++) 8
# 3rd_age_mage_hat 5
# Raw_anglerfish 7
# Premade_blurb'_sp. 6
# Mature_cider 6
# Graahk_headdress 6
# Uncut_diamond 8
# Gold_amulet 6
# Bob's_blue_shirt 6
# Armadyl_godsword 6
# Light_infinity_colour_kit 6
# Incomplete_heavy_ballista 6
# Armadyl_robe_top 6
# Red_d'hide_vamb 7
# Steel_kiteshield_(t) 7
# Antifire_mix(1) 7
# Jar_of_decay 5
# Super_combat_potion(3) 8
# Raw_ugthanki_meat 8
# Blue_wizard_robe_(g) 6
# Armadyl_hilt 6
# Blue_d'hide_body_(g) 6
# Ale_yeast 5
# Mud_pie 6
# Shark 7
# Unlit_torch 8
# Loop_half_of_key 6
# Gadderhammer 6
# Ancient_cloak 5
# Abyssal_dagger_(p) 4
# Sweetcorn 8
# Black_dagger(p+) 7
# Book_of_darkness_page_set 6
# Defence_potion(4) 7
# Raw_wild_pie 7
# Axeman's_folly(4) 7
# Steam_rune 8
# Adamant_cane 4
# Torag's_hammers 8
# Mithril_knife(p) 7
# Amethyst_javelin 4
# Machete 6
# Lava_rune 6
# Guam_potion_(unf) 6
# Adamant_arrow(p) 5
# Mole_skin 6
# Irit_potion_(unf) 6
# Bronze_dagger(p) 7
# Plank 6
# Mithril_javelin(p) 6
# Ring_of_nature 6
# Black_desert_robe 6
# Blue_wizard_robe_(t) 6
# Yellow_flowers 9
# Ball_of_wool 6
# Iron_dagger(p++) 7
# Mithril_hasta(p+) 7
# Rock-shell_plate 7
# Zamorak_brew(2) 9
# Zamorak_godsword 8
# Longbow_(u) 6
# Iron_platelegs_(t) 5
# Kebbit_bolts 6
# Ruby_bolts 7
# Mushroom_spore 7
# Oak_plank 6
# Toad_crunchies 8
# Timber_beam 8
# Ancient_d'hide 5
# Spider_carcass 8
# Adamant_dagger(p++) 5
# Wildblood_hops 8
# Mithril_platebody_(t) 6
# Wyvern_visage 4
# M._treasure_chest 8
# Torag's_platelegs 8
# Hunter_potion(3) 7
# Red_robe_bottoms 7
# Orange_tree_seed 7
# Harralander_tar 6
# Willow_blackjack 8
# Torag's_hammers_0 10
# Paddewwa_teleport 6
# Rune_dart(p) 7
# Red_cavalier 7
# Onyx_necklace 6
# Abyssal_dagger_(p+) 4
# Honourable_blessing 5
# Zamorak_page_3 8
# Sanfew_serum(1) 8
# Raw_dark_crab 7
# Snakeskin_chaps 8
# Teak_table 10
# Clockwork 6
# Red_boots 8
# Cod 6
# Ensouled_unicorn_head 6
# Limpwurt_root 6
# Tall_box_hedge 10
# Dwarf_weed 6
# Extended_super_antifire(4) 5
# Grain 6
# Teal_hat 9
# Iron_knife(p+) 7
# Dragon_claws 5
# Grand_seed_pod 6
# Kwuarm_seed 7
# Blue_d'hide_chaps_(g) 6
# Redwood_sapling 1
# Super_def._mix(1) 9
# Blue_d'hide_shield 5
# Rune_dart(p+) 8
# Gold_ring 6
# Super_defence(3) 8
# Santa_hat 7
# Dragon_scale_dust 6
# Pink_elegant_blouse 6
# Broad_arrowheads 6
# Swamp_weed 9
# Hydra_bones 1
# Clay 6
# Pegasian_boots 5
# Gianne_dough 6
# Leather 6
# Rune_warhammer 7
# Bolt_mould 6
# Carved_oak_table 8
# Meat_tenderiser 6
# Mind_altar_teleport 6
# Pitta_bread 6
# Mithril_bolts_(p) 8
# Black_plateskirt_(t) 6
# Guthix_dragonhide 5
# Diamond 6
# Superantipoison(1) 8
# Broad_bolts 6
# Bronze_platebody_(t) 6
# Mummy's_legs 5
# Skills_necklace(6) 9
# Dragonfruit_sapling 1
# Mole_claw 6
# Blood_rune 6
# Chef's_delight(m4) 7
# Limestone 6
# Grimy_ranarr_weed 6
# Gnome_spice 6
# Dragon_hasta(p) 1
# Mushroom 6
# Maple_shortbow 6
# Sapphire_glacialis 7
# Black_cavalier 6
# Torag's_armour_set 8
# Combat_potion(3) 8
# Rope 7
# Maple_shield 5
# Rune_plateskirt_(t) 6
# Rune_full_helm_(g) 7
# Bronze_knife 6
# Saradomin_godsword_ornament_kit 6
# Potato_cactus 6
# Common_kebbit_fur 6
# Lemon_slices 6
# Serpentine_helm_(uncharged) 8
# Weapon_poison 7
# Anti-poison_supermix(1) 7
# Silver_bolts_(p) 10
# Steel_med_helm 8
# Bucket_helm_(g) 5
# Tomato_seed 9
# Bandos_platelegs 6
# Cadava_berries 6
# Emerald_bolts 6
# Willow_pyre_logs 7
# Rabbit_foot 7
# Chocolate_cake 6
# Energy_potion(4) 7
# Irit_seed 7
# Dragon_bolts 5
# White_gloves 7
# Mahogany_magic_wardrobe 8
# Fishing_mix(1) 7
# Unstrung_light_ballista 7
# Rune_arrow(p++) 8
# Dragon_arrow(p++) 7
# Shortbow 8
# Guardian_boots 5
# Ranger_gloves 6
# Adamant_spear(p) 5
# Frog-leather_body 6
# Rainbow_fish 7
# Ensouled_troll_head 6
# Serum_207_(3) 7
# Team-25_cape 9
# Keg_of_beer 6
# Elder_chaos_hood 5
# Mystic_water_staff 6
# Raw_shark 7
# Mushroom_pie 5
# Unholy_book_page_set 6
# Gnome_scarf 6
# Bandos_page_4 6
# Runite_limbs 7
# Chaos_tiara 6
# Unicorn_horn_dust 7
# Teak_stock 7
# Combat_bracelet(4) 7
# Onions(10) 7
# Steel_knife(p) 9
# Steel_javelin(p) 9
# Zamorak_mix(2) 9
# Banana 6
# Unstrung_heavy_ballista 7
# Ancient_d'hide_boots 4
# Toxic_staff_(uncharged) 9
# Mahogany_bench 8
# Blue_d'hide_chaps 6
# Opal 6
# Kharyrll_teleport 6
# Team-17_cape 9
# Yellow_hat 9
# Armadyl_platelegs 6
# Limpwurt_seed 7
# Ahrim's_robetop_0 6
# Needle 6
# Air_talisman 5
# Vampyre_dust 6
# Brass_key 6
# Staff_of_air 8
# Bandos_godsword 6
# White_elegant_blouse 6
# Iron_scimitar 6
# Farseer_helm 6
# Iron_dart 6
# Saradomin_brew(1) 8
# Armadyl_full_helm 6
# Potato_with_butter 6
# Mystic_steam_staff 6
# Ankou_top 5
# Black_shield_(h1) 6
# Ogre_arrow_shaft 6
# Hammer 6
# Willow_longbow_(u) 7
# Strength_potion(3) 9
# Blue_dragon_mask 6
# Empty_fishbowl 7
# Magic_mix(1) 7
# Rune_chainbody 7
# Jogre_bones 6
# Antipoison(4) 7
# Tomato 8
# Bolt_rack 6
# Uncooked_dragonfruit_pie 1
# Grey_wolf_fur 6
# Ruby_bolt_tips 7
# Spiky_vambraces 8
# Cider 6
# Rune_plateskirt 8
# Rune_platebody_(t) 7
# Mithril_javelin 6
# Harralander 6
# Mith_grapple_tip 6
# Prayer_potion(4) 8
# Ancestral_robe_bottom 4
# Steel_javelin_heads 8
# Rune_knife(p++) 8
# Chopped_onion 6
# Lobster 6
# Mahogany_dresser 8
# Empty_candle_lantern 7
# Uncooked_berry_pie 8
# Raw_manta_ray 7
# Fried_mushrooms 6
# Heavy_ballista 6
# Prayer_mix(2) 8
# Spined_helm 8
# Adamantite_bar 4
# Bandos_chestplate 6
# Druid's_robe 6
# Chaos_rune 6
# Olive_oil(3) 7
# Navy_cavalier 6
# Salmon 7
# Steel_plateskirt_(g) 7
# Gold_amulet_(u) 6
# Small_box_hedge 10
# Yew_shield 4
# Redwood_logs 6
# Bronze_dart_tip 6
# Bottomless_compost_bucket 1
# Greenmans_ale(m4) 6
# Tiara 8
# Tarromin 8
# Sandstone_(10kg) 9
# Team-23_cape 8
# Granite_legs 6
# Skeletal_bottoms 8
# Splitbark_legs 8
# Fremennik_teal_cloak 7
# Ancient_totem 5
# Zamorak_d'hide 8
# Fenkenstrain's_castle_teleport 6
# Dwarf_weed_seed 7
# Gloves_of_darkness 5
# Pink_skirt 5
# Ring_of_forging 7
# Redwood_pyre_logs 5
# Triangle_sandwich 8
# Emerald_amulet_(u) 6
# Vial_of_blood 4
# Super_energy_mix(2) 9
# Mithril_spear(p) 7
# Restore_potion(3) 8
# Black_tourmaline_core 5
# Super_kebab 8
# Pot_of_flour 6
# Adamant_set_(sk) 4
# Empty_oil_lamp 7
# Snape_grass 8
# Saradomin_platebody 7
# Steel_set_(lg) 8
# Bagged_marigolds 8
# Antipoison(2) 7
# Steel_knife(p+) 9
# Blue_feather 6
# Curry_tree_seed 7
# Raw_lobster 7
# Arctic_pyre_logs 6
# Steel_platelegs_(g) 7
# Proselyte_tasset 7
# Ensouled_kalphite_head 6
# Oak_bed 8
# Mahogany_table 7
# Blacksmith's_helm 5
# Ahrim's_staff_0 6
# Oak_armour_case 8
# Stamina_potion(1) 9
# Weapon_poison(+) 7
# Green_dragonhide 5
# Mithril_arrow(p+) 7
# Crushed_superior_dragon_bones 5
# Statius's_warhammer 4
# Antipoison_mix(2) 7
# Camelot_teleport 6
# Zamorak_page_4 8
# Armadyl_stole 6
# Infinity_bottoms 6
# Dark_tuxedo_shoes 5
# 3rd_age_kiteshield 5
# Nature_talisman 6
# Bagged_dead_tree 8
# Dragon_scimitar_ornament_kit 5
# Black_shield_(h4) 6
# Pearl_bolts_(e) 5
# Dragon_plateskirt 6
# Urt_salt 4
# Proselyte_sallet 7
# Willow_comp_bow 7
# Splitbark_boots 7
# Amulet_of_avarice 4
# Studded_body_(g) 8
# Chocolate_bomb 6
# Hard_leather 6
# Teak_armour_case 10
# Uncut_emerald 7
# Premade_fr't_batta 7
# Spatula 7
# Zamorak_monk_bottom 4
# Dark_trousers 5
# Saradomin's_tear 7
# Silk 8
# Molten_glass 6
# Asgarnian_seed 7
# Unholy_blessing 6
# Black_dart(p) 7
# Granite_clamp 6
# Berserker_ring 6
# Team-19_cape 9
# Evil_chicken_wings 5
# Saradomin_brew(3) 8
# Opal_machete 6
# Adamant_platebody_(g) 4
# Cooked_slimy_eel 6
# Uncut_zenyte 7
# Granite_helm 6
# Black_d'hide_body_(g) 6
# Xerician_fabric 6
# Splitbark_helm 8
# Abyssal_bludgeon 4
# Saradomin_brew(2) 8
# Golden_apron 5
# Bronze_hasta(p++) 7
# Green_d'hide_shield 5
# Bronze_limbs 6
# Uncut_sapphire 7
# Potato_seed 7
# Kyatt_fur 6
# Mithril_full_helm_(t) 6
# Super_attack(4) 8
# Iron_hasta 6
# Grapes 6
# Mysterious_emblem 5
# Spined_gloves 8
# Tzhaar-ket-om 8
# Spectral_sigil 8
# Adamant_axe 4
# Soda_ash 8
# Karil's_leathertop 6
# Blessed_spirit_shield 6
# Bronze_knife(p) 7
# Yew_sapling 8
# Saradomin_robe_top 6
# Iron_bolts_(p) 8
# Axeman's_folly(m4) 7
# Unholy_symbol 7
# Sapphire_bolts 7
# Brown_apron 6
# Bookcase 8
# Sliced_banana 7
# Purple_robe_top 8
# Adamant_dagger(p) 5
# Mint_cake 6
# Marrentill_seed 7
# Orange_chunks 6
# Blue_cape 7
# Katana 6
# Black_med_helm 6
# Bronze_knife(p+) 7
# Bottled_dragonbreath 1
# Pizza_base 6
# Bone_dagger_(p++) 8
# Nunchaku 5
# Gianne's_cook_book 6
# Kyatt_hat 6
# Mithril_knife 6
# Dragon_bolts_(p+) 5
# Adamant_kiteshield_(g) 4
# Mystic_hat 6
# Zamorak_godsword_ornament_kit 6
# Dragon_bones 6
# Zamorak_page_1 8
# Mithril_arrowtips 6
# Willow_shield 4
# Uncooked_egg 8
# Pike 5
# Raw_cod 7
# Top_hat_&_monocle 8
# White_firelighter 7
# Soft_clay 8
# Drift_net 5
# Mithril_boots 6
# Raw_beef 7
# Ancient_crystal 4
# Smoke_rune 8
# Adamant_med_helm 4
# Granite_boots 5
# Bronze_chainbody 6
# Moonlight_mead(m4) 7
# Zenyte 8
# Oil_lantern_frame 6
# Bronze_knife(p++) 7
# Sapphire_bolts_(e) 7
# Rune_pickaxe 7
# Adamant_bolts_(p+) 6
# Bagged_oak_tree 8
# Adamant_2h_sword 4
# Mithril_gold-trimmed_set_(lg) 6
# Iron_plateskirt_(t) 6
# Dragon_battleaxe 6
# Rune_platebody 8
# Adamant_brutal 4
# Gilded_hasta 5
# Mithril_knife(p+) 7
# Red_boater 7
# Jade_machete 6
# Opal_dragon_bolts_(e) 4
# Dust_battlestaff 5
# Bronze_javelin 6
# Roast_bird_meat 7
# Mort_myre_pear 6
# Saradomin_page_2 7
# Adamantite_ore 5
# Bronze_2h_sword 6
# Steel_dart(p+) 9
# Trident_of_the_seas_(full) 9
# Steel_bolts 8
# Fibula_piece 6
# Blue_boots 7
# Steel_set_(sk) 8
# Raw_salmon 7
# Stone_statuette 7
# Pineapple_seed 7
# Maple_longbow_(u) 7
# Mist_battlestaff 4
# Marigolds 6
# Dragon_bitter 6
# Mithril_platebody 7
# Stone_seal 8
# Iron_claws 6
# Skeletal_gloves 8
# Dragon_dagger(p+) 7
# Bone_dagger 6
# Jade_bracelet 5
# 3rd_age_platebody 5
# Mahogany_cape_rack 8
# Mithril_nails 5
# Beer_barrel 8
# Dwarven_stout(m) 7
# Bronze_gold-trimmed_set_(lg) 6
# Dragon_platebody_ornament_kit 5
# Right_eye_patch 7
# Ring_of_recoil 7
# Premade_choc_s'dy 7
# Iron_battleaxe 6
# Rune_brutal 7
# Draconic_visage 6
# Magic_fang 6
# Bronze_platelegs 6
# Super_restore(1) 9
# Short_green_guy 8
# Amethyst_arrow(p++) 4
# Sanfew_serum(3) 7
# Dragon_hasta(p+) 1
# Gnomish_firelighter 5
# Slayer's_respite 8
# Bagged_yew_tree 8
# Super_energy(4) 9
# Rune_spear(p) 8
# Caviar 6
# Barley_seed 7
# Guam_seed 7
# Team-21_cape 9
# Ourg_bones 6
# 3rd_age_cloak 5
# Black_helm_(h4) 6
# Cream_robe_bottoms 7
# Ancient_robe_top 6
# Combat_potion(1) 8
# Oranges(5) 7
# Worm_crunchies 7
# Coconut 6
# Armadyl_godsword_ornament_kit 5
# Toad_batta 8
# Red_d'hide_body_(t) 7
# Fremennik_red_shirt 7
# Restore_potion(2) 8
# Zamorak_stole 7
# Guthix_robe_legs 6
# Fishing_rod 7
# Adamant_platebody 4
# Marrentill 6
# Extended_antifire(1) 7
# Runite_bolts_(p++) 7
# Dragon_full_helm_ornament_kit 6
# Half_full_wine_jug 6
# Mithril_arrow(p++) 7
# Fine_cloth 6
# Adamantite_limbs 4
# Premade_choc_bomb 7
# White_toy_horsey 8
# Blue_skirt 6
# Bronze_javelin(p) 7
# Battlemage_potion(1) 4
# Mithril_set_(lg) 6
# Candle 6
# Mystic_air_staff 7
# Red_dragon_leather 7
# Armadyl_chaps 6
# Karil's_leathertop_0 8
# Mithril_dart(p+) 7
# Eclectic_impling_jar 6
# Adamant_shield_(h4) 4
# Mithril_hasta 6
# Toy_soldier 7
# Lunar_isle_teleport 6
# Tooth_half_of_key 8
# Gilded_platebody 6
# Kwuarm 6
# Black_skirt 6
# Grimy_torstol 6
# Red_robe_top 8
# Steel_gold-trimmed_set_(sk) 7
# Yak-hide 8
# Thatch_spar_med 8
# Superattack_mix(1) 9
# Steel_hasta(p+) 9
# Bronze_spear(p) 7
# Strawberry 8
# Rock-shell_shard 7
# Dragon_halberd 7
# Ahrim's_robeskirt_0 6
# Black_battleaxe 6
# Rune_platelegs_(g) 7
# Gilded_boots 6
# Bronze_hasta(p) 7
# Mystic_lava_staff 7
# Death_rune 6
# Redwood_shield 6
# Necklace_mould 6
# Regen_bracelet 7
# Citizen_shoes 6
# Justiciar_armour_set 4
# Pat_of_butter 5
# Bronze_javelin(p++) 7
# Topaz_bracelet 5
# Bronze_bolts_(p++) 7
# Black_demon_mask 5
# Rune_2h_sword 7
# Runite_ore 6
# Mithril_limbs 6
# Bandos_plateskirt 7
# Top_hat 8
# Ancient_relic 5
# Amethyst_arrow(p) 4
# Fury_ornament_kit 6
# Fruit_blast 6
# 3rd_age_range_top 5
# Cat_mask 6
# Left_eye_patch 5
# Karil's_leatherskirt 6
# Purple_dye 7
# Teleport_to_house 8
# Iron_set_(sk) 6
# Lean_snail 6
# Morrigan's_throwing_axe 4
# Adamant_dart 4
# Mahogany_stock 6
# Magic_bird_house 5
# Yanillian_hops 8
# Dragon_armour_set_(lg) 5
# Banana_sapling 6
# Dragon_dagger(p) 7
# Fremennik_brown_shirt 7
# Purple_robe_bottoms 8
# Asgarnian_ale(m) 7
# Dragon_platebody 5
# Black_skirt_(g) 6
# Team_cape_x 7
# Opal_necklace 5
# Rolling_pin 7
# Emerald_dragon_bolts_(e) 5
# Papyrus 6
# Olive_oil(4) 7
# Toktz-mej-tal 8
# Green_d'hide_chaps_(g) 6
# Fremennik_cyan_cloak 7
# Iron_dagger 6
# Mystic_robe_bottom_(light) 7
# Restore_potion(4) 8
# Magic_stock 5
# Insect_repellent 7
# Lantadyme 6
# Blue_robe_bottoms 7
# Dynamite 6
# Maple_blackjack(o) 7
# Iron_hasta(p+) 7
# Red_salamander 7
# Logs 6
# Brine_sabre 6
# Coif 6
# Black_desert_shirt 6
# Iron_plateskirt 6
# Bagged_plant_2 6
# Amethyst_javelin(p) 4
# Thin_snail 8
# Premade_veg_ball 7
# Polished_buttons 6
# Mud_rune 5
# Pharaoh's_sceptre_(3) 7
# Adamant_platelegs_(t) 4
# Admiral_pie 5
# Infinity_top 6
# Monkey_bar 5
# Grimy_tarromin 5
# Calcite 5
# Black_kiteshield_(g) 6
# Bronze_bolts 6
# Shield_right_half 8
# Bandit's_brew 6
# Iron_knife(p) 7
# Dragon_pickaxe_upgrade_kit 6
# Steel_chainbody 8
# Shaikahan_bones 6
# Blue_elegant_legs 6
# Blue_spiky_vambs 6
# Oak_dining_table 7
# Steel_dart 8
# Pearl_bolts 5
# Mature_wmb 6
# Ship_ticket 9
# Green_robe_bottoms 7
# Oak_logs 6
# Small_fishing_net 8
# Adamant_arrowtips 4
# Tangled_toad's_legs 10
# Adamant_halberd 4
# Lava_dragon_mask 6
# Elder_maul 5
# Guthix_platelegs 6
# Steel_brutal 7
# Zamorak_brew(4) 9
# Ensouled_ogre_head 6
# Green_firelighter 8
# Bullseye_lantern_(unf) 7
# Jade 7
# Menaphite_red_kilt 7
# Arceuus_banner 5
# Mithril_seeds 6
# Mahogany_seed 5
# Onion_&_tomato 7
# Dragon_knife(p++) 1
# Dragon_bolts_(unf) 5
# Shield_left_half 8
# Mystic_robe_top_(dark) 7
# Iron_arrow 6
# Rune_shield_(h2) 7
# Cooked_sweetcorn 6
# Teak_clock 10
# Seaweed_spore 5
# Snakeskin_shield 5
# Ballista_spring 6
# Oak_bookcase 8
# Battlemage_potion(3) 4
# Amulet_of_defence 5
# Adamant_dart(p) 5
# Necklace_of_passage(5) 5
# Adamant_plateskirt_(t) 4
# Adamant_warhammer 4
# Silver_bolts_(p++) 9
# Willow_seed 8
# Super_energy(2) 9
# Shade_robe 7
# Crossbow 6
# Oak_clock 8
# Dragon_javelin(p+) 6
# Dragon_pickaxe 6
# Digsite_teleport 6
# Volcanic_whip_mix 7
# Crier_coat 5
# Verac's_helm_0 8
# Stamina_potion(2) 8
# Iron_sword 6
# Relicym's_balm(3) 8
# Red_elegant_shirt 7
# Flax 6
# Dragon_dart 6
# Piscatoris_teleport 6
# Mahogany_armour_case 8
# Ring_of_returning(5) 5
# Super_restore(4) 9
# Fremennik_boots 6
# Holy_symbol 6
# Adamant_helm_(h1) 4
# Rock-shell_gloves 6
# Green_d'hide_body_(g) 5
# Iron_arrow(p++) 7
# Zamorak_dragonhide_set 8
# Initiate_sallet 6
# Calquat_fruit 6
# Snakeskin_body 8
# Apple_sapling 6
# Earth_rune 6
# Abyssal_dagger_(p++) 4
# Steel_plateskirt_(t) 7
# Zenyte_necklace 9
# Teak_sapling 5
# Steel_platebody 8
# Teak_drawers 10
# Jade_necklace 5
# Mithril_bolts 6
# Torag's_helm 8
# Bronze_nails 6
# Opal_ring 5
# Stone_scarab 7
# Empty_oil_lantern 7
# Spottier_cape 8
# Oak_pyre_logs 5
# 3rd_age_platelegs 5
# Super_energy(3) 9
# Astral_rune 6
# White_beret 6
# Dragon_2h_sword 6
# Black_shield_(h5) 6
# Toy_doll 8
# Burnt_bones 6
# Mystic_smoke_staff 6
# Blue_wizard_hat_(g) 6
# Carved_oak_magic_wardrobe 8
# Wine_of_zamorak 7
# Uncharged_trident 9
# Ruby_dragon_bolts 5
# King_worm 6
# Ranging_mix(1) 8
# Batta_tin 6
# Magic_mix(2) 7
# Teak_dining_bench 10
# Unfinished_broad_bolts 7
# Oak_wardrobe 8
# Rune_platelegs 8
# Raw_jubbly 7
# Snakeskin 8
# Shayzien_scarf 1
# Bagged_willow_tree 8
# Opal_dragon_bolts 5
# Hat_eyepatch 6
# Team-12_cape 9
# Steel_dart_tip 8
# Zenyte_shard 7
# Blue_skirt_(t) 6
# Zamorak_d'hide_boots 7
# Adamant_spear 4
# White_2h_sword 7
# Ancient_platebody 6
# Ancient_medallion 4
# Flared_trousers 6
# Steel_bolts_(unf) 8
# Enchant_emerald_or_jade 6
# White_flowers 8
# Robin_hood_hat 7
# Dragon_hunter_lance 1
# Black_helm_(h3) 6
# Blue_flowers 7
# White_longsword 6
# Blue_firelighter 6
# Wildblood_seed 8
# Gold_headband 6
# Ring_of_wealth_scroll 7
# Premade_fr'_blast 7
# Highwayman_mask 6
# Pearl_bolt_tips 5
# Hunter_potion(1) 7
# Wooden_bench 8
# Lesser_demon_mask 5
# Bread_dough 6
# Pink_headband 6
# Ring_of_dueling(8) 8
# Adamant_shield_(h5) 4
# Magic_seed 7
# Ruby_necklace 7
# Bronze_kiteshield_(g) 6
# Wolf_bones 7
# Oil_lamp 6
# Menaphite_red_robe 7
# Rune_arrow(p) 8
# Barrel 6
# Waterskin(0) 8
# Mithril_kiteshield 6
# Dashing_kebbit_fur 6
# Mithril_dart 6
# Team-22_cape 9
# Cosmic_tiara 6
# Ancestral_robes_set 4
# Green_d'hide_chaps 6
# Dragon_spear(p++) 7
# Teak_magic_wardrobe 10
# Karil's_crossbow_0 8
# Iron_plateskirt_(g) 6
# Oak_toy_box 8
# Spiny_helmet 7
# Karil's_leatherskirt_0 7
# Rune_platebody_(g) 7
# Zamorak_full_helm 8
# Mos_le'harmless_teleport 6
# Adamant_dart(p+) 5
# Citizen_trousers 6
# Cup_of_hot_water 6
# Iron_crossbow 6
# Bandos_robe_top 6
# Bagged_plant_1 6
# Torture_ornament_kit 7
# Guthix_balance(2) 8
# Guthix_balance(1) 8
# Unstrung_comp_bow 8
# Guthix_page_3 6
# Dorgeshuun_crossbow 6
# Staff_of_water 8
# Leather_body 6
# Red_topaz_machete 7
# Steel_knife 8
# Fayrg_bones 6
# Egg 6
# Dragon_longsword 7
# Team-3_cape 9
# Raw_bass 7
# Proselyte_harness_f 9
# Rune_halberd 7
# Adamant_thrownaxe 4
# Torstol_seed 9
# Fremennik_black_cloak 7
# Desert_camo_legs 6
# Ancient_mace 5
# Dark_tuxedo_cuffs 5
# Elemental_talisman 6
# Raw_bird_meat 7
# Waterskin(4) 8
# Fire_tiara 6
# Raw_mud_pie 7
# Silver_sickle 8
# Old_school_bond 7
# Rune_helm_(h3) 7
# Adamant_gold-trimmed_set_(lg) 4
# Fishing_potion(3) 7
# Fremennik_green_cloak 7
# Onion 5
# Adamantite_nails 5
# Polar_kebbit_fur 6
# Iron_arrow(p+) 7
# Musketeer_pants 6
# Mithril_crossbow_(u) 6
# Unfinished_potion 8
# Unfired_pie_dish 8
# Pie_dish 5
# Runite_bolts_(p+) 8
# Guthix_armour_set_(sk) 6
# Premade_p'_punch 7
# Armadyl_crossbow 6
# Bronze_full_helm 6
# Mithril_dragon_mask 5
# Fishing_potion(4) 7
# Ensouled_horror_head 6
# Amulet_mould 5
# Ancient_crozier 5
# Team-48_cape 9
# Dharok's_greataxe_0 7
# Red_spiky_vambs 7
# Willow_blackjack(o) 8
# Supercompost 8
# Salve_graveyard_teleport 7
# Agility_potion(3) 6
# Dragonstone_bolts 6
# Black_knife(p+) 7
# Orange_boater 6
# Steel_javelin(p+) 9
# Dragon_mace 6
# Team-5_cape 9
# Unfired_pot 8
# White_sword 8
# Blue_elegant_skirt 6
# Grimy_avantoe 6
# Guthix_page_2 6
# Godsword_shard_1 6
# Blue_robe_top 7
# Team-8_cape 9
# Teasing_stick 7
# Amulet_of_glory_(t4) 6
# Pottery_scarab 6
# Black_spear 6
# Royal_crown 6
# Team-34_cape 9
# Ghrazi_rapier 4
# Sacred_oil(3) 8
# Dragon_bitter(m4) 7
# Oak_shaving_stand 8
# Shortbow_(u) 8
# Gold_elegant_shirt 6
# Vesta's_spear 4
# Ankou_mask 5
# Dharok's_platelegs_0 7
# Uncharged_toxic_trident 9
# Monkey_nuts 6
# Icy_basalt 4
# Red_headband 7
# Kraken_tentacle 6
# Mithril_set_(sk) 5
# Steel_sword 8
# Magic_roots 6
# Pottery_statuette 6
# Emerald_bolts_(e) 6
# Team-33_cape 9
# Green_dark_bow_paint 6
# Abyssal_dagger 4
# Ranger_boots 7
# Black_pickaxe 6
# Palm_tree_seed 7
# Black_warlock 7
# Proselyte_harness_m 9
# Cooked_rabbit 6
# Palm_sapling 6
# Drake_bones 1
# Super_combat_potion(4) 9
# Bandos_full_helm 6
# Black_shield_(h2) 6
# Samurai_boots 5
# Relicym's_mix(1) 8
# Dragon_dagger 7
# Mort_myre_stem 6
# Pineapple 6
# Long_kebbit_spike 7
# Grey_robe_bottoms 7
# Iron_dagger(p+) 7
# Strung_rabbit_foot 8
# Sanfew_serum(2) 8
# Larupia_legs 6
# Imbued_heart 5
# Revenant_cave_teleport 5
# Maple_stock 5
# Anti-venom(3) 7
# Iron_knife 6
# Ensouled_abyssal_head 6
# Silver_bolts_(p+) 9
# Armadyl_page_4 6
# Mahogany_logs 6
# Nose_peg 6
# Iron_platelegs 6
# Serum_207_(1) 8
# Yew_shortbow_(u) 8
# Black_toy_horsey 7
# Herring 6
# Premade_worm_hole 7
# Maple_bird_house 5
# Partyhat_&_specs 5
# Oak_sapling 6
# Black_spear(p+) 7
# Bastion_potion(4) 4
# Cheese+tom_batta 6
# Rune_arrow(p+) 8
# Magpie_impling_jar 6
# Iron_2h_sword 5
# Cadantine 6
# Team-28_cape 9
# Dragon_scimitar 7
# Black_d'hide_chaps_(t) 6
# Expeditious_bracelet 5
# Marigold_seed 7
# Te_salt 4
# Gnomebowl_mould 6
# Anchovy_pizza 5
# Bandos_stole 6
# Orange_sapling 6
# Mahogany_bird_house 5
# Tormented_bracelet 9
# Easter_egg 6
# Rock-shell_helm 7
# Monkfish 6
# Bronze_javelin(p+) 7
# Mith_crossbow 6
# Leaping_sturgeon 5
# Raw_sea_turtle 7
# Super_attack(3) 9
# Longbow 6
# Granite_hammer 5
# Zenyte_amulet_(u) 8
# Watchtower_teleport 9
# Orange_salamander 6
# Premade_w'm_batta 7
# Karidian_disguise 7
# Dragon_hunter_crossbow 5
# Ancient_dragonhide_set 5
# Maple_roots 6
# Dragonstone_bracelet 6
# Battlestaff 6
# Malediction_shard_3 6
# Mithril_plateskirt_(t) 6
# Wild_pie 7
# Iron_dart_tip 6
# Saradomin_godsword 7
# Blue_elegant_blouse 6
# Arceuus_hood 5
# Cave_goblin_wire 6
# Fish_food 7
# Banana_stew 7
# Extended_antifire_mix(2) 7
# Worm_hole 7
# Antifire_potion(4) 7
# Kebbit_teeth 6
# Red_topaz 7
# Green_dragonhide_set 6
# Teak_seed 5
# Moonlight_mead(4) 7
# Grimy_guam_leaf 7
# Ranging_potion(3) 8
# Black_longsword 7
# Adamant_javelin(p++) 5
# Red_hat 8
# Onyx_ring 6
# Mort'ton_teleport 6
# Marrentill_tar 6
# Chinchompa 6
# Thin_snail_meat 8
# Bandos_d'hide_boots 5
# Willow_roots 7
# Prayer_potion(1) 8
# Black_beret 6
# Turquoise_robe_bottoms 9
# Ring_of_pursuit 5
# Golden_scarab 6
# Pot_of_cream 6
# Rune_helm_(h4) 7
# Rune_kiteshield 8
# Anguish_ornament_kit 5
# Desert_devil_fur 6
# Cannon_stand 6
# Barley 6
# 3rd_age_vambraces 5
# Bracelet_of_clay 6
# Purple_flowers 8
# Beer_tankard 7
# Zamorak_platebody 8
# Ward_upgrade_kit 7
# Mystic_gloves_(light) 7
# Fedora 6
# Senntisten_teleport 7
# Fishing_bait 6
# Roe 7
# Mahogany_armchair 8
# Snowy_knight 9
# Thatch_spar_light 8
# Purple_elegant_blouse 7
# Magic_cape_rack 8
# Larupia_top 6
# Black_mask 6
# Ranging_potion(1) 8
# Poison_chalice 6
# Shrimps 7
# Acorn 5
# Gilded_magic_wardrobe 8
# Bandos_page_3 6
# Adamant_trimmed_set_(lg) 4
# Slayer's_staff 8
# Jar_of_miasma 6
# Secateurs 7
# Black_chainbody 6
# Mackerel 6
# Papaya_fruit 6
# Red_dragonhide 7
# Cake_tin 6
# Topaz_dragon_bolts 5
# Blue_elegant_shirt 6
# Team-11_cape 9
# Yellow_bead 8
# Bronze_bar 6
# Saradomin_dragonhide_set 7
# Extended_antifire(2) 7
# Bronze_axe 6
# Amulet_of_power 5
# Ranging_potion(2) 7
# Raw_chicken 8
# Team-49_cape 9
# Mithril_mace 6
# Fremennik_robe 6
# Oak_magic_wardrobe 8
# Barb_bolttips 6
# Guthix_dragonhide_set 6
# Grey_hat 7
# Willow_bird_house 4
# Extended_super_antifire(2) 5
# Opal_amulet 5
# Krandorian_hops 6
# Spinach_roll 8
# Mahogany_pyre_log 7
# Raw_chompy 7
# Belladonna_seed 7
# Lemon 6
# Iron_full_helm 6
# Purple_cape 8
# Steel_limbs 8
# Guam_leaf 6
# Frog-leather_chaps 6
# Wrath_tiara 3
# Soul_rune 8
# Dragon_metal_lump 5
# Adamant_longsword 4
# Sulliuscep_cap 5
# Gilded_wardrobe 8
# Bow_string 6
# Olive_oil(1) 7
# Seers_ring 7
# Cabbage_seed 7
# Adamant_claws 4
# Iron_halberd 6
# Diamond_amulet 6
# Cooking_apple 6
# White_halberd 7
# Cadantine_potion_(unf) 6
# Dharok's_greataxe 6
# Samurai_gloves 6
# Amulet_of_fury 5
# Steel_spear(p) 9
# Adamant_battleaxe 4
# Roast_rabbit 7
# Light_tuxedo_jacket 5
# Malediction_ward 6
# Yellow_feather 8
# Pot_lid 6
# Carved_teak_table 8
# Unfired_bowl 8
# Splitbark_gauntlets 9
# Raw_beast_meat 7
# Trout 8
# Bones_to_bananas 6
# Lantadyme_potion_(unf) 6
# Sandstone_(1kg) 9
# Red_chinchompa 7
# Raw_trout 6
# Steel_full_helm_(g) 6
# Axeman's_folly 6
# Adamant_javelin_heads 4
# Dark_bow_tie 5
# Topaz_bolts 8
# Rune_kiteshield_(t) 7
# Black_trimmed_set_(sk) 6
# Dagannoth_bones 6
# Steel_crossbow_(u) 8
# Body_talisman 6
# White_dagger(p++) 8
# Bandos_boots 6
# Energy_mix(2) 7
# Guthix_rest(2) 7
# Adamant_knife 4
# Team-4_cape 9
# Blue_beret 6
# Snapdragon_potion_(unf) 8
# Bronze_spear(p+) 7
# Eye_of_newt 6
# Rune_claws 7
# Crossbow_string 6
# Hunter_potion(4) 7
# Doogle_leaves 7
# Sinew 8
# Desert_boots 6
# Bolt_of_cloth 6
# Loar_remains 5
# Raw_oomlie 7
# Armadyl_rune_armour_set_(lg) 6
# Gilded_2h_sword 5
# Leather_cowl 6
# Bagged_plant_3 6
# Steel_bar 9
# Black_dart(p++) 7
# Serpentine_visage 7
# Celastrus_sapling 1
# Emerald_amulet 6
# Black_platebody_(t) 6
# Zamorak_brew(1) 9
# Steam_battlestaff 8
# White_platebody 7
# Rock-shell_legs 7
# Ahrim's_hood_0 6
# Elemental_shield 6
# Iron_arrow(p) 7
# Crunchy_tray 6
# Rune_dart 7
# Chilli_potato 6
# Bracelet_mould 6
# Bagged_sunflower 8
# Ancient_statuette 5
# Yew_roots 8
# Greenmans_ale(4) 7
# Cake 6
# Gardening_boots 6
# Super_defence(2) 9
# Defence_potion(3) 7
# Cannon_base 6
# Rune_gold-trimmed_set_(lg) 7
# Ancient_robe_legs 6
# Adamant_platelegs 4
# Skeletal_top 8
# Fishing_mix(2) 7
# Bronze_scimitar 6
# Raw_karambwan 7
# Maple_blackjack(d) 7
# Emerald_ring 6
# Super_antifire_potion(1) 5
# Spice 8
# Pure_essence 7
# Lumbridge_graveyard_teleport 6
# Bowl_wig 5
# Water_battlestaff 8
# Cosmic_talisman 6
# Iron_hasta(p++) 6
# Iron_platebody 6
# White_chainbody 7
# Armadyl_page_2 6
# Mithril_dart_tip 7
# Rune_shield_(h3) 7
# Magic_string 6
# Magic_longbow_(u) 6
# Archers_ring 6
# Mithril_spear 6
# Magic_shortbow 6
# White_mace 7
# Zamorak_coif 8
# Gilded_plateskirt 6
# Chopped_tuna 6
# Malediction_shard_2 6
# Cactus_spine 6
# Dharok's_platelegs 6
# Steel_arrow 8
# Black_headband 6
# Piscarilius_banner 5
# Bowl_of_water 6
# Moonlight_mead(m) 7
# Adamant_bolts(unf) 6
# Ensouled_giant_head 6
# Purple_sweets 7
# Rock-climbing_boots 7
# Rune_armour_set_(sk) 7
# Drake's_claw 1
# Mithril_kiteshield_(t) 6
# Cocktail_shaker 6
# White_full_helm 7
# Mithril_plateskirt_(g) 6
# Team-30_cape 8
# Black_knife(p) 7
# Dwellberry_seed 7
# Adamant_helm_(h3) 4
# Silver_dust 7
# Penguin_mask 5
# Dharok's_armour_set 6
# Mithril_halberd 6
# Big_bones 6
# Mystic_gloves 6
# Mahogany_toy_box 8
# Black_set_(lg) 6
# Saradomin_bracers 7
# Green_cape 7
# Strength_potion(1) 9
# Dagannoth_hide 6
# Comp_ogre_bow 6
# Black_helm_(h2) 6
# Old_demon_mask 5
# Black_sword 6
# Amulet_of_glory(6) 6
# Bronze_thrownaxe 6
# Plant_cure 6
# Strawberries(5) 9
# Chisel 6
# Mystic_fire_staff 6
# Steel_arrow(p) 8
# Thorny_hedge 10
# Cactus_seed 7
# Rocking_chair 9
# Yellow_dye 8
# Ribcage_piece 7
# Steel_dart(p) 9
# Pineapple_sapling 6
# White_dark_bow_paint 7
# Blamish_bark_shell 6
# Piscarilius_scarf 5
# Elemental_helmet 6
# Yellow_robe_bottoms 9
# Bracelet_of_ethereum_(uncharged) 5
# Teak_fancy_dress_box 10
# Ancient_stole 6
# Fat_snail_meat 6
# Leprechaun_hat 5
# Iron_trimmed_set_(sk) 6
# Dragon_dart(p) 7
# 3rd_age_amulet 5
# Rosemary_seed 8
# Bob's_green_shirt 6
# Mithril_platelegs_(t) 6
# Light_tuxedo_cuffs 5
# Black_warhammer 6
# Merfolk_trident 5
# Evil_chicken_feet 5
# Amulet_of_torture 5
# Willow_shortbow_(u) 7
# Explorer_backpack 6
# Premade_t'd_batta 7
# Steel_arrowtips 8
# Mithril_ore 6
# Bronze_kiteshield 6
# Amethyst_arrow 4
# Blue_d'hide_vamb 6
# Amulet_of_strength 5
# Desert_robe 6
# Long_kebbit_bolts 6
# Dragonstone_dragon_bolts 5
# Steel_platelegs 8
# Leaping_trout 6
# Team-38_cape 9
# Guthix_stole 7
# Black_d'hide_vamb 6
# Team-14_cape 9
# Sacred_oil(4) 8
# Bass 6
# Premade_wiz_blz'd 7
# Fremennik_yellow_cloak 7
# Ensouled_tzhaar_head 6
# Verac's_brassard_0 9
# Saradomin_plateskirt 7
# Rune_sq_shield 8
# Obsidian_helmet 5
# Robe_bottom_of_darkness 6
# Ring_of_suffering 8
# Obsidian_armour_set 5
# Apples(5) 7
# Iron_crossbow_(u) 6
# White_berries 7
# Frying_pan 6
# Red_d'hide_chaps 7
# Onyx_amulet_(u) 6
# Bread 6
# Tomatoes(5) 9
# Armadyl_coif 6
# Raw_rainbow_fish 7
# Enchant_onyx 6
# Leather_chaps 6
# 3rd_age_full_helmet 5
# Plain_pizza 6
# Kebab_mix 5
# Grimy_lantadyme 6
# Anglerfish 7
# Amulet_of_glory(4) 6
# Wooden_spoon 7
# Restore_potion(1) 8
# Raurg_bones 7
# Tarromin_seed 9
# Steel_spear(p++) 8
# Steel_gold-trimmed_set_(lg) 7
# Studded_body 8
# Saradomin_d'hide_boots 6
# Fire_rune 6
# Rune_scimitar 7
# Red_halloween_mask 8
# Verac's_flail_0 8
# Ham_cloak 6
# Team-35_cape 9
# Granite_(2kg) 8
# Saw 7
# Impling_jar 6
# Yew_seed 9
# Rune_spear(p+) 8
# Sleeping_cap 8
# Evil_chicken_legs 5
# Blue_hat 7
# Oyster_pearl 6
# Runite_bar 6
# Iron_trimmed_set_(lg) 6
# Dragonstone_bolt_tips 6
# Gold_elegant_blouse 6
# Guthix_platebody 5
# Krandorian_seed 6
# Cadavaberry_seed 7
# Bandos_rune_armour_set_(lg) 6
# Nardah_teleport 6
# Adamant_arrow(p++) 5
# Rune_dart_tip 7
# Primordial_boots 7
# Red_dragon_mask 7
# Mithril_spear(p+) 7
# Mithril_brutal 5
# Charge_dragonstone_jewellery_scroll 5
# Iron_bar 6
# Super_antifire_mix(2) 5
# Black_spear(p) 7
# Steel_knife(p++) 9
# Orange_feather 5
# Samurai_kasa 6
# Hunting_mix(2) 7
# Super_restore(2) 9
# Empty_cup 6
# Proselyte_cuisse 6
# Crystal_key 6
# Kwuarm_potion_(unf) 6
# Body_tiara 6
# Zamorak_chaps 7
# Steel_claws 8
# Tzhaar-ket-em 8
# Eternal_gem 5
# Dragonbone_necklace 5
# Dark_tuxedo_jacket 5
# Spirit_shield 8
# Magic_stone 6
# Blue_d'hide_body 7
# Adamant_dagger 4
# Dark_infinity_colour_kit 6
# Guam_tar 6
# Topaz_bolt_tips 7
# Heavy_frame 6
# Wrapped_oomlie 7
# Black_d'hide_body_(t) 6
# Onion_seed 7
# White_battleaxe 7
# Adamant_plateskirt_(g) 4
# Black_plateskirt_(g) 6
# Royal_gown_top 7
# Asgarnian_ale(4) 7
# Black_bead 6
# Sapphire_bolt_tips 7
# Raw_monkfish 7
# Steam_staff_upgrade_kit 8
# White_elegant_skirt 7
# Fremennik_gloves 7
# Mahogany_bookcase 7
# Menaphite_purple_hat 7
# Raw_fish_pie 7
# Bronze_halberd 6
# Justiciar_legguards 4
# Airtight_pot 5
# Climbing_boots 6
# Brown_toy_horsey 7
# Black_sq_shield 6
# Broken_bark_snelm 6
# Yew_comp_bow 8
# Guthix_bracers 6
# Armadyl_platebody 6
# Onyx_bolts 6
# Yellow_boots 9
# Guthan's_helm_0 7
# Zamorak_bracers 7
# Armadyl_d'hide_boots 5
# Coconut_milk 6
# Iron_dart(p+) 7
# Light_trousers 5
# Javelin_shaft 6
# Fire_orb 6
# Magic_pyre_logs 6
# Granite_longsword 4
# Mithril_scimitar 6
# Gnomeball 6
# Diamond_amulet_(u) 6
# 3rd_age_bow 5
# White_apron 7
# Saradomin_robe_legs 7
# Cooked_karambwan 6
# Yanillian_seed 9
# Ugthanki_meat 8
# Iron_thrownaxe 6
# White_scimitar 6
# Desert_camo_top 6
# Green_headband 5
# Team-42_cape 9
# Adamant_arrow(p+) 5
# Poison 7
# Iron_limbs 6
# Saradomin_sword 7
# Drake's_tooth 1
# Mining_helmet 6
# Jug_of_water 5
# Iron_kiteshield 6
# Yew_bird_house 5
# White_unicorn_mask 6
# Ensouled_monkey_head 6
# Young_impling_jar 8
# Guthan's_chainskirt_0 7
# Tatty_kyatt_fur 7
# Partyhat_set 5
# Bandos_hilt 6
# Charcoal 6
# Toadflax 8
# Iron_knife(p++) 7
# Mithril_trimmed_set_(lg) 6
# Extended_super_antifire_mix(1) 6
# Fur 6
# Green_elegant_blouse 6
# Bagged_nice_tree 6
# Snape_grass_seed 1
# Air_battlestaff 5
# Diamond_ring 6
# Deerstalker 6
# 3rd_age_longsword 5
# Bronze_set_(sk) 6
# Bandos_chaps 6
# Adamant_bolts_(p++) 6
# Dragon_knife(p) 1
# Pink_elegant_legs 6
# Incomplete_light_ballista 6
# Baby_impling_jar 6
# Red_dye 6
# Steel_dagger(p) 9
# Cocktail_guide 6
# Bronze_set_(lg) 6
# Gilded_full_helm 6
# Dragon_chainbody_ornament_kit 8
# Gilded_dresser 8
# Ensouled_goblin_head 6
# Armadyl_cloak 6
# Botanical_pie 5
# Blue_dragon_scale 6
# Wrath_talisman 4
# Archery_ticket 7
# Iron_javelin 6
# White_headband 7
# Robe_top_of_darkness 6
# Rune_essence 7
# Adamant_gold-trimmed_set_(sk) 4
# Menaphite_purple_robe 7
# Mithril_longsword 6
# Bird_snare 6
# Dragon_arrow(p+) 7
# Shears 7
# Uncooked_mushroom_pie 5
# Pink_boots 7
# Purple_hat 8
# Brandy 6
# Iron_platelegs_(g) 6
# Bronze_platelegs_(g) 6
# Four-poster_bed 8
# Green_hat 7
# Enchant_dragonstone 6
# Battlemage_potion(4) 4
# Larupia_fur 6
# Sapphire_amulet 7
# Bronze_arrow(p++) 7
# Studded_chaps 8
# Pirate_hat_&_patch 6
# Adamant_shield_(h3) 4
# Whiteberry_seed 8
# Sandworms 7
# Iron_boots 6
# Bandos_mitre 6
# Archer_helm 6
# Arcane_spirit_shield 6
# Super_antifire_mix(1) 4
# Lava_dragon_bones 6
# Pestle_and_mortar 4
# Tinderbox 7
# Menaphite_red_top 7
# Beanie 6
# Rune_med_helm 8
# Zombie_head 7
# Ruby_dragon_bolts_(e) 5
# Magic_essence_mix(1) 7
# Light_orb 6
# Iron_chainbody 5
# Bronze_arrow(p+) 7
# Dexterous_prayer_scroll 5
# Flattened_hide 6
# Unblessed_symbol 8
# Saradomin_stole 7
# Compost_potion(1) 7
# Spider_on_shaft 8
# Black_dagger(p++) 7
# Hill_giant_club 5
# Bronze_brutal 6
# Dragon_sq_shield 6
# Briefcase 6
# Black_platelegs 6
# Steel_longsword 7
# Bloody_bracer 4
# Bandos_godsword_ornament_kit 5
# Teak_kitchen_table 10
# Dragon_bolts_(p++) 5
# Ancient_staff 6
# Antidote++(1) 7
# Zul-andra_teleport 8
# Beer 6
# Jade_bolt_tips 6
# Adamant_shield_(h2) 4
# Amethyst_bolt_tips 4
# Mystic_earth_staff 7
# Graahk_legs 6
# Black_cape 7
# Hardleather_body 6
# Team-16_cape 9
# Raw_summer_pie 7
# Sapphire_bracelet 7
# Premade_ttl 7
# Lime_chunks 6
# Dragonstone_dragon_bolts_(e) 5
# Desert_goat_horn 6
# Iron_nails 6
# Staff_of_light 5
# Rune_battleaxe 8
# Mud_battlestaff 6
# Blue_dragon_leather 6
# Serum_207_(4) 8
# Gold_necklace 6
# Team-40_cape 9
# Black_mask_(10) 8
# Purple_elegant_skirt 6
# Spiked_boots 8
# Strength_mix(2) 9
# Nature_rune 7
# Holy_elixir 6
# Diamond_bracelet 6
# Dragon_dagger(p++) 7
# Steel_hasta 8
# Stripy_feather 7
# Wooden_chair 9
# Dharok's_helm 6
# Bandos_coif 6
# Superantipoison(4) 9
# Ruby_bolts_(e) 7
# Fishing_potion(2) 7
# Adamant_helm_(h4) 4
# Compost 6
# Locust_meat 8
# Onyx 6
# Bandos_rune_armour_set_(sk) 6
# Black_salamander 6
# Limestone_brick 6
# Adamant_bolts_(p) 6
# Achey_tree_logs 4
# Zamorak_robe_top 8
# Purple_firelighter 7
# Mithril_battleaxe 6
# Thammaron's_sceptre_(u) 4
# Goblin_mask 6
# Bandos_page_1 6
# Fremennik_hat 6
# Lantern_lens 5
# Greenman's_ale 6
# Black_halberd 6
# Ancient_blessing 4
# Zamorak_crozier 8
# Torstol_potion_(unf) 8
# Mithril_plateskirt 6
# Mystic_boots 6
# Ranarr_potion_(unf) 7
# Jade_amulet 5
# Bullseye_lantern 6
# Revenant_ether 5
# Ape_atoll_teleport 6
# Ring_of_wealth 7
# Bronze_hasta(p+) 7
# Mithril_javelin(p++) 7
# Guthix_chaps 6
# Mithril_platelegs_(g) 6
# A_powdered_wig 4
# Bronze_dagger(p++) 7
# Drunk_dragon 6
# Rune_axe 8
# Larupia_hat 6
# Tatty_larupia_fur 7
# Onyx_bolt_tips 6
# Mahogany_sapling 5
# Pile_of_salt 7
# Red_d'hide_chaps_(g) 7
# Bandos_cloak 6
# Citizen_top 6
# Amulet_of_glory_(t6) 6
# Extended_super_antifire(3) 5
# Lovakengj_hood 4
# Rune_spear 8
# Big_pirate_hat 6
# Marrentill_potion_(unf) 6
# Uncut_onyx 7
# Marble_block 6
# Mithril_dagger 6
# Dragon_necklace 6
# Black_platelegs_(g) 6
# Bones 6
# Crystal_seed 7
# Vesta's_longsword 4
# Purple_elegant_legs 7
# Jar_of_souls 6
# Diamond_bolts_(e) 6
# Spicy_crunchies 8
# Tuna_potato 8
# Dharok's_platebody 6
# Abyssal_bracelet(5) 5
# Desert_legs 6
# Woad_leaf 7
# Rune_hasta(p) 8
# Nature_tiara 6
# Vyrewatch_shoes 6
# Uncooked_botanical_pie 7
# Premade_ch'_crunch 7
# Steel_dragon_mask 8
# Karambwan_vessel 1
# Dragon_platelegs 7
# Black_kiteshield 6
# Anti-poison_supermix(2) 7
# Lumbridge_teleport 6
# Pineapple_ring 6
# Black_knife(p++) 7
# Extended_super_antifire_mix(2) 5
# Swamp_toad 8
# Hunters'_crossbow 7
# Slayer_bell 7
# Red_flowers 8
# Glassblowing_pipe 6
# Saradomin_page_3 7
# Super_combat_potion(2) 9
# Guthix_full_helm 6
# Cannonball 7
# Strength_potion(4) 9
# Bandos_robe_legs 6
# Blue_dragonhide 6
# Vial 7
# Agility_potion(1) 6
# Team-7_cape 9
# Leaf-bladed_sword 6
# Dragon_dart(p++) 7
# Compost_potion(2) 7
# Green_boots 7
# Rune_cane 7
# Monocle 6
# Castle_wars_bracelet(3) 7
# Adamant_arrow 4
# White_sq_shield 7
# Menaphite_purple_kilt 7
# Rune_spear(p++) 8
# Dragon_javelin_heads 6
# Mushroom_&_onion 8
# Armadyl_bracers 6
# Rangers'_tunic 7
# Jug 6
# Verac's_brassard 7
# Mystic_robe_top_(light) 7
# Green_partyhat 6
# Samurai_greaves 6
# Lime_slices 6
# Teak_bird_house 5
# Dragon_chainbody 6
# Super_restore(3) 9
# Dark_bow 6
# Spicy_sauce 8
# Flighted_ogre_arrow 7
# Skeletal_visage 5
# Raw_rat_meat 7
# Super_attack(1) 9
# Battlemage_potion(2) 4
# Team-37_cape 9
# Emerald_necklace 6
# Silver_bolts_(unf) 8
# Bronze_pickaxe 6
# Unstrung_emblem 7
# Cabbages(10) 7
# Ancient_plateskirt 6
# Rune_hasta(p+) 9
# Toy_doll_(wound) 10
# Green_dragon_mask 6
# Morrigan's_javelin 4
# Cabbage_round_shield 5
# Monkey_bones 6
# Antipoison(3) 7
# Fancy_hedge 8
# Pirate's_hat 6
# Brown_headband 6
# Chef's_hat 6
# Cider_barrel 8
# Zamorak_monk_top 17
# Dwarf_weed_potion_(unf) 6
# Bronze_plateskirt_(t) 6
# Mithril_bar 7
# Magic_shortbow_scroll 5
# Extended_antifire(3) 7
# Rune_gold-trimmed_set_(sk) 7
# Jade_ring 5
# Mirror_shield 6
# Bronze_dagger 6
# Pith_helmet 6
# Mummy's_body 5
# Mithril_chainbody 6
# Apprentice_wand 6
# Iron_pickaxe 6
# Magic_shield 5
# Blue_d'hide_chaps_(t) 6
# Goat_horn_dust 6
# Sacred_oil(1) 8
# Polar_camo_top 6
# Runite_bolts_(unf) 7
# Staff_of_earth 8
# Snapdragon 8
# Iron_bolts_(unf) 6
# Rune_full_helm_(t) 7
# Zamorak's_grapes 5
# Dark_fishing_bait 6
# Dragon_limbs 5
# Bronze_dart 6
# Steel_kiteshield 8
# Topaz_ring 5
# Wrath_rune 4
# Black_full_helm_(g) 6
# Ensouled_aviansie_head 6
# Enchanted_robe 6
# Amulet_of_eternal_glory 4
# 3rd_age_robe_top 5
# Runite_bolts_(p) 9
# Rune_shield_(h5) 6
# Bronze_dart(p++) 7
# Blue_headband 6
# Magic_staff 6
# Ancient_mitre 5
# Fremennik_skirt 6
# Odium_shard_1 6
# Mithril_dart(p) 7
# Strength_mix(1) 8
# Large_oak_bed 8
# Green_elegant_shirt 6
# Bone_spear 6
# Red_cape 7
# Lime 6
# Asgarnian_ale 6
# Rune_armour_set_(lg) 7
# Arcane_prayer_scroll 5
# Black_dragon_leather 6
# Fire_talisman 6
# Gold_elegant_skirt 6
# Gilded_cape_rack 8
# Scythe_of_vitur_(uncharged) 4
# Mithril_claws 6
# Babydragon_bones 6
# Sweetcorn_seed 9
# Saradomin_crozier 7
# Steel_hasta(p) 9
# Orange_cape 7
# Super_strength(3) 9
# Bottled_dragonbreath_(unpowered) 1
# Crier_bell 5
# Team-46_cape 9
# Steel_scimitar 8
# Black_gold-trimmed_set_(sk) 6
# Silver_bar 8
# Adamant_hasta(p) 5
# Raw_cave_eel 7
# Iron_spear(p++) 7
# Strength_amulet_(t) 8
# Xerician_robe 8
# Bronze_wire 6
# Dragon_kiteshield_ornament_kit 5
# Bob's_purple_shirt 6
# Zamorak_platelegs 8
# Ensouled_dagannoth_head 6
# Eternal_crystal 6
# Super_def._mix(2) 9
# Barb-tail_harpoon 6
# Super_antifire_potion(2) 5
# Bagged_daffodils 8
# Dark_crab 6
# Ham_logo 6
# Compost_potion(4) 7
# Butterfly_net 6
# Oak_longbow_(u) 7
# Dragonstone_ring 6
# Zamorak_mitre 8
# Rune_dagger(p++) 8
# Studded_chaps_(t) 8
# Bastion_potion(3) 4
# Worm_batta 7
# Curry_sapling 6
# Pantaloons 6
# Torag's_platebody 8
# Dragon_harpoon 5
# Verac's_flail 7
# Blurberry_special 6
# Superantipoison(2) 9
# Bag_of_salt 6
# Adamant_knife(p+) 5
# Dragon_sword 5
# Lava_battlestaff 7
# Relicym's_balm(2) 8
# Ring_of_life 7
# Granite_maul 6
# Saradomin_armour_set_(lg) 7
# Scrambled_egg 7
# Bottle_of_wine 6
# Adamant_trimmed_set_(sk) 4
# Egg_whisk 6
# Armadyl_chainskirt 6
# Light_ballista 6
# Oak_bird_house 5
# Team-32_cape 9
# Steel_battleaxe 8
# Crude_chair 8
# Wizard_boots 7
# Red_partyhat 7
# Super_energy(1) 9
# Rune_trimmed_set_(lg) 7
# Dharok's_platebody_0 7
# Bronze_bolts_(p+) 7
# Black_dragonhide_set 6
# Saradomin_armour_set_(sk) 7
# Jar_of_dirt 6
# Prayer_potion(2) 8
# Gardening_trowel 6
# Pest_control_teleport 5
# Menaphite_red_hat 7
# Antipoison_mix(1) 7
# Pyrophosphite 5
# Bronze_plateskirt_(g) 6
# Rune_dagger 7
# Mind_rune 6
# Mithril_platelegs 6
# Team-36_cape 9
# Jute_seed 6
# Leaping_salmon 6
# Mithril_platebody_(g) 6
# Guthix_coif 6
# Lumberyard_teleport 6
# Linen 7
# Willow_blackjack(d) 8
# Prayer_potion(3) 8
# Lava_staff_upgrade_kit 5
# Energy_potion(2) 7
# Watermelon_slice 7
# Tanzanite_fang 8
# Combat_potion_set 6
# Avantoe_seed 7
# Shaving_stand 9
# Adamant_bolts 5
# Skeletal_helm 8
# Dragon_full_helm 6
# Raw_pike 7
# Magic_comp_bow 6
# Guthix_balance(4) 8
# Odium_ward 6
# Chopped_garlic 6
# Ham_hood 6
# Dwarven_helmet 6
# Bryophyta's_essence 4
# Musketeer_hat 5
# Hosidius_hood 5
# Mithril_javelin_heads 6
# Pumpkin 7
# Dragon_metal_slice 5
# Mithril_warhammer 6
# Cocktail_glass 6
# Calquat_keg 6
# Mithril_arrow 6
# Team-15_cape 9
# Diamond_dragon_bolts 5
# 3rd_age_wand 4
# Fremennik_grey_cloak 7
# Karil's_coif 6
# Desert_robes 6
# Combat_bracelet(6) 7
# Willow_logs 6
# Grey_robe_top 7
# Jade_dragon_bolts 5
# Chef's_delight(m) 7
# Bronze_platelegs_(t) 6
# Justiciar_chestguard 4
# Black_gold-trimmed_set_(lg) 6
# Damaged_monkey_tail 5
# Dragon_defender_ornament_kit 5
# Mystic_hat_(light) 7
# Kharidian_headpiece 6
# Raw_shrimps 7
# Mystic_mist_staff 5
# Snakeskin_boots 8
# Garlic_powder 7
# Pearl_dragon_bolts_(e) 4
# Nature_impling_jar 6
# Berserker_helm 6
# Verac's_plateskirt_0 8
# Trading_sticks 8
# Infinity_hat 6
# Pie_shell 5
# Super_combat_potion(1) 9
# Holy_mould 6
# Large_teak_bed 8
# Spotted_kebbit_fur 8
# Granite_(5kg) 8
# Druid's_robe_top 6
# Spork 8
# Baked_potato 6
# Fremennik_red_cloak 7
# Mind_bomb(m4) 7
# Bagged_maple_tree 6
# Manta_ray 6
# Oyster 6
# Onyx_dragon_bolts 5
# Godsword_blade 6
# Amulet_of_accuracy 5
# Meat_pie 6
# Black_helm_(h5) 6
# Ivory_comb 6
# Blue_dye 6
# Jungle_camo_top 6
# Toktz-ket-xil 8
# Bronze_hasta 6
# Graahk_top 5
# Gnome_goggles 6
# Ensouled_chaos_druid_head 6
# Spicy_tomato 8
# Adamant_knife(p++) 5
# Imp_mask 6
# Dwarf_cannon_set 6
# Bronze_battleaxe 6
# Green_dragon_leather 6
# Yellow_robe_top 9
# Amethyst 4
# Kebbit_claws 6
# Lemon_chunks 6
# Kebbit_teeth_dust 6
# Sanguinesti_staff_(uncharged) 4
# Adamant_full_helm_(g) 4
# Cream_boots 7
# Super_restore_mix(1) 9
# White_lily_seed 1
# Red_firelighter 7
# Steel_thrownaxe 8
# Armadyl_robe_legs 6
# Cornflour 8
# Mist_rune 6
# Serum_207_(2) 8
# Steel_arrow(p++) 9
# Antidote+(4) 7
# Mushroom_potato 6
# Mithril_full_helm_(g) 6
# Defence_mix(1) 7
# Steel_javelin 8
# White_dagger 7
# Pink_boater 5
# Ancestral_hat 4
# Light_tuxedo_shoes 5
# Superior_dragon_bones 5
# Raw_mackerel 7
# Strange_fruit 8
# Ruby_amulet_(u) 7
# Fried_onions 6
# Rune_knife(p) 8
# Granite_shield 6
# Rune_knife 7
# Maple_shortbow_(u) 6
# Red_elegant_skirt 7
# Woad_seed 8
# Black_elegant_legs 6
# Light_frame 6
# Kebbit_spike 6
# Iron_javelin(p+) 7
# Dragon_crossbow_(u) 5
# Adamant_javelin(p+) 5
# Antidote+(3) 7
# White_claws 7
# Antidote++(4) 7
# Topaz_bolts_(e) 8
# Saradomin_full_helm 7
# Verac's_plateskirt 7
# Seed_dibber 7
# Fremennik_beige_shirt 7
# Pineapple_chunks 6
# Ruby_amulet 7
# Phoenix_necklace 5
# Turquoise_robe_top 9
# Arrow_shaft 6
# Saradomin_hilt 7
# Black_spiky_vambs 6
# Beer_glass 6
# Bastion_potion(1) 4
# Premade_t'd_crunch 7
# Team-18_cape 8
# Facemask 7
# Swamp_paste 9
# Ancient_emblem 4
# Restore_mix(2) 8
# Blue_halloween_mask 7
# Team-9_cape 9
# Roast_beast_meat 7
# Green_robe_top 7
# Fremennik_brown_cloak 7
# Draynor_manor_teleport 6
# Saradomin_cloak 7
# Rock_thrownhammer 5
# Brass_necklace 6
# Veg_ball 7
# Ancient_kiteshield 5
# Master_scroll_book_(empty) 5
# Cooked_oomlie_wrap 6
# Dragon_knife(p+) 1
# Ensouled_dragon_head 6
# Whisky 7
# Topaz_dragon_bolts_(e) 5
# Red_beret 7
# Ensouled_scorpion_head 6
# Warrior_ring 8
# Shaman_mask 5
# Elder_chaos_top 5
# Cannon_furnace 6
# Steel_platebody_(g) 7
# Monk's_robe_top_(g) 5
# Wooden_shield 7
# Dragon_arrowtips 6
# Law_rune 6
# Armadyl_page_3 6
# Obsidian_cape 6
# Dragonstone_bolts_(e) 6
# Guthan's_warspear 6
# Samurai_shirt 6
# Hammerstone_seed 7
# Anti-venom(1) 7
# Iron_set_(lg) 6
# Steel_platebody_(t) 6
# Attack_potion(2) 7
# Rune_javelin 7
# Agility_mix(2) 6
# Gilded_med_helm 5
# Steel_dagger 7
# Karil's_crossbow 6
# Bandos_crozier 6
# Ardougne_teleport 6
# Double_eye_patch 5
# Rune_arrowtips 7
# Binding_necklace 6
# Black_platelegs_(t) 6
# Hammerstone_hops 6
# Antidote+(2) 7
# Ham_gloves 6
# Adamant_sq_shield 4
# Wooden_bed 9
# Chaos_talisman 6
# Mystic_gloves_(dark) 7
# Games_necklace(8) 7
# Zamorak_plateskirt 8
# Bear_fur 6
# Spotted_cape 8
# Amethyst_arrow(p+) 4
# Feather 6
# Eternal_boots 6
# Ancient_page_3 5
# Anti-venom(4) 7
# Treasonous_ring 8
# Holy_sandals 5
# Uncut_red_topaz 7
# Curry 6
# Ahrim's_hood 5
# Annakarl_teleport 6
# White_dagger(p+) 8
# Teal_gloves 9
# Iron_brutal 6
# Dragonfire_ward 5
# Obsidian_platebody 5
# Tarromin_tar 8
# Steel_boots 8
# Onyx_amulet 6
# Stale_baguette 6
# Bronze_trimmed_set_(lg) 6
# Fiyr_remains 6
# Team-10_cape 9
# Armadyl_page_1 6
# War_blessing 6
# Bronze_boots 6
# Black_mace 6
# Bandos_tassets 6
# Iron_axe 6
# Fire_battlestaff 6
# Emerald 6
# Ancient_full_helm 5
# Axeman's_folly(m) 7
# Saltpetre 7
# Iron_javelin_heads 6
# Gilded_armour_set_(sk) 6
# Bronze_sq_shield 6
# Primordial_crystal 7
# Light_bow_tie 5
# Papaya_tree_seed 7
# Premade_c+t_batta 7
# Dwarven_stout(4) 7
# Guthix_kiteshield 6
# Boots_of_darkness 5
# Adamant_plateskirt 4
# Orange_slices 6
# Bronze_bolts_(unf) 6
# Diamond_bolts 7
# Black_2h_sword 6
# Bronze_platebody 6
# Jade_amulet_(u) 4
# Oak_chair 8
# Asyn_remains 6
# Raw_tuna 7
# Mystic_boots_(light) 6
# Stew 8
# Book_of_war_page_set 6
# Sandstone_(2kg) 9
# Thatch_spar_dense 8
# Phrin_remains 5
# Bob's_black_shirt 6
# Teak_armchair 10
# Ahrim's_staff 5
# Runite_crossbow_(u) 7
# Christmas_cracker 6
# Super_energy_mix(1) 9
# Team_cape_zero 6
# Bandos_dragonhide_set 6
# Slayer's_respite(m4) 9
# Godsword_shard_2 6
# Amulet_of_magic_(t) 5
# Dragon_metal_shard 5
# Ankou_gloves 5
# Bracelet_of_slaughter 5
# Tyras_helm 7
# Guthix_rest(3) 7
# Twisted_bow 5
# Grimy_harralander 6
# Musketeer_tabard 6
# Wolfbone_arrowtips 7
# Armadyl_chestplate 6
# White_cavalier 7
# Teak_cape_rack 10
# Saradomin_platelegs 7
# Black_boater 6
# Infinity_gloves 6
# Tan_cavalier 8
# Topiary_hedge 10
# Cavalier_mask 6
# Bucket_helm 5
# Black_wizard_robe_(g) 6
# Green_d'hide_body 7
# Iron_warhammer 6
# Armadyl_plateskirt 6
# Bronze_spear(p++) 7
# Pirate's_hook 6
# Green_d'hide_chaps_(t) 6
# Combat_bracelet 6
# Ground_guam 6
# Mystic_mud_staff 5
# Super_potion_set 7
# Carrallangar_teleport 6
# Toy_mouse_(wound) 10
# Granite_(500g) 8
# Black_chinchompa 6
# Oak_armchair 8
# Fancy_teak_dresser 8
# Cleaning_cloth 6
# Spade 8
# Summer_pie 8
# Black_shield_(h3) 6
# Jangerberries 6
# Pastry_dough 4
# Mithril_bolts_(unf) 6
# Magic_potion(2) 6
# Dragon_bitter(4) 7
# Raw_herring 6
# Toadflax_potion_(unf) 8
# Bronze_warhammer 6
# Infinity_boots 6
# Oak_longbow 6
# Mithril_kiteshield_(g) 6
# Dragon_boots_ornament_kit 5
# Casket 6
# Edible_seaweed 6
# Bandos_d'hide 6
# Blue_wizard_hat 6
# Peaceful_blessing 4
# Red_bead 7
# Filled_plant_pot 7
# Mixed_flowers 6
# Antifire_mix(2) 7
# Bronze_crossbow_(u) 6
# Combat_mix(2) 7
# Uncut_jade 8
# Dark_cavalier 6
# Team-39_cape 8
# Bones_to_peaches 6
# Adamant_kiteshield_(t) 4
# Toktz-xil-ek 8
# Rune_crossbow 7
# Leaf-bladed_battleaxe 5
# Adamant_full_helm_(t) 4
# Gilded_bench 8
# Guthix_cloak 7
# Black_claws 6
# Raw_garden_pie 7
# Combat_potion(2) 8
# White_platelegs 7
# Team-31_cape 9
# Fremennik_grey_shirt 7
# Mithril_gold-trimmed_set_(sk) 6
# Anti-venom+(4) 7
# Twisted_buckler 5
# Spectral_spirit_shield 8
# Red_d'hide_body 8
# Cup_of_water 7
# Onyx_dragon_bolts_(e) 5
# West_ardougne_teleport 7
# Bronze_full_helm_(t) 6
# Poison_ivy_berries 6
# Bandos_page_2 6
# Armadyl_dragonhide_set 6
# Tarromin_potion_(unf) 7
# Viggora's_chainmace_(u) 4
# 3rd_age_axe 5
# Guthix_crozier 6
# Initiate_cuisse 6
# Spicy_minced_meat 9
# Crushed_nest 6
# Magic_potion(4) 7
# Steel_crossbow 8
# Maple_seed 7
# Fancy_tiara 5
# Cream_hat 7
# Mahogany_wardrobe 8
# Holy_blessing 5
# Red_elegant_blouse 7
# Sliced_mushrooms 8
# Dragon_med_helm 7
# Giant_frog_legs 6
# Skewer_stick 8
# Dragonfruit 1
# Abyssal_whip 4
# Black_helm_(h1) 6
# Fish_pie 6
# Guthan's_platebody_0 7
# Gout_tuber 7
# 3rd_age_range_coif 5
# Dragon_dart(p+) 7
# Potato_cactus_seed 1
# Super_strength(1) 8
# Barbed_bolts 6
# Ruby_bracelet 7
# Iron_gold-trimmed_set_(lg) 6
# Odium_shard_2 6
# Saradomin's_light 7
# Adamant_spear(p++) 5
# Sapphire_necklace 7
# Amulet_of_the_damned_(full) 6
# Goblin_mail 6
# Adamant_boots 4
# Ancestral_robe_top 4
# Red_elegant_legs 7
# Black_kiteshield_(t) 6
# Dragon_javelin 6
# Cream_robe_top 7
# Steel_platelegs_(t) 7
# Ancient_rune_armour_set_(sk) 6
# Weapon_poison(++) 8
# Hunter_potion(2) 7
# Marble_magic_wardrobe 8
# Toad's_legs 8
# Antidote++(3) 7
# Rune_arrow 6
# Rune_shield_(h1) 7
# Bronze_full_helm_(g) 6
# Dragon_crossbow 5
# Bananas(5) 7
# Justiciar_faceguard 4
# Dust_rune 6
# Premade_veg_batta 7
# Redberries 7
# Gloves_of_silence 6
# Stamina_potion(3) 9
# Varrock_teleport 7
# Mithril_axe 5
# Garlic 6
# Black_full_helm_(t) 6
# Redwood_bird_house 5
# Adamant_knife(p) 5
# Tiara_mould 8
# Diamond_bolt_tips 7
# Steel_kiteshield_(g) 7
# Maple_sapling 6
# Runite_bolts 7
# Black_brutal 6
# Opal_bolts_(e) 6
# Rock_hammer 7
# Willow_stock 7
# Team-45_cape 9
# Dragon_bolts_(p) 5
# Box_trap 6
# Opal_bolts 6
# Halloween_mask_set 5
# Steel_hasta(p++) 9
# Yew_shortbow 8
# Nasturtiums 6
# Godsword_shard_3 6
# Oak_dresser 8
# Mind_bomb(4) 7
# Gilded_platelegs 6
# Guthix_balance(3) 8
# Emerald_dragon_bolts 5
# Red_spiders'_eggs 7
# Earth_orb 6
# Ancient_chaps 5
# Gold_bar 6
# Mithril_sq_shield 6
# Vial_of_water 6
# Wood_camo_top 7
# Staff 8
# Zenyte_ring 9
# Purple_elegant_shirt 7
# Black_d'hide_shield 5
# Steel_pickaxe 8
# Dragonfruit_tree_seed 1
# Teal_boots 9
# Arceuus_scarf 5
# Bronze_trimmed_set_(sk) 6
# Ruby_harvest 8
# Pot 6
# Greenman's_ale(m) 7
# Kebab 6
# Ugthanki_kebab 8
# Royal_sceptre 7
# Green_elegant_skirt 6
# Willow_longbow 7
# Super_strength(4) 9
# Bucket_of_wax 6
# Pink_robe_bottoms 7
# Iron_spear(p) 7
# Antifire_potion(1) 7
# Ham_boots 6
# Zenyte_bracelet 9
# Guthix_mjolnir 6
# Ugthanki_&_tomato 9
# Mithril_dagger(p) 7
# Oyster_pearls 5
# Ensouled_dog_head 6
# Bagged_flower 8
# Attack_potion(1) 7
# Ballista_limbs 6
# Saradomin_kiteshield 6
# Apple_mush 6
# Attack_potion(3) 7
# Jute_fibre 6
# Attack_mix(1) 7
# Super_defence(1) 9
# Iron_spear 6
# Mystic_boots_(dark) 7
# Kyatt_legs 6
# Wooden_shield_(g) 6
# Tin_ore 8
# Yew_longbow_(u) 7
# Granite_gloves 5
# Lantadyme_seed 7
# Premade_sgg 6
# Unpowered_orb 7
# Carved_teak_bench 8
# Burnt_page 5
# Vodka 7
# Rune_knife(p+) 7
# Onyx_bracelet 5
# Mithril_sword 6
# Yew_pyre_logs 8
# Bark 6
# Dragon_javelin(p) 6
# Monk's_robe 8
# Green_d'hide_vamb 6
# Banana_tree_seed 7
# Combat_mix(1) 7
# Bird_house 5
# Oak_cape_rack 8
# Adamant_full_helm 4
# Cleaver 6
# Hood_of_darkness 5
# Cup_of_tea 6
# Black_dart(p+) 7
# Uncut_opal 6
# Team-13_cape 9
# Toy_mouse 8
# Oak_stock 6
# Ruby 7
# Carved_oak_bench 8
# Rune_boots 7
# Iron_ore 6
# Assorted_flowers 7
# Bird_nest 5
# Dragon_arrow(p) 7
# Opulent_table 8
# Swamp_lizard 8
# Zamorakian_hasta 8
# Bagged_magic_tree 6
# Cured_yak-hide 6
# Iron_gold-trimmed_set_(sk) 6
# Barrows_teleport 6
# Grimy_cadantine 5
# Fez 6
# Skeletal_boots 8
# Bucket 6
# Bryophyta's_staff_(uncharged) 4
# Wood_camo_legs 7
# Skewer 8
# Kitchen_table 8
# Master_wand 5
# Monkey_tail 6
# Elder_chaos_robe 5
# Mummy's_hands 5
# Extended_antifire(4) 7
# Obsidian_platelegs 5
# Antipoison(1) 7
# Hunting_mix(1) 7
# Mithril_dart(p++) 7
# Adamant_platebody_(t) 4
# Moonlight_mead 6
# Butterfly_jar 6
# Adamant_shield_(h1) 4
# Bronze_platebody_(g) 6
# Black_leprechaun_hat 5
# Defence_potion(1) 7
# Oak_shortbow 6
# Monk's_robe_(g) 5
# Iron_dart(p) 7
# Adamant_crossbow 4
# Mithril_arrow(p) 7
# Enchant_diamond 6
# Karil's_coif_0 7
# Marble_cape_rack 8
# Bowl 6
# Mithril_dagger(p+) 7
# Occult_necklace 6
# Super_restore_mix(2) 9
# Asgarnian_ale(m4) 7
# Black_d'hide_chaps_(g) 6
# Redberry_pie 7
# Efh_salt 4
# Chopped_tomato 6
# Blue_skirt_(g) 6
# Sanfew_serum(4) 8
# Adamant_spear(p+) 5
# Steel_full_helm_(t) 6
# Inoculation_bracelet 6
# Chocolate_dust 6
# Wizard's_mind_bomb 7
# Gold_bracelet 6
# Raw_admiral_pie 7
# Mithril_pickaxe 6
# Amulet_of_magic 5
# Fremennik_blue_shirt 7
# Chocolate_bar 6
# Lassar_teleport 6
# Pink_elegant_skirt 6
# Premade_w'm_crun' 7
# Uncharged_toxic_trident_(e) 5
# Superantipoison(3) 9
# Calquat_tree_seed 7
# Ranarr_weed 8
# Pearl_dragon_bolts 4
# Elysian_spirit_shield 6
# Black_d'hide_body 7
# Dragon_kiteshield 5
# Yew_longbow 8
# Shade_robe_top 7
# Tome_of_fire_(empty) 6
# Pink_robe_top 7
# Purple_boots 8
# Teacher_wand 8
# Rune_full_helm 7
# Vyrewatch_top 7
# Tyrannical_ring 8
# Grimy_snapdragon 6
# Ring_of_the_gods 6
# Guthan's_platebody 6
# Combat_potion(4) 8
# Black_dart 6
# Yak-hide_armour 16
# White_dagger(p) 8
# Steel_studs 8
# Fake_beard 6
# Wizard_blizzard 6
# Gold_leaf 6
# Holy_book_page_set 6
# Rune_hasta 8
# Polar_camo_legs 6
# Smouldering_stone 7
# Black_set_(sk) 6
# Hosidius_banner 5
# Grape_seed 6
# Iron_spit 5
# Rune_javelin(p+) 8
# Jar_of_swamp 6
# Bronze_gold-trimmed_set_(sk) 6
# Slayer's_respite(m) 9
# Water_orb 6
# Black_elegant_shirt 6
# Fruit_batta 6
# Garden_pie 6
# Coal 6
# Steel_warhammer 8
# Mummy's_head 5
# Redberry_seed 8
# Nail_beast_nails 6
# Black_skirt_(t) 6
# Crier_hat 6
# Kyatt_top 6
# Unicorn_horn 7
# Bronze_crossbow 6
# Sagacious_spectacles 7
# Adamant_dart(p++) 5
# Mystic_robe_top 6
# Proselyte_hauberk 7
# Air_rune 5
# Unfired_pot_lid 8
# Teak_pyre_logs 8
# Mort_myre_fungus 6
# Oak_drawers 8
# Leather_vambraces 6
# Defence_mix(2) 7
# Team-20_cape 9
# Black_spear(p++) 7
# Lovakengj_scarf 5
# Saradomin_coif 6
# Magic_potion(3) 7
# Anti-venom(2) 7
# Steel_mace 8
# Mithril_bolts_(p++) 8
# Steel_arrow(p+) 8
# Guthix_plateskirt 6
# Amylase_crystal 5
# Uncooked_apple_pie 7
# Necklace_of_faith 5
# Iron_sq_shield 6
# Stretched_hide 8
# White_partyhat 7
# Mind_talisman 6
# Purple_boater 7
# Amulet_of_glory 5
# Super_strength(2) 9
# Kodai_wand 5
# Ancient_effigy 4
# Efaritay's_aid 5
# Enchant_sapphire_or_opal 6
# Ensouled_minotaur_head 6
# Team-2_cape 9
# Skills_necklace(4) 8
# Black_scimitar 6
# White_boater 6
# Amethyst_javelin_heads 4
# Jangerberry_seed 7
# Raw_rabbit 6
# Agility_potion(4) 6
# Empty_sack 6
# Raw_bear_meat 7
# Split_log 8
# Xerician_hat 7
# Chef's_delight 6
# Jar_of_sand 6
# Ensouled_bloodveld_head 6
# Shayzien_hood 6
# New_crystal_bow 8
# Falador_teleport 6
# Ancient_page_2 5
# Guthan's_armour_set 7
# Shrunk_ogleroot 8
# Earmuffs 6
# Mystic_robe_bottom 6
# Amethyst_javelin(p++) 4
# Iron_dragon_mask 6
# Papaya_sapling 6
# Super_antifire_potion(4) 5
# Mind_helmet 6
# Chef's_delight(4) 7
# Ogre_coffin_key 5
# Cadantine_seed 7
# Magic_shortbow_(u) 6
# Mind_tiara 6
# Super_str._mix(1) 9
# Mage's_book 8
# Guthix_mitre 6
# Goblin_book 7
# Rune_nails 7
# Desert_shirt 6
# Pineapple_punch 6
# Rune_platelegs_(t) 7
# Blue_boater 6
# Dragon_dart_tip 6
# Iron_longsword 6
# Team-6_cape 9
# Poison_ivy_seed 6
# Redwood_tree_seed 1
# Blue_dark_bow_paint 6
# Bronze_kiteshield_(t) 6
# Gilded_clock 8
# Ashes 6
# Greater_demon_mask 5
# Rune_helm_(h1) 7
# Copper_ore 6
# Lobster_pot 6
# Adamant_hasta(p++) 5
# Nice_hedge 8
# Zamorak_hilt 8
# 3rd_age_range_legs 5
# Bone_club 6
# Ghorrock_teleport 6
# Black_plateskirt 6
# Ancient_platelegs 5
# Bronze_med_helm 6
# Yellow_gloves 8
# Ranging_mix(2) 8
# Ancient_rune_armour_set_(lg) 6
# Guthix_rest(4) 7
# Irit_leaf 6
# Harmony_island_teleport 6
# Turquoise_hat 9
# Tai_bwo_wannai_teleport 8
# Dragon_impling_jar 6
# White_plateskirt 7
# Steel_bolts_(p+) 9
# Rune_trimmed_set_(sk) 7
# Black_unicorn_mask 5
# Iron_arrowtips 6
# Ring_of_wealth_(5) 8
# Adamant_mace 4
# Maple_longbow 6
# Iron_full_helm_(t) 6
# Jungle_camo_legs 6
# Black_full_helm 6
# Dragon_legs/skirt_ornament_kit 6
# Ogre_arrow 6
# Ranging_potion(4) 8
# Magic_logs 6
# Armadyl_kiteshield 6
# Red_gloves 8
# Iron_dart(p++) 6
# Orange_dye 6
# Hosidius_scarf 5
# Premade_dr'_dragon 7
# Iron_dagger(p) 7
# Magic_potion(1) 7
# Bronze_sword 6
# Adamant_hasta 4
# Air_orb 5
# Tuna_and_corn 8
# Iron_bolts 6
# Weeds 8
# Green_spiky_vambs 6
# Gilded_scimitar 6
# Dragon_spear 6
# Curry_leaf 6
# Ahrim's_armour_set 5
# Ranarr_seed 9
# Nasturtium_seed 7
# Verac's_helm 6
# Grimy_kwuarm 6
# Splitbark_body 8
# Chilli_con_carne 6
# Initiate_hauberk 6
# Iron_hasta(p) 7
# Raw_sardine 7
# Oak_blackjack(o) 7
# Ensouled_bear_head 6
# Willow_shortbow 7
# Meat_pizza 6
# Seasoned_sardine 8
# Cyclops_head 6
# Team-29_cape 9
# Mith_grapple 1
# Pirate_boots 6
# Ham_robe 6
# Opal_bracelet 5
# Armadyl_mitre 6
# Stamina_mix(2) 9
# Emerald_bracelet 6
# Raw_swordfish 7
# Iron_kiteshield_(t) 6
# Agility_potion(2) 6
# Black_trimmed_set_(lg) 6
# Agility_mix(1) 6
# Guthix_robe_top 6
# Gold_ore 6
# Dragon_javelin(p++) 6
# Anti-venom+(2) 7
# Bone_dagger_(p) 8
# Hard_leather_shield 4
# Guthix_page_4 6
# Teak_dresser 9
# Evil_chicken_head 5
# Team-50_cape 9
# Afro 5
# Granite_body 6
# Fremennik_pink_cloak 7
# Bronze_arrowtips 6
# Bronze_arrow(p) 7
# Iron_javelin(p) 7
# Adamant_dart_tip 4
# Volcanic_ash 4
# Dragon_axe 6
# Bandos_bracers 6
# Team-24_cape 9
# Cooked_jubbly 6
# Steel_trimmed_set_(sk) 7
# Strawberry_seed 9
# Attack_mix(2) 7
# Super_defence(4) 9
# Mystic_robe_bottom_(dark) 7
# Mithril_hasta(p++) 7
# Raw_yak_meat 7
# Saradomin_d'hide 7
# Saradomin_mitre 7
# Seercull 7
# Ring_mould 6
# Orange_flowers 7
# Mithril_javelin(p+) 7
# Lava_scale_shard 6
# Tortoise_shell 8
# Steel_axe 8
# Ancient_page_1 5
# Leather_gloves 6
# Feldip_hills_teleport 6
# Zamorakian_spear 8
# Choc-ice 6
# Green_elegant_legs 6
# Team-1_cape 9
# Saradomin_page_4 6
# Cooked_meat 6
# Bucket_of_water 6
# White_warhammer 6
# Security_book 7

# %%
data['Dragon_bones']
# Out:
# [415, 1026, 1246, 1249, 1253, 1346]

# %%
print(itemPrices['Dragon_bones'][414:417])
# Out:
# [(1463961600, 3175, -1), (1463961600, 3175, -1), (1464048000, 3143, -1)]

# %%
# fix duplicate dates
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    for index in sorted(repeats, reverse=True):
        del itemPrices[item][index]

# %%
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check if it worked

data = {}
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))

# %%
#itemPrices = scraper.loadItemPrices()
# just throw out first 90 days of data?
toPop = []
for item in itemPrices:
    if len(itemPrices[item])<30:
        print(item)
        toPop.append(item)
for item in toPop:
    itemPrices.pop(item)

# %%
# Find missing dates
item = 'Dragon_legs/skirt_ornament_kit'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-9af0a7929a5f> in <module>
#       1 # Find missing dates
#       2 item = 'Dragon_legs/skirt_ornament_kit'
# ----> 3 dates = [a[0] for a in itemPrices[item]]
#       4 day = 86400
#       5 hour = 3600
#
# KeyError: 'Dragon_legs/skirt_ornament_kit'

# %%
# Find missing dates
total = []
for item in itemPrices:
    if len(itemPrices[item])>0:
        dates = [a[0] for a in itemPrices[item]]
        day = 86400
        hour = 3600
        missing = 0
        for i in range(len(dates)-1):
            diff = dates[i+1]-dates[i]
            if diff<23*hour or diff>25*hour:
                #print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
                missing += int(diff/day)-1
        missRate = missing/len(itemPrices[item])
        total.append(missRate)
        if missing/len(itemPrices[item])>.1:
            print(item,missRate)
        if missing<0:
            print('wtf',item)
# Out:
# Redwood_tree_seed 0.10638297872340426

# %%
# Find missing dates
'''
item = 'Dragon_knife'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
'''
# Out:
# "\nitem = 'Dragon_knife'\ndates = [a[0] for a in itemPrices[item]]\nday = 86400\nhour = 3600\nmissing = 0\nfor i in range(len(dates)-1):\n    diff = dates[i+1]-dates[i]\n    if diff<23*hour or diff>25*hour:\n        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))\n        missing += int(diff/day)-1\nprint(missing/len(itemPrices[item]))\n"

# %%
print(len(total),max(total),min(total),np.mean(total),np.std(total))
# Out:
# 3395 0.10638297872340426 0.0 0.00039373287622321827 0.0045771163422805294

# %%
plt.hist(total,30)
# Out:
# (array([3.367e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.200e+01,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.        , 0.0035461 , 0.0070922 , 0.0106383 , 0.0141844 ,
#         0.0177305 , 0.0212766 , 0.0248227 , 0.02836879, 0.03191489,
#         0.03546099, 0.03900709, 0.04255319, 0.04609929, 0.04964539,
#         0.05319149, 0.05673759, 0.06028369, 0.06382979, 0.06737589,
#         0.07092199, 0.07446809, 0.07801418, 0.08156028, 0.08510638,
#         0.08865248, 0.09219858, 0.09574468, 0.09929078, 0.10283688,
#         0.10638298]),
#  <a list of 30 Patch objects>)

# %%
itemPrices.pop('Dragon_legs/skirt_ornament_kit',None)
itemPrices.pop('Dragon_hasta(kp)',None)

# %%
item = 'Abyssal_whip'
prices = [a[1] for a in itemPrices[item]]
plt.plot(prices)

# %%
def interPolateMissingDates(info):
    dates = [a[0] for a in info]
    prices = [a[1] for a in info]
    quants = [a[2] for a in info]
    fixed = []
    for i in range(len(dates)-1):
        fixed.append(info[i])
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            daysToAdd = int(diff/day)-1
            d = []
            p = []
            q = []
            if daysToAdd<0:
                print('huh')
            pToAdd = (prices[i+1]-prices[i])/(daysToAdd+1)
            qToAdd = (quants[i+1]-quants[i])/(daysToAdd+1)
            for j in range(daysToAdd):
                d.append(dates[i]+day*(j+1))
                p.append(prices[i]+(j+1)*pToAdd)
                q.append(quants[i]+(j+1)*qToAdd)
            for j in range(daysToAdd):
                fixed.append((d[j],p[j],q[j]))
    return fixed

# %%
# interpolate dates, prices, and quantities
#for item in itemPrices:
item = 'Abyssal_whip'
dates = [a[0] for a in itemPrices[item]]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("Before:",total)
fixed = interPolateMissingDates(itemPrices[item])
dates = [a[0] for a in fixed]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("After:",total)
prices = [a[1] for a in fixed]
plt.plot(prices)
# Out:
# Before: 0
# After: 0

# %%
# fix all items
items = list(itemPrices.keys())
for item in items:
    try:
        itemPrices[item] = interPolateMissingDates(itemPrices[item])
    except:
        itemPrices.pop(item,None)

# %%
for item in itemPrices:
    dates = [a[0] for a in itemPrices[item]]
    total = 0
    for i in range(len(dates)-1):
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            total += int(diff/day)-1
    if total>0:
        print(item,total)

# %%
def checkOutliers(prices):
    outliers = []
    manualAdjust = []
    for i in range(len(prices)-2):
        diff1 = abs(prices[i+1]-prices[i])
        diff2 = abs(prices[i+2]-prices[i+1])
        if diff1>100 and diff2>100 and diff1>prices[i]*0.15 and diff2>prices[i+1]*0.15:
            outliers.append(i+1)
        if diff1>100 and diff2>100 and diff1>prices[i]*0.17 and diff2<prices[i+1]*0.15:
            manualAdjust.append(i+1)
    return outliers,manualAdjust

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
# Out:
# 129
# 13

# %%
print(outlier)
#print(adjust)
# Out:
# {'Topaz_amulet': [66, 67, 68, 69], 'Blue_wizard_robe': [181], 'Restore_mix(1)': [1372, 1373, 1374], 'Defence_potion(2)': [181], "Monk's_robe_top": [180], 'Shayzien_banner': [275, 276, 277, 278, 279], "Mummy's_feet": [277, 278, 279], 'Opal_amulet_(u)': [66, 67, 68, 69], 'Yellow_cape': [181], 'Piscarilius_hood': [275, 276, 277, 278, 279], 'Fishing_potion(1)': [181], 'Wizard_hat': [181], 'Turquoise_boots': [181], 'Super_attack(2)': [181], 'Lovakengj_banner': [275, 276, 277, 278, 279], 'Spider_on_stick': [744, 745, 746, 747], 'Green_halloween_mask': [181], 'Topaz_amulet_(u)': [68, 69], 'Zamorak_brew(3)': [181], 'Amulet_of_bounty': [65, 66, 67, 68, 69], 'Jungle_demon_mask': [277, 278, 279], 'Pink_hat': [181], 'Black_robe': [181], 'Incomplete_heavy_ballista': [337, 338, 339, 340, 341], 'Zamorak_brew(2)': [181], 'Super_defence(3)': [181], 'Superantipoison(1)': [181], "Mummy's_legs": [277, 278, 279], 'Bucket_helm_(g)': [278, 279], 'Unstrung_light_ballista': [339, 340, 341], 'Mith_grapple_tip': [743, 744, 745, 746, 747], 'Gloves_of_darkness': [276, 277, 278, 279], 'Restore_potion(3)': [181], 'Antipoison(2)': [181], "Blacksmith's_helm": [276, 277, 278, 279], 'Blue_cape': [181], 'Gilded_hasta': [278, 279], 'Blue_boots': [181], 'Cream_robe_bottoms': [181], 'Restore_potion(2)': [181], 'Mithril_limbs': [745, 746, 747], 'Left_eye_patch': [275, 276, 277, 278, 279], 'Blue_robe_bottoms': [181], 'Iron_hasta(p+)': [764, 765, 766, 767, 768], 'Green_robe_bottoms': [181], 'Arceuus_banner': [276, 277, 278, 279], 'Empty_oil_lantern': [765, 766, 767, 768, 769], 'Enchant_emerald_or_jade': [745, 746, 747], 'Lesser_demon_mask': [275, 276, 277, 278, 279], 'Fishing_potion(3)': [181], 'Blue_robe_top': [181], 'Samurai_boots': [277, 278, 279], 'Super_attack(3)': [181], 'Arceuus_hood': [276, 277, 278, 279], 'Ranging_potion(3)': [181], 'Prayer_potion(1)': [181], 'Turquoise_robe_bottoms': [181], 'Ranging_potion(1)': [181], 'Ranging_potion(2)': [181], 'Opal_amulet': [65, 66, 67, 68, 69], 'Purple_cape': [181], 'Bones_to_bananas': [745, 746, 747], 'Zamorak_brew(1)': [181], 'Super_defence(2)': [181], 'Bowl_wig': [275, 276, 277, 278, 279], 'Iron_hasta(p++)': [764, 765, 766, 767, 768], 'Piscarilius_banner': [275, 276, 277, 278, 279], 'Old_demon_mask': [278, 279], 'Piscarilius_scarf': [275, 276, 277, 278, 279], 'Robe_bottom_of_darkness': [277, 278, 279], 'Enchant_onyx': [747], 'Restore_potion(1)': [181], 'Red_halloween_mask': [181], 'Blue_hat': [181], 'Incomplete_light_ballista': [338, 339, 340, 341], 'Robe_top_of_darkness': [278, 279], 'Pink_boots': [181], 'Green_hat': [181], 'Zombie_head': [276, 277, 278, 279], 'Spider_on_shaft': [744, 745, 746, 747], 'Black_cape': [181], 'Fishing_potion(2)': [181, 1375], 'Jade_amulet': [65, 66, 67, 68, 69], 'Lovakengj_hood': [276, 277, 278, 279], 'Strength_potion(4)': [181], 'Green_boots': [181], 'Super_attack(1)': [181], 'Antipoison(3)': [181], 'Zamorak_monk_top': [181], "Mummy's_body": [277, 278, 279], 'Strength_mix(1)': [1374], 'Orange_cape': [181], 'Super_strength(3)': [181], 'Superantipoison(2)': [181], 'Prayer_potion(2)': [181], 'Prayer_potion(3)': [181], 'Hosidius_hood': [276, 277, 278, 279], 'Cream_boots': [181], 'Turquoise_robe_top': [181], 'Restore_mix(2)': [1374], 'Blue_halloween_mask': [181], 'Green_robe_top': [181], 'Attack_potion(2)': [181], 'Boots_of_darkness': [275, 276, 277, 278, 279], 'Jade_amulet_(u)': [66, 67, 68, 69], 'Cream_hat': [181], 'Cream_robe_top': [181], 'Arceuus_scarf': [275, 276, 277, 278, 279], 'Pink_robe_bottoms': [181], 'Mithril_dagger(p)': [1063], 'Attack_potion(3)': [181], 'Super_defence(1)': [181], "Monk's_robe": [180], 'Monkey_tail': [340, 341], "Mummy's_hands": [277, 278, 279], 'Antipoison(1)': [181], 'Enchant_diamond': [744, 745, 746, 747], 'Pink_robe_top': [181], 'Hosidius_banner': [275, 276, 277, 278, 279], "Mummy's_head": [278, 279], 'Lovakengj_scarf': [275, 276, 277, 278, 279], 'Super_strength(2)': [181], 'Shayzien_hood': [278, 279], 'Greater_demon_mask': [276, 277, 278, 279], 'Turquoise_ha ...

# %%
item = 'Fishing_potion(1)'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [181]
# [1228, 1228, 1228, 54, 1228, 1228.0, 1228.0]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# adjust items that were revalued on 2017-04-11
week = 7 * 86400
checkPoint = 1491868800
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Topaz_amulet
# Shayzien_banner
# Mummy's_feet
# Opal_amulet_(u)
# Piscarilius_hood
# Lovakengj_banner
# Spider_on_stick
# Topaz_amulet_(u)
# Amulet_of_bounty
# Jungle_demon_mask
# Incomplete_heavy_ballista
# Mummy's_legs
# Bucket_helm_(g)
# Unstrung_light_ballista
# Mith_grapple_tip
# Gloves_of_darkness
# Blacksmith's_helm
# Gilded_hasta
# Mithril_limbs
# Left_eye_patch
# Iron_hasta(p+)
# Arceuus_banner
# Empty_oil_lantern
# Enchant_emerald_or_jade
# Lesser_demon_mask
# Samurai_boots
# Arceuus_hood
# Opal_amulet
# Bones_to_bananas
# Bowl_wig
# Iron_hasta(p++)
# Piscarilius_banner
# Old_demon_mask
# Piscarilius_scarf
# Robe_bottom_of_darkness
# Enchant_onyx
# Incomplete_light_ballista
# Robe_top_of_darkness
# Zombie_head
# Spider_on_shaft
# Jade_amulet
# Lovakengj_hood
# Mummy's_body
# Hosidius_hood
# Boots_of_darkness
# Jade_amulet_(u)
# Arceuus_scarf
# Monkey_tail
# Mummy's_hands
# Enchant_diamond
# Hosidius_banner
# Mummy's_head
# Lovakengj_scarf
# Shayzien_hood
# Greater_demon_mask
# Hosidius_scarf
# Iron_hasta(p)
# Cyclops_head

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 71
# 13
# {'Blue_wizard_robe': [181], 'Restore_mix(1)': [1372, 1373, 1374], 'Defence_potion(2)': [181], "Monk's_robe_top": [180], 'Yellow_cape': [181], 'Fishing_potion(1)': [181], 'Wizard_hat': [181], 'Turquoise_boots': [181], 'Super_attack(2)': [181], 'Green_halloween_mask': [181], 'Zamorak_brew(3)': [181], 'Pink_hat': [181], 'Black_robe': [181], 'Zamorak_brew(2)': [181], 'Super_defence(3)': [181], 'Superantipoison(1)': [181], 'Restore_potion(3)': [181], 'Antipoison(2)': [181], 'Blue_cape': [181], 'Blue_boots': [181], 'Cream_robe_bottoms': [181], 'Restore_potion(2)': [181], 'Blue_robe_bottoms': [181], 'Green_robe_bottoms': [181], 'Fishing_potion(3)': [181], 'Blue_robe_top': [181], 'Super_attack(3)': [181], 'Ranging_potion(3)': [181], 'Prayer_potion(1)': [181], 'Turquoise_robe_bottoms': [181], 'Ranging_potion(1)': [181], 'Ranging_potion(2)': [181], 'Purple_cape': [181], 'Zamorak_brew(1)': [181], 'Super_defence(2)': [181], 'Restore_potion(1)': [181], 'Red_halloween_mask': [181], 'Blue_hat': [181], 'Pink_boots': [181], 'Green_hat': [181], 'Black_cape': [181], 'Fishing_potion(2)': [181, 1375], 'Strength_potion(4)': [181], 'Green_boots': [181], 'Super_attack(1)': [181], 'Antipoison(3)': [181], 'Zamorak_monk_top': [181], 'Strength_mix(1)': [1374], 'Orange_cape': [181], 'Super_strength(3)': [181], 'Superantipoison(2)': [181], 'Prayer_potion(2)': [181], 'Prayer_potion(3)': [181], 'Cream_boots': [181], 'Turquoise_robe_top': [181], 'Restore_mix(2)': [1374], 'Blue_halloween_mask': [181], 'Green_robe_top': [181], 'Attack_potion(2)': [181], 'Cream_hat': [181], 'Cream_robe_top': [181], 'Pink_robe_bottoms': [181], 'Mithril_dagger(p)': [1063], 'Attack_potion(3)': [181], 'Super_defence(1)': [181], "Monk's_robe": [180], 'Antipoison(1)': [181], 'Pink_robe_top': [181], 'Super_strength(2)': [181], 'Turquoise_hat': [181], 'Dragon_impling_jar': [1133]}

# %%
item = 'Turquoise_robe_bottoms'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [181]
# [2865, 2865, 2865, 83, 2865, 2837.2, 2809.4]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# fix outliers caused by misread on 2015-09-02 00:00:00
week = 7 * 86400
checkPoint = 1441152000
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Blue_wizard_robe
# Defence_potion(2)
# Monk's_robe_top
# Yellow_cape
# Fishing_potion(1)
# Wizard_hat
# Turquoise_boots
# Super_attack(2)
# Green_halloween_mask
# Zamorak_brew(3)
# Pink_hat
# Black_robe
# Zamorak_brew(2)
# Super_defence(3)
# Superantipoison(1)
# Restore_potion(3)
# Antipoison(2)
# Blue_cape
# Blue_boots
# Cream_robe_bottoms
# Restore_potion(2)
# Blue_robe_bottoms
# Green_robe_bottoms
# Fishing_potion(3)
# Blue_robe_top
# Super_attack(3)
# Ranging_potion(3)
# Prayer_potion(1)
# Turquoise_robe_bottoms
# Ranging_potion(1)
# Ranging_potion(2)
# Purple_cape
# Zamorak_brew(1)
# Super_defence(2)
# Restore_potion(1)
# Red_halloween_mask
# Blue_hat
# Pink_boots
# Green_hat
# Black_cape
# Fishing_potion(2)
# Strength_potion(4)
# Green_boots
# Super_attack(1)
# Antipoison(3)
# Zamorak_monk_top
# Orange_cape
# Super_strength(3)
# Superantipoison(2)
# Prayer_potion(2)
# Prayer_potion(3)
# Cream_boots
# Turquoise_robe_top
# Blue_halloween_mask
# Green_robe_top
# Attack_potion(2)
# Cream_hat
# Cream_robe_top
# Pink_robe_bottoms
# Attack_potion(3)
# Super_defence(1)
# Monk's_robe
# Antipoison(1)
# Pink_robe_top
# Super_strength(2)
# Turquoise_hat

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 6
# 9
# {'Restore_mix(1)': [1372, 1373, 1374], 'Fishing_potion(2)': [1187], 'Strength_mix(1)': [1374], 'Restore_mix(2)': [1374], 'Mithril_dagger(p)': [1063], 'Dragon_impling_jar': [1133]}

# %%
for item in outlier:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Restore_mix(1)
# Fishing_potion(2)
# Strength_mix(1)
# Restore_mix(2)
# Mithril_dagger(p)
# Dragon_impling_jar

# %%
# guess I'll just get rid of these ones
for item in outlier:
    itemPrices.pop(item,None)

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 0
# 8
# {}

# %%
for item in adjust:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Craw's_bow_(u)
# Disk_of_returning
# Heavy_ballista
# Dragonbone_necklace
# Thammaron's_sceptre_(u)
# Dragon_harpoon
# Dragon_sword
# Viggora's_chainmace_(u)

# %%
# noticed that dragon sword price was changed after an update on january 10th
# and that information was stored on its wiki page, should probably scrape that as well

# %%
# save results back to itemPrices
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1463: 2
# 1456: 256
# 1455: 494
# 1454: 14
# 1451: 10
# 1450: 25
# 1434: 1899
# 1433: 54
# 1429: 66
# 1268: 62
# 1267: 2
# 1263: 1
# 1241: 6
# 1147: 6
# 1146: 25
# 1141: 1
# 1126: 1
# 1098: 1
# 1028: 29
# 1027: 2
# 1021: 10
# 1007: 3
# 1006: 1
# 1000: 2
# 987: 1
# 972: 1
# 966: 76
# 965: 7
# 964: 2
# 961: 3
# 958: 1
# 949: 6
# 938: 1
# 931: 1
# 903: 2
# 896: 5
# 891: 1
# 882: 1
# 875: 1
# 854: 1
# 784: 13
# 783: 1
# 776: 1
# 771: 1
# 770: 1
# 764: 1
# 761: 1
# 756: 17
# 755: 1
# 751: 2
# 749: 1
# 728: 1
# 686: 1
# 684: 20
# 683: 16
# 682: 11
# 681: 9
# 680: 1
# 678: 1
# 664: 1
# 636: 3
# 635: 1
# 616: 12
# 611: 1
# 588: 1
# 538: 23
# 533: 1
# 490: 5
# 485: 1
# 484: 1
# 461: 7
# 447: 1
# 420: 47
# 419: 3
# 415: 1
# 406: 5
# 399: 1
# 398: 8
# 393: 1
# 392: 8
# 391: 2
# 387: 2
# 385: 6
# 301: 2
# 280: 1
# 266: 17
# 265: 1
# 216: 3
# 215: 1
# 175: 9
# 174: 1
# 170: 2

# %%
# probably 1306
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l].append(item)
    else:
        sizes[l] = [item]

# %%
s = 1463
print(sizes[s][0])
print(datetime.utcfromtimestamp(itemPrices[sizes[s][0]][0][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Karambwan_vessel
# 2015-02-26 00:00:00

# %%
#undervalued items
for item in itemPrices:
    prices = [a[1] for a in itemPrices[item]]
    sma = items.sma(prices,7)
    slope = sma[0]<sma[1]
    for i in range(2,len(sma)-1):
        if sma[i-1]>sma[i]:
            break
    itemPrices[item] = itemPrices[item][i-2:]

# %%
#overvalued items
for item in itemPrices:
    prices = [a[1] for a in itemPrices[item]]
    sma = items.sma(prices,7)
    slope = sma[0]>sma[1]
    for i in range(2,len(sma)-1):
        if sma[i-1]<sma[i]:
            break
    itemPrices[item] = itemPrices[item][i-2:]

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1455: 1
# 1454: 3
# 1453: 4
# 1452: 1
# 1451: 1
# 1450: 3
# 1449: 3
# 1448: 1
# 1447: 9
# 1446: 4
# 1445: 1
# 1444: 3
# 1443: 2
# 1442: 6
# 1441: 1
# 1440: 2
# 1439: 2
# 1438: 3
# 1437: 4
# 1436: 2
# 1435: 3
# 1434: 2
# 1433: 45
# 1432: 24
# 1431: 49
# 1430: 44
# 1429: 19
# 1428: 28
# 1427: 41
# 1426: 37
# 1425: 43
# 1424: 45
# 1423: 21
# 1422: 32
# 1421: 32
# 1420: 34
# 1419: 23
# 1418: 25
# 1417: 25
# 1416: 16
# 1415: 31
# 1414: 21
# 1413: 27
# 1412: 28
# 1411: 25
# 1410: 16
# 1409: 18
# 1408: 12
# 1407: 15
# 1406: 23
# 1405: 11
# 1404: 8
# 1403: 14
# 1402: 15
# 1401: 6
# 1400: 8
# 1399: 12
# 1398: 7
# 1397: 10
# 1396: 11
# 1395: 14
# 1394: 7
# 1393: 13
# 1392: 15
# 1391: 7
# 1390: 14
# 1389: 11
# 1388: 12
# 1387: 8
# 1386: 11
# 1385: 10
# 1384: 8
# 1383: 18
# 1382: 12
# 1381: 6
# 1380: 6
# 1379: 23
# 1378: 12
# 1377: 11
# 1376: 8
# 1375: 5
# 1374: 5
# 1373: 9
# 1372: 13
# 1371: 7
# 1370: 9
# 1369: 8
# 1368: 8
# 1367: 6
# 1366: 4
# 1365: 7
# 1364: 6
# 1363: 6
# 1362: 8
# 1361: 9
# 1360: 10
# 1359: 6
# 1358: 11
# 1357: 16
# 1356: 10
# 1355: 6
# 1354: 6
# 1353: 2
# 1352: 7
# 1351: 5
# 1350: 4
# 1349: 2
# 1348: 9
# 1347: 4
# 1346: 11
# 1345: 5
# 1344: 6
# 1343: 7
# 1342: 6
# 1341: 10
# 1340: 4
# 1339: 10
# 1338: 4
# 1337: 2
# 1336: 8
# 1335: 5
# 1334: 4
# 1333: 6
# 1332: 3
# 1331: 5
# 1330: 2
# 1329: 6
# 1328: 1
# 1327: 7
# 1326: 4
# 1325: 2
# 1324: 6
# 1323: 3
# 1322: 4
# 1321: 4
# 1320: 2
# 1319: 7
# 1318: 2
# 1317: 8
# 1316: 2
# 1315: 7
# 1314: 4
# 1313: 4
# 1312: 5
# 1310: 4
# 1309: 3
# 1308: 3
# 1307: 4
# 1306: 3
# 1305: 5
# 1304: 4
# 1303: 3
# 1302: 5
# 1301: 3
# 1300: 6
# 1299: 3
# 1298: 3
# 1297: 3
# 1296: 3
# 1295: 1
# 1294: 3
# 1293: 1
# 1292: 6
# 1291: 3
# 1290: 3
# 1289: 5
# 1288: 3
# 1287: 4
# 1286: 5
# 1284: 2
# 1283: 3
# 1282: 2
# 1281: 4
# 1280: 2
# 1279: 2
# 1278: 3
# 1277: 3
# 1276: 6
# 1274: 1
# 1273: 3
# 1272: 6
# 1271: 1
# 1270: 1
# 1269: 5
# 1267: 8
# 1266: 1
# 1265: 5
# 1264: 4
# 1263: 4
# 1262: 6
# 1261: 4
# 1260: 1
# 1259: 1
# 1258: 5
# 1257: 2
# 1256: 1
# 1255: 4
# 1254: 3
# 1253: 7
# 1252: 4
# 1250: 2
# 1249: 2
# 1248: 1
# 1247: 4
# 1246: 4
# 1245: 1
# 1244: 3
# 1243: 1
# 1242: 3
# 1241: 3
# 1240: 3
# 1238: 1
# 1237: 1
# 1236: 2
# 1235: 2
# 1234: 1
# 1233: 2
# 1231: 6
# 1230: 1
# 1229: 3
# 1228: 3
# 1226: 4
# 1225: 1
# 1224: 2
# 1223: 2
# 1222: 3
# 1221: 1
# 1220: 3
# 1219: 3
# 1218: 1
# 1217: 2
# 1216: 3
# 1215: 2
# 1214: 4
# 1212: 2
# 1211: 5
# 1210: 1
# 1209: 3
# 1208: 3
# 1207: 4
# 1206: 1
# 1205: 3
# 1204: 3
# 1203: 3
# 1202: 1
# 1201: 7
# 1200: 1
# 1199: 2
# 1198: 2
# 1197: 1
# 1196: 4
# 1195: 1
# 1194: 3
# 1193: 1
# 1192: 1
# 1190: 3
# 1188: 3
# 1187: 2
# 1186: 4
# 1185: 2
# 1184: 5
# 1183: 1
# 1179: 2
# 1178: 1
# 1177: 4
# 1176: 2
# 1175: 5
# 1174: 3
# 1173: 5
# 1172: 3
# 1171: 2
# 1170: 1
# 1169: 1
# 1168: 3
# 1167: 2
# 1166: 2
# 1165: 3
# 1162: 1
# 1159: 4
# 1158: 3
# 1153: 1
# 1152: 3
# 1150: 5
# 1149: 1
# 1148: 1
# 1147: 4
# 1145: 5
# 1143: 6
# 1142: 1
# 1140: 2
# 1139: 2
# 1138: 1
# 1137: 1
# 1136: 2
# 1135: 1
# 1134: 1
# 1133: 2
# 1131: 4
# 1130: 3
# 1129: 3
# 1128: 5
# 1126: 3
# 1125: 1
# 1124: 3
# 1122: 1
# 1121: 3
# 1119: 1
# 1118: 5
# 1116: 1
# 1115: 2
# 1112: 2
# 1111: 2
# 1110: 1
# 1108: 1
# 1107: 1
# 1106: 1
# 1104: 2
# 1103: 2
# 1101: 2
# 1099: 3
# 1098: 1
# 1097: 1
# 1096: 4
# 1094: 4
# 1092: 2
# 1091: 2
# 1087: 2
# 1086: 1
# 1085: 1
# 1083: 2
# 1082: 1
# 1081: 1
# 1080: 1
# 1079: 4
# 1077: 2
# 1076: 2
# 1075: 1
# 1074: 2
# 1073: 1
# 1071: 1
# 1069: 1
# 1068: 4
# 1064: 3
# 1063: 1
# 1062: 2
# 1061: 2
# 1059: 1
# 1058: 1
# 1055: 4
# 1054: 1
# 1053: 2
# 1052: 1
# 1049: 1
# 1048: 1
# 1047: 3
# 1046: 1
# 1045: 1
# 1043: 2
# 1040: 1
# 1039: 1
# 1038: 2
# 1037: 1
# 1036: 3
# 1035: 1
# 1034: 1
# 1031: 1
# 1030: 1
# 1029: 1
# 1028: 2
# 1027: 1
# 1026: 1
# 1025: 1
# 1024: 3
# 1021: 1
# 1019: 1
# 1018: 2
# 1017: 2
# 1015: 1
# 1012: 3
# 1011: 2
# 1010: 1
# 1009: 3
# 1008: 2
# 1006: 1
# 1004: 5
# 1003: 2
# 1002: 2
# 1001: 1
# 997: 1
# 995: 1
# 988: 1
# 987: 2
# 986: 1
# 985: 2
# 984: 2
# 983: 1
# 982: 1
# 976: 1
# 975: 1
# 974: 2
# 973: 1
# 972: 2
# 971: 1
# 970: 2
# 967: 1
# 966: 1
# 961: 1
# 960: 1
# 956: 1
# 954: 1
# 953: 1
# 951: 2
# 948: 1
# 947: 4
# 946: 3
# 945: 2
# 944: 1
# 943: 1
# 940: 2
# 939: 2
# 934: 2
# 932: 1
# 929: 1
# 928: 1
# 926: 1
# 922: 1
# 920: 2
# 919: 2
# 917: 3
# 916: 1
# 915: 1
# 914: 1
# 910: 2
# 909: 1
# 908: 2
# 906: 2
# 905: 1
# 904: 2
# 903: 2
# 902: 1
# 901: 2
# 899: 1
# 897: 1
# 896: 1
# 894: 1
# 893: 2
# 891: 1
# 888: 2
# 884: 1
# 881: 2
# 880: 1
# 878: 2
# 876: 1
# 873: 3
# 872: 1
# 871: 1
# 870: 1
# 866: 1
# 864: 2
# 858: 1
# 857: 2
# 856: 2
# 855: 1
# 853: 1
# 852: 1
# 851: 1
# 849: 1
# 848: 2
# 847: 4
# 845: 2
# 842: 5
# 841: 5
# 839: 1
# 836: 1
# 819: 1
# 818: 1
# 816: 3
# 814: 1
# 813: 2
# 812: 1
# 811: 2
# 810: 1
# 808: 1
# 807: 1
# 805: 2
# 803: 1
# 802: 1
# 801: 1
# 800: 1
# 799: 1
# 796: 1
# 792: 2
# 789: 1
# 787: 1
# 786: 1
# 784: 1
# 783: 1
# 782: 3
# 781: 3
# 780: 1
# 779: 4
# 776: 2
# 774: 1
# 773: 4
# 771: 1
# 767: 1
# 763: 1
# 762: 6
# 761: 2
# 760: 3
# 759: 1
# 757: 2
# 756: 1
# 753: 1
# 751: 2
# 749: 2
# 748: 1
# 747: 1
# 746: 1
# 742: 1
# 740: 1
# 739: 1
# 737: 1
# 736: 1
# 735: 2
# 734: 1
# 733: 1
# 732: 1
# 731: 1
# 727: 1
# 726: 2
# 725: 2
# 718: 2
# 717: 2
# 715: 1
# 712: 2
# 711: 3
# 710: 2
# 709: 1
# 708: 1
# 706: 1
# 705: 1
# 704: 1
# 701: 2
# 700: 1
# 697: 1
# 691: 1
# 690: 1
# 689: 1
# 688: 2
# 687: 4
# 686: 1
# 685: 1
# 684: 1
# 683: 1
# 681: 2
# 680: 1
# 679: 1
# 678: 1
# 677: 4
# 676: 3
# 675: 2
# 673: 1
# 672: 2
# 671: 3
# 670: 2
# 669: 2
# 667: 4
# 666: 2
# 663: 1
# 662: 1
# 660: 4
# 656: 2
# 654: 1
# 652: 2
# 651: 1
# 650: 1
# 645: 1
# 642: 1
# 641: 3
# 640: 1
# 639: 4
# 634: 1
# 633: 2
# 632: 5
# 630: 1
# 629: 1
# 625: 1
# 624: 2
# 620: 2
# 619: 2
# 618: 1
# 617: 2
# 616: 1
# 615: 1
# 614: 1
# 613: 1
# 609: 2
# 607: 1
# 606: 2
# 602: 1
# 601: 2
# 599: 1
# 598: 1
# 596: 2
# 595: 2
# 593: 1
# 589: 2
# 586: 1
# 583: 1
# 579: 2
# 578: 2
# 577: 1
# 576: 1
# 574: 1
# 573: 1
# 572: 1
# 569: 1
# 568: 2
# 566: 1
# 565: 2
# 564: 2
# 562: 1
# 560: 1
# 556: 1
# 555: 1
# 554: 2
# 553: 1
# 551: 2
# 549: 1
# 546: 1
# 545: 1
# 544: 1
# 540: 1
# 537: 1
# 535: 1
# 534: 1
# 533: 1
# 530: 3
# 529: 1
# 527: 1
# 526: 1
# 525: 1
# 523: 2
# 522: 1
# 520: 1
# 519: 1
# 518: 1
# 517: 1
# 515: 1
# 513: 3
# 512: 3
# 511: 1
# 510: 1
# 508: 1
# 504: 1
# 503: 1
# 502: 1
# 501: 2
# 497: 1
# 496: 1
# 487: 1
# 486: 1
# 485: 2
# 484: 2
# 483: 1
# 482: 1
# 481: 1
# 479: 1
# 477: 1
# 471: 3
# 470: 1
# 469: 1
# 468: 1
# 466: 2
# 463: 1
# 460: 1
# 459: 1
# 458: 1
# 457: 3
# 456: 1
# 455: 1
# 452: 2
# 451: 2
# 450: 1
# 449: 1
# 447: 1
# 443: 1
# 440: 1
# 439: 1
# 436: 1
# 435: 1
# 434: 1
# 433: 1
# 431: 1
# 430: 2
# 428: 1
# 427: 1
# 425: 2
# 423: 2
# 421: 1
# 419: 2
# 416: 1
# 415: 1
# 413: 1
# 412: 1
# 411: 1
# 410: 1
# 408: 1
# 407: 9
# 406: 1
# 405: 1
# 404: 4
# 402: 2
# 398: 1
# 397: 1
# 395: 2
# 394: 2
# 393: 2
# 392: 1
# 391: 2
# 390: 3
# 389: 1
# 388: 1
# 387: 1
# 386: 2
# 385: 2
# 384: 3
# 383: 1
# 382: 3
# 381: 2
# 380: 3
# 379: 3
# 378: 3
# 377: 1
# 376: 3
# 375: 3
# 374: 1
# 373: 5
# 372: 1
# 370: 3
# 369: 1
# 368: 1
# 366: 1
# 365: 1
# 364: 1
# 363: 1
# 360: 2
# 359: 1
# 357: 1
# 354: 1
# 353: 1
# 352: 2
# 351: 2
# 350: 1
# 347: 4
# 344: 1
# 343: 2
# 342: 2
# 340: 1
# 339: 1
# 334: 2
# 332: 1
# 331: 2
# 330: 1
# 327: 2
# 326: 1
# 325: 1
# 324: 2
# 322: 1
# 321: 1
# 320: 1
# 319: 1
# 317: 1
# 314: 2
# 311: 1
# 310: 1
# 306: 1
# 304: 2
# 301: 3
# 300: 1
# 299: 1
# 293: 1
# 292: 1
# 290: 1
# 288: 1
# 287: 2
# 285: 1
# 280: 2
# 279: 1
# 275: 1
# 271: 1
# 270: 2
# 267: 1
# 265: 1
# 264: 1
# 263: 3
# 262: 1
# 260: 1
# 259: 1
# 258: 2
# 254: 1
# 253: 1
# 250: 1
# 249: 1
# 247: 2
# 246: 1
# 244: 1
# 242: 1
# 241: 1
# 240: 2
# 239: 1
# 238: 1
# 236: 1
# 235: 2
# 233: 1
# 229: 1
# 226: 1
# 224: 1
# 219: 2
# 217: 1
# 215: 1
# 212: 1
# 211: 1
# 209: 2
# 207: 1
# 205: 1
# 204: 1
# 202: 2
# 200: 2
# 195: 1
# 194: 1
# 193: 2
# 192: 1
# 191: 1
# 190: 1
# 189: 1
# 186: 1
# 184: 1
# 181: 1
# 180: 1
# 179: 1
# 177: 1
# 176: 1
# 173: 2
# 172: 1
# 169: 2
# 167: 1
# 164: 1
# 163: 1
# 162: 1
# 160: 1
# 157: 1
# 156: 2
# 155: 3
# 154: 1
# 153: 1
# 152: 2
# 151: 1
# 150: 2
# 147: 1
# 145: 1
# 144: 1
# 143: 2
# 142: 1
# 141: 1
# 140: 1
# 136: 4
# 135: 1
# 131: 2
# 130: 1
# 129: 2
# 126: 1
# 125: 2
# 124: 1
# 122: 1
# 121: 1
# 119: 2
# 118: 2
# 117: 2
# 116: 2
# 115: 1
# 113: 1
# 112: 1
# 111: 1
# 110: 1
# 109: 2
# 107: 1
# 104: 1
# 103: 2
# 101: 1
# 99: 2
# 98: 2
# 97: 1
# 93: 1
# 92: 3
# 91: 1
# 90: 1
# 88: 1
# 86: 1
# 85: 1
# 83: 1
# 82: 1
# 80: 1
# 79: 1
# 73: 1
# 72: 1
# 70: 2
# 69: 2
# 68: 2
# 63: 1
# 59: 1
# 54: 2
# 53: 2
# 52: 1
# 51: 1
# 50: 1
# 47: 1
# 46: 1
# 37: 1
# 34: 2
# 33: 1
# 32: 2
# 28: 2
# 27: 1
# 25: 1
# 23: 2
# 18: 1
# 14: 1
# 10: 384

# %%
# probably 1306
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l].append(item)
    else:
        sizes[l] = [item]

# %%
s = 1455
print(sizes[s][0])
print(datetime.utcfromtimestamp(itemPrices[sizes[s][0]][0][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Mystic_robe_top_(dark)
# 2015-03-06 00:00:00

# %%
with open('Data/itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
viableItems = []
print(len(itemPrices))
for item in itemPrices:
    if len(itemPrices[item])>1200 and itemPrices[item][-1][1]>10:
        viableItems.append(item)
print(len(viableItems))
# Out:
# 3361
# 1788

# %%
with open('Data/viableItems.pickle','wb') as f:
    pickle.dump(viableItems,f)
