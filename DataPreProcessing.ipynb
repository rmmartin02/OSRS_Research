# %%
import sys
import os
address = (os.sep).join(os.getcwd().split(os.sep)[:-2])
print(address)
sys.path.append(address)
print(sys.path)
import util.scraper
import util.items
import pickle
import matplotlib.pyplot as plt
from sklearn import preprocessing
import numpy as np
import sys
from datetime import datetime
# Out:
# /home/makoa
# ['/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '', '/home/makoa/.local/lib/python3.6/site-packages', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/home/makoa/.local/lib/python3.6/site-packages/IPython/extensions', '/home/makoa/.ipython', '/home/makoa', '/home/makoa']

# %%
with open('Data/itemPricesOriginal.pickle','rb') as f:
    itemPrices = pickle.load(f)

# %%
def checkDates(dates):
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    return repeats

# %%
data = {}
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)

# %%
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))
# Out:
# 3rd_age_amulet 9
# 3rd_age_axe 9
# 3rd_age_bow 9
# 3rd_age_cloak 9
# 3rd_age_full_helmet 9
# 3rd_age_kiteshield 9
# 3rd_age_longsword 9
# 3rd_age_mage_hat 9
# 3rd_age_pickaxe 9
# 3rd_age_platebody 9
# 3rd_age_platelegs 9
# 3rd_age_range_coif 9
# 3rd_age_range_legs 9
# 3rd_age_range_top 9
# 3rd_age_robe 9
# 3rd_age_robe_top 9
# 3rd_age_vambraces 9
# 3rd_age_wand 8
# A_powdered_wig 8
# Abyssal_bludgeon 8
# Abyssal_bracelet(5) 9
# Abyssal_dagger 8
# Abyssal_dagger_(p) 8
# Abyssal_dagger_(p+) 8
# Abyssal_dagger_(p++) 8
# Abyssal_whip 8
# Achey_tree_logs 8
# Acorn 9
# Adamant_2h_sword 8
# Adamant_arrow 8
# Adamant_arrow(p) 9
# Adamant_arrow(p+) 9
# Adamant_arrow(p++) 9
# Adamant_arrowtips 8
# Adamant_axe 8
# Adamant_battleaxe 8
# Adamant_bolts 9
# Adamant_bolts_(p) 10
# Adamant_bolts_(p+) 10
# Adamant_bolts_(p++) 10
# Adamant_bolts(unf) 10
# Adamant_boots 8
# Adamant_brutal 8
# Adamant_cane 8
# Adamant_chainbody 8
# Adamant_claws 8
# Adamant_crossbow 8
# Adamant_crossbow_(u) 8
# Adamant_dagger 8
# Adamant_dagger(p) 9
# Adamant_dagger(p+) 9
# Adamant_dagger(p++) 9
# Adamant_dart 8
# Adamant_dart(p) 9
# Adamant_dart(p+) 9
# Adamant_dart(p++) 9
# Adamant_dart_tip 8
# Adamant_full_helm 8
# Adamant_full_helm_(g) 8
# Adamant_full_helm_(t) 8
# Adamant_gold-trimmed_set_(lg) 8
# Adamant_gold-trimmed_set_(sk) 8
# Adamant_halberd 8
# Adamant_hasta 8
# Adamant_hasta(p) 9
# Adamant_hasta(p+) 9
# Adamant_hasta(p++) 9
# Adamant_helm_(h1) 8
# Adamant_helm_(h2) 8
# Adamant_helm_(h3) 8
# Adamant_helm_(h4) 8
# Adamant_helm_(h5) 8
# Adamant_javelin 8
# Adamant_javelin(p) 9
# Adamant_javelin(p+) 9
# Adamant_javelin(p++) 9
# Adamant_javelin_heads 8
# Adamant_kiteshield 8
# Adamant_kiteshield_(g) 8
# Adamant_kiteshield_(t) 8
# Adamant_knife 8
# Adamant_knife(p) 9
# Adamant_knife(p+) 9
# Adamant_knife(p++) 9
# Adamant_longsword 8
# Adamant_mace 8
# Adamant_med_helm 8
# Adamant_pickaxe 8
# Adamant_platebody 8
# Adamant_platebody_(g) 8
# Adamant_platebody_(t) 8
# Adamant_platelegs 8
# Adamant_platelegs_(g) 8
# Adamant_platelegs_(t) 8
# Adamant_plateskirt 8
# Adamant_plateskirt_(g) 8
# Adamant_plateskirt_(t) 8
# Adamant_scimitar 8
# Adamant_set_(lg) 8
# Adamant_set_(sk) 8
# Adamant_shield_(h1) 8
# Adamant_shield_(h2) 8
# Adamant_shield_(h3) 8
# Adamant_shield_(h4) 8
# Adamant_shield_(h5) 8
# Adamant_spear 8
# Adamant_spear(p) 9
# Adamant_spear(p+) 9
# Adamant_spear(p++) 9
# Adamant_sq_shield 8
# Adamant_sword 8
# Adamant_thrownaxe 8
# Adamant_trimmed_set_(lg) 8
# Adamant_trimmed_set_(sk) 8
# Adamant_warhammer 8
# Adamantite_bar 8
# Adamantite_limbs 8
# Adamantite_nails 9
# Adamantite_ore 9
# Admiral_pie 9
# Afro 9
# Agility_mix(1) 10
# Agility_mix(2) 10
# Agility_potion(1) 10
# Agility_potion(2) 10
# Agility_potion(3) 10
# Agility_potion(4) 10
# Ahrim's_armour_set 9
# Ahrim's_hood 9
# Ahrim's_hood_0 10
# Ahrim's_robeskirt 9
# Ahrim's_robeskirt_0 10
# Ahrim's_robetop 9
# Ahrim's_robetop_0 10
# Ahrim's_staff 9
# Ahrim's_staff_0 10
# Air_battlestaff 9
# Air_orb 9
# Air_rune 9
# Air_talisman 9
# Air_tiara 9
# Airtight_pot 9
# Ale_of_the_gods 8
# Ale_yeast 9
# Amethyst 8
# Amethyst_arrow 8
# Amethyst_arrow(p) 8
# Amethyst_arrow(p+) 8
# Amethyst_arrow(p++) 8
# Amethyst_arrowtips 8
# Amethyst_bolt_tips 8
# Amethyst_broad_bolts 8
# Amethyst_javelin 8
# Amethyst_javelin(p) 8
# Amethyst_javelin(p+) 8
# Amethyst_javelin(p++) 8
# Amethyst_javelin_heads 8
# Amulet_mould 9
# Amulet_of_accuracy 9
# Amulet_of_avarice 8
# Amulet_of_bounty 8
# Amulet_of_chemistry 8
# Amulet_of_defence 9
# Amulet_of_eternal_glory 8
# Amulet_of_fury 9
# Amulet_of_glory 9
# Amulet_of_glory(4) 10
# Amulet_of_glory(6) 10
# Amulet_of_glory_(t) 9
# Amulet_of_glory_(t4) 10
# Amulet_of_glory_(t6) 10
# Amulet_of_magic 9
# Amulet_of_magic_(t) 9
# Amulet_of_power 9
# Amulet_of_strength 9
# Amulet_of_the_damned_(full) 10
# Amulet_of_torture 9
# Amylase_crystal 9
# Ancestral_hat 8
# Ancestral_robe_bottom 8
# Ancestral_robe_top 8
# Ancestral_robes_set 8
# Anchovies 9
# Anchovy_pizza 9
# Ancient_blessing 8
# Ancient_bracers 9
# Ancient_chaps 9
# Ancient_cloak 9
# Ancient_coif 9
# Ancient_crozier 9
# Ancient_crystal 8
# Ancient_d'hide 9
# Ancient_d'hide_boots 8
# Ancient_dragonhide_set 9
# Ancient_effigy 8
# Ancient_emblem 8
# Ancient_full_helm 9
# Ancient_kiteshield 9
# Ancient_mace 9
# Ancient_medallion 8
# Ancient_mitre 9
# Ancient_page_1 9
# Ancient_page_2 9
# Ancient_page_3 9
# Ancient_page_4 9
# Ancient_platebody 10
# Ancient_platelegs 9
# Ancient_plateskirt 10
# Ancient_relic 9
# Ancient_robe_legs 10
# Ancient_robe_top 10
# Ancient_rune_armour_set_(lg) 10
# Ancient_rune_armour_set_(sk) 10
# Ancient_staff 10
# Ancient_statuette 9
# Ancient_stole 10
# Ancient_totem 9
# Ancient_wyvern_shield 9
# Anglerfish 11
# Anguish_ornament_kit 9
# Ankou_gloves 9
# Ankou_mask 9
# Ankou_socks 9
# Ankou_top 9
# Ankou's_leggings 9
# Annakarl_teleport 10
# Anti-dragon_shield 10
# Anti-poison_supermix(1) 11
# Anti-poison_supermix(2) 11
# Anti-venom(1) 11
# Anti-venom(2) 11
# Anti-venom(3) 11
# Anti-venom(4) 11
# Anti-venom+(1) 11
# Anti-venom+(2) 11
# Anti-venom+(3) 11
# Anti-venom+(4) 11
# Antidote+(1) 11
# Antidote+(2) 11
# Antidote+(3) 11
# Antidote+(4) 11
# Superattack_mix(1) 13
# Superattack_mix(2) 12
# Antidote++(1) 11
# Antidote++(2) 11
# Antidote++(3) 11
# Antidote++(4) 11
# Antifire_mix(1) 11
# Antifire_mix(2) 11
# Antifire_potion(1) 11
# Antifire_potion(2) 11
# Antifire_potion(3) 11
# Antifire_potion(4) 11
# Antipoison(1) 11
# Antipoison(2) 11
# Antipoison(3) 11
# Antipoison(4) 11
# Antipoison_mix(1) 11
# Antipoison_mix(2) 11
# Ape_atoll_teleport 10
# Apple_mush 10
# Apple_pie 10
# Apple_sapling 10
# Apple_tree_seed 11
# Apples(5) 11
# Apprentice_wand 10
# Arcane_prayer_scroll 9
# Arcane_sigil 10
# Arcane_spirit_shield 10
# Arceuus_banner 9
# Arceuus_hood 9
# Arceuus_scarf 9
# Archer_helm 10
# Archers_ring 10
# Archery_ticket 11
# Arctic_pine_logs 10
# Arctic_pyre_logs 10
# Ardougne_teleport 10
# Arena_book 12
# Armadyl_bracers 10
# Armadyl_chainskirt 10
# Armadyl_chaps 10
# Armadyl_chestplate 10
# Armadyl_cloak 10
# Armadyl_coif 10
# Armadyl_crossbow 10
# Armadyl_crozier 10
# Armadyl_d'hide 10
# Armadyl_d'hide_boots 9
# Armadyl_dragonhide_set 10
# Armadyl_full_helm 10
# Armadyl_godsword 10
# Armadyl_godsword_ornament_kit 9
# Armadyl_helmet 10
# Armadyl_hilt 10
# Armadyl_kiteshield 10
# Armadyl_mitre 10
# Armadyl_page_1 10
# Armadyl_page_2 10
# Armadyl_page_3 10
# Armadyl_page_4 10
# Armadyl_platebody 10
# Armadyl_platelegs 10
# Armadyl_plateskirt 10
# Armadyl_robe_legs 10
# Armadyl_robe_top 10
# Armadyl_rune_armour_set_(lg) 10
# Armadyl_rune_armour_set_(sk) 10
# Armadyl_stole 10
# Arrow_shaft 10
# Asgarnian_ale 10
# Asgarnian_ale(4) 11
# Asgarnian_ale(m) 11
# Asgarnian_ale(m4) 11
# Asgarnian_hops 10
# Asgarnian_seed 11
# Ashes 10
# Assorted_flowers 11
# Astral_rune 10
# Asyn_remains 10
# Attack_mix(1) 11
# Attack_mix(2) 11
# Attack_potion(1) 11
# Attack_potion(2) 11
# Attack_potion(3) 11
# Attack_potion(4) 11
# Avantoe 10
# Avantoe_potion_(unf) 10
# Avantoe_seed 11
# Avernic_defender_hilt 8
# Axeman's_folly 10
# Axeman's_folly(4) 11
# Axeman's_folly(m) 11
# Axeman's_folly(m4) 11
# Baby_impling_jar 10
# Babydragon_bones 10
# Bag_of_salt 10
# Bagged_bluebells 12
# Bagged_daffodils 12
# Bagged_dead_tree 12
# Bagged_flower 12
# Bagged_magic_tree 10
# Bagged_maple_tree 10
# Bagged_marigolds 12
# Bagged_nice_tree 10
# Bagged_oak_tree 12
# Bagged_plant_1 10
# Bagged_plant_2 10
# Bagged_plant_3 10
# Bagged_roses 12
# Bagged_sunflower 12
# Bagged_willow_tree 12
# Bagged_yew_tree 12
# Baked_potato 10
# Ball_of_wool 10
# Ballista_limbs 10
# Ballista_spring 10
# Banana 10
# Banana_sapling 10
# Banana_stew 11
# Banana_tree_seed 11
# Bananas(5) 11
# Bandit's_brew 10
# Bandos_boots 10
# Bandos_bracers 10
# Bandos_chaps 10
# Bandos_chestplate 10
# Bandos_cloak 10
# Bandos_coif 10
# Bandos_crozier 10
# Bandos_d'hide 10
# Bandos_d'hide_boots 9
# Bandos_dragonhide_set 10
# Bandos_full_helm 10
# Bandos_godsword 10
# Bandos_godsword_ornament_kit 9
# Bandos_hilt 10
# Bandos_kiteshield 10
# Bandos_mitre 10
# Bandos_page_1 10
# Bandos_page_2 10
# Bandos_page_3 10
# Bandos_page_4 10
# Bandos_platebody 10
# Bandos_platelegs 10
# Bandos_plateskirt 11
# Bandos_robe_legs 10
# Bandos_robe_top 10
# Bandos_rune_armour_set_(lg) 10
# Bandos_rune_armour_set_(sk) 10
# Bandos_stole 10
# Bandos_tassets 10
# Barb_bolttips 10
# Barb-tail_harpoon 10
# Barbed_bolts 10
# Bark 10
# Barley 10
# Barley_malt 10
# Barley_seed 11
# Barrel 10
# Barrows_teleport 10
# Basalt 8
# Basket 10
# Bass 10
# Bastion_potion(1) 8
# Bastion_potion(2) 8
# Bastion_potion(3) 8
# Bastion_potion(4) 8
# Bat_bones 10
# Batta_tin 10
# Battlemage_potion(1) 8
# Battlemage_potion(2) 8
# Battlemage_potion(3) 8
# Battlemage_potion(4) 8
# Battlestaff 10
# Beanie 10
# Bear_fur 10
# Beer 10
# Beer_barrel 12
# Beer_glass 10
# Beer_tankard 11
# Beginner_wand 10
# Belladonna_seed 11
# Berserker_helm 10
# Berserker_necklace 10
# Berserker_ring 10
# Big_bones 10
# Big_fishing_net 10
# Big_pirate_hat 10
# Binding_necklace 10
# Bird_house 9
# Bird_nest 9
# Bird_snare 10
# Black_2h_sword 10
# Black_axe 10
# Black_battleaxe 10
# Black_bead 10
# Black_beret 10
# Black_boater 10
# Black_boots 10
# Black_brutal 10
# Black_cane 10
# Black_cape 11
# Black_cavalier 10
# Black_chainbody 10
# Black_chinchompa 10
# Black_claws 10
# Black_d'hide_body 11
# Black_d'hide_body_(g) 10
# Black_d'hide_body_(t) 10
# Black_d'hide_chaps 10
# Black_d'hide_chaps_(g) 10
# Black_d'hide_chaps_(t) 10
# Black_d'hide_shield 9
# Black_d'hide_vamb 10
# Black_dagger 10
# Black_dagger(p) 11
# Black_dagger(p+) 11
# Black_dagger(p++) 11
# Black_dart 10
# Black_dart(p) 11
# Black_dart(p+) 11
# Black_dart(p++) 11
# Black_demon_mask 9
# Black_desert_robe 10
# Black_desert_shirt 10
# Black_dragon_leather 10
# Black_dragon_mask 10
# Black_dragonhide 10
# Black_dragonhide_set 10
# Black_elegant_legs 10
# Black_elegant_shirt 10
# Black_flowers 11
# Black_full_helm 10
# Black_full_helm_(g) 10
# Black_full_helm_(t) 10
# Black_gold-trimmed_set_(lg) 10
# Black_gold-trimmed_set_(sk) 10
# Black_halberd 10
# Black_headband 10
# Black_helm_(h1) 10
# Black_helm_(h2) 10
# Black_helm_(h3) 10
# Black_helm_(h4) 10
# Black_helm_(h5) 10
# Black_kiteshield 10
# Black_kiteshield_(g) 10
# Black_kiteshield_(t) 10
# Black_knife 10
# Black_knife(p) 11
# Black_knife(p+) 11
# Black_knife(p++) 11
# Black_leprechaun_hat 9
# Black_longsword 11
# Black_mace 10
# Black_mask 10
# Black_mask_(10) 12
# Black_med_helm 10
# Black_nails 10
# Black_pickaxe 10
# Black_platebody 10
# Black_platebody_(g) 10
# Black_platebody_(t) 10
# Black_platelegs 10
# Black_platelegs_(g) 10
# Black_platelegs_(t) 10
# Black_plateskirt 10
# Black_plateskirt_(g) 10
# Black_plateskirt_(t) 10
# Black_robe 11
# Black_salamander 10
# Black_scimitar 10
# Black_set_(lg) 10
# Black_set_(sk) 10
# Black_shield_(h1) 10
# Black_shield_(h2) 10
# Black_shield_(h3) 10
# Black_shield_(h4) 10
# Black_shield_(h5) 10
# Black_skirt 10
# Black_skirt_(g) 10
# Black_skirt_(t) 10
# Black_spear 10
# Black_spear(p) 11
# Black_spear(p+) 11
# Black_spear(p++) 11
# Black_spiky_vambs 10
# Black_sq_shield 10
# Black_sword 10
# Black_tourmaline_core 9
# Black_toy_horsey 11
# Black_trimmed_set_(lg) 10
# Black_trimmed_set_(sk) 10
# Black_unicorn_mask 9
# Black_warhammer 10
# Black_warlock 11
# Black_wizard_hat_(g) 10
# Black_wizard_hat_(t) 10
# Black_wizard_robe_(g) 10
# Black_wizard_robe_(t) 10
# Blacksmith's_helm 9
# Blamish_bark_shell 10
# Blessed_spirit_shield 10
# Blood_rune 10
# Bloody_bracer 8
# Blue_beret 10
# Blue_boater 10
# Blue_boots 11
# Blue_cape 11
# Blue_d'hide_body 11
# Blue_d'hide_body_(g) 10
# Blue_d'hide_body_(t) 10
# Blue_d'hide_chaps 10
# Blue_d'hide_chaps_(g) 10
# Blue_d'hide_chaps_(t) 10
# Blue_d'hide_shield 9
# Blue_d'hide_vamb 10
# Blue_dark_bow_paint 10
# Blue_dragon_leather 10
# Blue_dragon_mask 10
# Blue_dragon_scale 10
# Blue_dragonhide 10
# Blue_dragonhide_set 10
# Blue_dye 10
# Blue_elegant_blouse 10
# Blue_elegant_legs 10
# Blue_elegant_shirt 10
# Blue_elegant_skirt 10
# Blue_feather 10
# Blue_firelighter 10
# Blue_flowers 11
# Blue_halloween_mask 11
# Blue_hat 11
# Blue_headband 10
# Blue_partyhat 10
# Blue_robe_bottoms 11
# Blue_robe_top 11
# Blue_skirt 10
# Blue_skirt_(g) 10
# Blue_skirt_(t) 10
# Blue_spiky_vambs 10
# Blue_wizard_hat 10
# Blue_wizard_hat_(g) 10
# Blue_wizard_hat_(t) 10
# Blue_wizard_robe 11
# Blue_wizard_robe_(g) 10
# Blue_wizard_robe_(t) 10
# Blurberry_special 10
# Bob's_black_shirt 10
# Bob's_blue_shirt 10
# Bob's_green_shirt 10
# Bob's_purple_shirt 10
# Bob's_red_shirt 10
# Body_rune 10
# Body_talisman 10
# Body_tiara 10
# Bolt_mould 10
# Bolt_of_cloth 10
# Bolt_rack 10
# Bone_bolts 10
# Bone_club 10
# Bone_dagger 10
# Bone_dagger_(p) 12
# Bone_dagger_(p+) 12
# Bone_dagger_(p++) 12
# Bone_spear 10
# Bones 10
# Bones_to_bananas 10
# Bones_to_peaches 10
# Book_of_balance_page_set 10
# Book_of_darkness_page_set 10
# Book_of_law_page_set 10
# Book_of_war_page_set 10
# Bookcase 12
# Boots_of_darkness 9
# Botanical_pie 9
# Bottle_of_wine 10
# Bottled_dragonbreath_(unpowered) 5
# Bottled_dragonbreath 5
# Bottomless_compost_bucket 5
# Bounty_teleport_scroll 10
# Bow_string 10
# Bowl 10
# Bowl_of_hot_water 10
# Bowl_of_water 10
# Bowl_wig 9
# Box_trap 10
# Bracelet_mould 10
# Bracelet_of_clay 10
# Bracelet_of_ethereum_(uncharged) 9
# Bracelet_of_slaughter 9
# Brandy 10
# Brass_key 10
# Brass_necklace 10
# Bread 10
# Bread_dough 10
# Briefcase 10
# Brine_sabre 10
# Broad_arrowheads 10
# Broad_bolts 10
# Broken_bark_snelm 10
# Bronze_2h_sword 10
# Bronze_arrow 10
# Bronze_arrow(p) 11
# Bronze_arrow(p+) 11
# Bronze_arrow(p++) 11
# Bronze_arrowtips 10
# Bronze_axe 10
# Bronze_bar 10
# Bronze_battleaxe 10
# Bronze_bolts 10
# Bronze_bolts_(p) 11
# Bronze_bolts_(p+) 11
# Bronze_bolts_(p++) 11
# Bronze_bolts_(unf) 10
# Bronze_boots 10
# Bronze_brutal 10
# Bronze_chainbody 10
# Bronze_claws 10
# Bronze_crossbow 10
# Bronze_crossbow_(u) 10
# Bronze_dagger 10
# Bronze_dagger(p) 11
# Bronze_dagger(p+) 11
# Bronze_dagger(p++) 11
# Bronze_dart 10
# Bronze_dart(p) 11
# Bronze_dart(p+) 11
# Bronze_dart(p++) 11
# Bronze_dart_tip 10
# Bronze_dragon_mask 10
# Bronze_full_helm 10
# Bronze_full_helm_(g) 10
# Bronze_full_helm_(t) 10
# Bronze_gold-trimmed_set_(lg) 10
# Bronze_gold-trimmed_set_(sk) 10
# Bronze_halberd 10
# Bronze_hasta 10
# Bronze_hasta(p) 11
# Bronze_hasta(p+) 11
# Bronze_hasta(p++) 11
# Bronze_javelin 10
# Bronze_javelin(p) 11
# Bronze_javelin(p+) 11
# Bronze_javelin(p++) 11
# Bronze_javelin_heads 10
# Bronze_kiteshield 10
# Bronze_kiteshield_(g) 10
# Bronze_kiteshield_(t) 10
# Bronze_knife 10
# Bronze_knife(p) 11
# Bronze_knife(p+) 11
# Bronze_knife(p++) 11
# Bronze_limbs 10
# Bronze_longsword 10
# Bronze_mace 10
# Bronze_med_helm 10
# Bronze_nails 10
# Bronze_pickaxe 10
# Bronze_platebody 10
# Bronze_platebody_(g) 10
# Bronze_platebody_(t) 10
# Bronze_platelegs 10
# Bronze_platelegs_(g) 10
# Bronze_platelegs_(t) 10
# Bronze_plateskirt 11
# Bronze_plateskirt_(g) 10
# Bronze_plateskirt_(t) 10
# Bronze_scimitar 10
# Bronze_set_(lg) 10
# Bronze_set_(sk) 10
# Bronze_spear 10
# Bronze_spear(p) 11
# Bronze_spear(p+) 11
# Bronze_spear(p++) 11
# Bronze_sq_shield 10
# Bronze_sword 10
# Bronze_thrownaxe 10
# Bronze_trimmed_set_(lg) 10
# Bronze_trimmed_set_(sk) 10
# Bronze_warhammer 10
# Bronze_wire 10
# Brown_apron 10
# Brown_headband 10
# Brown_toy_horsey 11
# Bryophyta's_essence 8
# Bryophyta's_staff_(uncharged) 8
# Bucket 10
# Bucket_helm 9
# Bucket_helm_(g) 9
# Bucket_of_milk 10
# Bucket_of_sand 10
# Bucket_of_sap 10
# Bucket_of_water 10
# Bucket_of_wax 10
# Unlit_bug_lantern 13
# Bullseye_lantern 10
# Burning_amulet(5) 9
# Burnt_bones 10
# Burnt_page 9
# Butterfly_jar 10
# Butterfly_net 10
# Cabbage 10
# Cabbage_round_shield 9
# Cabbage_seed 11
# Cabbages(10) 11
# Cactus_seed 11
# Cactus_spine 10
# Cadantine 10
# Cadantine_blood_potion_(unf) 8
# Cadantine_potion_(unf) 10
# Cadantine_seed 11
# Cadava_berries 10
# Cadavaberry_seed 11
# Cake 10
# Cake_tin 10
# Calcite 9
# Calquat_fruit 10
# Calquat_keg 10
# Calquat_sapling 10
# Calquat_tree_seed 11
# Camelot_teleport 10
# Candle 10
# Cannon_barrels 10
# Cannon_base 10
# Cannon_furnace 10
# Cannon_stand 10
# Cannonball 11
# Carrallangar_teleport 10
# Carved_oak_bench 12
# Carved_oak_magic_wardrobe 12
# Carved_oak_table 12
# Carved_teak_bench 12
# Carved_teak_magic_wardrobe 12
# Carved_teak_table 12
# Casket 10
# Castle_wars_bracelet(3) 11
# Cat_mask 10
# Cavalier_mask 10
# Cave_eel 10
# Cave_goblin_wire 10
# Caviar 10
# Celastrus_sapling 5
# Cemetery_teleport 10
# Chaos_rune 10
# Chaos_talisman 10
# Chaos_tiara 10
# Charcoal 10
# Charge_dragonstone_jewellery_scroll 9
# Cheese 10
# Cheese+tom_batta 10
# Chef's_delight 10
# Chef's_delight(4) 11
# Chef's_delight(m) 11
# Chef's_delight(m4) 11
# Chef's_hat 10
# Chilli_con_carne 10
# Chilli_potato 10
# Chinchompa 10
# Chisel 10
# Choc_saturday 10
# Choc-ice 10
# Chocchip_crunchies 10
# Chocolate_bar 10
# Chocolate_bomb 10
# Chocolate_cake 10
# Chocolate_dust 10
# Chopped_garlic 10
# Chopped_onion 10
# Chopped_tomato 10
# Chopped_tuna 10
# Chopped_ugthanki 11
# Christmas_cracker 10
# Cider 10
# Cider(4) 11
# Cider_barrel 12
# Cider(m4) 11
# Circular_hide 10
# Citizen_shoes 10
# Citizen_top 10
# Citizen_trousers 10
# Clay 10
# Cleaning_cloth 10
# Cleaver 10
# Climbing_boots 10
# Clockwork 10
# Clue_box 10
# Coal 10
# Cocktail_glass 10
# Cocktail_guide 10
# Cocktail_shaker 10
# Coconut 10
# Coconut_milk 10
# Cod 10
# Coif 10
# Combat_bracelet 10
# Combat_bracelet(4) 11
# Combat_bracelet(6) 11
# Combat_mix(1) 11
# Combat_mix(2) 11
# Combat_potion(1) 12
# Combat_potion(2) 12
# Combat_potion(3) 12
# Combat_potion(4) 12
# Combat_potion_set 10
# Common_kebbit_fur 10
# Comp_ogre_bow 10
# Compost 10
# Compost_potion(1) 11
# Compost_potion(2) 11
# Compost_potion(3) 11
# Compost_potion(4) 11
# Cooked_chicken 10
# Cooked_chompy 10
# Cooked_jubbly 10
# Cooked_karambwan 10
# Cooked_meat 10
# Cooked_oomlie_wrap 10
# Cooked_rabbit 10
# Cooked_slimy_eel 10
# Cooked_sweetcorn 10
# Cooking_apple 10
# Copper_ore 10
# Cornflour 12
# Cosmic_rune 10
# Cosmic_talisman 10
# Cosmic_tiara 10
# Cowhide 10
# Craw's_bow_(u) 8
# Cream_boots 11
# Cream_hat 11
# Cream_robe_bottoms 11
# Cream_robe_top 11
# Crier_bell 9
# Crier_coat 9
# Crier_hat 10
# Crossbow 10
# Crossbow_string 10
# Crude_chair 12
# Crunchy_tray 10
# Crushed_nest 10
# Crushed_superior_dragon_bones 9
# New_crystal_bow 12
# Crystal_key 10
# Crystal_seed 11
# New_crystal_shield 11
# Cup_of_hot_water 10
# Cup_of_tea 10
# Cup_of_water 11
# Cured_yak-hide 10
# Curry 10
# Curry_leaf 10
# Curry_sapling 10
# Curry_tree_seed 11
# Cyclops_head 10
# Dagannoth_bones 10
# Dagannoth_hide 10
# Damaged_monkey_tail 9
# Dareeyak_teleport 10
# Dark_bow 10
# Dark_bow_tie 9
# Dark_cavalier 10
# Dark_crab 10
# Dark_fishing_bait 10
# Dark_infinity_colour_kit 10
# Dark_kebbit_fur 10
# Dark_trousers 9
# Dark_tuxedo_cuffs 9
# Dark_tuxedo_jacket 9
# Dark_tuxedo_shoes 9
# Dashing_kebbit_fur 10
# Death_rune 10
# Death_talisman 10
# Death_tiara 10
# Deerstalker 10
# Defence_mix(1) 11
# Defence_mix(2) 11
# Defence_potion(1) 11
# Defence_potion(2) 11
# Defence_potion(3) 11
# Defence_potion(4) 11
# Desert_boots 10
# Desert_camo_legs 10
# Desert_camo_top 10
# Desert_devil_fur 10
# Desert_goat_horn 10
# Desert_legs 10
# Desert_robe 10
# Desert_robes 10
# Desert_shirt 10
# Desert_top 10
# Dexterous_prayer_scroll 9
# Dharok's_armour_set 10
# Dharok's_greataxe 10
# Dharok's_greataxe_0 11
# Dharok's_helm 10
# Dharok's_helm_0 11
# Dharok's_platebody 10
# Dharok's_platebody_0 11
# Dharok's_platelegs 10
# Dharok's_platelegs_0 11
# Diamond 10
# Diamond_amulet 10
# Diamond_amulet_(u) 10
# Diamond_bolt_tips 11
# Diamond_bolts 11
# Diamond_bolts_(e) 10
# Diamond_bracelet 10
# Diamond_dragon_bolts 9
# Diamond_dragon_bolts_(e) 9
# Diamond_necklace 10
# Diamond_ring 10
# Digsite_teleport 10
# Dinh's_bulwark 9
# Disk_of_returning 10
# Dodgy_necklace 9
# Doogle_leaves 11
# Dorgeshuun_crossbow 10
# Double_eye_patch 9
# Draconic_visage 10
# Dragon_2h_sword 10
# Dragon_armour_set_(lg) 9
# Dragon_armour_set_(sk) 9
# Dragon_arrow 10
# Dragon_arrow(p) 11
# Dragon_arrow(p+) 11
# Dragon_arrow(p++) 11
# Dragon_arrowtips 10
# Dragon_axe 10
# Dragon_battleaxe 10
# Dragon_bitter 10
# Dragon_bitter(4) 11
# Dragon_bitter(m) 11
# Dragon_bitter(m4) 11
# Dragon_bolts 9
# Dragon_bolts_(p) 9
# Dragon_bolts_(p+) 9
# Dragon_bolts_(p++) 9
# Dragon_bolts_(unf) 9
# Dragon_bones 10
# Dragon_boots 10
# Dragon_boots_ornament_kit 9
# Dragon_cane 10
# Dragon_chainbody 10
# Dragon_chainbody_ornament_kit 12
# Dragon_claws 9
# Dragon_crossbow 9
# Dragon_crossbow_(u) 9
# Dragon_dagger 11
# Dragon_dagger(p) 11
# Dragon_dagger(p+) 11
# Dragon_dagger(p++) 11
# Dragon_dart 10
# Dragon_dart(p) 11
# Dragon_dart(p+) 11
# Dragon_dart(p++) 11
# Dragon_dart_tip 10
# Dragon_defender_ornament_kit 9
# Dragon_full_helm 10
# Dragon_full_helm_ornament_kit 10
# Dragon_halberd 11
# Dragon_harpoon 9
# Dragon_hasta 5
# Dragon_hasta(p) 5
# Dragon_hasta(p+) 5
# Dragon_hasta(p++) 5
# Dragon_hunter_crossbow 9
# Dragon_hunter_lance 5
# Dragon_impling_jar 10
# Dragon_javelin 10
# Dragon_javelin(p) 10
# Dragon_javelin(p+) 10
# Dragon_javelin(p++) 10
# Dragon_javelin_heads 10
# Dragon_kiteshield 9
# Dragon_kiteshield_ornament_kit 9
# Dragon_knife 5
# Dragon_knife(p) 5
# Dragon_knife(p+) 5
# Dragon_knife(p++) 5
# Dragon_legs/skirt_ornament_kit 10
# Dragon_limbs 9
# Dragon_longsword 11
# Dragon_mace 10
# Dragon_med_helm 11
# Dragon_metal_lump 9
# Dragon_metal_shard 9
# Dragon_metal_slice 9
# Dragon_necklace 10
# Dragon_pickaxe 10
# Dragon_pickaxe_upgrade_kit 10
# Dragon_platebody 9
# Dragon_platebody_ornament_kit 9
# Dragon_platelegs 11
# Dragon_plateskirt 10
# Dragon_scale_dust 10
# Dragon_scimitar 11
# Dragon_scimitar_ornament_kit 9
# Dragon_spear 10
# Dragon_spear(p) 11
# Dragon_spear(p+) 11
# Dragon_spear(p++) 11
# Dragon_sq_shield 10
# Dragon_sq_shield_ornament_kit 11
# Dragon_sword 9
# Dragon_thrownaxe 10
# Dragon_warhammer 10
# Dragonbone_necklace 9
# Dragonfire_shield 10
# Dragonfire_ward 9
# Dragonfruit 5
# Dragonfruit_pie 5
# Dragonfruit_sapling 5
# Dragonfruit_tree_seed 5
# Dragonstone 10
# Dragonstone_amulet 10
# Dragonstone_amulet_(u) 11
# Dragonstone_bolt_tips 10
# Dragonstone_bolts 10
# Dragonstone_bolts_(e) 10
# Dragonstone_bracelet 10
# Dragonstone_dragon_bolts 9
# Dragonstone_dragon_bolts_(e) 9
# Dragonstone_ring 10
# Drake_bones 5
# Drake's_claw 5
# Drake's_tooth 5
# Draynor_manor_teleport 10
# Drift_net 9
# Druid's_robe 10
# Druid's_robe_top 10
# Drunk_dragon 10
# Dust_battlestaff 9
# Dust_rune 10
# Dwarf_cannon_set 10
# Dwarf_weed 10
# Dwarf_weed_potion_(unf) 10
# Dwarf_weed_seed 11
# Dwarven_helmet 10
# Dwarven_stout 10
# Dwarven_stout(4) 11
# Dwarven_stout(m) 11
# Dwarven_stout(m4) 11
# Dwellberries 10
# Dwellberry_seed 11
# Dynamite 10
# Earmuffs 10
# Earth_battlestaff 10
# Earth_impling_jar 10
# Earth_orb 10
# Earth_rune 10
# Earth_talisman 10
# Earth_tiara 10
# Easter_egg 10
# Eclectic_impling_jar 10
# Edible_seaweed 10
# Efaritay's_aid 9
# Efh_salt 8
# Egg 10
# Egg_and_tomato 10
# Egg_potato 10
# Egg_whisk 10
# Elder_chaos_hood 9
# Elder_chaos_robe 9
# Elder_chaos_top 9
# Elder_maul 9
# Elemental_helmet 10
# Elemental_shield 10
# Elemental_talisman 10
# Elf_camp_teleport 10
# Elysian_sigil 10
# Elysian_spirit_shield 10
# Emerald 10
# Emerald_amulet 10
# Emerald_amulet_(u) 10
# Emerald_bolt_tips 10
# Emerald_bolts 10
# Emerald_bolts_(e) 10
# Emerald_bracelet 10
# Emerald_dragon_bolts 9
# Emerald_dragon_bolts_(e) 9
# Emerald_necklace 10
# Emerald_ring 10
# Empty_candle_lantern 11
# Empty_cup 10
# Empty_oil_lamp 11
# Empty_oil_lantern 11
# Empty_plant_pot 11
# Empty_sack 10
# Enchant_diamond 10
# Enchant_dragonstone 10
# Enchant_emerald_or_jade 10
# Enchant_onyx 10
# Enchant_ruby_or_topaz 10
# Enchant_sapphire_or_opal 10
# Enchanted_hat 10
# Enchanted_robe 10
# Enchanted_top 10
# Energy_mix(1) 11
# Energy_mix(2) 11
# Energy_potion(1) 11
# Energy_potion(2) 11
# Energy_potion(3) 11
# Energy_potion(4) 11
# Ensouled_abyssal_head 10
# Ensouled_aviansie_head 10
# Ensouled_bear_head 10
# Ensouled_bloodveld_head 10
# Ensouled_chaos_druid_head 10
# Ensouled_dagannoth_head 10
# Ensouled_demon_head 10
# Ensouled_dog_head 10
# Ensouled_dragon_head 10
# Ensouled_elf_head 10
# Ensouled_giant_head 10
# Ensouled_goblin_head 10
# Ensouled_horror_head 10
# Ensouled_imp_head 10
# Ensouled_kalphite_head 10
# Ensouled_minotaur_head 10
# Ensouled_monkey_head 10
# Ensouled_ogre_head 10
# Ensouled_scorpion_head 10
# Ensouled_troll_head 10
# Ensouled_tzhaar_head 10
# Ensouled_unicorn_head 10
# Equa_leaves 10
# Essence_impling_jar 11
# Eternal_boots 10
# Eternal_crystal 10
# Eternal_gem 9
# Evil_chicken_feet 9
# Evil_chicken_head 9
# Evil_chicken_legs 9
# Evil_chicken_wings 9
# Expeditious_bracelet 9
# Explorer_backpack 10
# Extended_antifire(1) 11
# Extended_antifire(2) 11
# Extended_antifire(3) 11
# Extended_antifire(4) 11
# Extended_antifire_mix(1) 11
# Extended_antifire_mix(2) 11
# Extended_super_antifire(1) 9
# Extended_super_antifire(2) 9
# Extended_super_antifire(3) 9
# Extended_super_antifire(4) 9
# Extended_super_antifire_mix(1) 10
# Extended_super_antifire_mix(2) 9
# Eye_of_newt 10
# Facemask 11
# Fake_beard 10
# Falador_teleport 10
# Fancy_hedge 12
# Fancy_teak_dresser 12
# Fancy_tiara 9
# Farseer_helm 10
# Fat_snail 10
# Fat_snail_meat 10
# Fayrg_bones 10
# Feather 10
# Fedora 10
# Feldip_hills_teleport 10
# Feldip_weasel_fur 10
# Fenkenstrain's_castle_teleport 10
# Fez 10
# Fibula_piece 10
# Filled_plant_pot 11
# Fine_cloth 10
# Fire_battlestaff 10
# Fire_orb 10
# Fire_rune 10
# Fire_talisman 10
# Fire_tiara 10
# Fish_food 11
# Fish_offcuts 10
# Fish_pie 10
# Empty_fishbowl 11
# Fishing_bait 10
# Fishing_mix(1) 11
# Fishing_mix(2) 11
# Fishing_potion(1) 11
# Fishing_potion(2) 11
# Fishing_potion(3) 11
# Fishing_potion(4) 11
# Fishing_rod 11
# Fiyr_remains 10
# Flamtaer_bracelet 9
# Flamtaer_hammer 11
# Flared_trousers 10
# Flattened_hide 10
# Flax 10
# Flighted_ogre_arrow 11
# Fly_fishing_rod 10
# Four-poster_bed 12
# Fremennik_beige_shirt 11
# Fremennik_black_cloak 11
# Fremennik_blue_cloak 11
# Fremennik_blue_shirt 11
# Fremennik_boots 10
# Fremennik_brown_cloak 11
# Fremennik_brown_shirt 11
# Fremennik_cyan_cloak 11
# Fremennik_gloves 11
# Fremennik_green_cloak 11
# Fremennik_grey_cloak 11
# Fremennik_grey_shirt 11
# Fremennik_hat 10
# Fremennik_pink_cloak 11
# Fremennik_purple_cloak 11
# Fremennik_red_cloak 11
# Fremennik_red_shirt 11
# Fremennik_robe 10
# Fremennik_skirt 10
# Fremennik_teal_cloak 11
# Fremennik_yellow_cloak 11
# Fried_mushrooms 10
# Fried_onions 10
# Frog-leather_body 10
# Frog-leather_boots 10
# Frog-leather_chaps 10
# Frozen_whip_mix 10
# Fruit_batta 10
# Fruit_blast 10
# Frying_pan 10
# Fur 10
# Fury_ornament_kit 10
# Gadderhammer 10
# Games_necklace(8) 11
# Garden_pie 10
# Gardening_boots 10
# Gardening_trowel 10
# Garlic 10
# Garlic_powder 11
# Ghorrock_teleport 10
# Ghrazi_rapier 8
# Gianne_dough 10
# Gianne's_cook_book 10
# Giant_frog_legs 10
# Giant_seaweed 10
# Gilded_2h_sword 9
# Gilded_armour_set_(lg) 10
# Gilded_armour_set_(sk) 10
# Gilded_bench 12
# Gilded_boots 10
# Gilded_cape_rack 12
# Gilded_chainbody 9
# Gilded_clock 12
# Gilded_dresser 12
# Gilded_four-poster 12
# Gilded_full_helm 10
# Gilded_hasta 9
# Gilded_kiteshield 10
# Gilded_magic_wardrobe 12
# Gilded_med_helm 9
# Gilded_platebody 10
# Gilded_platelegs 10
# Gilded_plateskirt 10
# Gilded_scimitar 10
# Gilded_spear 9
# Gilded_sq_shield 9
# Gilded_wardrobe 12
# Gin 10
# Glassblowing_pipe 10
# Gloves_of_darkness 9
# Gloves_of_silence 10
# Gnome_goggles 10
# Gnome_scarf 10
# Gnome_spice 10
# Gnomeball 10
# Gnomebowl_mould 10
# Gnomish_firelighter 9
# Goat_horn_dust 10
# Goblin_book 11
# Goblin_mail 10
# Goblin_mask 10
# Godsword_blade 10
# Godsword_shard_1 10
# Godsword_shard_2 10
# Godsword_shard_3 10
# Gold_amulet 10
# Gold_amulet_(u) 10
# Gold_bar 10
# Gold_bracelet 10
# Gold_elegant_blouse 10
# Gold_elegant_legs 10
# Gold_elegant_shirt 10
# Gold_elegant_skirt 10
# Gold_headband 10
# Gold_leaf 10
# Gold_necklace 10
# Gold_ore 10
# Gold_ring 10
# Gold_seal 10
# Golden_apron 9
# Golden_chef's_hat 9
# Golden_scarab 10
# Golden_statuette 10
# Golovanova_fruit_top 9
# Gourmet_impling_jar 11
# Gout_tuber 11
# Graahk_fur 10
# Graahk_headdress 10
# Graahk_legs 10
# Graahk_top 9
# Grain 10
# Grand_seed_pod 10
# Granite_(500g) 12
# Granite_(2kg) 12
# Granite_(5kg) 12
# Granite_body 10
# Granite_boots 8
# Granite_clamp 10
# Granite_gloves 9
# Granite_hammer 9
# Granite_helm 10
# Granite_legs 10
# Granite_longsword 8
# Granite_maul 10
# Granite_ring 9
# Granite_shield 10
# Grape_seed 10
# Grapes 10
# Greater_demon_mask 9
# Green_boater 10
# Green_boots 11
# Green_cape 10
# Green_d'hide_body 11
# Green_d'hide_body_(g) 9
# Green_d'hide_body_(t) 10
# Green_d'hide_chaps 10
# Green_d'hide_chaps_(g) 10
# Green_d'hide_chaps_(t) 10
# Green_d'hide_shield 9
# Green_d'hide_vamb 10
# Green_dark_bow_paint 10
# Green_dragon_leather 10
# Green_dragon_mask 10
# Green_dragonhide 9
# Green_dragonhide_set 10
# Green_dye 10
# Green_elegant_blouse 10
# Green_elegant_legs 10
# Green_elegant_shirt 10
# Green_elegant_skirt 10
# Green_firelighter 12
# Green_halloween_mask 11
# Green_hat 11
# Green_headband 9
# Green_partyhat 10
# Green_robe_bottoms 11
# Green_robe_top 11
# Green_spiky_vambs 10
# Greenman's_ale 9
# Greenmans_ale(4) 11
# Greenman's_ale(m) 11
# Greenmans_ale(m4) 10
# Grey_boots 11
# Grey_gloves 11
# Grey_hat 11
# Grey_robe_bottoms 11
# Grey_robe_top 11
# Grey_toy_horsey 11
# Grey_wolf_fur 10
# Grimy_avantoe 10
# Grimy_cadantine 9
# Grimy_dwarf_weed 10
# Grimy_guam_leaf 11
# Grimy_harralander 10
# Grimy_irit_leaf 11
# Grimy_kwuarm 10
# Grimy_lantadyme 10
# Grimy_marrentill 10
# Grimy_ranarr_weed 10
# Grimy_snapdragon 10
# Grimy_tarromin 8
# Grimy_toadflax 11
# Grimy_torstol 10
# Grog 10
# Ground_guam 10
# Guam_leaf 10
# Guam_potion_(unf) 10
# Guam_seed 11
# Guam_tar 10
# Guardian_boots 9
# Guthan's_armour_set 11
# Guthan's_chainskirt 10
# Guthan's_chainskirt_0 11
# Guthan's_helm 9
# Guthan's_helm_0 11
# Guthan's_platebody 10
# Guthan's_platebody_0 10
# Guthan's_warspear 10
# Guthan's_warspear_0 11
# Guthix_armour_set_(lg) 10
# Guthix_armour_set_(sk) 10
# Guthix_balance(1) 12
# Guthix_balance(2) 12
# Guthix_balance(3) 12
# Guthix_balance(4) 12
# Guthix_bracers 10
# Guthix_chaps 10
# Guthix_cloak 11
# Guthix_coif 10
# Guthix_crozier 10
# Guthix_d'hide_boots 9
# Guthix_dragonhide_set 10
# Guthix_full_helm 10
# Guthix_kiteshield 10
# Guthix_mitre 10
# Guthix_mjolnir 10
# Guthix_page_1 10
# Guthix_page_2 10
# Guthix_page_3 10
# Guthix_page_4 10
# Guthix_platebody 9
# Guthix_platelegs 9
# Guthix_plateskirt 10
# Guthix_rest(1) 11
# Guthix_rest(2) 11
# Guthix_rest(3) 11
# Guthix_rest(4) 11
# Guthix_robe_legs 10
# Guthix_robe_top 10
# Guthix_stole 11
# Hair 10
# Half_full_wine_jug 10
# Half_moon_spectacles 9
# Halloween_mask_set 9
# Ham_boots 10
# Ham_cloak 10
# Ham_gloves 10
# Ham_hood 10
# Ham_logo 10
# Ham_robe 10
# Ham_shirt 10
# Hammer 10
# Hammerstone_hops 10
# Hammerstone_seed 11
# Hard_leather 10
# Hard_leather_shield 8
# Hardleather_body 10
# Harmony_island_teleport 10
# Harpoon 10
# Harralander 10
# Harralander_potion_(unf) 10
# Harralander_seed 11
# Harralander_tar 10
# Hat_eyepatch 9
# Headless_arrow 9
# Heavy_ballista 10
# Heavy_frame 10
# Helm_of_neitiznot 10
# Herring 10
# Highwayman_mask 10
# Hill_giant_club 9
# Holy_blessing 9
# Holy_book_page_set 10
# Holy_elixir 10
# Holy_mould 10
# Holy_sandals 9
# Holy_symbol 10
# Holy_wraps 9
# Honourable_blessing 9
# Hood_of_darkness 9
# Hosidius_banner 9
# Hosidius_hood 9
# Hosidius_scarf 9
# Hunter_potion(1) 10
# Hunter_potion(2) 11
# Hunter_potion(3) 11
# Hunter_potion(4) 11
# Hunters'_crossbow 11
# Hunting_mix(1) 11
# Hunting_mix(2) 11
# Hydra_bones 5
# Icy_basalt 8
# Imbued_heart 9
# Imp_mask 10
# Impling_jar 10
# Incomplete_heavy_ballista 10
# Incomplete_light_ballista 10
# Infinity_boots 10
# Infinity_bottoms 10
# Infinity_gloves 10
# Infinity_hat 10
# Infinity_top 10
# Initiate_cuisse 10
# Initiate_harness_m 8
# Initiate_hauberk 10
# Initiate_sallet 10
# Inoculation_bracelet 10
# Insect_repellent 11
# Insulated_boots 10
# Irit_leaf 10
# Irit_potion_(unf) 10
# Irit_seed 11
# Iron_2h_sword 9
# Iron_arrow 10
# Iron_arrow(p) 11
# Iron_arrow(p+) 11
# Iron_arrow(p++) 11
# Iron_arrowtips 9
# Iron_axe 10
# Iron_bar 10
# Iron_battleaxe 10
# Iron_bolts 10
# Iron_bolts_(p) 12
# Iron_bolts_(p+) 12
# Iron_bolts_(p++) 12
# Iron_bolts_(unf) 10
# Iron_boots 10
# Iron_brutal 10
# Iron_chainbody 9
# Iron_claws 10
# Iron_crossbow 10
# Iron_crossbow_(u) 9
# Iron_dagger 10
# Iron_dagger(p) 11
# Iron_dagger(p+) 11
# Iron_dagger(p++) 11
# Iron_dart 10
# Iron_dart(p) 11
# Iron_dart(p+) 11
# Iron_dart(p++) 10
# Iron_dart_tip 10
# Iron_dragon_mask 10
# Iron_full_helm 10
# Iron_full_helm_(g) 10
# Iron_full_helm_(t) 10
# Iron_gold-trimmed_set_(lg) 10
# Iron_gold-trimmed_set_(sk) 10
# Iron_halberd 10
# Iron_hasta 10
# Iron_hasta(p) 11
# Iron_hasta(p+) 11
# Iron_hasta(p++) 10
# Iron_javelin 10
# Iron_javelin(p) 11
# Iron_javelin(p+) 11
# Iron_javelin(p++) 11
# Iron_javelin_heads 10
# Iron_kiteshield 10
# Iron_kiteshield_(g) 9
# Iron_kiteshield_(t) 10
# Iron_knife 10
# Iron_knife(p) 11
# Iron_knife(p+) 11
# Iron_knife(p++) 11
# Iron_limbs 10
# Iron_longsword 10
# Iron_mace 9
# Iron_med_helm 10
# Iron_nails 10
# Iron_ore 10
# Iron_pickaxe 10
# Iron_platebody 10
# Iron_platebody_(g) 10
# Iron_platebody_(t) 10
# Iron_platelegs 10
# Iron_platelegs_(g) 10
# Iron_platelegs_(t) 9
# Iron_plateskirt 10
# Iron_plateskirt_(g) 9
# Iron_plateskirt_(t) 10
# Iron_scimitar 10
# Iron_set_(lg) 10
# Iron_set_(sk) 10
# Iron_spear 10
# Iron_spear(p) 11
# Iron_spear(p+) 11
# Iron_spear(p++) 11
# Iron_spit 9
# Iron_sq_shield 10
# Iron_sword 10
# Iron_thrownaxe 10
# Iron_trimmed_set_(lg) 9
# Iron_trimmed_set_(sk) 10
# Iron_warhammer 10
# Ivory_comb 10
# Jade 11
# Jade_amulet 9
# Jade_amulet_(u) 8
# Jade_bolt_tips 10
# Jade_bracelet 9
# Jade_dragon_bolts 9
# Jade_dragon_bolts_(e) 9
# Jade_machete 10
# Jade_necklace 9
# Jade_ring 9
# Jangerberries 10
# Jangerberry_seed 11
# Jar_of_darkness 8
# Jar_of_decay 9
# Jar_of_dirt 10
# Jar_of_miasma 9
# Jar_of_sand 10
# Jar_of_souls 10
# Jar_of_stone 9
# Jar_of_swamp 10
# Javelin_shaft 10
# Jogre_bones 10
# Jug 10
# Jug_of_water 9
# Jug_of_wine 10
# Jungle_camo_legs 10
# Jungle_camo_top 10
# Jungle_demon_mask 9
# Justiciar_armour_set 8
# Justiciar_chestguard 8
# Justiciar_faceguard 8
# Justiciar_legguards 8
# Jute_fibre 10
# Jute_seed 10
# Karambwan_vessel 5
# Karidian_disguise 11
# Karil's_armour_set 10
# Karil's_coif 10
# Karil's_coif_0 11
# Karil's_crossbow 10
# Karil's_crossbow_0 12
# Karil's_leatherskirt 10
# Karil's_leatherskirt_0 11
# Karil's_leathertop 10
# Karil's_leathertop_0 12
# Katana 10
# Kebab 10
# Kebab_mix 9
# Kebbit_bolts 9
# Kebbit_claws 10
# Kebbit_spike 10
# Kebbit_teeth 10
# Kebbit_teeth_dust 10
# Keg_of_beer 10
# Kharidian_headpiece 10
# Kharyrll_teleport 10
# King_worm 10
# Kitchen_knife 10
# Kitchen_table 12
# Knife 10
# Kodai_insignia 9
# Kodai_wand 9
# Kraken_tentacle 10
# Krandorian_hops 10
# Krandorian_seed 10
# Kwuarm 10
# Kwuarm_potion_(unf) 10
# Kwuarm_seed 11
# Kyatt_fur 10
# Kyatt_hat 10
# Kyatt_legs 10
# Kyatt_top 9
# Lantadyme 10
# Lantadyme_potion_(unf) 10
# Lantadyme_seed 11
# Lantern_lens 9
# Large_oak_bed 12
# Large_teak_bed 11
# Larupia_fur 10
# Larupia_hat 10
# Larupia_legs 10
# Larupia_top 10
# Lassar_teleport 10
# Lava_battlestaff 11
# Lava_dragon_bones 10
# Lava_dragon_mask 10
# Lava_rune 10
# Lava_scale 9
# Lava_scale_shard 10
# Lava_staff_upgrade_kit 9
# Law_rune 10
# Leaf-bladed_battleaxe 9
# Leaf-bladed_sword 10
# Lean_snail 10
# Lean_snail_meat 10
# Leaping_salmon 10
# Leaping_sturgeon 9
# Leaping_trout 10
# Leather 10
# Leather_body 10
# Leather_boots 10
# Leather_chaps 10
# Leather_cowl 9
# Leather_gloves 10
# Leather_vambraces 10
# Left_eye_patch 9
# Lemon 10
# Lemon_chunks 10
# Lemon_slices 10
# Leprechaun_hat 9
# Lesser_demon_mask 9
# Light_ballista 10
# Light_bow_tie 9
# Light_frame 10
# Light_infinity_colour_kit 9
# Light_orb 10
# Light_trousers 9
# Light_tuxedo_cuffs 9
# Light_tuxedo_jacket 9
# Light_tuxedo_shoes 9
# Lime 10
# Lime_chunks 10
# Lime_slices 10
# Limestone 10
# Limestone_brick 10
# Limpwurt_root 10
# Limpwurt_seed 11
# Linen 11
# Lizardman_fang 10
# Loar_remains 9
# Lobster 10
# Lobster_pot 9
# Lockpick 10
# Locust_meat 12
# Logs 10
# Long_kebbit_bolts 10
# Long_kebbit_spike 11
# Longbow 10
# Longbow_(u) 10
# Loop_half_of_key 10
# Lovakengj_banner 9
# Lovakengj_hood 8
# Lovakengj_scarf 9
# Lumberyard_teleport 10
# Lumbridge_graveyard_teleport 10
# Lumbridge_teleport 10
# Lunar_isle_teleport 10
# M._treasure_chest 12
# Machete 10
# Mackerel 10
# Mage's_book 12
# Magic_bird_house 9
# Magic_box 9
# Magic_cape_rack 12
# Magic_comp_bow 10
# Magic_essence_mix(1) 11
# Magic_essence_mix(2) 10
# Magic_fang 10
# Magic_logs 10
# Magic_longbow 10
# Magic_longbow_(u) 10
# Magic_mix(1) 11
# Magic_mix(2) 11
# Magic_potion(1) 11
# Magic_potion(2) 10
# Magic_potion(3) 11
# Magic_potion(4) 10
# Magic_pyre_logs 10
# Magic_roots 10
# Magic_sapling 10
# Magic_seed 11
# Magic_shield 9
# Magic_shortbow 10
# Magic_shortbow_(u) 10
# Magic_shortbow_scroll 9
# Magic_staff 10
# Magic_stock 9
# Magic_stone 10
# Magic_string 10
# Magpie_impling_jar 10
# Mahogany_armchair 12
# Mahogany_armour_case 12
# Mahogany_bench 12
# Mahogany_bird_house 9
# Mahogany_bookcase 11
# Mahogany_cape_rack 12
# Mahogany_dresser 12
# Mahogany_fancy_dress_box 12
# Mahogany_logs 10
# Mahogany_magic_wardrobe 12
# Mahogany_plank 10
# Mahogany_pyre_log 11
# Mahogany_sapling 9
# Mahogany_seed 9
# Mahogany_stock 10
# Mahogany_table 11
# Mahogany_toy_box 12
# Mahogany_wardrobe 12
# Malediction_shard_1 10
# Malediction_shard_2 10
# Malediction_shard_3 10
# Malediction_ward 10
# Manta_ray 10
# Maple_bird_house 9
# Maple_blackjack 10
# Maple_blackjack(d) 11
# Maple_blackjack(o) 11
# Maple_logs 9
# Maple_longbow 10
# Maple_longbow_(u) 11
# Maple_pyre_logs 10
# Maple_roots 10
# Maple_sapling 10
# Maple_seed 11
# Maple_shield 9
# Maple_shortbow 10
# Maple_shortbow_(u) 10
# Maple_stock 9
# Marble_block 10
# Marble_cape_rack 12
# Marble_magic_wardrobe 12
# Marigold_seed 11
# Marigolds 10
# Marrentill 10
# Marrentill_potion_(unf) 10
# Marrentill_seed 11
# Marrentill_tar 10
# Master_scroll_book_(empty) 9
# Master_wand 9
# Mature_cider 10
# Mature_wmb 10
# Meat_pie 10
# Meat_pizza 10
# Meat_tenderiser 10
# Menaphite_purple_hat 11
# Menaphite_purple_kilt 11
# Menaphite_purple_robe 11
# Menaphite_purple_top 11
# Menaphite_red_hat 11
# Menaphite_red_kilt 11
# Menaphite_red_robe 11
# Menaphite_red_top 11
# Merfolk_trident 9
# Minced_meat 12
# Mind_altar_teleport 10
# Mind_bomb(4) 11
# Mind_bomb(m4) 11
# Mind_helmet 10
# Mind_rune 10
# Mind_shield 10
# Mind_talisman 10
# Mind_tiara 10
# Mining_helmet 10
# Mint_cake 10
# Mirror_shield 10
# Mist_battlestaff 8
# Mist_rune 10
# Mith_crossbow 10
# Mith_grapple 5
# Mith_grapple_tip 10
# Mithril_2h_sword 10
# Mithril_arrow 10
# Mithril_arrow(p) 11
# Mithril_arrow(p+) 11
# Mithril_arrow(p++) 11
# Mithril_arrowtips 10
# Mithril_axe 9
# Mithril_bar 11
# Mithril_battleaxe 10
# Mithril_bolts 10
# Mithril_bolts_(p) 12
# Mithril_bolts_(p+) 12
# Mithril_bolts_(p++) 12
# Mithril_bolts_(unf) 10
# Mithril_boots 10
# Mithril_brutal 9
# Mithril_chainbody 10
# Mithril_claws 10
# Mithril_crossbow_(u) 10
# Mithril_dagger 10
# Mithril_dagger(p) 11
# Mithril_dagger(p+) 11
# Mithril_dagger(p++) 11
# Mithril_dart 10
# Mithril_dart(p) 11
# Mithril_dart(p+) 11
# Mithril_dart(p++) 11
# Mithril_dart_tip 11
# Mithril_dragon_mask 9
# Mithril_full_helm 10
# Mithril_full_helm_(g) 10
# Mithril_full_helm_(t) 10
# Mithril_gold-trimmed_set_(lg) 10
# Mithril_gold-trimmed_set_(sk) 10
# Mithril_halberd 10
# Mithril_hasta 10
# Mithril_hasta(p) 11
# Mithril_hasta(p+) 11
# Mithril_hasta(p++) 11
# Mithril_javelin 10
# Mithril_javelin(p) 10
# Mithril_javelin(p+) 11
# Mithril_javelin(p++) 11
# Mithril_javelin_heads 10
# Mithril_kiteshield 10
# Mithril_kiteshield_(g) 10
# Mithril_kiteshield_(t) 10
# Mithril_knife 10
# Mithril_knife(p) 11
# Mithril_knife(p+) 11
# Mithril_knife(p++) 11
# Mithril_limbs 10
# Mithril_longsword 10
# Mithril_mace 10
# Mithril_med_helm 10
# Mithril_nails 9
# Mithril_ore 10
# Mithril_pickaxe 10
# Mithril_platebody 11
# Mithril_platebody_(g) 10
# Mithril_platebody_(t) 10
# Mithril_platelegs 10
# Mithril_platelegs_(g) 10
# Mithril_platelegs_(t) 10
# Mithril_plateskirt 10
# Mithril_plateskirt_(g) 10
# Mithril_plateskirt_(t) 10
# Mithril_scimitar 10
# Mithril_seeds 10
# Mithril_set_(lg) 10
# Mithril_set_(sk) 9
# Mithril_spear 10
# Mithril_spear(p) 11
# Mithril_spear(p+) 11
# Mithril_spear(p++) 11
# Mithril_sq_shield 10
# Mithril_sword 10
# Mithril_thrownaxe 10
# Mithril_trimmed_set_(lg) 10
# Mithril_trimmed_set_(sk) 10
# Mithril_warhammer 10
# Mixed_flowers 10
# Mole_claw 10
# Mole_skin 10
# Molten_glass 10
# Monk's_robe 12
# Monk's_robe_(g) 9
# Monk's_robe_top 12
# Monk's_robe_top_(g) 9
# Monkey_bar 9
# Monkey_bones 10
# Monkey_nuts 10
# Monkey_tail 10
# Monkfish 10
# Monocle 10
# Moonlight_mead 10
# Moonlight_mead(4) 11
# Moonlight_mead(m) 11
# Moonlight_mead(m4) 11
# Morrigan's_javelin 8
# Morrigan's_throwing_axe 8
# Mort_myre_fungus 10
# Mort_myre_pear 10
# Mort_myre_stem 10
# Mort'ton_teleport 10
# Mos_le'harmless_teleport 10
# Mud_battlestaff 10
# Mud_pie 10
# Mud_rune 9
# Muddy_key 10
# Mummy's_body 9
# Mummy's_feet 9
# Mummy's_hands 9
# Mummy's_head 9
# Mummy's_legs 9
# Mushroom 10
# Mushroom_&_onion 12
# Mushroom_pie 9
# Mushroom_potato 10
# Mushroom_spore 11
# Musketeer_hat 9
# Musketeer_pants 10
# Musketeer_tabard 10
# Mysterious_emblem 9
# Mystic_air_staff 11
# Mystic_boots 10
# Mystic_boots_(dark) 11
# Mystic_boots_(light) 10
# Mystic_dust_staff 9
# Mystic_earth_staff 11
# Mystic_fire_staff 10
# Mystic_gloves 10
# Mystic_gloves_(dark) 11
# Mystic_gloves_(light) 11
# Mystic_hat 10
# Mystic_hat_(dark) 11
# Mystic_hat_(light) 11
# Mystic_lava_staff 11
# Mystic_mist_staff 9
# Mystic_mud_staff 9
# Mystic_robe_bottom 10
# Mystic_robe_bottom_(dark) 11
# Mystic_robe_bottom_(light) 11
# Mystic_robe_top 10
# Mystic_robe_top_(dark) 11
# Mystic_robe_top_(light) 11
# Mystic_smoke_staff 10
# Mystic_steam_staff 10
# Mystic_water_staff 10
# Nail_beast_nails 10
# Nardah_teleport 10
# Nasturtium_seed 11
# Nasturtiums 10
# Nature_impling_jar 10
# Nature_rune 11
# Nature_talisman 10
# Nature_tiara 10
# Navy_cavalier 10
# Necklace_mould 10
# Necklace_of_anguish 10
# Necklace_of_faith 9
# Necklace_of_passage(5) 9
# Needle 10
# Nice_hedge 12
# Ninja_impling_jar 10
# Noose_wand 10
# Nose_peg 10
# Numulite 8
# Nunchaku 9
# Oak_armchair 12
# Oak_armour_case 12
# Oak_bed 12
# Oak_bench 12
# Oak_bird_house 9
# Oak_blackjack(d) 11
# Oak_blackjack(o) 11
# Oak_bookcase 12
# Oak_cape_rack 12
# Oak_chair 12
# Oak_clock 12
# Oak_dining_table 11
# Oak_drawers 12
# Oak_dresser 12
# Oak_fancy_dress_box 12
# Oak_kitchen_table 12
# Oak_logs 10
# Oak_longbow 10
# Oak_longbow_(u) 11
# Oak_magic_wardrobe 12
# Oak_plank 10
# Oak_pyre_logs 9
# Oak_roots 10
# Oak_sapling 10
# Oak_shaving_stand 12
# Oak_shield 9
# Oak_shortbow 10
# Oak_shortbow_(u) 11
# Oak_stock 10
# Oak_toy_box 12
# Oak_treasure_chest 11
# Oak_wardrobe 12
# Obsidian_armour_set 9
# Obsidian_cape 10
# Obsidian_cape_(r) 9
# Obsidian_helmet 9
# Obsidian_platebody 9
# Obsidian_platelegs 9
# Occult_necklace 10
# Occult_ornament_kit 8
# Odium_shard_1 10
# Odium_shard_2 10
# Odium_shard_3 10
# Odium_ward 10
# Ogre_arrow 10
# Ogre_arrow_shaft 10
# Ogre_coffin_key 9
# Oil_lamp 10
# Oil_lantern 11
# Oil_lantern_frame 10
# Old_demon_mask 9
# Old_school_bond 8
# Olive_oil(1) 11
# Olive_oil(2) 11
# Olive_oil(3) 11
# Olive_oil(4) 11
# Onion 9
# Onion_&_tomato 11
# Onion_seed 11
# Onions(10) 11
# Onyx 10
# Onyx_amulet 10
# Onyx_amulet_(u) 10
# Onyx_bolt_tips 10
# Onyx_bolts 10
# Onyx_bolts_(e) 11
# Onyx_bracelet 9
# Onyx_dragon_bolts 9
# Onyx_dragon_bolts_(e) 9
# Onyx_necklace 10
# Onyx_ring 10
# Opal 10
# Opal_amulet 9
# Opal_amulet_(u) 9
# Opal_bolt_tips 10
# Opal_bolts 10
# Opal_bolts_(e) 10
# Opal_bracelet 9
# Opal_dragon_bolts 9
# Opal_dragon_bolts_(e) 8
# Opal_machete 10
# Opal_necklace 9
# Opal_ring 9
# Opulent_table 12
# Orange 10
# Orange_boater 10
# Orange_cape 11
# Orange_chunks 10
# Orange_dye 10
# Orange_feather 9
# Orange_flowers 11
# Orange_salamander 10
# Orange_sapling 10
# Orange_slices 10
# Orange_tree_seed 11
# Oranges(5) 11
# Ourg_bones 10
# Oyster 10
# Oyster_pearl 10
# Oyster_pearls 9
# Paddewwa_teleport 10
# Palm_sapling 10
# Palm_tree_seed 11
# Pantaloons 10
# Papaya_fruit 10
# Papaya_sapling 10
# Papaya_tree_seed 11
# Papyrus 10
# Partyhat_&_specs 9
# Partyhat_set 9
# Pastry_dough 8
# Pat_of_butter 9
# Peaceful_blessing 8
# Pearl_bolt_tips 9
# Pearl_bolts 9
# Pearl_bolts_(e) 9
# Pearl_dragon_bolts 8
# Pearl_dragon_bolts_(e) 8
# Pegasian_boots 9
# Pegasian_crystal 9
# Penguin_mask 9
# Pest_control_teleport 9
# Pestle_and_mortar 8
# Pharaoh's_sceptre 9
# Pharaoh's_sceptre_(3) 11
# Phoenix_necklace 9
# Phrin_remains 9
# Pie_dish 9
# Pie_recipe_book 9
# Pie_shell 9
# Pike 9
# Pile_of_salt 11
# Pineapple 10
# Pineapple_chunks 10
# Pineapple_pizza 10
# Pineapple_punch 10
# Pineapple_ring 10
# Pineapple_sapling 10
# Pineapple_seed 11
# Pink_boater 9
# Pink_boots 11
# Pink_cape 12
# Pink_elegant_blouse 10
# Pink_elegant_legs 10
# Pink_elegant_shirt 10
# Pink_elegant_skirt 10
# Pink_hat 11
# Pink_headband 10
# Pink_robe_bottoms 11
# Pink_robe_top 11
# Pink_skirt 9
# Pirate_boots 10
# Pirate_hat_&_patch 10
# Pirate's_hat 10
# Pirate's_hook 9
# Piscarilius_banner 9
# Piscarilius_hood 9
# Piscarilius_scarf 9
# Piscatoris_teleport 10
# Pith_helmet 9
# Pitta_bread 10
# Pizza_base 10
# Plain_pizza 10
# Plank 10
# Plant_cure 10
# Poison 11
# Poison_chalice 10
# Poison_ivy_berries 10
# Poison_ivy_seed 10
# Polar_camo_legs 10
# Polar_camo_top 10
# Polar_kebbit_fur 10
# Polished_buttons 9
# Pot 10
# Pot_lid 10
# Pot_of_cornflour 10
# Pot_of_cream 10
# Pot_of_flour 10
# Potato 9
# Potato_cactus 10
# Potato_cactus_seed 5
# Potato_seed 11
# Potato_with_butter 9
# Potato_with_cheese 10
# Potatoes(10) 11
# Pottery_scarab 10
# Pottery_statuette 10
# Prayer_mix(1) 11
# Prayer_mix(2) 12
# Prayer_potion(1) 12
# Prayer_potion(2) 12
# Prayer_potion(3) 12
# Prayer_potion(4) 12
# Premade_blurb'_sp. 10
# Premade_c+t_batta 11
# Premade_ch'_crunch 11
# Premade_choc_bomb 11
# Premade_choc_s'dy 11
# Premade_dr'_dragon 11
# Premade_fr'_blast 11
# Premade_fr't_batta 11
# Premade_p'_punch 11
# Premade_s'y_crunch 11
# Premade_sgg 9
# Premade_t'd_batta 11
# Premade_t'd_crunch 11
# Premade_ttl 11
# Premade_veg_ball 11
# Premade_veg_batta 11
# Premade_w'm_batta 11
# Premade_w'm_crun' 11
# Premade_wiz_blz'd 11
# Premade_worm_hole 11
# Primordial_boots 11
# Primordial_crystal 11
# Proboscis 11
# Proselyte_cuisse 10
# Proselyte_harness_f 13
# Proselyte_harness_m 13
# Proselyte_hauberk 11
# Proselyte_sallet 10
# Proselyte_tasset 11
# Pumpkin 11
# Pure_essence 11
# Purple_boater 11
# Purple_boots 12
# Purple_cape 12
# Purple_dye 11
# Purple_elegant_blouse 11
# Purple_elegant_legs 11
# Purple_elegant_shirt 10
# Purple_elegant_skirt 10
# Purple_firelighter 11
# Purple_flowers 12
# Purple_gloves 12
# Purple_hat 12
# Purple_partyhat 11
# Purple_robe_bottoms 12
# Purple_robe_top 12
# Purple_sweets 11
# Pyre_logs 11
# Pyrophosphite 9
# Rabbit_foot 11
# Rabbit_snare 11
# Rainbow_fish 11
# Rake 10
# Ranarr_potion_(unf) 11
# Ranarr_seed 13
# Ranarr_weed 12
# Ranger_boots 11
# Ranger_gloves 10
# Rangers'_tunic 11
# Ranging_mix(1) 12
# Ranging_mix(2) 12
# Ranging_potion(1) 12
# Ranging_potion(2) 11
# Ranging_potion(3) 12
# Ranging_potion(4) 12
# Raurg_bones 11
# Raw_admiral_pie 11
# Raw_anchovies 11
# Raw_anglerfish 10
# Raw_bass 11
# Raw_bear_meat 11
# Raw_beast_meat 11
# Raw_beef 11
# Raw_bird_meat 11
# Raw_cave_eel 11
# Raw_chicken 12
# Raw_chompy 11
# Raw_cod 11
# Raw_dark_crab 11
# Raw_fish_pie 10
# Raw_garden_pie 11
# Raw_herring 10
# Raw_jubbly 11
# Raw_karambwan 11
# Raw_lobster 11
# Raw_mackerel 11
# Raw_manta_ray 11
# Raw_monkfish 11
# Raw_mud_pie 11
# Raw_oomlie 11
# Raw_pike 11
# Raw_rabbit 10
# Raw_rainbow_fish 11
# Raw_rat_meat 11
# Raw_salmon 11
# Raw_sardine 11
# Raw_sea_turtle 11
# Raw_shark 11
# Raw_shrimps 11
# Raw_slimy_eel 12
# Raw_summer_pie 11
# Raw_swordfish 11
# Raw_trout 10
# Raw_tuna 11
# Raw_ugthanki_meat 12
# Raw_wild_pie 11
# Raw_yak_meat 10
# Red_bead 11
# Red_beret 11
# Red_boater 11
# Red_boots 12
# Red_cape 11
# Red_cavalier 11
# Red_chinchompa 11
# Red_d'hide_body 12
# Red_d'hide_body_(g) 11
# Red_d'hide_body_(t) 11
# Red_d'hide_chaps 11
# Red_d'hide_chaps_(g) 11
# Red_d'hide_chaps_(t) 11
# Red_d'hide_shield 8
# Red_d'hide_vamb 11
# Red_dragon_leather 11
# Red_dragon_mask 11
# Red_dragonhide 11
# Red_dye 10
# Red_elegant_blouse 11
# Red_elegant_legs 11
# Red_elegant_shirt 11
# Red_elegant_skirt 11
# Red_feather 11
# Red_firelighter 11
# Red_flowers 12
# Red_gloves 12
# Red_halloween_mask 11
# Red_hat 12
# Red_headband 11
# Red_partyhat 11
# Red_robe_bottoms 11
# Red_robe_top 12
# Red_salamander 11
# Red_spiders'_eggs 11
# Red_spiky_vambs 11
# Red_topaz 11
# Red_topaz_machete 11
# Redberries 10
# Redberry_pie 11
# Redberry_seed 12
# Redwood_bird_house 9
# Redwood_logs 10
# Redwood_pyre_logs 9
# Redwood_sapling 5
# Redwood_tree_seed 5
# Redwood_shield 10
# Regen_bracelet 11
# Relicym's_balm(1) 12
# Relicym's_balm(2) 12
# Relicym's_balm(3) 12
# Relicym's_balm(4) 12
# Relicym's_mix(1) 12
# Relicym's_mix(2) 11
# Restore_mix(1) 12
# Restore_mix(2) 12
# Restore_potion(1) 12
# Restore_potion(2) 12
# Restore_potion(3) 12
# Restore_potion(4) 12
# Revenant_cave_teleport 9
# Revenant_ether 9
# Ribcage_piece 10
# Right_eye_patch 11
# Ring_mould 10
# Ring_of_coins 10
# Ring_of_dueling(8) 12
# Ring_of_forging 11
# Ring_of_life 11
# Ring_of_nature 10
# Ring_of_pursuit 9
# Ring_of_recoil 11
# Ring_of_returning(5) 8
# Ring_of_stone 11
# Ring_of_suffering 12
# Ring_of_the_gods 10
# Ring_of_wealth 11
# Ring_of_wealth_(5) 12
# Ring_of_wealth_scroll 11
# Riyl_remains 11
# Roast_beast_meat 11
# Roast_bird_meat 11
# Roast_rabbit 11
# Robe_bottom_of_darkness 10
# Robe_top_of_darkness 10
# Robin_hood_hat 11
# Rock_hammer 11
# Rock_thrownhammer 9
# Rock-climbing_boots 11
# Rock-shell_boots 11
# Rock-shell_chunk 11
# Rock-shell_gloves 10
# Rock-shell_helm 11
# Rock-shell_legs 11
# Rock-shell_plate 11
# Rock-shell_shard 11
# Rock-shell_splinter 11
# Rocking_chair 12
# Roe 11
# Rolling_pin 11
# Rope 11
# Rosemary 11
# Rosemary_seed 12
# Royal_crown 10
# Royal_gown_bottom 11
# Royal_gown_top 11
# Royal_sceptre 11
# Ruby 10
# Ruby_amulet 11
# Ruby_amulet_(u) 11
# Ruby_bolt_tips 11
# Ruby_bolts 11
# Ruby_bolts_(e) 11
# Ruby_bracelet 11
# Ruby_dragon_bolts 9
# Ruby_dragon_bolts_(e) 9
# Ruby_harvest 12
# Ruby_necklace 11
# Ruby_ring 11
# Rune_2h_sword 11
# Rune_armour_set_(lg) 11
# Rune_armour_set_(sk) 11
# Rune_arrow 9
# Rune_arrow(p) 12
# Rune_arrow(p+) 12
# Rune_arrow(p++) 12
# Rune_arrowtips 11
# Rune_axe 12
# Rune_battleaxe 12
# Rune_boots 11
# Rune_brutal 11
# Rune_cane 11
# Rune_chainbody 11
# Rune_claws 11
# Rune_crossbow 11
# Rune_dagger 11
# Rune_dagger(p) 11
# Rune_dagger(p+) 13
# Rune_dagger(p++) 12
# Rune_dart 10
# Rune_dart(p) 11
# Rune_dart(p+) 12
# Rune_dart(p++) 12
# Rune_dart_tip 11
# Rune_essence 11
# Rune_full_helm 11
# Rune_full_helm_(g) 11
# Rune_full_helm_(t) 11
# Rune_gold-trimmed_set_(lg) 11
# Rune_gold-trimmed_set_(sk) 11
# Rune_halberd 11
# Rune_hasta 12
# Rune_hasta(p) 12
# Rune_hasta(p+) 12
# Rune_hasta(p++) 12
# Rune_helm_(h1) 11
# Rune_helm_(h2) 11
# Rune_helm_(h3) 11
# Rune_helm_(h4) 11
# Rune_helm_(h5) 10
# Rune_javelin 11
# Rune_javelin(p) 11
# Rune_javelin(p+) 12
# Rune_javelin(p++) 12
# Rune_javelin_heads 11
# Rune_kiteshield 12
# Rune_kiteshield_(g) 11
# Rune_kiteshield_(t) 11
# Rune_knife 11
# Rune_knife(p) 12
# Rune_knife(p+) 11
# Rune_knife(p++) 12
# Rune_longsword 13
# Rune_mace 12
# Rune_med_helm 11
# Rune_nails 11
# Rune_pickaxe 11
# Rune_platebody 12
# Rune_platebody_(g) 11
# Rune_platebody_(t) 11
# Rune_platelegs 12
# Rune_platelegs_(g) 11
# Rune_platelegs_(t) 11
# Rune_plateskirt 12
# Rune_plateskirt_(g) 11
# Rune_plateskirt_(t) 10
# Rune_scimitar 11
# Rune_shield_(h1) 11
# Rune_shield_(h2) 11
# Rune_shield_(h3) 11
# Rune_shield_(h4) 11
# Rune_shield_(h5) 10
# Rune_spear 11
# Rune_spear(p) 12
# Rune_spear(p+) 12
# Rune_spear(p++) 12
# Rune_sq_shield 12
# Rune_sword 11
# Rune_thrownaxe 11
# Rune_trimmed_set_(lg) 11
# Rune_trimmed_set_(sk) 11
# Rune_warhammer 11
# Runite_bar 10
# Runite_bolts 11
# Runite_bolts_(p) 13
# Runite_bolts_(p+) 12
# Runite_bolts_(p++) 11
# Runite_bolts_(unf) 11
# Runite_crossbow_(u) 11
# Runite_limbs 11
# Runite_ore 10
# Sacred_oil(1) 12
# Sacred_oil(2) 11
# Sacred_oil(3) 12
# Sacred_oil(4) 12
# Sagacious_spectacles 11
# Salmon 11
# Saltpetre 11
# Salve_graveyard_teleport 11
# Samurai_boots 9
# Samurai_gloves 10
# Samurai_greaves 10
# Samurai_kasa 10
# Samurai_shirt 10
# Sandstone_(1kg) 13
# Sandstone_(2kg) 13
# Sandstone_(5kg) 13
# Sandstone_(10kg) 13
# Sandworms 11
# Sanfew_serum(1) 12
# Sanfew_serum(2) 12
# Sanfew_serum(3) 11
# Sanfew_serum(4) 11
# Sanguinesti_staff_(uncharged) 8
# Santa_hat 11
# Sapphire 11
# Sapphire_amulet 11
# Sapphire_amulet_(u) 11
# Sapphire_bolt_tips 11
# Sapphire_bolts 11
# Sapphire_bolts_(e) 11
# Sapphire_bracelet 11
# Sapphire_dragon_bolts 9
# Sapphire_dragon_bolts_(e) 9
# Sapphire_glacialis 11
# Sapphire_necklace 11
# Sapphire_ring 11
# Saradomin_armour_set_(lg) 11
# Saradomin_armour_set_(sk) 11
# Saradomin_bracers 11
# Saradomin_brew(1) 12
# Saradomin_brew(2) 12
# Saradomin_brew(3) 12
# Saradomin_brew(4) 12
# Saradomin_chaps 11
# Saradomin_cloak 11
# Saradomin_coif 10
# Saradomin_crozier 11
# Saradomin_d'hide 11
# Saradomin_d'hide_boots 10
# Saradomin_dragonhide_set 11
# Saradomin_full_helm 11
# Saradomin_godsword 11
# Saradomin_godsword_ornament_kit 10
# Saradomin_hilt 11
# Saradomin_kiteshield 10
# Saradomin_mitre 11
# Saradomin_mjolnir 11
# Saradomin_page_1 11
# Saradomin_page_2 11
# Saradomin_page_3 11
# Saradomin_page_4 10
# Saradomin_platebody 11
# Saradomin_platelegs 11
# Saradomin_plateskirt 11
# Saradomin_robe_legs 11
# Saradomin_robe_top 10
# Saradomin_stole 11
# Saradomin_sword 11
# Saradomin's_light 11
# Saradomin's_tear 11
# Sardine 11
# Saw 11
# Scrambled_egg 11
# Scythe_of_vitur_(uncharged) 8
# Sea_turtle 10
# Seasoned_sardine 12
# Seaweed 13
# Seaweed_spore 9
# Secateurs 11
# Security_book 11
# Seed_dibber 11
# Seercull 11
# Seers_ring 11
# Senntisten_teleport 11
# Serpentine_helm_(uncharged) 12
# Serpentine_visage 11
# Serum_207_(1) 12
# Serum_207_(2) 12
# Serum_207_(3) 11
# Serum_207_(4) 12
# Shade_robe 11
# Shade_robe_top 11
# Shaikahan_bones 10
# Shaman_mask 9
# Shantay_pass 12
# Shark 11
# Shaving_stand 13
# Shayzien_banner 9
# Shayzien_hood 10
# Shayzien_scarf 5
# Shears 11
# Shield_left_half 12
# Shield_right_half 12
# Ship_ticket 13
# Shoe_box 14
# Short_green_guy 12
# Shortbow 12
# Shortbow_(u) 12
# Shrimps 11
# Shrunk_ogleroot 12
# Sickle_mould 12
# Silk 12
# Silver_bar 12
# Silver_bolts 12
# Silver_bolts_(p) 14
# Silver_bolts_(p+) 13
# Silver_bolts_(p++) 13
# Silver_bolts_(unf) 12
# Silver_dust 11
# Silver_ore 12
# Silver_sickle 12
# Sinew 12
# Sinister_key 12
# Skeletal_boots 12
# Skeletal_bottoms 12
# Skeletal_gloves 12
# Skeletal_helm 12
# Skeletal_top 12
# Skeletal_visage 9
# Skewer 12
# Skewer_stick 12
# Skills_necklace 12
# Skills_necklace(4) 12
# Skills_necklace(6) 13
# Skull_piece 12
# Slayer_bell 11
# Slayer's_enchantment 9
# Slayer's_respite 12
# Slayer's_respite(4) 13
# Slayer's_respite(m) 13
# Slayer's_respite(m4) 13
# Slayer's_staff 12
# Sleeping_cap 12
# Sliced_banana 11
# Sliced_mushrooms 12
# Small_box_hedge 14
# Small_fishing_net 12
# Smoke_battlestaff 12
# Smoke_rune 12
# Smouldering_stone 11
# Snake_hide 12
# Snakeskin 12
# Snakeskin_bandana 12
# Snakeskin_body 11
# Snakeskin_boots 12
# Snakeskin_chaps 12
# Snakeskin_shield 9
# Snakeskin_vambraces 12
# Snapdragon 12
# Snapdragon_potion_(unf) 12
# Snapdragon_seed 13
# Snape_grass 12
# Snape_grass_seed 5
# Snowy_knight 13
# Soda_ash 12
# Soft_clay 12
# Soul_rune 12
# Spade 12
# Spatula 11
# Spectral_sigil 12
# Spectral_spirit_shield 12
# Spice 12
# Spicy_crunchies 12
# Spicy_minced_meat 13
# Spicy_sauce 12
# Spicy_tomato 12
# Spider_carcass 12
# Spider_on_shaft 12
# Spider_on_stick 12
# Spiked_boots 12
# Spiky_vambraces 12
# Spinach_roll 12
# Spined_body 12
# Spined_boots 12
# Spined_chaps 12
# Spined_gloves 12
# Spined_helm 12
# Spiny_helmet 11
# Spirit_shield 12
# Split_log 12
# Splitbark_body 12
# Splitbark_boots 11
# Splitbark_gauntlets 13
# Splitbark_helm 12
# Splitbark_legs 12
# Spork 12
# Spotted_cape 12
# Spotted_kebbit_fur 12
# Spottier_cape 12
# Staff 12
# Staff_of_air 12
# Staff_of_earth 12
# Staff_of_fire 11
# Staff_of_light 9
# Staff_of_the_dead 12
# Staff_of_water 12
# Stale_baguette 10
# Stamina_mix(1) 13
# Stamina_mix(2) 13
# Stamina_potion(1) 13
# Stamina_potion(2) 12
# Stamina_potion(3) 13
# Stamina_potion(4) 13
# Statius's_warhammer 8
# Steam_battlestaff 12
# Steam_rune 12
# Steam_staff_upgrade_kit 12
# Steel_2h_sword 12
# Steel_arrow 12
# Steel_arrow(p) 12
# Steel_arrow(p+) 12
# Steel_arrow(p++) 13
# Steel_arrowtips 12
# Steel_axe 12
# Steel_bar 13
# Steel_battleaxe 12
# Steel_bolts 12
# Steel_bolts_(p) 14
# Steel_bolts_(p+) 13
# Steel_bolts_(p++) 12
# Steel_bolts_(unf) 12
# Steel_boots 12
# Steel_brutal 11
# Steel_chainbody 12
# Steel_claws 12
# Steel_crossbow 12
# Steel_crossbow_(u) 12
# Steel_dagger 11
# Steel_dagger(p) 13
# Steel_dagger(p+) 13
# Steel_dagger(p++) 13
# Steel_dart 12
# Steel_dart(p) 13
# Steel_dart(p+) 13
# Steel_dart(p++) 13
# Steel_dart_tip 12
# Steel_dragon_mask 12
# Steel_full_helm 12
# Steel_full_helm_(g) 10
# Steel_full_helm_(t) 10
# Steel_gold-trimmed_set_(lg) 11
# Steel_gold-trimmed_set_(sk) 11
# Steel_halberd 12
# Steel_hasta 12
# Steel_hasta(p) 13
# Steel_hasta(p+) 13
# Steel_hasta(p++) 13
# Steel_javelin 12
# Steel_javelin(p) 13
# Steel_javelin(p+) 13
# Steel_javelin(p++) 12
# Steel_javelin_heads 12
# Steel_kiteshield 12
# Steel_kiteshield_(g) 11
# Steel_kiteshield_(t) 11
# Steel_knife 12
# Steel_knife(p) 13
# Steel_knife(p+) 13
# Steel_knife(p++) 13
# Steel_limbs 12
# Steel_longsword 11
# Steel_mace 12
# Steel_med_helm 12
# Steel_nails 12
# Steel_pickaxe 12
# Steel_platebody 12
# Steel_platebody_(g) 11
# Steel_platebody_(t) 10
# Steel_platelegs 12
# Steel_platelegs_(g) 11
# Steel_platelegs_(t) 11
# Steel_plateskirt 11
# Steel_plateskirt_(g) 11
# Steel_plateskirt_(t) 11
# Steel_scimitar 12
# Steel_set_(lg) 12
# Steel_set_(sk) 12
# Steel_spear 12
# Steel_spear(p) 13
# Steel_spear(p+) 13
# Steel_spear(p++) 12
# Steel_sq_shield 12
# Steel_studs 12
# Steel_sword 12
# Steel_thrownaxe 12
# Steel_trimmed_set_(lg) 11
# Steel_trimmed_set_(sk) 11
# Steel_warhammer 12
# Stew 12
# Stone_scarab 11
# Stone_seal 12
# Stone_statuette 11
# Stony_basalt 8
# Strange_fruit 12
# Strawberries(5) 13
# Strawberry 12
# Strawberry_seed 13
# Strength_amulet_(t) 12
# Strength_mix(1) 12
# Strength_mix(2) 13
# Strength_potion(1) 13
# Strength_potion(2) 12
# Strength_potion(3) 13
# Strength_potion(4) 13
# Stretched_hide 12
# Stripy_feather 11
# Stronghold_notes 12
# Strung_rabbit_foot 12
# Studded_body 12
# Studded_body_(g) 12
# Studded_body_(t) 12
# Studded_chaps 12
# Studded_chaps_(g) 12
# Studded_chaps_(t) 11
# Sulliuscep_cap 9
# Summer_pie 12
# Super_antifire_mix(1) 8
# Super_antifire_mix(2) 9
# Super_antifire_potion(1) 9
# Super_antifire_potion(2) 9
# Super_antifire_potion(3) 9
# Super_antifire_potion(4) 9
# Super_attack(1) 13
# Super_attack(2) 13
# Super_attack(3) 13
# Super_attack(4) 12
# Super_combat_potion(1) 13
# Super_combat_potion(2) 13
# Super_combat_potion(3) 11
# Super_combat_potion(4) 13
# Super_def._mix(1) 13
# Super_def._mix(2) 13
# Super_defence(1) 13
# Super_defence(2) 13
# Super_defence(3) 12
# Super_defence(4) 13
# Super_energy(1) 13
# Super_energy(2) 13
# Super_energy(3) 13
# Super_energy(4) 13
# Super_energy_mix(1) 13
# Super_energy_mix(2) 13
# Super_kebab 12
# Super_potion_set 11
# Super_restore(1) 13
# Super_restore(2) 13
# Super_restore(3) 13
# Super_restore(4) 13
# Super_restore_mix(1) 12
# Super_restore_mix(2) 13
# Super_str._mix(1) 13
# Super_str._mix(2) 13
# Super_strength(1) 12
# Super_strength(2) 13
# Super_strength(3) 13
# Super_strength(4) 13
# Superantipoison(1) 12
# Superantipoison(2) 13
# Superantipoison(3) 13
# Superantipoison(4) 13
# Supercompost 12
# Superior_dragon_bones 9
# Swamp_lizard 12
# Swamp_paste 12
# Swamp_tar 12
# Swamp_toad 12
# Swamp_weed 13
# Sweetcorn 12
# Sweetcorn_seed 13
# Swordfish 11
# Tai_bwo_wannai_teleport 12
# Tall_box_hedge 14
# Tall_fancy_hedge 14
# Tan_cavalier 12
# Tangled_toad's_legs 14
# Tanzanite_fang 12
# Tarromin 12
# Tarromin_potion_(unf) 11
# Tarromin_seed 13
# Tarromin_tar 12
# Tatty_graahk_fur 12
# Tatty_kyatt_fur 11
# Tatty_larupia_fur 11
# Te_salt 7
# Teacher_wand 12
# Teak_armchair 14
# Teak_armour_case 14
# Teak_bed 14
# Teak_bird_house 9
# Teak_cape_rack 14
# Teak_clock 14
# Teak_dining_bench 14
# Teak_drawers 14
# Teak_dresser 13
# Teak_fancy_dress_box 14
# Teak_kitchen_table 14
# Teak_logs 12
# Teak_magic_wardrobe 14
# Teak_plank 12
# Teak_pyre_logs 12
# Teak_sapling 9
# Teak_seed 9
# Teak_stock 11
# Teak_table 14
# Teak_toy_box 14
# Teak_treasure_chest 14
# Teak_wardrobe 14
# Teal_boots 13
# Teal_gloves 13
# Teal_hat 13
# Teal_robe_bottoms 13
# Teal_robe_top 13
# Team_cape_i 11
# Team_cape_x 11
# Team_cape_zero 10
# Team-1_cape 13
# Team-10_cape 13
# Team-11_cape 13
# Team-12_cape 13
# Team-13_cape 13
# Team-14_cape 13
# Team-15_cape 13
# Team-16_cape 13
# Team-17_cape 13
# Team-18_cape 12
# Team-19_cape 13
# Team-2_cape 13
# Team-20_cape 13
# Team-21_cape 13
# Team-22_cape 13
# Team-23_cape 12
# Team-24_cape 13
# Team-25_cape 13
# Team-26_cape 13
# Team-27_cape 13
# Team-28_cape 13
# Team-29_cape 13
# Team-3_cape 13
# Team-30_cape 12
# Team-31_cape 13
# Team-32_cape 13
# Team-33_cape 13
# Team-34_cape 13
# Team-35_cape 13
# Team-36_cape 13
# Team-37_cape 13
# Team-38_cape 13
# Team-39_cape 12
# Team-4_cape 13
# Team-40_cape 13
# Team-41_cape 13
# Team-42_cape 13
# Team-43_cape 13
# Team-44_cape 13
# Team-45_cape 13
# Team-46_cape 13
# Team-47_cape 12
# Team-48_cape 13
# Team-49_cape 13
# Team-5_cape 13
# Team-50_cape 13
# Team-6_cape 13
# Team-7_cape 13
# Team-8_cape 13
# Team-9_cape 13
# Teasing_stick 11
# Teleport_to_house 12
# Thammaron's_sceptre_(u) 8
# Thatch_spar_dense 12
# Thatch_spar_light 12
# Thatch_spar_med 12
# Thin_snail 12
# Thin_snail_meat 12
# Thorny_hedge 14
# Thread 12
# Tiara 12
# Tiara_mould 12
# Timber_beam 12
# Tin_ore 12
# Tinderbox 11
# Toad_batta 12
# Toad_crunchies 12
# Toad's_legs 12
# Toadflax 11
# Toadflax_potion_(unf) 12
# Toadflax_seed 13
# Toktz-ket-xil 12
# Toktz-mej-tal 12
# Toktz-xil-ak 12
# Toktz-xil-ek 12
# Toktz-xil-ul 11
# Tomato 12
# Tomato_seed 13
# Tomatoes(5) 13
# Tome_of_fire_(empty) 10
# Tooth_half_of_key 12
# Top_hat 12
# Top_hat_&_monocle 12
# Topaz_amulet 9
# Topaz_amulet_(u) 9
# Topaz_bolt_tips 10
# Topaz_bolts 12
# Topaz_bolts_(e) 12
# Topaz_bracelet 9
# Topaz_dragon_bolts 9
# Topaz_dragon_bolts_(e) 9
# Topaz_necklace 9
# Topaz_ring 9
# Topiary_hedge 14
# Torag's_armour_set 12
# Torag's_hammers 12
# Torag's_hammers_0 14
# Torag's_helm 12
# Torag's_helm_0 12
# Torag's_platebody 12
# Torag's_platebody_0 13
# Torag's_platelegs 12
# Torag's_platelegs_0 12
# Unlit_torch 12
# Tormented_bracelet 13
# Torn_prayer_scroll 10
# Torstol 12
# Torstol_potion_(unf) 12
# Torstol_seed 13
# Tortoise_shell 12
# Torture_ornament_kit 11
# Toxic_blowpipe_(empty) 13
# Toxic_staff_(uncharged) 13
# Toy_cat 12
# Toy_doll 12
# Toy_doll_(wound) 14
# Toy_mouse 11
# Toy_mouse_(wound) 14
# Toy_soldier 11
# Toy_soldier_(wound) 14
# Trading_sticks 12
# Treasonous_ring 12
# Triangle_sandwich 12
# Uncharged_trident 13
# Trident_of_the_seas_(full) 13
# Uncharged_trident_(e) 9
# Uncharged_toxic_trident 13
# Uncharged_toxic_trident_(e) 9
# Trout 12
# Tuna 12
# Tuna_and_corn 12
# Tuna_potato 12
# Turquoise_boots 13
# Turquoise_hat 13
# Turquoise_robe_bottoms 12
# Turquoise_robe_top 13
# Twisted_bow 9
# Twisted_buckler 9
# Tyrannical_ring 12
# Tyras_helm 11
# Tzhaar-ket-em 12
# Tzhaar-ket-om 12
# Ugthanki_&_onion 13
# Ugthanki_&_tomato 13
# Ugthanki_kebab 12
# Ugthanki_meat 11
# Ultracompost 9
# Unblessed_symbol 12
# Uncooked_apple_pie 11
# Uncooked_berry_pie 12
# Uncooked_botanical_pie 11
# Uncooked_dragonfruit_pie 5
# Uncooked_egg 12
# Uncooked_meat_pie 12
# Uncooked_mushroom_pie 9
# Uncut_diamond 12
# Uncut_dragonstone 12
# Uncut_emerald 10
# Uncut_jade 12
# Uncut_onyx 11
# Uncut_opal 10
# Uncut_red_topaz 11
# Uncut_ruby 11
# Uncut_sapphire 11
# Uncut_zenyte 11
# Unfinished_broad_bolts 11
# Unfinished_potion 12
# Unfired_bowl 12
# Unfired_pie_dish 11
# Unfired_plant_pot 11
# Unfired_pot 12
# Unfired_pot_lid 12
# Unholy_blessing 10
# Unholy_book_page_set 10
# Unholy_symbol 11
# Unicorn_horn 11
# Unicorn_horn_dust 11
# Unpowered_orb 11
# Unpowered_symbol 11
# Unstrung_comp_bow 12
# Unstrung_emblem 11
# Unstrung_heavy_ballista 11
# Unstrung_light_ballista 10
# Unstrung_symbol 11
# Urt_salt 8
# Vampyre_dust 10
# Varrock_teleport 11
# Veg_ball 11
# Vegetable_batta 11
# Verac's_armour_set 11
# Verac's_brassard 11
# Verac's_brassard_0 13
# Verac's_flail 11
# Verac's_flail_0 12
# Verac's_helm 10
# Verac's_helm_0 11
# Verac's_plateskirt 11
# Verac's_plateskirt_0 12
# Vesta's_longsword 8
# Vesta's_spear 8
# Vial 11
# Vial_of_blood 8
# Vial_of_water 10
# Viggora's_chainmace_(u) 8
# Vodka 11
# Volcanic_ash 8
# Volcanic_whip_mix 11
# Vyrewatch_legs 11
# Vyrewatch_shoes 10
# Vyrewatch_top 11
# War_blessing 9
# Ward_upgrade_kit 11
# Warrior_helm 11
# Warrior_ring 12
# Watchtower_teleport 13
# Water_battlestaff 12
# Water_orb 10
# Water_rune 11
# Water_talisman 11
# Water_tiara 11
# Watering_can 11
# Watermelon 11
# Watermelon_seed 12
# Watermelon_slice 11
# Waterskin(0) 12
# Waterskin(4) 12
# Weapon_poison 11
# Weapon_poison(+) 11
# Weapon_poison(++) 12
# Weeds 12
# West_ardougne_teleport 10
# Whisky 11
# White_2h_sword 11
# White_apron 11
# White_battleaxe 11
# White_bead 11
# White_beret 10
# White_berries 11
# White_boater 10
# White_boots 11
# White_cavalier 11
# White_chainbody 11
# White_claws 11
# White_dagger 11
# White_dagger(p) 12
# White_dagger(p+) 11
# White_dagger(p++) 12
# White_dark_bow_paint 11
# White_elegant_blouse 10
# White_elegant_skirt 11
# White_firelighter 11
# White_flowers 12
# White_full_helm 11
# White_gloves 11
# White_halberd 11
# White_headband 11
# White_kiteshield 11
# White_lily_seed 5
# White_longsword 10
# White_mace 11
# White_magic_staff 11
# White_med_helm 11
# White_partyhat 11
# White_platebody 11
# White_platelegs 11
# White_plateskirt 11
# White_scimitar 10
# White_sq_shield 11
# White_sword 12
# White_toy_horsey 12
# White_unicorn_mask 9
# White_warhammer 10
# Whiteberry_seed 12
# Wild_pie 11
# Wildblood_hops 12
# Wildblood_seed 12
# Willow_bird_house 8
# Willow_blackjack 12
# Willow_blackjack(d) 12
# Willow_blackjack(o) 12
# Willow_branch 11
# Willow_comp_bow 11
# Willow_logs 9
# Willow_longbow 11
# Willow_longbow_(u) 11
# Willow_pyre_logs 11
# Willow_roots 11
# Willow_sapling 11
# Willow_seed 12
# Willow_shield 8
# Willow_shortbow 11
# Willow_shortbow_(u) 11
# Willow_stock 11
# Wine_of_zamorak 11
# Wizard_blizzard 10
# Wizard_boots 11
# Wizard_hat 11
# Wizard's_mind_bomb 11
# Woad_leaf 11
# Woad_seed 12
# Wolf_bones 11
# Wolfbone_arrowtips 11
# Wood_camo_legs 11
# Wood_camo_top 11
# Wood_dining_table 13
# Wooden_bed 13
# Wooden_bench 12
# Wooden_cat 11
# Wooden_chair 13
# Wooden_shield 11
# Wooden_shield_(g) 10
# Wooden_spoon 11
# Wooden_stock 11
# Wool 11
# Worm_batta 11
# Worm_crunchies 11
# Worm_hole 11
# Wrapped_oomlie 11
# Wrath_rune 8
# Wrath_talisman 7
# Wrath_tiara 7
# Wyrm_bones 5
# Wyvern_bones 11
# Wyvern_visage 8
# Xerician_fabric 10
# Xerician_hat 11
# Xerician_robe 12
# Xerician_top 12
# Yak-hide 12
# Yak-hide_armour 20
# Yanillian_hops 12
# Yanillian_seed 13
# Yellow_bead 12
# Yellow_boots 13
# Yellow_cape 13
# Yellow_dark_bow_paint 12
# Yellow_dye 12
# Yellow_feather 11
# Yellow_flowers 13
# Yellow_gloves 12
# Yellow_hat 13
# Yellow_partyhat 12
# Yellow_robe_bottoms 13
# Yellow_robe_top 13
# Yew_bird_house 9
# Yew_comp_bow 12
# Yew_logs 12
# Yew_longbow 12
# Yew_longbow_(u) 11
# Yew_pyre_logs 12
# Yew_roots 12
# Yew_sapling 12
# Yew_seed 13
# Yew_shield 8
# Yew_shortbow 12
# Yew_shortbow_(u) 12
# Yew_stock 12
# Young_impling_jar 12
# Zamorak_armour_set_(lg) 11
# Zamorak_armour_set_(sk) 11
# Zamorak_bracers 11
# Zamorak_brew(1) 13
# Zamorak_brew(2) 13
# Zamorak_brew(3) 12
# Zamorak_brew(4) 13
# Zamorak_chaps 11
# Zamorak_cloak 12
# Zamorak_coif 12
# Zamorak_crozier 12
# Zamorak_d'hide 12
# Zamorak_d'hide_boots 11
# Zamorak_dragonhide_set 12
# Zamorak_full_helm 12
# Zamorak_godsword 12
# Zamorak_godsword_ornament_kit 10
# Zamorak_hilt 12
# Zamorak_kiteshield 12
# Zamorak_mitre 12
# Zamorak_mix(1) 13
# Zamorak_mix(2) 13
# Zamorak_mjolnir 12
# Zamorak_monk_bottom 8
# Zamorak_monk_top 21
# Zamorak_page_1 12
# Zamorak_page_2 11
# Zamorak_page_3 12
# Zamorak_page_4 12
# Zamorak_platebody 12
# Zamorak_platelegs 12
# Zamorak_plateskirt 12
# Zamorak_robe_legs 12
# Zamorak_robe_top 12
# Zamorak_stole 11
# Zamorak's_grapes 9
# Zamorakian_hasta 12
# Zamorakian_spear 12
# Zenyte 12
# Zenyte_amulet 13
# Zenyte_amulet_(u) 11
# Zenyte_bracelet 13
# Zenyte_necklace 13
# Zenyte_ring 13
# Zenyte_shard 11
# Zogre_bones 12
# Zombie_head 11
# Zul-andra_teleport 12
# Zulrah's_scales 12
# Zuriel's_staff 6

# %%
data['Dragon_bones']
# Out:
# [415, 1026, 1246, 1249, 1253, 1346, 1376, 1391, 1393, 1399]

# %%
print(itemPrices['Dragon_bones'][414:417])
# Out:
# [(1463961600, 3175, -1), (1463961600, 3175, -1), (1464048000, 3143, -1)]

# %%
# fix duplicate dates
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    for index in sorted(repeats, reverse=True):
        del itemPrices[item][index]

# %%
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check if it worked

data = {}
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))

# %%
#itemPrices = scraper.loadItemPrices()
# just throw out first 90 days of data?
toPop = []
for item in itemPrices:
    if len(itemPrices[item])<30:
        print(item)
        toPop.append(item)
for item in toPop:
    itemPrices.pop(item)
# Out:
# Dragon_hasta(kp)

# %%
# Find missing dates
item = 'Dragon_legs/skirt_ornament_kit'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
# Out:
# 179 5232.0 2015-09-22 00:00:00
# 203 72.0 2016-05-20 00:00:00
# 261 120.0 2016-07-19 00:00:00
# 296 48.0 2016-08-27 00:00:00
# 297 72.0 2016-08-29 00:00:00
# 374 528.0 2016-11-16 00:00:00
# 422 96.0 2017-01-24 00:00:00
# 443 48.0 2017-02-17 00:00:00
# 489 192.0 2017-04-05 00:00:00
# 577 120.0 2017-07-09 00:00:00
# 602 72.0 2017-08-07 00:00:00
# 626 48.0 2017-09-02 00:00:00
# 769 48.0 2018-01-24 00:00:00
# 822 48.0 2018-03-19 00:00:00
# 824 48.0 2018-03-22 00:00:00
# 864 48.0 2018-05-02 00:00:00
# 867 48.0 2018-05-06 00:00:00
# 965 48.0 2018-08-13 00:00:00
# 966 48.0 2018-08-15 00:00:00
# 1044 48.0 2018-11-02 00:00:00
# 1071 48.0 2018-11-30 00:00:00
# 1074 48.0 2018-12-04 00:00:00
# 1075 48.0 2018-12-06 00:00:00
# 1076 48.0 2018-12-08 00:00:00
# 1105 48.0 2019-01-07 00:00:00
# 1106 48.0 2019-01-09 00:00:00
# 1137 48.0 2019-02-10 00:00:00
# 1141 48.0 2019-02-15 00:00:00
# 1152 48.0 2019-02-27 00:00:00
# 0.23918575063613232

# %%
# Find missing dates
total = []
for item in itemPrices:
    if len(itemPrices[item])>0:
        dates = [a[0] for a in itemPrices[item]]
        day = 86400
        hour = 3600
        missing = 0
        for i in range(len(dates)-1):
            diff = dates[i+1]-dates[i]
            if diff<23*hour or diff>25*hour:
                #print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
                missing += int(diff/day)-1
        missRate = missing/len(itemPrices[item])
        total.append(missRate)
        if missing/len(itemPrices[item])>.1:
            print(item,missRate)
# Out:
# Dragon_legs/skirt_ornament_kit 0.23918575063613232

# %%
# Find missing dates
'''
item = 'Dragon_knife'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
'''
# Out:
# "\nitem = 'Dragon_knife'\ndates = [a[0] for a in itemPrices[item]]\nday = 86400\nhour = 3600\nmissing = 0\nfor i in range(len(dates)-1):\n    diff = dates[i+1]-dates[i]\n    if diff<23*hour or diff>25*hour:\n        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))\n        missing += int(diff/day)-1\nprint(missing/len(itemPrices[item]))\n"

# %%
print(len(total),max(total),min(total),np.mean(total),np.std(total))
# Out:
# 3393 0.23918575063613232 0.004043126684636119 0.05649578227166029 0.010072246962180438

# %%
plt.hist(total,30)
# Out:
# (array([2.000e+00, 0.000e+00, 4.100e+01, 3.100e+01, 1.850e+02, 7.350e+02,
#         1.171e+03, 6.310e+02, 5.150e+02, 7.900e+01, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.00404313, 0.01188121, 0.0197193 , 0.02755739, 0.03539548,
#         0.04323356, 0.05107165, 0.05890974, 0.06674783, 0.07458591,
#         0.082424  , 0.09026209, 0.09810018, 0.10593826, 0.11377635,
#         0.12161444, 0.12945253, 0.13729061, 0.1451287 , 0.15296679,
#         0.16080488, 0.16864296, 0.17648105, 0.18431914, 0.19215723,
#         0.19999531, 0.2078334 , 0.21567149, 0.22350958, 0.23134766,
#         0.23918575]),
#  <a list of 30 Patch objects>)

# %%
itemPrices.pop('Dragon_legs/skirt_ornament_kit',None)

# %%
item = 'Abyssal_whip'
prices = [a[1] for a in itemPrices[item]]
plt.plot(prices)

# %%
def interPolateMissingDates(info):
    dates = [a[0] for a in info]
    prices = [a[1] for a in info]
    quants = [a[2] for a in info]
    fixed = []
    for i in range(len(dates)-1):
        fixed.append(info[i])
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            daysToAdd = int(diff/day)-1
            d = []
            p = []
            q = []
            pToAdd = (prices[i+1]-prices[i])/(daysToAdd+1)
            qToAdd = (quants[i+1]-quants[i])/(daysToAdd+1)
            for j in range(daysToAdd):
                d.append(dates[i]+day*(j+1))
                p.append(prices[i]+(j+1)*pToAdd)
                q.append(quants[i]+(j+1)*qToAdd)
            for j in range(daysToAdd):
                fixed.append((d[j],p[j],q[j]))
    return fixed

# %%
# interpolate dates, prices, and quantities
#for item in itemPrices:
item = 'Abyssal_whip'
dates = [a[0] for a in itemPrices[item]]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("Before:",total)
fixed = interPolateMissingDates(itemPrices[item])
dates = [a[0] for a in fixed]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("After:",total)
prices = [a[1] for a in fixed]
plt.plot(prices)
# Out:
# Before: 58
# After: 0

# %%
# fix all items
toPop = []
for item in itemPrices:
    try:
        itemPrices[item] = interPolateMissingDates(itemPrices[item])
    except ZeroDivisionError:
        print(item)
        toPop.append(item)

# %%
for item in toPop:
    itemPrices.pop(item,None)

# %%
for item in itemPrices:
    dates = [a[0] for a in itemPrices[item]]
    total = 0
    for i in range(len(dates)-1):
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            total += int(diff/day)-1
    if total>0:
        print(item,total)

# %%
def checkOutliers(prices):
    outliers = []
    manualAdjust = []
    for i in range(len(prices)-2):
        diff1 = abs(prices[i+1]-prices[i])
        diff2 = abs(prices[i+2]-prices[i+1])
        if diff1>100 and diff2>100 and diff1>prices[i]*0.15 and diff2>prices[i+1]*0.15:
            outliers.append(i+1)
        if diff1>100 and diff2>100 and diff1>prices[i]*0.17 and diff2<prices[i+1]*0.15:
            manualAdjust.append(i+1)
    return outliers,manualAdjust

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
# Out:
# 130
# 13

# %%
print(outlier)
#print(adjust)
# Out:
# {'Amulet_of_bounty': [65, 66, 67, 68, 69], 'Antipoison(1)': [181], 'Antipoison(2)': [181], 'Antipoison(3)': [181], 'Arceuus_banner': [276, 277, 278, 279], 'Arceuus_hood': [276, 277, 278, 279], 'Arceuus_scarf': [275, 276, 277, 278, 279], 'Attack_potion(2)': [181], 'Attack_potion(3)': [181], 'Black_cape': [181], 'Black_robe': [181], "Blacksmith's_helm": [276, 277, 278, 279], 'Blue_boots': [181], 'Blue_cape': [181], 'Blue_halloween_mask': [181], 'Blue_hat': [181], 'Blue_robe_bottoms': [181], 'Blue_robe_top': [181], 'Blue_wizard_robe': [181], 'Bones_to_bananas': [745, 746, 747], 'Boots_of_darkness': [275, 276, 277, 278, 279], 'Bowl_wig': [275, 276, 277, 278, 279], 'Bucket_helm_(g)': [278, 279], 'Cream_boots': [181], 'Cream_hat': [181], 'Cream_robe_bottoms': [181], 'Cream_robe_top': [181], 'Cyclops_head': [259, 260], 'Defence_potion(2)': [181], 'Dragon_impling_jar': [1133], 'Empty_oil_lantern': [765, 766, 767, 768, 769], 'Enchant_diamond': [744, 745, 746, 747], 'Enchant_emerald_or_jade': [745, 746, 747], 'Enchant_onyx': [747], 'Fishing_potion(1)': [181], 'Fishing_potion(2)': [181, 1375], 'Fishing_potion(3)': [181], 'Gilded_hasta': [278, 279], 'Gilded_spear': [277, 278, 279], 'Gloves_of_darkness': [276, 277, 278, 279], 'Greater_demon_mask': [276, 277, 278, 279], 'Green_boots': [181], 'Green_halloween_mask': [181], 'Green_hat': [181], 'Green_robe_bottoms': [181], 'Green_robe_top': [181], 'Hosidius_banner': [275, 276, 277, 278, 279], 'Hosidius_hood': [276, 277, 278, 279], 'Hosidius_scarf': [275, 276, 277, 278, 279], 'Incomplete_heavy_ballista': [337, 338, 339, 340, 341], 'Incomplete_light_ballista': [338, 339, 340, 341], 'Iron_hasta(p)': [765, 766, 767, 768], 'Iron_hasta(p+)': [764, 765, 766, 767, 768], 'Iron_hasta(p++)': [764, 765, 766, 767, 768], 'Jade_amulet': [65, 66, 67, 68, 69], 'Jade_amulet_(u)': [66, 67, 68, 69], 'Jungle_demon_mask': [277, 278, 279], 'Left_eye_patch': [275, 276, 277, 278, 279], 'Lesser_demon_mask': [275, 276, 277, 278, 279], 'Lovakengj_banner': [275, 276, 277, 278, 279], 'Lovakengj_hood': [276, 277, 278, 279], 'Lovakengj_scarf': [275, 276, 277, 278, 279], 'Mith_grapple_tip': [743, 744, 745, 746, 747], 'Mithril_dagger(p)': [1063], 'Mithril_limbs': [745, 746, 747], "Monk's_robe": [180], "Monk's_robe_top": [180], 'Monkey_tail': [340, 341], "Mummy's_body": [277, 278, 279], "Mummy's_feet": [277, 278, 279], "Mummy's_hands": [277, 278, 279], "Mummy's_head": [278, 279], "Mummy's_legs": [277, 278, 279], 'Old_demon_mask': [278, 279], 'Opal_amulet': [65, 66, 67, 68, 69], 'Opal_amulet_(u)': [66, 67, 68, 69], 'Orange_cape': [181], 'Pink_boots': [181], 'Pink_hat': [181], 'Pink_robe_bottoms': [181], 'Pink_robe_top': [181], 'Piscarilius_banner': [275, 276, 277, 278, 279], 'Piscarilius_hood': [275, 276, 277, 278, 279], 'Piscarilius_scarf': [275, 276, 277, 278, 279], 'Prayer_potion(1)': [181], 'Prayer_potion(2)': [181], 'Prayer_potion(3)': [181], 'Purple_cape': [181], 'Ranging_potion(1)': [181], 'Ranging_potion(2)': [181], 'Ranging_potion(3)': [181], 'Red_halloween_mask': [181], 'Restore_mix(1)': [1372, 1373, 1374], 'Restore_mix(2)': [1374], 'Restore_potion(1)': [181], 'Restore_potion(2)': [181], 'Restore_potion(3)': [181], 'Robe_bottom_of_darkness': [277, 278, 279], 'Robe_top_of_darkness': [278, 279], 'Samurai_boots': [277, 278, 279], 'Shayzien_banner': [275, 276, 277, 278, 279], 'Shayzien_hood': [278, 279], 'Spider_on_shaft': [744, 745, 746, 747], 'Spider_on_stick': [744, 745, 746, 747], 'Strength_mix(1)': [1374], 'Strength_potion(4)': [181], 'Super_attack(1)': [181], 'Super_attack(2)': [181], 'Super_attack(3)': [181], 'Super_defence(1)': [181], 'Super_defence(2)': [181], 'Super_defence(3)': [181], 'Super_strength(2)': [181], 'Super_strength(3)': [181], 'Superantipoison(1)': [181], 'Superantipoison(2)': [181], 'Topaz_amulet': [66, 67, 68, 69], 'Topaz_amulet_(u)': [68, 69], 'Turquoise_boots': [181], 'Turquoise_hat': [181], 'Turquoise_robe_bottoms': [181], 'Turquoise_robe_top': [181], 'Unstrung_light_ballista': [339, 340, 341], ...

# %%
item = 'Fishing_potion(1)'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [181]
# [1228, 1228, 1228, 54, 1228, 1228.0, 1228.0]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# adjust items that were revalued on 2017-04-11
week = 7 * 86400
checkPoint = 1491868800
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Amulet_of_bounty
# Arceuus_banner
# Arceuus_hood
# Arceuus_scarf
# Blacksmith's_helm
# Bones_to_bananas
# Boots_of_darkness
# Bowl_wig
# Bucket_helm_(g)
# Cyclops_head
# Empty_oil_lantern
# Enchant_diamond
# Enchant_emerald_or_jade
# Enchant_onyx
# Gilded_hasta
# Gilded_spear
# Gloves_of_darkness
# Greater_demon_mask
# Hosidius_banner
# Hosidius_hood
# Hosidius_scarf
# Incomplete_heavy_ballista
# Incomplete_light_ballista
# Iron_hasta(p)
# Iron_hasta(p+)
# Iron_hasta(p++)
# Jade_amulet
# Jade_amulet_(u)
# Jungle_demon_mask
# Left_eye_patch
# Lesser_demon_mask
# Lovakengj_banner
# Lovakengj_hood
# Lovakengj_scarf
# Mith_grapple_tip
# Mithril_limbs
# Monkey_tail
# Mummy's_body
# Mummy's_feet
# Mummy's_hands
# Mummy's_head
# Mummy's_legs
# Old_demon_mask
# Opal_amulet
# Opal_amulet_(u)
# Piscarilius_banner
# Piscarilius_hood
# Piscarilius_scarf
# Robe_bottom_of_darkness
# Robe_top_of_darkness
# Samurai_boots
# Shayzien_banner
# Shayzien_hood
# Spider_on_shaft
# Spider_on_stick
# Topaz_amulet
# Topaz_amulet_(u)
# Unstrung_light_ballista
# Zombie_head

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 71
# 13
# {'Antipoison(1)': [181], 'Antipoison(2)': [181], 'Antipoison(3)': [181], 'Attack_potion(2)': [181], 'Attack_potion(3)': [181], 'Black_cape': [181], 'Black_robe': [181], 'Blue_boots': [181], 'Blue_cape': [181], 'Blue_halloween_mask': [181], 'Blue_hat': [181], 'Blue_robe_bottoms': [181], 'Blue_robe_top': [181], 'Blue_wizard_robe': [181], 'Cream_boots': [181], 'Cream_hat': [181], 'Cream_robe_bottoms': [181], 'Cream_robe_top': [181], 'Defence_potion(2)': [181], 'Dragon_impling_jar': [1133], 'Fishing_potion(1)': [181], 'Fishing_potion(2)': [181, 1375], 'Fishing_potion(3)': [181], 'Green_boots': [181], 'Green_halloween_mask': [181], 'Green_hat': [181], 'Green_robe_bottoms': [181], 'Green_robe_top': [181], 'Mithril_dagger(p)': [1063], "Monk's_robe": [180], "Monk's_robe_top": [180], 'Orange_cape': [181], 'Pink_boots': [181], 'Pink_hat': [181], 'Pink_robe_bottoms': [181], 'Pink_robe_top': [181], 'Prayer_potion(1)': [181], 'Prayer_potion(2)': [181], 'Prayer_potion(3)': [181], 'Purple_cape': [181], 'Ranging_potion(1)': [181], 'Ranging_potion(2)': [181], 'Ranging_potion(3)': [181], 'Red_halloween_mask': [181], 'Restore_mix(1)': [1372, 1373, 1374], 'Restore_mix(2)': [1374], 'Restore_potion(1)': [181], 'Restore_potion(2)': [181], 'Restore_potion(3)': [181], 'Strength_mix(1)': [1374], 'Strength_potion(4)': [181], 'Super_attack(1)': [181], 'Super_attack(2)': [181], 'Super_attack(3)': [181], 'Super_defence(1)': [181], 'Super_defence(2)': [181], 'Super_defence(3)': [181], 'Super_strength(2)': [181], 'Super_strength(3)': [181], 'Superantipoison(1)': [181], 'Superantipoison(2)': [181], 'Turquoise_boots': [181], 'Turquoise_hat': [181], 'Turquoise_robe_bottoms': [181], 'Turquoise_robe_top': [181], 'Wizard_hat': [181], 'Yellow_cape': [181], 'Zamorak_brew(1)': [181], 'Zamorak_brew(2)': [181], 'Zamorak_brew(3)': [181], 'Zamorak_monk_top': [181]}

# %%
item = 'Turquoise_robe_bottoms'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [181]
# [2865, 2865, 2865, 83, 2865, 2837.2, 2809.4]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# fix outliers caused by misread on 2015-09-02 00:00:00
week = 7 * 86400
checkPoint = 1441152000
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Antipoison(1)
# Antipoison(2)
# Antipoison(3)
# Attack_potion(2)
# Attack_potion(3)
# Black_cape
# Black_robe
# Blue_boots
# Blue_cape
# Blue_halloween_mask
# Blue_hat
# Blue_robe_bottoms
# Blue_robe_top
# Blue_wizard_robe
# Cream_boots
# Cream_hat
# Cream_robe_bottoms
# Cream_robe_top
# Defence_potion(2)
# Fishing_potion(1)
# Fishing_potion(2)
# Fishing_potion(3)
# Green_boots
# Green_halloween_mask
# Green_hat
# Green_robe_bottoms
# Green_robe_top
# Monk's_robe
# Monk's_robe_top
# Orange_cape
# Pink_boots
# Pink_hat
# Pink_robe_bottoms
# Pink_robe_top
# Prayer_potion(1)
# Prayer_potion(2)
# Prayer_potion(3)
# Purple_cape
# Ranging_potion(1)
# Ranging_potion(2)
# Ranging_potion(3)
# Red_halloween_mask
# Restore_potion(1)
# Restore_potion(2)
# Restore_potion(3)
# Strength_potion(4)
# Super_attack(1)
# Super_attack(2)
# Super_attack(3)
# Super_defence(1)
# Super_defence(2)
# Super_defence(3)
# Super_strength(2)
# Super_strength(3)
# Superantipoison(1)
# Superantipoison(2)
# Turquoise_boots
# Turquoise_hat
# Turquoise_robe_bottoms
# Turquoise_robe_top
# Wizard_hat
# Yellow_cape
# Zamorak_brew(1)
# Zamorak_brew(2)
# Zamorak_brew(3)
# Zamorak_monk_top

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 6
# 9
# {'Dragon_impling_jar': [1133], 'Fishing_potion(2)': [1187], 'Mithril_dagger(p)': [1063], 'Restore_mix(1)': [1372, 1373, 1374], 'Restore_mix(2)': [1374], 'Strength_mix(1)': [1374]}

# %%
for item in outlier:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Dragon_impling_jar
# Fishing_potion(2)
# Mithril_dagger(p)
# Restore_mix(1)
# Restore_mix(2)
# Strength_mix(1)

# %%
# guess I'll just get rid of these ones
for item in outlier:
    itemPrices.pop(item,None)

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 0
# 8
# {}

# %%
for item in adjust:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Craw's_bow_(u)
# Disk_of_returning
# Dragon_harpoon
# Dragon_sword
# Dragonbone_necklace
# Heavy_ballista
# Thammaron's_sceptre_(u)
# Viggora's_chainmace_(u)

# %%
# noticed that dragon sword price was changed after an update on january 10th
# and that information was stored on its wiki page, should probably scrape that as well

# %%
# save results back to itemPrices
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1487: 2
# 1480: 243
# 1479: 429
# 1478: 29
# 1477: 97
# 1458: 1621
# 1456: 394
# 1454: 1
# 1292: 51
# 1290: 14
# 1265: 1
# 1263: 5
# 1171: 6
# 1170: 25
# 1168: 1
# 1155: 1
# 1122: 1
# 1052: 27
# 1050: 4
# 1045: 8
# 1043: 2
# 1031: 3
# 1029: 1
# 1024: 2
# 1011: 1
# 994: 1
# 990: 67
# 989: 3
# 988: 18
# 982: 1
# 973: 6
# 962: 1
# 955: 1
# 927: 2
# 920: 6
# 906: 1
# 899: 1
# 876: 1
# 808: 11
# 806: 3
# 800: 2
# 792: 1
# 788: 1
# 783: 1
# 780: 19
# 778: 1
# 773: 1
# 752: 1
# 710: 1
# 708: 18
# 707: 13
# 706: 14
# 705: 12
# 704: 2
# 688: 1
# 660: 3
# 659: 1
# 638: 13
# 612: 1
# 562: 22
# 560: 2
# 514: 5
# 512: 1
# 508: 1
# 485: 3
# 483: 4
# 471: 1
# 444: 51
# 430: 5
# 422: 9
# 421: 1
# 416: 8
# 415: 2
# 414: 2
# 409: 3
# 407: 3
# 325: 2
# 302: 1
# 290: 9
# 288: 9
# 240: 3
# 238: 1
# 199: 11
# 197: 1

# %%
# probably 1306
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l].append(item)
    else:
        sizes[l] = [item]

# %%
s = 1487
print(sizes[s][0])
print(datetime.utcfromtimestamp(itemPrices[sizes[s][0]][0][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Karambwan_vessel
# 2015-02-26 00:00:00

# %%
for item in itemPrices:
    prices = [a[1] for a in itemPrices[item]]
    ma7 = util.items.sma(prices,7)
    for i in range(1,len(ma7)):
        if ma7[i]<ma7[i-1]:
            itemPrices[item] = itemPrices[item][i:]
            break
    prices = [a[1] for a in itemPrices[item]]
    ma7 = util.items.sma(prices,7)
    for i in range(1,len(ma7)):
        if ma7[i]>ma7[i-1]:
            itemPrices[item] = itemPrices[item][i:]
            break

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1480: 2
# 1479: 7
# 1478: 1
# 1477: 7
# 1476: 3
# 1475: 5
# 1474: 1
# 1473: 3
# 1472: 4
# 1471: 1
# 1470: 1
# 1469: 9
# 1468: 3
# 1467: 2
# 1466: 3
# 1465: 2
# 1464: 4
# 1463: 1
# 1462: 4
# 1461: 2
# 1460: 3
# 1459: 5
# 1458: 10
# 1457: 7
# 1456: 30
# 1455: 41
# 1454: 31
# 1453: 48
# 1452: 42
# 1451: 23
# 1450: 30
# 1449: 35
# 1448: 38
# 1447: 44
# 1446: 38
# 1445: 18
# 1444: 34
# 1443: 25
# 1442: 33
# 1441: 30
# 1440: 23
# 1439: 28
# 1438: 21
# 1437: 24
# 1436: 19
# 1435: 31
# 1434: 27
# 1433: 23
# 1432: 18
# 1431: 17
# 1430: 9
# 1429: 19
# 1428: 19
# 1427: 12
# 1426: 5
# 1425: 18
# 1424: 17
# 1423: 9
# 1422: 11
# 1421: 11
# 1420: 10
# 1419: 12
# 1418: 11
# 1417: 16
# 1416: 7
# 1415: 11
# 1414: 13
# 1413: 6
# 1412: 17
# 1411: 11
# 1410: 14
# 1409: 9
# 1408: 7
# 1407: 10
# 1406: 10
# 1405: 14
# 1404: 6
# 1403: 11
# 1402: 13
# 1401: 44
# 1400: 10
# 1399: 18
# 1398: 6
# 1397: 5
# 1396: 8
# 1395: 9
# 1394: 13
# 1393: 10
# 1392: 11
# 1391: 8
# 1390: 9
# 1389: 10
# 1388: 6
# 1387: 5
# 1386: 4
# 1385: 8
# 1384: 9
# 1383: 9
# 1382: 10
# 1381: 8
# 1380: 7
# 1379: 16
# 1378: 14
# 1377: 6
# 1376: 5
# 1375: 3
# 1374: 11
# 1373: 3
# 1372: 4
# 1371: 5
# 1370: 9
# 1369: 6
# 1368: 14
# 1367: 4
# 1366: 3
# 1365: 8
# 1364: 4
# 1363: 10
# 1362: 5
# 1361: 11
# 1360: 5
# 1359: 3
# 1358: 5
# 1357: 6
# 1356: 6
# 1355: 7
# 1354: 4
# 1353: 4
# 1352: 3
# 1351: 6
# 1350: 3
# 1349: 8
# 1348: 4
# 1347: 3
# 1346: 7
# 1345: 2
# 1344: 3
# 1343: 4
# 1342: 5
# 1341: 8
# 1340: 2
# 1339: 13
# 1338: 2
# 1337: 8
# 1336: 5
# 1335: 5
# 1334: 3
# 1333: 1
# 1332: 7
# 1331: 2
# 1330: 3
# 1329: 3
# 1328: 3
# 1327: 7
# 1326: 5
# 1325: 3
# 1324: 6
# 1323: 4
# 1322: 6
# 1321: 5
# 1320: 5
# 1319: 2
# 1318: 3
# 1317: 1
# 1316: 3
# 1315: 1
# 1314: 7
# 1313: 4
# 1312: 4
# 1311: 4
# 1310: 3
# 1309: 4
# 1308: 4
# 1307: 1
# 1306: 4
# 1305: 3
# 1304: 2
# 1303: 2
# 1302: 1
# 1301: 5
# 1300: 3
# 1299: 2
# 1298: 6
# 1297: 1
# 1296: 2
# 1295: 3
# 1294: 7
# 1293: 2
# 1292: 1
# 1291: 5
# 1289: 11
# 1288: 1
# 1287: 4
# 1286: 3
# 1285: 6
# 1284: 5
# 1283: 4
# 1282: 2
# 1281: 1
# 1280: 4
# 1279: 1
# 1278: 4
# 1277: 2
# 1276: 3
# 1275: 9
# 1274: 4
# 1273: 1
# 1272: 4
# 1271: 2
# 1270: 2
# 1269: 3
# 1268: 4
# 1267: 2
# 1266: 3
# 1265: 1
# 1264: 4
# 1263: 2
# 1262: 3
# 1261: 2
# 1260: 1
# 1259: 1
# 1258: 1
# 1257: 1
# 1256: 2
# 1255: 2
# 1253: 4
# 1252: 1
# 1251: 6
# 1250: 2
# 1249: 1
# 1248: 4
# 1247: 1
# 1246: 2
# 1245: 2
# 1244: 3
# 1243: 2
# 1242: 2
# 1241: 3
# 1240: 1
# 1239: 2
# 1238: 6
# 1237: 1
# 1236: 3
# 1234: 3
# 1233: 2
# 1232: 1
# 1231: 5
# 1230: 3
# 1229: 4
# 1228: 1
# 1227: 3
# 1226: 3
# 1225: 3
# 1224: 2
# 1223: 8
# 1222: 1
# 1221: 2
# 1220: 1
# 1219: 1
# 1218: 6
# 1217: 1
# 1216: 3
# 1215: 1
# 1213: 1
# 1212: 3
# 1210: 3
# 1209: 4
# 1208: 4
# 1207: 2
# 1206: 4
# 1205: 2
# 1204: 2
# 1203: 1
# 1202: 1
# 1201: 3
# 1200: 1
# 1199: 3
# 1198: 3
# 1197: 5
# 1196: 4
# 1195: 2
# 1194: 3
# 1193: 5
# 1192: 2
# 1191: 1
# 1190: 4
# 1189: 1
# 1188: 2
# 1187: 2
# 1186: 1
# 1185: 1
# 1182: 1
# 1181: 5
# 1180: 2
# 1179: 1
# 1178: 2
# 1177: 1
# 1175: 1
# 1174: 2
# 1173: 1
# 1172: 4
# 1171: 1
# 1170: 1
# 1169: 2
# 1168: 2
# 1167: 7
# 1165: 6
# 1162: 4
# 1161: 2
# 1160: 1
# 1159: 2
# 1158: 1
# 1157: 1
# 1156: 2
# 1155: 2
# 1153: 4
# 1152: 3
# 1151: 4
# 1150: 5
# 1149: 1
# 1148: 3
# 1147: 2
# 1146: 4
# 1144: 1
# 1143: 3
# 1141: 3
# 1140: 4
# 1138: 3
# 1137: 2
# 1135: 1
# 1134: 2
# 1133: 3
# 1132: 1
# 1130: 2
# 1128: 2
# 1127: 2
# 1126: 1
# 1125: 1
# 1123: 1
# 1121: 4
# 1119: 2
# 1118: 4
# 1116: 4
# 1115: 2
# 1114: 3
# 1113: 2
# 1109: 1
# 1108: 1
# 1107: 1
# 1105: 4
# 1104: 1
# 1103: 2
# 1102: 2
# 1101: 4
# 1099: 2
# 1098: 2
# 1097: 1
# 1096: 2
# 1095: 3
# 1091: 2
# 1090: 3
# 1086: 2
# 1085: 1
# 1084: 3
# 1083: 3
# 1082: 1
# 1081: 1
# 1080: 2
# 1079: 1
# 1077: 3
# 1075: 3
# 1074: 2
# 1073: 1
# 1071: 1
# 1070: 2
# 1069: 2
# 1068: 2
# 1067: 1
# 1066: 1
# 1065: 2
# 1062: 2
# 1061: 2
# 1060: 3
# 1059: 1
# 1058: 4
# 1057: 1
# 1056: 2
# 1055: 1
# 1054: 1
# 1053: 1
# 1052: 1
# 1051: 3
# 1050: 2
# 1049: 1
# 1048: 1
# 1047: 1
# 1046: 2
# 1044: 1
# 1043: 3
# 1041: 1
# 1040: 1
# 1039: 2
# 1038: 1
# 1037: 2
# 1035: 1
# 1034: 3
# 1033: 1
# 1032: 1
# 1031: 4
# 1030: 3
# 1026: 3
# 1025: 2
# 1024: 5
# 1023: 1
# 1021: 1
# 1019: 1
# 1018: 1
# 1017: 1
# 1016: 1
# 1015: 1
# 1013: 1
# 1010: 2
# 1009: 2
# 1008: 1
# 1007: 1
# 1006: 2
# 1005: 1
# 1004: 2
# 1002: 1
# 1001: 1
# 998: 1
# 996: 2
# 995: 3
# 994: 1
# 993: 1
# 992: 2
# 989: 1
# 988: 2
# 985: 1
# 983: 2
# 982: 1
# 981: 1
# 978: 1
# 976: 1
# 975: 1
# 973: 2
# 971: 1
# 970: 1
# 969: 1
# 968: 3
# 967: 5
# 966: 1
# 963: 1
# 962: 3
# 961: 2
# 956: 3
# 955: 1
# 952: 1
# 951: 2
# 949: 1
# 947: 1
# 946: 1
# 944: 1
# 942: 2
# 941: 3
# 939: 1
# 937: 3
# 936: 1
# 932: 2
# 931: 2
# 930: 2
# 928: 3
# 927: 1
# 926: 1
# 925: 2
# 924: 2
# 923: 3
# 921: 1
# 919: 1
# 918: 1
# 917: 1
# 916: 1
# 915: 2
# 913: 1
# 910: 2
# 906: 1
# 903: 2
# 902: 1
# 901: 1
# 900: 2
# 899: 1
# 898: 1
# 896: 1
# 895: 2
# 893: 1
# 892: 1
# 891: 1
# 889: 1
# 888: 1
# 886: 2
# 880: 1
# 879: 1
# 878: 2
# 877: 2
# 874: 1
# 873: 1
# 872: 1
# 871: 1
# 870: 1
# 869: 3
# 868: 2
# 867: 2
# 866: 1
# 864: 6
# 863: 3
# 861: 2
# 858: 1
# 841: 1
# 840: 1
# 839: 1
# 838: 3
# 836: 1
# 835: 2
# 834: 1
# 833: 1
# 832: 1
# 831: 2
# 830: 1
# 827: 3
# 825: 1
# 824: 1
# 823: 1
# 821: 1
# 820: 1
# 814: 2
# 811: 1
# 809: 2
# 806: 2
# 805: 1
# 804: 2
# 803: 3
# 802: 1
# 801: 6
# 799: 1
# 796: 1
# 795: 5
# 794: 1
# 793: 1
# 790: 1
# 785: 1
# 784: 6
# 783: 2
# 782: 1
# 781: 1
# 780: 2
# 779: 2
# 778: 1
# 776: 1
# 775: 1
# 773: 1
# 771: 3
# 768: 2
# 767: 2
# 766: 2
# 764: 2
# 760: 1
# 759: 2
# 758: 2
# 757: 2
# 756: 1
# 755: 1
# 754: 1
# 753: 1
# 750: 1
# 748: 2
# 747: 3
# 741: 2
# 740: 1
# 739: 2
# 737: 1
# 734: 1
# 733: 4
# 732: 1
# 731: 4
# 728: 2
# 727: 1
# 723: 4
# 720: 1
# 717: 1
# 713: 1
# 712: 1
# 711: 1
# 710: 2
# 709: 5
# 708: 3
# 707: 2
# 706: 1
# 705: 1
# 703: 2
# 702: 1
# 700: 2
# 699: 4
# 698: 3
# 697: 3
# 695: 1
# 693: 5
# 692: 1
# 691: 2
# 690: 2
# 689: 4
# 688: 2
# 685: 2
# 684: 1
# 683: 1
# 682: 2
# 680: 1
# 678: 2
# 676: 2
# 674: 2
# 673: 1
# 671: 1
# 670: 1
# 667: 1
# 664: 1
# 663: 3
# 661: 3
# 660: 1
# 659: 1
# 656: 1
# 655: 2
# 654: 5
# 652: 1
# 651: 1
# 648: 1
# 647: 2
# 646: 3
# 641: 1
# 640: 3
# 639: 2
# 636: 1
# 635: 2
# 634: 2
# 631: 2
# 628: 3
# 624: 1
# 623: 2
# 621: 2
# 620: 1
# 618: 2
# 617: 2
# 614: 1
# 613: 1
# 609: 1
# 608: 1
# 605: 1
# 601: 1
# 600: 1
# 599: 4
# 598: 1
# 595: 1
# 592: 1
# 591: 1
# 590: 2
# 588: 1
# 587: 1
# 586: 2
# 585: 1
# 584: 1
# 582: 1
# 578: 1
# 577: 1
# 576: 2
# 574: 1
# 573: 2
# 571: 2
# 566: 4
# 565: 1
# 562: 1
# 561: 1
# 559: 1
# 557: 1
# 556: 1
# 555: 1
# 554: 1
# 552: 3
# 549: 1
# 548: 1
# 547: 1
# 546: 1
# 545: 2
# 544: 1
# 542: 1
# 539: 2
# 538: 1
# 537: 1
# 535: 3
# 534: 3
# 533: 1
# 532: 1
# 530: 1
# 526: 1
# 525: 1
# 524: 1
# 523: 1
# 521: 1
# 519: 2
# 518: 1
# 515: 1
# 510: 1
# 509: 1
# 508: 1
# 507: 2
# 506: 2
# 505: 1
# 504: 2
# 501: 3
# 493: 2
# 492: 1
# 491: 2
# 490: 2
# 488: 2
# 486: 1
# 482: 1
# 481: 3
# 480: 1
# 479: 4
# 478: 1
# 477: 1
# 475: 1
# 474: 1
# 473: 1
# 472: 1
# 471: 2
# 470: 1
# 467: 1
# 465: 1
# 463: 1
# 462: 1
# 461: 1
# 458: 2
# 457: 1
# 456: 1
# 455: 1
# 454: 1
# 453: 2
# 452: 2
# 450: 2
# 448: 1
# 447: 3
# 445: 2
# 444: 1
# 443: 5
# 442: 1
# 441: 1
# 439: 2
# 438: 1
# 437: 1
# 436: 1
# 435: 1
# 432: 2
# 430: 1
# 429: 35
# 427: 3
# 426: 4
# 424: 1
# 423: 1
# 421: 1
# 420: 1
# 419: 1
# 417: 2
# 416: 2
# 415: 2
# 413: 2
# 412: 2
# 411: 2
# 410: 3
# 409: 2
# 408: 2
# 407: 1
# 406: 1
# 405: 1
# 404: 5
# 403: 3
# 402: 3
# 401: 3
# 400: 3
# 399: 2
# 398: 3
# 397: 1
# 396: 1
# 395: 4
# 394: 1
# 393: 3
# 392: 2
# 391: 2
# 390: 2
# 387: 1
# 386: 1
# 385: 1
# 384: 1
# 383: 1
# 382: 2
# 379: 2
# 376: 1
# 375: 1
# 374: 1
# 373: 2
# 372: 3
# 369: 6
# 366: 1
# 365: 2
# 364: 1
# 362: 1
# 361: 1
# 359: 1
# 356: 2
# 354: 1
# 353: 2
# 352: 1
# 349: 1
# 348: 1
# 347: 2
# 346: 2
# 344: 1
# 342: 2
# 341: 2
# 337: 2
# 336: 1
# 334: 1
# 332: 1
# 331: 1
# 328: 2
# 326: 2
# 324: 3
# 323: 2
# 321: 1
# 320: 1
# 315: 1
# 314: 1
# 312: 1
# 310: 1
# 309: 2
# 307: 1
# 302: 3
# 301: 2
# 297: 2
# 293: 1
# 292: 1
# 290: 1
# 287: 2
# 286: 1
# 285: 2
# 284: 1
# 283: 1
# 282: 1
# 281: 1
# 280: 1
# 278: 1
# 276: 1
# 273: 1
# 272: 1
# 271: 1
# 269: 2
# 268: 1
# 264: 1
# 262: 3
# 261: 1
# 260: 1
# 258: 1
# 255: 2
# 253: 1
# 251: 1
# 248: 1
# 246: 1
# 244: 1
# 241: 1
# 239: 2
# 237: 1
# 231: 3
# 229: 1
# 227: 1
# 226: 1
# 224: 2
# 222: 2
# 217: 1
# 215: 2
# 214: 2
# 213: 1
# 210: 1
# 209: 1
# 208: 1
# 205: 1
# 202: 1
# 201: 2
# 199: 7
# 198: 1
# 195: 2
# 194: 1
# 191: 1
# 189: 2
# 186: 1
# 185: 1
# 183: 1
# 182: 2
# 179: 1
# 178: 1
# 177: 4
# 174: 1
# 173: 2
# 172: 2
# 170: 1
# 169: 1
# 167: 2
# 166: 1
# 165: 1
# 164: 1
# 163: 3
# 158: 1
# 157: 1
# 156: 2
# 153: 1
# 152: 1
# 151: 2
# 150: 1
# 149: 1
# 148: 1
# 147: 1
# 146: 1
# 144: 1
# 143: 1
# 142: 1
# 141: 2
# 140: 1
# 138: 2
# 137: 3
# 136: 1
# 135: 1
# 134: 1
# 133: 2
# 132: 2
# 131: 3
# 127: 1
# 125: 2
# 123: 1
# 122: 1
# 121: 3
# 120: 2
# 119: 2
# 115: 4
# 114: 3
# 113: 2
# 107: 2
# 106: 1
# 105: 2
# 104: 1
# 103: 1
# 101: 1
# 100: 2
# 99: 1
# 94: 2
# 93: 1
# 92: 2
# 91: 2
# 90: 3
# 85: 1
# 81: 1
# 76: 2
# 75: 1
# 74: 1
# 73: 2
# 72: 1
# 71: 1
# 67: 1
# 66: 2
# 64: 1
# 59: 1
# 56: 3
# 54: 1
# 53: 1
# 52: 2
# 51: 1
# 50: 2
# 49: 1
# 48: 1
# 47: 1
# 45: 2
# 41: 1
# 40: 1
# 39: 1
# 36: 1
# 31: 1
# 30: 1
# 24: 1
# 22: 1
# 19: 2
# 18: 1
# 15: 1
# 13: 2
# 10: 1
# 8: 1

# %%
# probably 1306
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l].append(item)
    else:
        sizes[l] = [item]

# %%
s = 50
print(sizes[s][0])
print(datetime.utcfromtimestamp(itemPrices[sizes[s][0]][0][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Fancy_teak_dresser
# 2019-02-02 00:00:00

# %%
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)
