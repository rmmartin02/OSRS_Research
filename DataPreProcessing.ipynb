# %%
import sys
import os
address = (os.sep).join(os.getcwd().split(os.sep)[:-2])
print(address)
sys.path.append(address)
print(sys.path)
import util.scraper
import util.items
import pickle
import matplotlib.pyplot as plt
from sklearn import preprocessing
import numpy as np
import sys
from datetime import datetime
# Out:
# /home/makoa
# ['/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '', '/home/makoa/.local/lib/python3.6/site-packages', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/home/makoa/.local/lib/python3.6/site-packages/IPython/extensions', '/home/makoa/.ipython', '/home/makoa']

# %%
with open('Data/itemPricesOriginal.pickle','rb') as f:
    itemPrices = pickle.load(f)

# %%
len(itemPrices)
# Out:
# 3394

# %%
def checkDates(dates):
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    return repeats

# %%
data = {}
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)

# %%
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))
# Out:
# 3rd_age_amulet 10
# 3rd_age_axe 10
# 3rd_age_bow 10
# 3rd_age_cloak 10
# 3rd_age_full_helmet 10
# 3rd_age_kiteshield 10
# 3rd_age_longsword 10
# 3rd_age_mage_hat 10
# 3rd_age_pickaxe 10
# 3rd_age_platebody 10
# 3rd_age_platelegs 10
# 3rd_age_range_coif 10
# 3rd_age_range_legs 10
# 3rd_age_range_top 10
# 3rd_age_robe 10
# 3rd_age_robe_top 10
# 3rd_age_vambraces 10
# 3rd_age_wand 9
# A_powdered_wig 9
# Abyssal_bludgeon 9
# Abyssal_bracelet(5) 10
# Abyssal_dagger 9
# Abyssal_dagger_(p) 9
# Abyssal_dagger_(p+) 9
# Abyssal_dagger_(p++) 9
# Abyssal_whip 9
# Achey_tree_logs 9
# Acorn 10
# Adamant_2h_sword 9
# Adamant_arrow 9
# Adamant_arrow(p) 10
# Adamant_arrow(p+) 10
# Adamant_arrow(p++) 10
# Adamant_arrowtips 9
# Adamant_axe 9
# Adamant_battleaxe 9
# Adamant_bolts 10
# Adamant_bolts_(p) 11
# Adamant_bolts_(p+) 11
# Adamant_bolts_(p++) 11
# Adamant_bolts(unf) 11
# Adamant_boots 9
# Adamant_brutal 9
# Adamant_cane 9
# Adamant_chainbody 9
# Adamant_claws 9
# Adamant_crossbow 9
# Adamant_crossbow_(u) 9
# Adamant_dagger 9
# Adamant_dagger(p) 10
# Adamant_dagger(p+) 10
# Adamant_dagger(p++) 10
# Adamant_dart 9
# Adamant_dart(p) 10
# Adamant_dart(p+) 10
# Adamant_dart(p++) 10
# Adamant_dart_tip 9
# Adamant_full_helm 9
# Adamant_full_helm_(g) 9
# Adamant_full_helm_(t) 9
# Adamant_gold-trimmed_set_(lg) 9
# Adamant_gold-trimmed_set_(sk) 9
# Adamant_halberd 9
# Adamant_hasta 9
# Adamant_hasta(p) 10
# Adamant_hasta(p+) 10
# Adamant_hasta(p++) 10
# Adamant_helm_(h1) 9
# Adamant_helm_(h2) 9
# Adamant_helm_(h3) 9
# Adamant_helm_(h4) 9
# Adamant_helm_(h5) 9
# Adamant_javelin 9
# Adamant_javelin(p) 10
# Adamant_javelin(p+) 10
# Adamant_javelin(p++) 10
# Adamant_javelin_heads 9
# Adamant_kiteshield 9
# Adamant_kiteshield_(g) 9
# Adamant_kiteshield_(t) 9
# Adamant_knife 9
# Adamant_knife(p) 10
# Adamant_knife(p+) 10
# Adamant_knife(p++) 10
# Adamant_longsword 9
# Adamant_mace 9
# Adamant_med_helm 9
# Adamant_pickaxe 9
# Adamant_platebody 9
# Adamant_platebody_(g) 9
# Adamant_platebody_(t) 9
# Adamant_platelegs 9
# Adamant_platelegs_(g) 9
# Adamant_platelegs_(t) 9
# Adamant_plateskirt 9
# Adamant_plateskirt_(g) 9
# Adamant_plateskirt_(t) 9
# Adamant_scimitar 9
# Adamant_set_(lg) 9
# Adamant_set_(sk) 9
# Adamant_shield_(h1) 9
# Adamant_shield_(h2) 9
# Adamant_shield_(h3) 9
# Adamant_shield_(h4) 9
# Adamant_shield_(h5) 9
# Adamant_spear 9
# Adamant_spear(p) 10
# Adamant_spear(p+) 10
# Adamant_spear(p++) 10
# Adamant_sq_shield 9
# Adamant_sword 9
# Adamant_thrownaxe 9
# Adamant_trimmed_set_(lg) 9
# Adamant_trimmed_set_(sk) 9
# Adamant_warhammer 9
# Adamantite_bar 9
# Adamantite_limbs 9
# Adamantite_nails 10
# Adamantite_ore 10
# Admiral_pie 10
# Afro 10
# Agility_mix(1) 11
# Agility_mix(2) 11
# Agility_potion(1) 11
# Agility_potion(2) 11
# Agility_potion(3) 11
# Agility_potion(4) 11
# Ahrim's_armour_set 10
# Ahrim's_hood 10
# Ahrim's_hood_0 11
# Ahrim's_robeskirt 10
# Ahrim's_robeskirt_0 11
# Ahrim's_robetop 10
# Ahrim's_robetop_0 11
# Ahrim's_staff 10
# Ahrim's_staff_0 11
# Air_battlestaff 10
# Air_orb 10
# Air_rune 10
# Air_talisman 10
# Air_tiara 10
# Airtight_pot 10
# Ale_of_the_gods 9
# Ale_yeast 10
# Amethyst 9
# Amethyst_arrow 9
# Amethyst_arrow(p) 9
# Amethyst_arrow(p+) 9
# Amethyst_arrow(p++) 9
# Amethyst_arrowtips 9
# Amethyst_bolt_tips 9
# Amethyst_broad_bolts 9
# Amethyst_javelin 9
# Amethyst_javelin(p) 9
# Amethyst_javelin(p+) 9
# Amethyst_javelin(p++) 9
# Amethyst_javelin_heads 9
# Amulet_mould 10
# Amulet_of_accuracy 10
# Amulet_of_avarice 9
# Amulet_of_bounty 9
# Amulet_of_chemistry 9
# Amulet_of_defence 10
# Amulet_of_eternal_glory 9
# Amulet_of_fury 10
# Amulet_of_glory 10
# Amulet_of_glory(4) 11
# Amulet_of_glory(6) 11
# Amulet_of_glory_(t) 10
# Amulet_of_glory_(t4) 11
# Amulet_of_glory_(t6) 11
# Amulet_of_magic 10
# Amulet_of_magic_(t) 10
# Amulet_of_power 10
# Amulet_of_strength 10
# Amulet_of_the_damned_(full) 11
# Amulet_of_torture 10
# Amylase_crystal 10
# Ancestral_hat 9
# Ancestral_robe_bottom 9
# Ancestral_robe_top 9
# Ancestral_robes_set 9
# Anchovies 10
# Anchovy_pizza 10
# Ancient_blessing 9
# Ancient_bracers 10
# Ancient_chaps 10
# Ancient_cloak 10
# Ancient_coif 10
# Ancient_crozier 10
# Ancient_crystal 9
# Ancient_d'hide 10
# Ancient_d'hide_boots 9
# Ancient_dragonhide_set 10
# Ancient_effigy 9
# Ancient_emblem 9
# Ancient_full_helm 10
# Ancient_kiteshield 10
# Ancient_mace 10
# Ancient_medallion 9
# Ancient_mitre 10
# Ancient_page_1 10
# Ancient_page_2 10
# Ancient_page_3 10
# Ancient_page_4 10
# Ancient_platebody 11
# Ancient_platelegs 10
# Ancient_plateskirt 11
# Ancient_relic 10
# Ancient_robe_legs 11
# Ancient_robe_top 11
# Ancient_rune_armour_set_(lg) 11
# Ancient_rune_armour_set_(sk) 11
# Ancient_staff 11
# Ancient_statuette 10
# Ancient_stole 11
# Ancient_totem 10
# Ancient_wyvern_shield 10
# Anglerfish 12
# Anguish_ornament_kit 10
# Ankou_gloves 10
# Ankou_mask 10
# Ankou_socks 10
# Ankou_top 10
# Ankou's_leggings 10
# Annakarl_teleport 11
# Anti-dragon_shield 11
# Anti-poison_supermix(1) 12
# Anti-poison_supermix(2) 12
# Anti-venom(1) 12
# Anti-venom(2) 12
# Anti-venom(3) 12
# Anti-venom(4) 12
# Anti-venom+(1) 12
# Anti-venom+(2) 12
# Anti-venom+(3) 12
# Anti-venom+(4) 12
# Antidote+(1) 12
# Antidote+(2) 12
# Antidote+(3) 12
# Antidote+(4) 12
# Superattack_mix(1) 14
# Superattack_mix(2) 13
# Antidote++(1) 12
# Antidote++(2) 12
# Antidote++(3) 12
# Antidote++(4) 12
# Antifire_mix(1) 12
# Antifire_mix(2) 12
# Antifire_potion(1) 12
# Antifire_potion(2) 12
# Antifire_potion(3) 12
# Antifire_potion(4) 12
# Antipoison(1) 12
# Antipoison(2) 12
# Antipoison(3) 12
# Antipoison(4) 12
# Antipoison_mix(1) 12
# Antipoison_mix(2) 12
# Ape_atoll_teleport 11
# Apple_mush 11
# Apple_pie 11
# Apple_sapling 11
# Apple_tree_seed 12
# Apples(5) 12
# Apprentice_wand 11
# Arcane_prayer_scroll 10
# Arcane_sigil 11
# Arcane_spirit_shield 11
# Arceuus_banner 10
# Arceuus_hood 10
# Arceuus_scarf 10
# Archer_helm 11
# Archers_ring 11
# Archery_ticket 12
# Arctic_pine_logs 11
# Arctic_pyre_logs 11
# Ardougne_teleport 11
# Arena_book 13
# Armadyl_bracers 11
# Armadyl_chainskirt 11
# Armadyl_chaps 11
# Armadyl_chestplate 11
# Armadyl_cloak 11
# Armadyl_coif 11
# Armadyl_crossbow 11
# Armadyl_crozier 11
# Armadyl_d'hide 11
# Armadyl_d'hide_boots 10
# Armadyl_dragonhide_set 11
# Armadyl_full_helm 11
# Armadyl_godsword 11
# Armadyl_godsword_ornament_kit 10
# Armadyl_helmet 11
# Armadyl_hilt 11
# Armadyl_kiteshield 11
# Armadyl_mitre 11
# Armadyl_page_1 11
# Armadyl_page_2 11
# Armadyl_page_3 11
# Armadyl_page_4 11
# Armadyl_platebody 11
# Armadyl_platelegs 11
# Armadyl_plateskirt 11
# Armadyl_robe_legs 11
# Armadyl_robe_top 11
# Armadyl_rune_armour_set_(lg) 11
# Armadyl_rune_armour_set_(sk) 11
# Armadyl_stole 11
# Arrow_shaft 11
# Asgarnian_ale 11
# Asgarnian_ale(4) 12
# Asgarnian_ale(m) 12
# Asgarnian_ale(m4) 12
# Asgarnian_hops 11
# Asgarnian_seed 12
# Ashes 11
# Assorted_flowers 12
# Astral_rune 11
# Asyn_remains 11
# Attack_mix(1) 12
# Attack_mix(2) 12
# Attack_potion(1) 12
# Attack_potion(2) 12
# Attack_potion(3) 12
# Attack_potion(4) 12
# Avantoe 11
# Avantoe_potion_(unf) 11
# Avantoe_seed 12
# Avernic_defender_hilt 9
# Axeman's_folly 11
# Axeman's_folly(4) 12
# Axeman's_folly(m) 12
# Axeman's_folly(m4) 12
# Baby_impling_jar 11
# Babydragon_bones 11
# Bag_of_salt 11
# Bagged_bluebells 13
# Bagged_daffodils 13
# Bagged_dead_tree 13
# Bagged_flower 13
# Bagged_magic_tree 11
# Bagged_maple_tree 11
# Bagged_marigolds 13
# Bagged_nice_tree 11
# Bagged_oak_tree 13
# Bagged_plant_1 11
# Bagged_plant_2 11
# Bagged_plant_3 11
# Bagged_roses 13
# Bagged_sunflower 13
# Bagged_willow_tree 13
# Bagged_yew_tree 13
# Baked_potato 11
# Ball_of_wool 11
# Ballista_limbs 11
# Ballista_spring 11
# Banana 11
# Banana_sapling 11
# Banana_stew 12
# Banana_tree_seed 12
# Bananas(5) 12
# Bandit's_brew 11
# Bandos_boots 11
# Bandos_bracers 11
# Bandos_chaps 11
# Bandos_chestplate 11
# Bandos_cloak 11
# Bandos_coif 11
# Bandos_crozier 11
# Bandos_d'hide 11
# Bandos_d'hide_boots 10
# Bandos_dragonhide_set 11
# Bandos_full_helm 11
# Bandos_godsword 11
# Bandos_godsword_ornament_kit 10
# Bandos_hilt 11
# Bandos_kiteshield 11
# Bandos_mitre 11
# Bandos_page_1 11
# Bandos_page_2 11
# Bandos_page_3 11
# Bandos_page_4 11
# Bandos_platebody 11
# Bandos_platelegs 11
# Bandos_plateskirt 12
# Bandos_robe_legs 11
# Bandos_robe_top 11
# Bandos_rune_armour_set_(lg) 11
# Bandos_rune_armour_set_(sk) 11
# Bandos_stole 11
# Bandos_tassets 11
# Barb_bolttips 11
# Barb-tail_harpoon 11
# Barbed_bolts 11
# Bark 11
# Barley 11
# Barley_malt 11
# Barley_seed 12
# Barrel 11
# Barrows_teleport 11
# Basalt 9
# Basket 11
# Bass 11
# Bastion_potion(1) 9
# Bastion_potion(2) 9
# Bastion_potion(3) 9
# Bastion_potion(4) 9
# Bat_bones 11
# Batta_tin 11
# Battlemage_potion(1) 9
# Battlemage_potion(2) 9
# Battlemage_potion(3) 9
# Battlemage_potion(4) 9
# Battlestaff 11
# Beanie 11
# Bear_fur 11
# Beer 11
# Beer_barrel 13
# Beer_glass 11
# Beer_tankard 12
# Beginner_wand 11
# Belladonna_seed 12
# Berserker_helm 11
# Berserker_necklace 11
# Berserker_ring 11
# Big_bones 11
# Big_fishing_net 11
# Big_pirate_hat 11
# Binding_necklace 11
# Bird_house 10
# Bird_nest 10
# Bird_snare 11
# Black_2h_sword 11
# Black_axe 11
# Black_battleaxe 11
# Black_bead 11
# Black_beret 11
# Black_boater 11
# Black_boots 11
# Black_brutal 11
# Black_cane 11
# Black_cape 12
# Black_cavalier 11
# Black_chainbody 11
# Black_chinchompa 11
# Black_claws 11
# Black_d'hide_body 12
# Black_d'hide_body_(g) 11
# Black_d'hide_body_(t) 11
# Black_d'hide_chaps 11
# Black_d'hide_chaps_(g) 11
# Black_d'hide_chaps_(t) 11
# Black_d'hide_shield 10
# Black_d'hide_vamb 11
# Black_dagger 11
# Black_dagger(p) 12
# Black_dagger(p+) 12
# Black_dagger(p++) 12
# Black_dart 11
# Black_dart(p) 12
# Black_dart(p+) 12
# Black_dart(p++) 12
# Black_demon_mask 10
# Black_desert_robe 11
# Black_desert_shirt 11
# Black_dragon_leather 11
# Black_dragon_mask 11
# Black_dragonhide 11
# Black_dragonhide_set 11
# Black_elegant_legs 11
# Black_elegant_shirt 11
# Black_flowers 12
# Black_full_helm 11
# Black_full_helm_(g) 11
# Black_full_helm_(t) 11
# Black_gold-trimmed_set_(lg) 11
# Black_gold-trimmed_set_(sk) 11
# Black_halberd 11
# Black_headband 11
# Black_helm_(h1) 11
# Black_helm_(h2) 11
# Black_helm_(h3) 11
# Black_helm_(h4) 11
# Black_helm_(h5) 11
# Black_kiteshield 11
# Black_kiteshield_(g) 11
# Black_kiteshield_(t) 11
# Black_knife 11
# Black_knife(p) 12
# Black_knife(p+) 12
# Black_knife(p++) 12
# Black_leprechaun_hat 10
# Black_longsword 12
# Black_mace 11
# Black_mask 11
# Black_mask_(10) 13
# Black_med_helm 11
# Black_nails 11
# Black_pickaxe 11
# Black_platebody 11
# Black_platebody_(g) 11
# Black_platebody_(t) 11
# Black_platelegs 11
# Black_platelegs_(g) 11
# Black_platelegs_(t) 11
# Black_plateskirt 11
# Black_plateskirt_(g) 11
# Black_plateskirt_(t) 11
# Black_robe 12
# Black_salamander 11
# Black_scimitar 11
# Black_set_(lg) 11
# Black_set_(sk) 11
# Black_shield_(h1) 11
# Black_shield_(h2) 11
# Black_shield_(h3) 11
# Black_shield_(h4) 11
# Black_shield_(h5) 11
# Black_skirt 11
# Black_skirt_(g) 11
# Black_skirt_(t) 11
# Black_spear 11
# Black_spear(p) 12
# Black_spear(p+) 12
# Black_spear(p++) 12
# Black_spiky_vambs 11
# Black_sq_shield 11
# Black_sword 11
# Black_tourmaline_core 10
# Black_toy_horsey 12
# Black_trimmed_set_(lg) 11
# Black_trimmed_set_(sk) 11
# Black_unicorn_mask 10
# Black_warhammer 11
# Black_warlock 12
# Black_wizard_hat_(g) 11
# Black_wizard_hat_(t) 11
# Black_wizard_robe_(g) 11
# Black_wizard_robe_(t) 11
# Blacksmith's_helm 10
# Blamish_bark_shell 11
# Blessed_spirit_shield 11
# Blood_rune 11
# Bloody_bracer 9
# Blue_beret 11
# Blue_boater 11
# Blue_boots 12
# Blue_cape 12
# Blue_d'hide_body 12
# Blue_d'hide_body_(g) 11
# Blue_d'hide_body_(t) 11
# Blue_d'hide_chaps 11
# Blue_d'hide_chaps_(g) 11
# Blue_d'hide_chaps_(t) 11
# Blue_d'hide_shield 10
# Blue_d'hide_vamb 11
# Blue_dark_bow_paint 11
# Blue_dragon_leather 11
# Blue_dragon_mask 11
# Blue_dragon_scale 11
# Blue_dragonhide 11
# Blue_dragonhide_set 11
# Blue_dye 11
# Blue_elegant_blouse 11
# Blue_elegant_legs 11
# Blue_elegant_shirt 11
# Blue_elegant_skirt 11
# Blue_feather 11
# Blue_firelighter 11
# Blue_flowers 12
# Blue_halloween_mask 12
# Blue_hat 12
# Blue_headband 11
# Blue_partyhat 11
# Blue_robe_bottoms 12
# Blue_robe_top 12
# Blue_skirt 11
# Blue_skirt_(g) 11
# Blue_skirt_(t) 11
# Blue_spiky_vambs 11
# Blue_wizard_hat 11
# Blue_wizard_hat_(g) 11
# Blue_wizard_hat_(t) 11
# Blue_wizard_robe 12
# Blue_wizard_robe_(g) 11
# Blue_wizard_robe_(t) 11
# Blurberry_special 11
# Bob's_black_shirt 11
# Bob's_blue_shirt 11
# Bob's_green_shirt 11
# Bob's_purple_shirt 11
# Bob's_red_shirt 11
# Body_rune 11
# Body_talisman 11
# Body_tiara 11
# Bolt_mould 11
# Bolt_of_cloth 11
# Bolt_rack 11
# Bone_bolts 11
# Bone_club 11
# Bone_dagger 11
# Bone_dagger_(p) 13
# Bone_dagger_(p+) 13
# Bone_dagger_(p++) 13
# Bone_spear 11
# Bones 11
# Bones_to_bananas 11
# Bones_to_peaches 11
# Book_of_balance_page_set 11
# Book_of_darkness_page_set 11
# Book_of_law_page_set 11
# Book_of_war_page_set 11
# Bookcase 13
# Boots_of_darkness 10
# Botanical_pie 10
# Bottle_of_wine 11
# Bottled_dragonbreath_(unpowered) 6
# Bottled_dragonbreath 6
# Bottomless_compost_bucket 6
# Bounty_teleport_scroll 11
# Bow_string 11
# Bowl 11
# Bowl_of_hot_water 11
# Bowl_of_water 11
# Bowl_wig 10
# Box_trap 11
# Bracelet_mould 11
# Bracelet_of_clay 11
# Bracelet_of_ethereum_(uncharged) 10
# Bracelet_of_slaughter 10
# Brandy 11
# Brass_key 11
# Brass_necklace 11
# Bread 11
# Bread_dough 11
# Briefcase 11
# Brine_sabre 11
# Broad_arrowheads 11
# Broad_bolts 11
# Broken_bark_snelm 11
# Bronze_2h_sword 11
# Bronze_arrow 11
# Bronze_arrow(p) 12
# Bronze_arrow(p+) 12
# Bronze_arrow(p++) 12
# Bronze_arrowtips 11
# Bronze_axe 11
# Bronze_bar 11
# Bronze_battleaxe 11
# Bronze_bolts 11
# Bronze_bolts_(p) 12
# Bronze_bolts_(p+) 12
# Bronze_bolts_(p++) 12
# Bronze_bolts_(unf) 11
# Bronze_boots 11
# Bronze_brutal 11
# Bronze_chainbody 11
# Bronze_claws 11
# Bronze_crossbow 11
# Bronze_crossbow_(u) 11
# Bronze_dagger 11
# Bronze_dagger(p) 12
# Bronze_dagger(p+) 12
# Bronze_dagger(p++) 12
# Bronze_dart 11
# Bronze_dart(p) 12
# Bronze_dart(p+) 12
# Bronze_dart(p++) 12
# Bronze_dart_tip 11
# Bronze_dragon_mask 11
# Bronze_full_helm 11
# Bronze_full_helm_(g) 11
# Bronze_full_helm_(t) 11
# Bronze_gold-trimmed_set_(lg) 11
# Bronze_gold-trimmed_set_(sk) 11
# Bronze_halberd 11
# Bronze_hasta 11
# Bronze_hasta(p) 12
# Bronze_hasta(p+) 12
# Bronze_hasta(p++) 12
# Bronze_javelin 11
# Bronze_javelin(p) 12
# Bronze_javelin(p+) 12
# Bronze_javelin(p++) 12
# Bronze_javelin_heads 11
# Bronze_kiteshield 11
# Bronze_kiteshield_(g) 11
# Bronze_kiteshield_(t) 11
# Bronze_knife 11
# Bronze_knife(p) 12
# Bronze_knife(p+) 12
# Bronze_knife(p++) 12
# Bronze_limbs 11
# Bronze_longsword 11
# Bronze_mace 11
# Bronze_med_helm 11
# Bronze_nails 11
# Bronze_pickaxe 11
# Bronze_platebody 11
# Bronze_platebody_(g) 11
# Bronze_platebody_(t) 11
# Bronze_platelegs 11
# Bronze_platelegs_(g) 11
# Bronze_platelegs_(t) 11
# Bronze_plateskirt 12
# Bronze_plateskirt_(g) 11
# Bronze_plateskirt_(t) 11
# Bronze_scimitar 11
# Bronze_set_(lg) 11
# Bronze_set_(sk) 11
# Bronze_spear 11
# Bronze_spear(p) 12
# Bronze_spear(p+) 12
# Bronze_spear(p++) 12
# Bronze_sq_shield 11
# Bronze_sword 11
# Bronze_thrownaxe 11
# Bronze_trimmed_set_(lg) 11
# Bronze_trimmed_set_(sk) 11
# Bronze_warhammer 11
# Bronze_wire 11
# Brown_apron 11
# Brown_headband 11
# Brown_toy_horsey 12
# Bryophyta's_essence 9
# Bryophyta's_staff_(uncharged) 9
# Bucket 11
# Bucket_helm 10
# Bucket_helm_(g) 10
# Bucket_of_milk 11
# Bucket_of_sand 11
# Bucket_of_sap 11
# Bucket_of_water 11
# Bucket_of_wax 11
# Unlit_bug_lantern 14
# Bullseye_lantern 11
# Burning_amulet(5) 10
# Burnt_bones 11
# Burnt_page 10
# Butterfly_jar 11
# Butterfly_net 11
# Cabbage 11
# Cabbage_round_shield 10
# Cabbage_seed 12
# Cabbages(10) 12
# Cactus_seed 12
# Cactus_spine 11
# Cadantine 11
# Cadantine_blood_potion_(unf) 9
# Cadantine_potion_(unf) 11
# Cadantine_seed 12
# Cadava_berries 11
# Cadavaberry_seed 12
# Cake 11
# Cake_tin 11
# Calcite 10
# Calquat_fruit 11
# Calquat_keg 11
# Calquat_sapling 11
# Calquat_tree_seed 12
# Camelot_teleport 11
# Candle 11
# Cannon_barrels 11
# Cannon_base 11
# Cannon_furnace 11
# Cannon_stand 11
# Cannonball 12
# Carrallangar_teleport 11
# Carved_oak_bench 13
# Carved_oak_magic_wardrobe 13
# Carved_oak_table 13
# Carved_teak_bench 13
# Carved_teak_magic_wardrobe 13
# Carved_teak_table 13
# Casket 11
# Castle_wars_bracelet(3) 12
# Cat_mask 11
# Cavalier_mask 11
# Cave_eel 11
# Cave_goblin_wire 11
# Caviar 11
# Celastrus_sapling 6
# Cemetery_teleport 11
# Chaos_rune 11
# Chaos_talisman 11
# Chaos_tiara 11
# Charcoal 11
# Charge_dragonstone_jewellery_scroll 10
# Cheese 11
# Cheese+tom_batta 11
# Chef's_delight 11
# Chef's_delight(4) 12
# Chef's_delight(m) 12
# Chef's_delight(m4) 12
# Chef's_hat 11
# Chilli_con_carne 11
# Chilli_potato 11
# Chinchompa 11
# Chisel 11
# Choc_saturday 11
# Choc-ice 11
# Chocchip_crunchies 11
# Chocolate_bar 11
# Chocolate_bomb 11
# Chocolate_cake 11
# Chocolate_dust 11
# Chopped_garlic 11
# Chopped_onion 11
# Chopped_tomato 11
# Chopped_tuna 11
# Chopped_ugthanki 12
# Christmas_cracker 11
# Cider 11
# Cider(4) 12
# Cider_barrel 13
# Cider(m4) 12
# Circular_hide 11
# Citizen_shoes 11
# Citizen_top 11
# Citizen_trousers 11
# Clay 11
# Cleaning_cloth 11
# Cleaver 11
# Climbing_boots 11
# Clockwork 11
# Clue_box 11
# Coal 11
# Cocktail_glass 11
# Cocktail_guide 11
# Cocktail_shaker 11
# Coconut 11
# Coconut_milk 11
# Cod 11
# Coif 11
# Combat_bracelet 11
# Combat_bracelet(4) 12
# Combat_bracelet(6) 12
# Combat_mix(1) 12
# Combat_mix(2) 12
# Combat_potion(1) 13
# Combat_potion(2) 13
# Combat_potion(3) 13
# Combat_potion(4) 13
# Combat_potion_set 11
# Common_kebbit_fur 11
# Comp_ogre_bow 11
# Compost 11
# Compost_potion(1) 12
# Compost_potion(2) 12
# Compost_potion(3) 12
# Compost_potion(4) 12
# Cooked_chicken 11
# Cooked_chompy 11
# Cooked_jubbly 11
# Cooked_karambwan 11
# Cooked_meat 11
# Cooked_oomlie_wrap 11
# Cooked_rabbit 11
# Cooked_slimy_eel 11
# Cooked_sweetcorn 11
# Cooking_apple 11
# Copper_ore 11
# Cornflour 13
# Cosmic_rune 11
# Cosmic_talisman 11
# Cosmic_tiara 11
# Cowhide 11
# Craw's_bow_(u) 9
# Cream_boots 12
# Cream_hat 12
# Cream_robe_bottoms 12
# Cream_robe_top 12
# Crier_bell 10
# Crier_coat 10
# Crier_hat 11
# Crossbow 11
# Crossbow_string 11
# Crude_chair 13
# Crunchy_tray 11
# Crushed_nest 11
# Crushed_superior_dragon_bones 10
# New_crystal_bow 13
# Crystal_key 11
# Crystal_seed 12
# New_crystal_shield 12
# Cup_of_hot_water 11
# Cup_of_tea 11
# Cup_of_water 12
# Cured_yak-hide 11
# Curry 11
# Curry_leaf 11
# Curry_sapling 11
# Curry_tree_seed 12
# Cyclops_head 11
# Dagannoth_bones 11
# Dagannoth_hide 11
# Damaged_monkey_tail 10
# Dareeyak_teleport 11
# Dark_bow 11
# Dark_bow_tie 10
# Dark_cavalier 11
# Dark_crab 11
# Dark_fishing_bait 11
# Dark_infinity_colour_kit 11
# Dark_kebbit_fur 11
# Dark_trousers 10
# Dark_tuxedo_cuffs 10
# Dark_tuxedo_jacket 10
# Dark_tuxedo_shoes 10
# Dashing_kebbit_fur 11
# Death_rune 11
# Death_talisman 11
# Death_tiara 11
# Deerstalker 11
# Defence_mix(1) 12
# Defence_mix(2) 12
# Defence_potion(1) 12
# Defence_potion(2) 12
# Defence_potion(3) 12
# Defence_potion(4) 12
# Desert_boots 11
# Desert_camo_legs 11
# Desert_camo_top 11
# Desert_devil_fur 11
# Desert_goat_horn 11
# Desert_legs 11
# Desert_robe 11
# Desert_robes 11
# Desert_shirt 11
# Desert_top 11
# Dexterous_prayer_scroll 10
# Dharok's_armour_set 11
# Dharok's_greataxe 11
# Dharok's_greataxe_0 12
# Dharok's_helm 11
# Dharok's_helm_0 12
# Dharok's_platebody 11
# Dharok's_platebody_0 12
# Dharok's_platelegs 11
# Dharok's_platelegs_0 12
# Diamond 11
# Diamond_amulet 11
# Diamond_amulet_(u) 11
# Diamond_bolt_tips 12
# Diamond_bolts 12
# Diamond_bolts_(e) 11
# Diamond_bracelet 11
# Diamond_dragon_bolts 10
# Diamond_dragon_bolts_(e) 10
# Diamond_necklace 11
# Diamond_ring 11
# Digsite_teleport 11
# Dinh's_bulwark 10
# Disk_of_returning 11
# Dodgy_necklace 10
# Doogle_leaves 12
# Dorgeshuun_crossbow 11
# Double_eye_patch 10
# Draconic_visage 11
# Dragon_2h_sword 11
# Dragon_armour_set_(lg) 10
# Dragon_armour_set_(sk) 10
# Dragon_arrow 11
# Dragon_arrow(p) 12
# Dragon_arrow(p+) 12
# Dragon_arrow(p++) 12
# Dragon_arrowtips 11
# Dragon_axe 11
# Dragon_battleaxe 11
# Dragon_bitter 11
# Dragon_bitter(4) 12
# Dragon_bitter(m) 12
# Dragon_bitter(m4) 12
# Dragon_bolts 10
# Dragon_bolts_(p) 10
# Dragon_bolts_(p+) 10
# Dragon_bolts_(p++) 10
# Dragon_bolts_(unf) 10
# Dragon_bones 11
# Dragon_boots 11
# Dragon_boots_ornament_kit 10
# Dragon_cane 11
# Dragon_chainbody 11
# Dragon_chainbody_ornament_kit 13
# Dragon_claws 10
# Dragon_crossbow 10
# Dragon_crossbow_(u) 10
# Dragon_dagger 12
# Dragon_dagger(p) 12
# Dragon_dagger(p+) 12
# Dragon_dagger(p++) 12
# Dragon_dart 11
# Dragon_dart(p) 12
# Dragon_dart(p+) 12
# Dragon_dart(p++) 12
# Dragon_dart_tip 11
# Dragon_defender_ornament_kit 10
# Dragon_full_helm 11
# Dragon_full_helm_ornament_kit 11
# Dragon_halberd 12
# Dragon_harpoon 10
# Dragon_hasta 6
# Dragon_hasta(p) 6
# Dragon_hasta(p+) 6
# Dragon_hasta(p++) 6
# Dragon_hunter_crossbow 10
# Dragon_hunter_lance 6
# Dragon_impling_jar 11
# Dragon_javelin 11
# Dragon_javelin(p) 11
# Dragon_javelin(p+) 11
# Dragon_javelin(p++) 11
# Dragon_javelin_heads 11
# Dragon_kiteshield 10
# Dragon_kiteshield_ornament_kit 10
# Dragon_knife 6
# Dragon_knife(p) 6
# Dragon_knife(p+) 6
# Dragon_knife(p++) 6
# Dragon_legs/skirt_ornament_kit 11
# Dragon_limbs 10
# Dragon_longsword 12
# Dragon_mace 11
# Dragon_med_helm 12
# Dragon_metal_lump 10
# Dragon_metal_shard 10
# Dragon_metal_slice 10
# Dragon_necklace 11
# Dragon_pickaxe 11
# Dragon_pickaxe_upgrade_kit 11
# Dragon_platebody 10
# Dragon_platebody_ornament_kit 10
# Dragon_platelegs 12
# Dragon_plateskirt 11
# Dragon_scale_dust 11
# Dragon_scimitar 12
# Dragon_scimitar_ornament_kit 10
# Dragon_spear 11
# Dragon_spear(p) 12
# Dragon_spear(p+) 12
# Dragon_spear(p++) 12
# Dragon_sq_shield 11
# Dragon_sq_shield_ornament_kit 12
# Dragon_sword 10
# Dragon_thrownaxe 11
# Dragon_warhammer 11
# Dragonbone_necklace 10
# Dragonfire_shield 11
# Dragonfire_ward 10
# Dragonfruit 6
# Dragonfruit_pie 6
# Dragonfruit_sapling 6
# Dragonfruit_tree_seed 6
# Dragonstone 11
# Dragonstone_amulet 11
# Dragonstone_amulet_(u) 12
# Dragonstone_bolt_tips 11
# Dragonstone_bolts 11
# Dragonstone_bolts_(e) 11
# Dragonstone_bracelet 11
# Dragonstone_dragon_bolts 10
# Dragonstone_dragon_bolts_(e) 10
# Dragonstone_ring 11
# Drake_bones 6
# Drake's_claw 6
# Drake's_tooth 6
# Draynor_manor_teleport 11
# Drift_net 10
# Druid's_robe 11
# Druid's_robe_top 11
# Drunk_dragon 11
# Dust_battlestaff 10
# Dust_rune 11
# Dwarf_cannon_set 11
# Dwarf_weed 11
# Dwarf_weed_potion_(unf) 11
# Dwarf_weed_seed 12
# Dwarven_helmet 11
# Dwarven_stout 11
# Dwarven_stout(4) 12
# Dwarven_stout(m) 12
# Dwarven_stout(m4) 12
# Dwellberries 11
# Dwellberry_seed 12
# Dynamite 11
# Earmuffs 11
# Earth_battlestaff 11
# Earth_impling_jar 11
# Earth_orb 11
# Earth_rune 11
# Earth_talisman 11
# Earth_tiara 11
# Easter_egg 11
# Eclectic_impling_jar 11
# Edible_seaweed 11
# Efaritay's_aid 10
# Efh_salt 9
# Egg 11
# Egg_and_tomato 11
# Egg_potato 11
# Egg_whisk 11
# Elder_chaos_hood 10
# Elder_chaos_robe 10
# Elder_chaos_top 10
# Elder_maul 10
# Elemental_helmet 11
# Elemental_shield 11
# Elemental_talisman 11
# Elf_camp_teleport 11
# Elysian_sigil 11
# Elysian_spirit_shield 11
# Emerald 11
# Emerald_amulet 11
# Emerald_amulet_(u) 11
# Emerald_bolt_tips 11
# Emerald_bolts 11
# Emerald_bolts_(e) 11
# Emerald_bracelet 11
# Emerald_dragon_bolts 10
# Emerald_dragon_bolts_(e) 10
# Emerald_necklace 11
# Emerald_ring 11
# Empty_candle_lantern 12
# Empty_cup 11
# Empty_oil_lamp 12
# Empty_oil_lantern 12
# Empty_plant_pot 12
# Empty_sack 11
# Enchant_diamond 11
# Enchant_dragonstone 11
# Enchant_emerald_or_jade 11
# Enchant_onyx 11
# Enchant_ruby_or_topaz 11
# Enchant_sapphire_or_opal 11
# Enchanted_hat 11
# Enchanted_robe 11
# Enchanted_top 11
# Energy_mix(1) 12
# Energy_mix(2) 12
# Energy_potion(1) 12
# Energy_potion(2) 12
# Energy_potion(3) 12
# Energy_potion(4) 12
# Ensouled_abyssal_head 11
# Ensouled_aviansie_head 11
# Ensouled_bear_head 11
# Ensouled_bloodveld_head 11
# Ensouled_chaos_druid_head 11
# Ensouled_dagannoth_head 11
# Ensouled_demon_head 11
# Ensouled_dog_head 11
# Ensouled_dragon_head 11
# Ensouled_elf_head 11
# Ensouled_giant_head 11
# Ensouled_goblin_head 11
# Ensouled_horror_head 11
# Ensouled_imp_head 11
# Ensouled_kalphite_head 11
# Ensouled_minotaur_head 11
# Ensouled_monkey_head 11
# Ensouled_ogre_head 11
# Ensouled_scorpion_head 11
# Ensouled_troll_head 11
# Ensouled_tzhaar_head 11
# Ensouled_unicorn_head 11
# Equa_leaves 11
# Essence_impling_jar 12
# Eternal_boots 11
# Eternal_crystal 11
# Eternal_gem 10
# Evil_chicken_feet 10
# Evil_chicken_head 10
# Evil_chicken_legs 10
# Evil_chicken_wings 10
# Expeditious_bracelet 10
# Explorer_backpack 11
# Extended_antifire(1) 12
# Extended_antifire(2) 12
# Extended_antifire(3) 12
# Extended_antifire(4) 12
# Extended_antifire_mix(1) 12
# Extended_antifire_mix(2) 12
# Extended_super_antifire(1) 10
# Extended_super_antifire(2) 10
# Extended_super_antifire(3) 10
# Extended_super_antifire(4) 10
# Extended_super_antifire_mix(1) 11
# Extended_super_antifire_mix(2) 10
# Eye_of_newt 11
# Facemask 12
# Fake_beard 11
# Falador_teleport 11
# Fancy_hedge 13
# Fancy_teak_dresser 13
# Fancy_tiara 10
# Farseer_helm 11
# Fat_snail 11
# Fat_snail_meat 11
# Fayrg_bones 11
# Feather 11
# Fedora 11
# Feldip_hills_teleport 11
# Feldip_weasel_fur 11
# Fenkenstrain's_castle_teleport 11
# Fez 11
# Fibula_piece 11
# Filled_plant_pot 12
# Fine_cloth 11
# Fire_battlestaff 11
# Fire_orb 11
# Fire_rune 11
# Fire_talisman 11
# Fire_tiara 11
# Fish_food 12
# Fish_offcuts 11
# Fish_pie 11
# Empty_fishbowl 12
# Fishing_bait 11
# Fishing_mix(1) 12
# Fishing_mix(2) 12
# Fishing_potion(1) 12
# Fishing_potion(2) 12
# Fishing_potion(3) 12
# Fishing_potion(4) 12
# Fishing_rod 12
# Fiyr_remains 11
# Flamtaer_bracelet 10
# Flamtaer_hammer 12
# Flared_trousers 11
# Flattened_hide 11
# Flax 11
# Flighted_ogre_arrow 12
# Fly_fishing_rod 11
# Four-poster_bed 13
# Fremennik_beige_shirt 12
# Fremennik_black_cloak 12
# Fremennik_blue_cloak 12
# Fremennik_blue_shirt 12
# Fremennik_boots 11
# Fremennik_brown_cloak 12
# Fremennik_brown_shirt 12
# Fremennik_cyan_cloak 12
# Fremennik_gloves 12
# Fremennik_green_cloak 12
# Fremennik_grey_cloak 12
# Fremennik_grey_shirt 12
# Fremennik_hat 11
# Fremennik_pink_cloak 12
# Fremennik_purple_cloak 12
# Fremennik_red_cloak 12
# Fremennik_red_shirt 12
# Fremennik_robe 11
# Fremennik_skirt 11
# Fremennik_teal_cloak 12
# Fremennik_yellow_cloak 12
# Fried_mushrooms 11
# Fried_onions 11
# Frog-leather_body 11
# Frog-leather_boots 11
# Frog-leather_chaps 11
# Frozen_whip_mix 11
# Fruit_batta 11
# Fruit_blast 11
# Frying_pan 11
# Fur 11
# Fury_ornament_kit 11
# Gadderhammer 11
# Games_necklace(8) 12
# Garden_pie 11
# Gardening_boots 11
# Gardening_trowel 11
# Garlic 11
# Garlic_powder 12
# Ghorrock_teleport 11
# Ghrazi_rapier 9
# Gianne_dough 11
# Gianne's_cook_book 11
# Giant_frog_legs 11
# Giant_seaweed 11
# Gilded_2h_sword 10
# Gilded_armour_set_(lg) 11
# Gilded_armour_set_(sk) 11
# Gilded_bench 13
# Gilded_boots 11
# Gilded_cape_rack 13
# Gilded_chainbody 10
# Gilded_clock 13
# Gilded_dresser 13
# Gilded_four-poster 13
# Gilded_full_helm 11
# Gilded_hasta 10
# Gilded_kiteshield 11
# Gilded_magic_wardrobe 13
# Gilded_med_helm 10
# Gilded_platebody 11
# Gilded_platelegs 11
# Gilded_plateskirt 11
# Gilded_scimitar 11
# Gilded_spear 10
# Gilded_sq_shield 10
# Gilded_wardrobe 13
# Gin 11
# Glassblowing_pipe 11
# Gloves_of_darkness 10
# Gloves_of_silence 11
# Gnome_goggles 11
# Gnome_scarf 11
# Gnome_spice 11
# Gnomeball 11
# Gnomebowl_mould 11
# Gnomish_firelighter 10
# Goat_horn_dust 11
# Goblin_book 12
# Goblin_mail 11
# Goblin_mask 11
# Godsword_blade 11
# Godsword_shard_1 11
# Godsword_shard_2 11
# Godsword_shard_3 11
# Gold_amulet 11
# Gold_amulet_(u) 11
# Gold_bar 11
# Gold_bracelet 11
# Gold_elegant_blouse 11
# Gold_elegant_legs 11
# Gold_elegant_shirt 11
# Gold_elegant_skirt 11
# Gold_headband 11
# Gold_leaf 11
# Gold_necklace 11
# Gold_ore 11
# Gold_ring 11
# Gold_seal 11
# Golden_apron 10
# Golden_chef's_hat 10
# Golden_scarab 11
# Golden_statuette 11
# Golovanova_fruit_top 10
# Gourmet_impling_jar 12
# Gout_tuber 12
# Graahk_fur 11
# Graahk_headdress 11
# Graahk_legs 11
# Graahk_top 10
# Grain 11
# Grand_seed_pod 11
# Granite_(500g) 13
# Granite_(2kg) 13
# Granite_(5kg) 13
# Granite_body 11
# Granite_boots 9
# Granite_clamp 11
# Granite_gloves 10
# Granite_hammer 10
# Granite_helm 11
# Granite_legs 11
# Granite_longsword 9
# Granite_maul 11
# Granite_ring 10
# Granite_shield 11
# Grape_seed 11
# Grapes 11
# Greater_demon_mask 10
# Green_boater 11
# Green_boots 12
# Green_cape 11
# Green_d'hide_body 12
# Green_d'hide_body_(g) 10
# Green_d'hide_body_(t) 11
# Green_d'hide_chaps 11
# Green_d'hide_chaps_(g) 11
# Green_d'hide_chaps_(t) 11
# Green_d'hide_shield 10
# Green_d'hide_vamb 11
# Green_dark_bow_paint 11
# Green_dragon_leather 11
# Green_dragon_mask 11
# Green_dragonhide 10
# Green_dragonhide_set 11
# Green_dye 11
# Green_elegant_blouse 11
# Green_elegant_legs 11
# Green_elegant_shirt 11
# Green_elegant_skirt 11
# Green_firelighter 13
# Green_halloween_mask 12
# Green_hat 12
# Green_headband 10
# Green_partyhat 11
# Green_robe_bottoms 12
# Green_robe_top 12
# Green_spiky_vambs 11
# Greenman's_ale 10
# Greenmans_ale(4) 12
# Greenman's_ale(m) 12
# Greenmans_ale(m4) 11
# Grey_boots 12
# Grey_gloves 12
# Grey_hat 12
# Grey_robe_bottoms 12
# Grey_robe_top 12
# Grey_toy_horsey 12
# Grey_wolf_fur 11
# Grimy_avantoe 11
# Grimy_cadantine 10
# Grimy_dwarf_weed 11
# Grimy_guam_leaf 12
# Grimy_harralander 11
# Grimy_irit_leaf 12
# Grimy_kwuarm 11
# Grimy_lantadyme 11
# Grimy_marrentill 11
# Grimy_ranarr_weed 11
# Grimy_snapdragon 11
# Grimy_tarromin 9
# Grimy_toadflax 12
# Grimy_torstol 11
# Grog 11
# Ground_guam 11
# Guam_leaf 11
# Guam_potion_(unf) 11
# Guam_seed 12
# Guam_tar 11
# Guardian_boots 10
# Guthan's_armour_set 12
# Guthan's_chainskirt 11
# Guthan's_chainskirt_0 12
# Guthan's_helm 10
# Guthan's_helm_0 12
# Guthan's_platebody 11
# Guthan's_platebody_0 11
# Guthan's_warspear 11
# Guthan's_warspear_0 12
# Guthix_armour_set_(lg) 11
# Guthix_armour_set_(sk) 11
# Guthix_balance(1) 13
# Guthix_balance(2) 13
# Guthix_balance(3) 13
# Guthix_balance(4) 13
# Guthix_bracers 11
# Guthix_chaps 11
# Guthix_cloak 12
# Guthix_coif 11
# Guthix_crozier 11
# Guthix_d'hide_boots 10
# Guthix_dragonhide_set 11
# Guthix_full_helm 11
# Guthix_kiteshield 11
# Guthix_mitre 11
# Guthix_mjolnir 11
# Guthix_page_1 11
# Guthix_page_2 11
# Guthix_page_3 11
# Guthix_page_4 11
# Guthix_platebody 10
# Guthix_platelegs 10
# Guthix_plateskirt 11
# Guthix_rest(1) 12
# Guthix_rest(2) 12
# Guthix_rest(3) 12
# Guthix_rest(4) 12
# Guthix_robe_legs 11
# Guthix_robe_top 11
# Guthix_stole 12
# Hair 11
# Half_full_wine_jug 11
# Half_moon_spectacles 10
# Halloween_mask_set 10
# Ham_boots 11
# Ham_cloak 11
# Ham_gloves 11
# Ham_hood 11
# Ham_logo 11
# Ham_robe 11
# Ham_shirt 11
# Hammer 11
# Hammerstone_hops 11
# Hammerstone_seed 12
# Hard_leather 11
# Hard_leather_shield 9
# Hardleather_body 11
# Harmony_island_teleport 11
# Harpoon 11
# Harralander 11
# Harralander_potion_(unf) 11
# Harralander_seed 12
# Harralander_tar 11
# Hat_eyepatch 10
# Headless_arrow 10
# Heavy_ballista 11
# Heavy_frame 11
# Helm_of_neitiznot 11
# Herring 11
# Highwayman_mask 11
# Hill_giant_club 10
# Holy_blessing 10
# Holy_book_page_set 11
# Holy_elixir 11
# Holy_mould 11
# Holy_sandals 10
# Holy_symbol 11
# Holy_wraps 10
# Honourable_blessing 10
# Hood_of_darkness 10
# Hosidius_banner 10
# Hosidius_hood 10
# Hosidius_scarf 10
# Hunter_potion(1) 11
# Hunter_potion(2) 12
# Hunter_potion(3) 12
# Hunter_potion(4) 12
# Hunters'_crossbow 12
# Hunting_mix(1) 12
# Hunting_mix(2) 12
# Hydra_bones 6
# Icy_basalt 9
# Imbued_heart 10
# Imp_mask 11
# Impling_jar 11
# Incomplete_heavy_ballista 11
# Incomplete_light_ballista 11
# Infinity_boots 11
# Infinity_bottoms 11
# Infinity_gloves 11
# Infinity_hat 11
# Infinity_top 11
# Initiate_cuisse 11
# Initiate_harness_m 9
# Initiate_hauberk 11
# Initiate_sallet 11
# Inoculation_bracelet 11
# Insect_repellent 12
# Insulated_boots 11
# Irit_leaf 11
# Irit_potion_(unf) 11
# Irit_seed 12
# Iron_2h_sword 10
# Iron_arrow 11
# Iron_arrow(p) 12
# Iron_arrow(p+) 12
# Iron_arrow(p++) 12
# Iron_arrowtips 10
# Iron_axe 11
# Iron_bar 11
# Iron_battleaxe 11
# Iron_bolts 11
# Iron_bolts_(p) 13
# Iron_bolts_(p+) 13
# Iron_bolts_(p++) 13
# Iron_bolts_(unf) 11
# Iron_boots 11
# Iron_brutal 11
# Iron_chainbody 10
# Iron_claws 11
# Iron_crossbow 11
# Iron_crossbow_(u) 10
# Iron_dagger 11
# Iron_dagger(p) 12
# Iron_dagger(p+) 12
# Iron_dagger(p++) 12
# Iron_dart 11
# Iron_dart(p) 12
# Iron_dart(p+) 12
# Iron_dart(p++) 11
# Iron_dart_tip 11
# Iron_dragon_mask 11
# Iron_full_helm 11
# Iron_full_helm_(g) 11
# Iron_full_helm_(t) 11
# Iron_gold-trimmed_set_(lg) 11
# Iron_gold-trimmed_set_(sk) 11
# Iron_halberd 11
# Iron_hasta 11
# Iron_hasta(p) 12
# Iron_hasta(p+) 12
# Iron_hasta(p++) 11
# Iron_javelin 11
# Iron_javelin(p) 12
# Iron_javelin(p+) 12
# Iron_javelin(p++) 12
# Iron_javelin_heads 11
# Iron_kiteshield 11
# Iron_kiteshield_(g) 10
# Iron_kiteshield_(t) 11
# Iron_knife 11
# Iron_knife(p) 12
# Iron_knife(p+) 12
# Iron_knife(p++) 12
# Iron_limbs 11
# Iron_longsword 11
# Iron_mace 10
# Iron_med_helm 11
# Iron_nails 11
# Iron_ore 11
# Iron_pickaxe 11
# Iron_platebody 11
# Iron_platebody_(g) 11
# Iron_platebody_(t) 11
# Iron_platelegs 11
# Iron_platelegs_(g) 11
# Iron_platelegs_(t) 10
# Iron_plateskirt 11
# Iron_plateskirt_(g) 10
# Iron_plateskirt_(t) 11
# Iron_scimitar 11
# Iron_set_(lg) 11
# Iron_set_(sk) 11
# Iron_spear 11
# Iron_spear(p) 12
# Iron_spear(p+) 12
# Iron_spear(p++) 12
# Iron_spit 10
# Iron_sq_shield 11
# Iron_sword 11
# Iron_thrownaxe 11
# Iron_trimmed_set_(lg) 10
# Iron_trimmed_set_(sk) 11
# Iron_warhammer 11
# Ivory_comb 11
# Jade 12
# Jade_amulet 10
# Jade_amulet_(u) 9
# Jade_bolt_tips 11
# Jade_bracelet 10
# Jade_dragon_bolts 10
# Jade_dragon_bolts_(e) 10
# Jade_machete 11
# Jade_necklace 10
# Jade_ring 10
# Jangerberries 11
# Jangerberry_seed 12
# Jar_of_darkness 9
# Jar_of_decay 10
# Jar_of_dirt 11
# Jar_of_miasma 10
# Jar_of_sand 11
# Jar_of_souls 11
# Jar_of_stone 10
# Jar_of_swamp 11
# Javelin_shaft 11
# Jogre_bones 11
# Jug 11
# Jug_of_water 10
# Jug_of_wine 11
# Jungle_camo_legs 11
# Jungle_camo_top 11
# Jungle_demon_mask 10
# Justiciar_armour_set 9
# Justiciar_chestguard 9
# Justiciar_faceguard 9
# Justiciar_legguards 9
# Jute_fibre 11
# Jute_seed 11
# Karambwan_vessel 6
# Karidian_disguise 12
# Karil's_armour_set 11
# Karil's_coif 11
# Karil's_coif_0 12
# Karil's_crossbow 11
# Karil's_crossbow_0 13
# Karil's_leatherskirt 11
# Karil's_leatherskirt_0 12
# Karil's_leathertop 11
# Karil's_leathertop_0 13
# Katana 11
# Kebab 11
# Kebab_mix 10
# Kebbit_bolts 10
# Kebbit_claws 11
# Kebbit_spike 11
# Kebbit_teeth 11
# Kebbit_teeth_dust 11
# Keg_of_beer 11
# Kharidian_headpiece 11
# Kharyrll_teleport 11
# King_worm 11
# Kitchen_knife 11
# Kitchen_table 13
# Knife 11
# Kodai_insignia 10
# Kodai_wand 10
# Kraken_tentacle 11
# Krandorian_hops 11
# Krandorian_seed 11
# Kwuarm 11
# Kwuarm_potion_(unf) 11
# Kwuarm_seed 12
# Kyatt_fur 11
# Kyatt_hat 11
# Kyatt_legs 11
# Kyatt_top 10
# Lantadyme 11
# Lantadyme_potion_(unf) 11
# Lantadyme_seed 12
# Lantern_lens 10
# Large_oak_bed 13
# Large_teak_bed 12
# Larupia_fur 11
# Larupia_hat 11
# Larupia_legs 11
# Larupia_top 11
# Lassar_teleport 11
# Lava_battlestaff 12
# Lava_dragon_bones 11
# Lava_dragon_mask 11
# Lava_rune 11
# Lava_scale 10
# Lava_scale_shard 11
# Lava_staff_upgrade_kit 10
# Law_rune 11
# Leaf-bladed_battleaxe 10
# Leaf-bladed_sword 11
# Lean_snail 11
# Lean_snail_meat 11
# Leaping_salmon 11
# Leaping_sturgeon 10
# Leaping_trout 11
# Leather 11
# Leather_body 11
# Leather_boots 11
# Leather_chaps 11
# Leather_cowl 10
# Leather_gloves 11
# Leather_vambraces 11
# Left_eye_patch 10
# Lemon 11
# Lemon_chunks 11
# Lemon_slices 11
# Leprechaun_hat 10
# Lesser_demon_mask 10
# Light_ballista 11
# Light_bow_tie 10
# Light_frame 11
# Light_infinity_colour_kit 10
# Light_orb 11
# Light_trousers 10
# Light_tuxedo_cuffs 10
# Light_tuxedo_jacket 10
# Light_tuxedo_shoes 10
# Lime 11
# Lime_chunks 11
# Lime_slices 11
# Limestone 11
# Limestone_brick 11
# Limpwurt_root 11
# Limpwurt_seed 12
# Linen 12
# Lizardman_fang 11
# Loar_remains 10
# Lobster 11
# Lobster_pot 10
# Lockpick 11
# Locust_meat 13
# Logs 11
# Long_kebbit_bolts 11
# Long_kebbit_spike 12
# Longbow 11
# Longbow_(u) 11
# Loop_half_of_key 11
# Lovakengj_banner 10
# Lovakengj_hood 9
# Lovakengj_scarf 10
# Lumberyard_teleport 11
# Lumbridge_graveyard_teleport 11
# Lumbridge_teleport 11
# Lunar_isle_teleport 11
# M._treasure_chest 13
# Machete 11
# Mackerel 11
# Mage's_book 13
# Magic_bird_house 10
# Magic_box 10
# Magic_cape_rack 13
# Magic_comp_bow 11
# Magic_essence_mix(1) 12
# Magic_essence_mix(2) 11
# Magic_fang 11
# Magic_logs 11
# Magic_longbow 11
# Magic_longbow_(u) 11
# Magic_mix(1) 12
# Magic_mix(2) 12
# Magic_potion(1) 12
# Magic_potion(2) 11
# Magic_potion(3) 12
# Magic_potion(4) 11
# Magic_pyre_logs 11
# Magic_roots 11
# Magic_sapling 11
# Magic_seed 12
# Magic_shield 10
# Magic_shortbow 11
# Magic_shortbow_(u) 11
# Magic_shortbow_scroll 10
# Magic_staff 11
# Magic_stock 10
# Magic_stone 11
# Magic_string 11
# Magpie_impling_jar 11
# Mahogany_armchair 13
# Mahogany_armour_case 13
# Mahogany_bench 13
# Mahogany_bird_house 10
# Mahogany_bookcase 12
# Mahogany_cape_rack 13
# Mahogany_dresser 13
# Mahogany_fancy_dress_box 13
# Mahogany_logs 11
# Mahogany_magic_wardrobe 13
# Mahogany_plank 11
# Mahogany_pyre_log 12
# Mahogany_sapling 10
# Mahogany_seed 10
# Mahogany_stock 11
# Mahogany_table 12
# Mahogany_toy_box 13
# Mahogany_wardrobe 13
# Malediction_shard_1 11
# Malediction_shard_2 11
# Malediction_shard_3 11
# Malediction_ward 11
# Manta_ray 11
# Maple_bird_house 10
# Maple_blackjack 11
# Maple_blackjack(d) 12
# Maple_blackjack(o) 12
# Maple_logs 10
# Maple_longbow 11
# Maple_longbow_(u) 12
# Maple_pyre_logs 11
# Maple_roots 11
# Maple_sapling 11
# Maple_seed 12
# Maple_shield 10
# Maple_shortbow 11
# Maple_shortbow_(u) 11
# Maple_stock 10
# Marble_block 11
# Marble_cape_rack 13
# Marble_magic_wardrobe 13
# Marigold_seed 12
# Marigolds 11
# Marrentill 11
# Marrentill_potion_(unf) 11
# Marrentill_seed 12
# Marrentill_tar 11
# Master_scroll_book_(empty) 10
# Master_wand 10
# Mature_cider 11
# Mature_wmb 11
# Meat_pie 11
# Meat_pizza 11
# Meat_tenderiser 11
# Menaphite_purple_hat 12
# Menaphite_purple_kilt 12
# Menaphite_purple_robe 12
# Menaphite_purple_top 12
# Menaphite_red_hat 12
# Menaphite_red_kilt 12
# Menaphite_red_robe 12
# Menaphite_red_top 12
# Merfolk_trident 10
# Minced_meat 13
# Mind_altar_teleport 11
# Mind_bomb(4) 12
# Mind_bomb(m4) 12
# Mind_helmet 11
# Mind_rune 11
# Mind_shield 11
# Mind_talisman 11
# Mind_tiara 11
# Mining_helmet 11
# Mint_cake 11
# Mirror_shield 11
# Mist_battlestaff 9
# Mist_rune 11
# Mith_crossbow 11
# Mith_grapple 6
# Mith_grapple_tip 11
# Mithril_2h_sword 11
# Mithril_arrow 11
# Mithril_arrow(p) 12
# Mithril_arrow(p+) 12
# Mithril_arrow(p++) 12
# Mithril_arrowtips 11
# Mithril_axe 10
# Mithril_bar 12
# Mithril_battleaxe 11
# Mithril_bolts 11
# Mithril_bolts_(p) 13
# Mithril_bolts_(p+) 13
# Mithril_bolts_(p++) 13
# Mithril_bolts_(unf) 11
# Mithril_boots 11
# Mithril_brutal 10
# Mithril_chainbody 11
# Mithril_claws 11
# Mithril_crossbow_(u) 11
# Mithril_dagger 11
# Mithril_dagger(p) 12
# Mithril_dagger(p+) 12
# Mithril_dagger(p++) 12
# Mithril_dart 11
# Mithril_dart(p) 12
# Mithril_dart(p+) 12
# Mithril_dart(p++) 12
# Mithril_dart_tip 12
# Mithril_dragon_mask 10
# Mithril_full_helm 11
# Mithril_full_helm_(g) 11
# Mithril_full_helm_(t) 11
# Mithril_gold-trimmed_set_(lg) 11
# Mithril_gold-trimmed_set_(sk) 11
# Mithril_halberd 11
# Mithril_hasta 11
# Mithril_hasta(p) 12
# Mithril_hasta(p+) 12
# Mithril_hasta(p++) 12
# Mithril_javelin 11
# Mithril_javelin(p) 11
# Mithril_javelin(p+) 12
# Mithril_javelin(p++) 12
# Mithril_javelin_heads 11
# Mithril_kiteshield 11
# Mithril_kiteshield_(g) 11
# Mithril_kiteshield_(t) 11
# Mithril_knife 11
# Mithril_knife(p) 12
# Mithril_knife(p+) 12
# Mithril_knife(p++) 12
# Mithril_limbs 11
# Mithril_longsword 11
# Mithril_mace 11
# Mithril_med_helm 11
# Mithril_nails 10
# Mithril_ore 11
# Mithril_pickaxe 11
# Mithril_platebody 12
# Mithril_platebody_(g) 11
# Mithril_platebody_(t) 11
# Mithril_platelegs 11
# Mithril_platelegs_(g) 11
# Mithril_platelegs_(t) 11
# Mithril_plateskirt 11
# Mithril_plateskirt_(g) 11
# Mithril_plateskirt_(t) 11
# Mithril_scimitar 11
# Mithril_seeds 11
# Mithril_set_(lg) 11
# Mithril_set_(sk) 10
# Mithril_spear 11
# Mithril_spear(p) 12
# Mithril_spear(p+) 12
# Mithril_spear(p++) 12
# Mithril_sq_shield 11
# Mithril_sword 11
# Mithril_thrownaxe 11
# Mithril_trimmed_set_(lg) 11
# Mithril_trimmed_set_(sk) 11
# Mithril_warhammer 11
# Mixed_flowers 11
# Mole_claw 11
# Mole_skin 11
# Molten_glass 11
# Monk's_robe 13
# Monk's_robe_(g) 10
# Monk's_robe_top 13
# Monk's_robe_top_(g) 10
# Monkey_bar 10
# Monkey_bones 11
# Monkey_nuts 11
# Monkey_tail 11
# Monkfish 11
# Monocle 11
# Moonlight_mead 11
# Moonlight_mead(4) 12
# Moonlight_mead(m) 12
# Moonlight_mead(m4) 12
# Morrigan's_javelin 9
# Morrigan's_throwing_axe 9
# Mort_myre_fungus 11
# Mort_myre_pear 11
# Mort_myre_stem 11
# Mort'ton_teleport 11
# Mos_le'harmless_teleport 11
# Mud_battlestaff 11
# Mud_pie 11
# Mud_rune 10
# Muddy_key 11
# Mummy's_body 10
# Mummy's_feet 10
# Mummy's_hands 10
# Mummy's_head 10
# Mummy's_legs 10
# Mushroom 11
# Mushroom_&_onion 13
# Mushroom_pie 10
# Mushroom_potato 11
# Mushroom_spore 12
# Musketeer_hat 10
# Musketeer_pants 11
# Musketeer_tabard 11
# Mysterious_emblem 10
# Mystic_air_staff 12
# Mystic_boots 11
# Mystic_boots_(dark) 12
# Mystic_boots_(light) 11
# Mystic_dust_staff 10
# Mystic_earth_staff 12
# Mystic_fire_staff 11
# Mystic_gloves 11
# Mystic_gloves_(dark) 12
# Mystic_gloves_(light) 12
# Mystic_hat 11
# Mystic_hat_(dark) 12
# Mystic_hat_(light) 12
# Mystic_lava_staff 12
# Mystic_mist_staff 10
# Mystic_mud_staff 10
# Mystic_robe_bottom 11
# Mystic_robe_bottom_(dark) 12
# Mystic_robe_bottom_(light) 12
# Mystic_robe_top 11
# Mystic_robe_top_(dark) 12
# Mystic_robe_top_(light) 12
# Mystic_smoke_staff 11
# Mystic_steam_staff 11
# Mystic_water_staff 11
# Nail_beast_nails 11
# Nardah_teleport 11
# Nasturtium_seed 12
# Nasturtiums 11
# Nature_impling_jar 11
# Nature_rune 13
# Nature_talisman 11
# Nature_tiara 11
# Navy_cavalier 11
# Necklace_mould 11
# Necklace_of_anguish 11
# Necklace_of_faith 10
# Necklace_of_passage(5) 10
# Needle 11
# Nice_hedge 13
# Ninja_impling_jar 11
# Noose_wand 11
# Nose_peg 11
# Numulite 9
# Nunchaku 10
# Oak_armchair 13
# Oak_armour_case 13
# Oak_bed 13
# Oak_bench 13
# Oak_bird_house 10
# Oak_blackjack(d) 12
# Oak_blackjack(o) 12
# Oak_bookcase 13
# Oak_cape_rack 13
# Oak_chair 13
# Oak_clock 13
# Oak_dining_table 12
# Oak_drawers 13
# Oak_dresser 13
# Oak_fancy_dress_box 13
# Oak_kitchen_table 13
# Oak_logs 11
# Oak_longbow 11
# Oak_longbow_(u) 12
# Oak_magic_wardrobe 13
# Oak_plank 11
# Oak_pyre_logs 10
# Oak_roots 11
# Oak_sapling 11
# Oak_shaving_stand 13
# Oak_shield 10
# Oak_shortbow 11
# Oak_shortbow_(u) 12
# Oak_stock 11
# Oak_toy_box 13
# Oak_treasure_chest 12
# Oak_wardrobe 13
# Obsidian_armour_set 10
# Obsidian_cape 11
# Obsidian_cape_(r) 10
# Obsidian_helmet 10
# Obsidian_platebody 10
# Obsidian_platelegs 10
# Occult_necklace 11
# Occult_ornament_kit 9
# Odium_shard_1 11
# Odium_shard_2 11
# Odium_shard_3 11
# Odium_ward 11
# Ogre_arrow 11
# Ogre_arrow_shaft 11
# Ogre_coffin_key 10
# Oil_lamp 11
# Oil_lantern 12
# Oil_lantern_frame 11
# Old_demon_mask 10
# Old_school_bond 9
# Olive_oil(1) 12
# Olive_oil(2) 12
# Olive_oil(3) 12
# Olive_oil(4) 12
# Onion 10
# Onion_&_tomato 12
# Onion_seed 12
# Onions(10) 12
# Onyx 11
# Onyx_amulet 11
# Onyx_amulet_(u) 11
# Onyx_bolt_tips 11
# Onyx_bolts 11
# Onyx_bolts_(e) 12
# Onyx_bracelet 10
# Onyx_dragon_bolts 10
# Onyx_dragon_bolts_(e) 10
# Onyx_necklace 11
# Onyx_ring 11
# Opal 11
# Opal_amulet 10
# Opal_amulet_(u) 10
# Opal_bolt_tips 11
# Opal_bolts 11
# Opal_bolts_(e) 11
# Opal_bracelet 10
# Opal_dragon_bolts 10
# Opal_dragon_bolts_(e) 9
# Opal_machete 11
# Opal_necklace 10
# Opal_ring 10
# Opulent_table 13
# Orange 11
# Orange_boater 11
# Orange_cape 12
# Orange_chunks 11
# Orange_dye 11
# Orange_feather 10
# Orange_flowers 12
# Orange_salamander 11
# Orange_sapling 11
# Orange_slices 11
# Orange_tree_seed 12
# Oranges(5) 12
# Ourg_bones 11
# Oyster 11
# Oyster_pearl 11
# Oyster_pearls 10
# Paddewwa_teleport 11
# Palm_sapling 11
# Palm_tree_seed 12
# Pantaloons 11
# Papaya_fruit 11
# Papaya_sapling 11
# Papaya_tree_seed 12
# Papyrus 11
# Partyhat_&_specs 10
# Partyhat_set 10
# Pastry_dough 9
# Pat_of_butter 10
# Peaceful_blessing 9
# Pearl_bolt_tips 10
# Pearl_bolts 10
# Pearl_bolts_(e) 10
# Pearl_dragon_bolts 9
# Pearl_dragon_bolts_(e) 9
# Pegasian_boots 10
# Pegasian_crystal 10
# Penguin_mask 10
# Pest_control_teleport 10
# Pestle_and_mortar 9
# Pharaoh's_sceptre 10
# Pharaoh's_sceptre_(3) 12
# Phoenix_necklace 10
# Phrin_remains 10
# Pie_dish 10
# Pie_recipe_book 10
# Pie_shell 10
# Pike 10
# Pile_of_salt 12
# Pineapple 11
# Pineapple_chunks 11
# Pineapple_pizza 11
# Pineapple_punch 11
# Pineapple_ring 11
# Pineapple_sapling 11
# Pineapple_seed 12
# Pink_boater 10
# Pink_boots 12
# Pink_cape 13
# Pink_elegant_blouse 11
# Pink_elegant_legs 11
# Pink_elegant_shirt 11
# Pink_elegant_skirt 11
# Pink_hat 12
# Pink_headband 11
# Pink_robe_bottoms 12
# Pink_robe_top 12
# Pink_skirt 10
# Pirate_boots 11
# Pirate_hat_&_patch 11
# Pirate's_hat 11
# Pirate's_hook 10
# Piscarilius_banner 10
# Piscarilius_hood 10
# Piscarilius_scarf 10
# Piscatoris_teleport 11
# Pith_helmet 10
# Pitta_bread 11
# Pizza_base 11
# Plain_pizza 11
# Plank 11
# Plant_cure 11
# Poison 12
# Poison_chalice 11
# Poison_ivy_berries 11
# Poison_ivy_seed 11
# Polar_camo_legs 11
# Polar_camo_top 11
# Polar_kebbit_fur 11
# Polished_buttons 10
# Pot 11
# Pot_lid 11
# Pot_of_cornflour 11
# Pot_of_cream 11
# Pot_of_flour 11
# Potato 10
# Potato_cactus 11
# Potato_cactus_seed 6
# Potato_seed 12
# Potato_with_butter 10
# Potato_with_cheese 11
# Potatoes(10) 12
# Pottery_scarab 11
# Pottery_statuette 11
# Prayer_mix(1) 12
# Prayer_mix(2) 13
# Prayer_potion(1) 13
# Prayer_potion(2) 13
# Prayer_potion(3) 13
# Prayer_potion(4) 13
# Premade_blurb'_sp. 11
# Premade_c+t_batta 12
# Premade_ch'_crunch 12
# Premade_choc_bomb 12
# Premade_choc_s'dy 12
# Premade_dr'_dragon 12
# Premade_fr'_blast 12
# Premade_fr't_batta 12
# Premade_p'_punch 12
# Premade_s'y_crunch 12
# Premade_sgg 10
# Premade_t'd_batta 12
# Premade_t'd_crunch 12
# Premade_ttl 12
# Premade_veg_ball 12
# Premade_veg_batta 12
# Premade_w'm_batta 12
# Premade_w'm_crun' 12
# Premade_wiz_blz'd 12
# Premade_worm_hole 12
# Primordial_boots 12
# Primordial_crystal 12
# Proboscis 12
# Proselyte_cuisse 11
# Proselyte_harness_f 14
# Proselyte_harness_m 14
# Proselyte_hauberk 12
# Proselyte_sallet 11
# Proselyte_tasset 12
# Pumpkin 12
# Pure_essence 12
# Purple_boater 12
# Purple_boots 13
# Purple_cape 13
# Purple_dye 12
# Purple_elegant_blouse 12
# Purple_elegant_legs 12
# Purple_elegant_shirt 11
# Purple_elegant_skirt 11
# Purple_firelighter 12
# Purple_flowers 13
# Purple_gloves 13
# Purple_hat 13
# Purple_partyhat 12
# Purple_robe_bottoms 13
# Purple_robe_top 13
# Purple_sweets 12
# Pyre_logs 12
# Pyrophosphite 10
# Rabbit_foot 12
# Rabbit_snare 12
# Rainbow_fish 12
# Rake 11
# Ranarr_potion_(unf) 12
# Ranarr_seed 14
# Ranarr_weed 13
# Ranger_boots 12
# Ranger_gloves 11
# Rangers'_tunic 12
# Ranging_mix(1) 13
# Ranging_mix(2) 13
# Ranging_potion(1) 13
# Ranging_potion(2) 12
# Ranging_potion(3) 13
# Ranging_potion(4) 13
# Raurg_bones 12
# Raw_admiral_pie 12
# Raw_anchovies 12
# Raw_anglerfish 11
# Raw_bass 12
# Raw_bear_meat 12
# Raw_beast_meat 12
# Raw_beef 12
# Raw_bird_meat 12
# Raw_cave_eel 12
# Raw_chicken 13
# Raw_chompy 12
# Raw_cod 12
# Raw_dark_crab 12
# Raw_fish_pie 11
# Raw_garden_pie 12
# Raw_herring 11
# Raw_jubbly 12
# Raw_karambwan 12
# Raw_lobster 12
# Raw_mackerel 12
# Raw_manta_ray 12
# Raw_monkfish 12
# Raw_mud_pie 12
# Raw_oomlie 12
# Raw_pike 12
# Raw_rabbit 11
# Raw_rainbow_fish 12
# Raw_rat_meat 12
# Raw_salmon 12
# Raw_sardine 12
# Raw_sea_turtle 12
# Raw_shark 12
# Raw_shrimps 12
# Raw_slimy_eel 13
# Raw_summer_pie 12
# Raw_swordfish 12
# Raw_trout 11
# Raw_tuna 12
# Raw_ugthanki_meat 13
# Raw_wild_pie 12
# Raw_yak_meat 11
# Red_bead 12
# Red_beret 12
# Red_boater 12
# Red_boots 13
# Red_cape 12
# Red_cavalier 12
# Red_chinchompa 12
# Red_d'hide_body 13
# Red_d'hide_body_(g) 12
# Red_d'hide_body_(t) 12
# Red_d'hide_chaps 12
# Red_d'hide_chaps_(g) 12
# Red_d'hide_chaps_(t) 12
# Red_d'hide_shield 9
# Red_d'hide_vamb 12
# Red_dragon_leather 12
# Red_dragon_mask 12
# Red_dragonhide 12
# Red_dye 11
# Red_elegant_blouse 12
# Red_elegant_legs 12
# Red_elegant_shirt 12
# Red_elegant_skirt 12
# Red_feather 12
# Red_firelighter 12
# Red_flowers 13
# Red_gloves 13
# Red_halloween_mask 12
# Red_hat 13
# Red_headband 12
# Red_partyhat 12
# Red_robe_bottoms 12
# Red_robe_top 13
# Red_salamander 12
# Red_spiders'_eggs 12
# Red_spiky_vambs 12
# Red_topaz 12
# Red_topaz_machete 12
# Redberries 11
# Redberry_pie 12
# Redberry_seed 13
# Redwood_bird_house 10
# Redwood_logs 11
# Redwood_pyre_logs 10
# Redwood_sapling 6
# Redwood_tree_seed 6
# Redwood_shield 11
# Regen_bracelet 12
# Relicym's_balm(1) 13
# Relicym's_balm(2) 13
# Relicym's_balm(3) 13
# Relicym's_balm(4) 13
# Relicym's_mix(1) 13
# Relicym's_mix(2) 12
# Restore_mix(1) 13
# Restore_mix(2) 13
# Restore_potion(1) 13
# Restore_potion(2) 13
# Restore_potion(3) 13
# Restore_potion(4) 13
# Revenant_cave_teleport 10
# Revenant_ether 10
# Ribcage_piece 11
# Right_eye_patch 12
# Ring_mould 11
# Ring_of_coins 11
# Ring_of_dueling(8) 13
# Ring_of_forging 12
# Ring_of_life 12
# Ring_of_nature 11
# Ring_of_pursuit 10
# Ring_of_recoil 12
# Ring_of_returning(5) 9
# Ring_of_stone 12
# Ring_of_suffering 13
# Ring_of_the_gods 11
# Ring_of_wealth 12
# Ring_of_wealth_(5) 13
# Ring_of_wealth_scroll 12
# Riyl_remains 12
# Roast_beast_meat 12
# Roast_bird_meat 12
# Roast_rabbit 12
# Robe_bottom_of_darkness 11
# Robe_top_of_darkness 11
# Robin_hood_hat 12
# Rock_hammer 12
# Rock_thrownhammer 10
# Rock-climbing_boots 12
# Rock-shell_boots 12
# Rock-shell_chunk 12
# Rock-shell_gloves 11
# Rock-shell_helm 12
# Rock-shell_legs 12
# Rock-shell_plate 12
# Rock-shell_shard 12
# Rock-shell_splinter 12
# Rocking_chair 13
# Roe 12
# Rolling_pin 12
# Rope 12
# Rosemary 12
# Rosemary_seed 13
# Royal_crown 11
# Royal_gown_bottom 12
# Royal_gown_top 12
# Royal_sceptre 12
# Ruby 11
# Ruby_amulet 12
# Ruby_amulet_(u) 12
# Ruby_bolt_tips 12
# Ruby_bolts 12
# Ruby_bolts_(e) 12
# Ruby_bracelet 12
# Ruby_dragon_bolts 10
# Ruby_dragon_bolts_(e) 10
# Ruby_harvest 13
# Ruby_necklace 12
# Ruby_ring 12
# Rune_2h_sword 12
# Rune_armour_set_(lg) 12
# Rune_armour_set_(sk) 12
# Rune_arrow 10
# Rune_arrow(p) 13
# Rune_arrow(p+) 13
# Rune_arrow(p++) 13
# Rune_arrowtips 12
# Rune_axe 13
# Rune_battleaxe 13
# Rune_boots 12
# Rune_brutal 12
# Rune_cane 12
# Rune_chainbody 12
# Rune_claws 12
# Rune_crossbow 12
# Rune_dagger 12
# Rune_dagger(p) 12
# Rune_dagger(p+) 14
# Rune_dagger(p++) 13
# Rune_dart 11
# Rune_dart(p) 12
# Rune_dart(p+) 13
# Rune_dart(p++) 13
# Rune_dart_tip 12
# Rune_essence 12
# Rune_full_helm 12
# Rune_full_helm_(g) 12
# Rune_full_helm_(t) 12
# Rune_gold-trimmed_set_(lg) 12
# Rune_gold-trimmed_set_(sk) 12
# Rune_halberd 12
# Rune_hasta 13
# Rune_hasta(p) 13
# Rune_hasta(p+) 13
# Rune_hasta(p++) 13
# Rune_helm_(h1) 12
# Rune_helm_(h2) 12
# Rune_helm_(h3) 12
# Rune_helm_(h4) 12
# Rune_helm_(h5) 11
# Rune_javelin 12
# Rune_javelin(p) 12
# Rune_javelin(p+) 13
# Rune_javelin(p++) 13
# Rune_javelin_heads 12
# Rune_kiteshield 13
# Rune_kiteshield_(g) 12
# Rune_kiteshield_(t) 12
# Rune_knife 12
# Rune_knife(p) 13
# Rune_knife(p+) 12
# Rune_knife(p++) 13
# Rune_longsword 14
# Rune_mace 13
# Rune_med_helm 12
# Rune_nails 12
# Rune_pickaxe 12
# Rune_platebody 13
# Rune_platebody_(g) 12
# Rune_platebody_(t) 12
# Rune_platelegs 13
# Rune_platelegs_(g) 12
# Rune_platelegs_(t) 12
# Rune_plateskirt 13
# Rune_plateskirt_(g) 12
# Rune_plateskirt_(t) 11
# Rune_scimitar 12
# Rune_shield_(h1) 12
# Rune_shield_(h2) 12
# Rune_shield_(h3) 12
# Rune_shield_(h4) 12
# Rune_shield_(h5) 11
# Rune_spear 12
# Rune_spear(p) 13
# Rune_spear(p+) 13
# Rune_spear(p++) 13
# Rune_sq_shield 13
# Rune_sword 12
# Rune_thrownaxe 12
# Rune_trimmed_set_(lg) 12
# Rune_trimmed_set_(sk) 12
# Rune_warhammer 12
# Runite_bar 11
# Runite_bolts 12
# Runite_bolts_(p) 14
# Runite_bolts_(p+) 13
# Runite_bolts_(p++) 12
# Runite_bolts_(unf) 12
# Runite_crossbow_(u) 12
# Runite_limbs 12
# Runite_ore 11
# Sacred_oil(1) 13
# Sacred_oil(2) 12
# Sacred_oil(3) 13
# Sacred_oil(4) 13
# Sagacious_spectacles 12
# Salmon 12
# Saltpetre 12
# Salve_graveyard_teleport 12
# Samurai_boots 10
# Samurai_gloves 11
# Samurai_greaves 11
# Samurai_kasa 11
# Samurai_shirt 11
# Sandstone_(1kg) 14
# Sandstone_(2kg) 14
# Sandstone_(5kg) 14
# Sandstone_(10kg) 14
# Sandworms 12
# Sanfew_serum(1) 13
# Sanfew_serum(2) 13
# Sanfew_serum(3) 12
# Sanfew_serum(4) 12
# Sanguinesti_staff_(uncharged) 9
# Santa_hat 12
# Sapphire 12
# Sapphire_amulet 12
# Sapphire_amulet_(u) 12
# Sapphire_bolt_tips 12
# Sapphire_bolts 12
# Sapphire_bolts_(e) 12
# Sapphire_bracelet 12
# Sapphire_dragon_bolts 10
# Sapphire_dragon_bolts_(e) 10
# Sapphire_glacialis 12
# Sapphire_necklace 12
# Sapphire_ring 12
# Saradomin_armour_set_(lg) 12
# Saradomin_armour_set_(sk) 12
# Saradomin_bracers 12
# Saradomin_brew(1) 13
# Saradomin_brew(2) 13
# Saradomin_brew(3) 13
# Saradomin_brew(4) 13
# Saradomin_chaps 12
# Saradomin_cloak 12
# Saradomin_coif 11
# Saradomin_crozier 12
# Saradomin_d'hide 12
# Saradomin_d'hide_boots 11
# Saradomin_dragonhide_set 12
# Saradomin_full_helm 12
# Saradomin_godsword 12
# Saradomin_godsword_ornament_kit 11
# Saradomin_hilt 12
# Saradomin_kiteshield 11
# Saradomin_mitre 12
# Saradomin_mjolnir 12
# Saradomin_page_1 12
# Saradomin_page_2 12
# Saradomin_page_3 12
# Saradomin_page_4 11
# Saradomin_platebody 12
# Saradomin_platelegs 12
# Saradomin_plateskirt 12
# Saradomin_robe_legs 12
# Saradomin_robe_top 11
# Saradomin_stole 12
# Saradomin_sword 12
# Saradomin's_light 12
# Saradomin's_tear 12
# Sardine 12
# Saw 12
# Scrambled_egg 12
# Scythe_of_vitur_(uncharged) 9
# Sea_turtle 11
# Seasoned_sardine 13
# Seaweed 14
# Seaweed_spore 10
# Secateurs 12
# Security_book 12
# Seed_dibber 12
# Seercull 12
# Seers_ring 12
# Senntisten_teleport 12
# Serpentine_helm_(uncharged) 13
# Serpentine_visage 12
# Serum_207_(1) 13
# Serum_207_(2) 13
# Serum_207_(3) 12
# Serum_207_(4) 13
# Shade_robe 12
# Shade_robe_top 12
# Shaikahan_bones 11
# Shaman_mask 10
# Shantay_pass 13
# Shark 12
# Shaving_stand 14
# Shayzien_banner 10
# Shayzien_hood 11
# Shayzien_scarf 6
# Shears 12
# Shield_left_half 13
# Shield_right_half 13
# Ship_ticket 14
# Shoe_box 15
# Short_green_guy 13
# Shortbow 13
# Shortbow_(u) 13
# Shrimps 12
# Shrunk_ogleroot 13
# Sickle_mould 13
# Silk 13
# Silver_bar 13
# Silver_bolts 13
# Silver_bolts_(p) 15
# Silver_bolts_(p+) 14
# Silver_bolts_(p++) 14
# Silver_bolts_(unf) 13
# Silver_dust 12
# Silver_ore 13
# Silver_sickle 13
# Sinew 13
# Sinister_key 13
# Skeletal_boots 13
# Skeletal_bottoms 13
# Skeletal_gloves 13
# Skeletal_helm 13
# Skeletal_top 13
# Skeletal_visage 10
# Skewer 13
# Skewer_stick 13
# Skills_necklace 13
# Skills_necklace(4) 13
# Skills_necklace(6) 14
# Skull_piece 13
# Slayer_bell 12
# Slayer's_enchantment 10
# Slayer's_respite 13
# Slayer's_respite(4) 14
# Slayer's_respite(m) 14
# Slayer's_respite(m4) 14
# Slayer's_staff 13
# Sleeping_cap 13
# Sliced_banana 12
# Sliced_mushrooms 13
# Small_box_hedge 15
# Small_fishing_net 13
# Smoke_battlestaff 13
# Smoke_rune 13
# Smouldering_stone 12
# Snake_hide 13
# Snakeskin 13
# Snakeskin_bandana 13
# Snakeskin_body 12
# Snakeskin_boots 13
# Snakeskin_chaps 13
# Snakeskin_shield 10
# Snakeskin_vambraces 13
# Snapdragon 13
# Snapdragon_potion_(unf) 13
# Snapdragon_seed 14
# Snape_grass 13
# Snape_grass_seed 6
# Snowy_knight 14
# Soda_ash 13
# Soft_clay 13
# Soul_rune 13
# Spade 13
# Spatula 12
# Spectral_sigil 13
# Spectral_spirit_shield 13
# Spice 13
# Spicy_crunchies 13
# Spicy_minced_meat 14
# Spicy_sauce 13
# Spicy_tomato 13
# Spider_carcass 13
# Spider_on_shaft 13
# Spider_on_stick 13
# Spiked_boots 13
# Spiky_vambraces 13
# Spinach_roll 13
# Spined_body 13
# Spined_boots 13
# Spined_chaps 13
# Spined_gloves 13
# Spined_helm 13
# Spiny_helmet 12
# Spirit_shield 13
# Split_log 13
# Splitbark_body 13
# Splitbark_boots 12
# Splitbark_gauntlets 14
# Splitbark_helm 13
# Splitbark_legs 13
# Spork 13
# Spotted_cape 13
# Spotted_kebbit_fur 13
# Spottier_cape 13
# Staff 13
# Staff_of_air 13
# Staff_of_earth 13
# Staff_of_fire 12
# Staff_of_light 10
# Staff_of_the_dead 13
# Staff_of_water 13
# Stale_baguette 11
# Stamina_mix(1) 14
# Stamina_mix(2) 14
# Stamina_potion(1) 14
# Stamina_potion(2) 13
# Stamina_potion(3) 14
# Stamina_potion(4) 14
# Statius's_warhammer 9
# Steam_battlestaff 13
# Steam_rune 13
# Steam_staff_upgrade_kit 13
# Steel_2h_sword 13
# Steel_arrow 13
# Steel_arrow(p) 13
# Steel_arrow(p+) 13
# Steel_arrow(p++) 14
# Steel_arrowtips 13
# Steel_axe 13
# Steel_bar 14
# Steel_battleaxe 13
# Steel_bolts 13
# Steel_bolts_(p) 15
# Steel_bolts_(p+) 14
# Steel_bolts_(p++) 13
# Steel_bolts_(unf) 13
# Steel_boots 13
# Steel_brutal 12
# Steel_chainbody 13
# Steel_claws 13
# Steel_crossbow 13
# Steel_crossbow_(u) 13
# Steel_dagger 12
# Steel_dagger(p) 14
# Steel_dagger(p+) 14
# Steel_dagger(p++) 14
# Steel_dart 13
# Steel_dart(p) 14
# Steel_dart(p+) 14
# Steel_dart(p++) 14
# Steel_dart_tip 13
# Steel_dragon_mask 13
# Steel_full_helm 13
# Steel_full_helm_(g) 11
# Steel_full_helm_(t) 11
# Steel_gold-trimmed_set_(lg) 12
# Steel_gold-trimmed_set_(sk) 12
# Steel_halberd 13
# Tomatoes(5) 14
# Tome_of_fire_(empty) 11
# Tooth_half_of_key 13
# Top_hat 13
# Top_hat_&_monocle 13
# Topaz_amulet 10
# Topaz_amulet_(u) 10
# Topaz_bolt_tips 11
# Topaz_bolts 13
# Topaz_bolts_(e) 13
# Topaz_bracelet 10
# Topaz_dragon_bolts 10
# Topaz_dragon_bolts_(e) 10
# Topaz_necklace 10
# Topaz_ring 10
# Topiary_hedge 15
# Torag's_armour_set 13
# Torag's_hammers 13
# Torag's_hammers_0 15
# Torag's_helm 13
# Torag's_helm_0 13
# Torag's_platebody 13
# Torag's_platebody_0 14
# Torag's_platelegs 13
# Torag's_platelegs_0 13
# Unlit_torch 13
# Tormented_bracelet 14
# Torn_prayer_scroll 11
# Torstol 13
# Torstol_potion_(unf) 13
# Torstol_seed 14
# Tortoise_shell 13
# Torture_ornament_kit 12
# Toxic_blowpipe_(empty) 14
# Toxic_staff_(uncharged) 14
# Toy_cat 13
# Toy_doll 13
# Toy_doll_(wound) 15
# Toy_mouse 12
# Toy_mouse_(wound) 15
# Toy_soldier 12
# Toy_soldier_(wound) 15
# Trading_sticks 13
# Treasonous_ring 13
# Triangle_sandwich 13
# Uncharged_trident 14
# Trident_of_the_seas_(full) 14
# Uncharged_trident_(e) 10
# Uncharged_toxic_trident 14
# Uncharged_toxic_trident_(e) 10
# Trout 13
# Tuna 13
# Tuna_and_corn 13
# Tuna_potato 13
# Turquoise_boots 14
# Turquoise_hat 14
# Turquoise_robe_bottoms 13
# Turquoise_robe_top 14
# Twisted_bow 10
# Twisted_buckler 10
# Tyrannical_ring 13
# Tyras_helm 12
# Tzhaar-ket-em 13
# Tzhaar-ket-om 13
# Ugthanki_&_onion 14
# Ugthanki_&_tomato 14
# Ugthanki_kebab 13
# Ugthanki_meat 12
# Ultracompost 10
# Unblessed_symbol 13
# Uncooked_apple_pie 12
# Uncooked_berry_pie 13
# Uncooked_botanical_pie 12
# Uncooked_dragonfruit_pie 6
# Uncooked_egg 13
# Uncooked_meat_pie 13
# Uncooked_mushroom_pie 10
# Uncut_diamond 13
# Uncut_dragonstone 13
# Uncut_emerald 11
# Uncut_jade 13
# Uncut_onyx 12
# Uncut_opal 11
# Uncut_red_topaz 12
# Uncut_ruby 12
# Uncut_sapphire 12
# Uncut_zenyte 12
# Unfinished_broad_bolts 12
# Unfinished_potion 13
# Unfired_bowl 13
# Unfired_pie_dish 12
# Unfired_plant_pot 12
# Unfired_pot 13
# Unfired_pot_lid 13
# Unholy_blessing 11
# Unholy_book_page_set 11
# Unholy_symbol 12
# Unicorn_horn 12
# Unicorn_horn_dust 12
# Unpowered_orb 12
# Unpowered_symbol 12
# Unstrung_comp_bow 13
# Unstrung_emblem 12
# Unstrung_heavy_ballista 12
# Unstrung_light_ballista 11
# Unstrung_symbol 12
# Urt_salt 9
# Vampyre_dust 11
# Varrock_teleport 12
# Veg_ball 12
# Vegetable_batta 12
# Verac's_armour_set 12
# Verac's_brassard 12
# Verac's_brassard_0 14
# Verac's_flail 12
# Verac's_flail_0 13
# Verac's_helm 11
# Verac's_helm_0 12
# Verac's_plateskirt 12
# Verac's_plateskirt_0 13
# Vesta's_longsword 9
# Vesta's_spear 9
# Vial 12
# Vial_of_blood 9
# Vial_of_water 11
# Viggora's_chainmace_(u) 9
# Vodka 12
# Volcanic_ash 9
# Volcanic_whip_mix 12
# Vyrewatch_legs 12
# Vyrewatch_shoes 11
# Vyrewatch_top 12
# War_blessing 10
# Ward_upgrade_kit 12
# Warrior_helm 12
# Warrior_ring 13
# Watchtower_teleport 14
# Water_battlestaff 13
# Water_orb 11
# Water_rune 12
# Water_talisman 12
# Water_tiara 12
# Watering_can 12
# Watermelon 12
# Watermelon_seed 13
# Watermelon_slice 12
# Waterskin(0) 13
# Waterskin(4) 13
# Weapon_poison 12
# Weapon_poison(+) 12
# Weapon_poison(++) 13
# Weeds 13
# West_ardougne_teleport 11
# Whisky 12
# White_2h_sword 12
# White_apron 12
# White_battleaxe 12
# White_bead 12
# White_beret 11
# White_berries 12
# White_boater 11
# White_boots 12
# White_cavalier 12
# White_chainbody 12
# White_claws 12
# White_dagger 12
# White_dagger(p) 13
# White_dagger(p+) 12
# White_dagger(p++) 13
# White_dark_bow_paint 12
# White_elegant_blouse 11
# White_elegant_skirt 12
# White_firelighter 12
# White_flowers 13
# White_full_helm 12
# White_gloves 12
# White_halberd 12
# White_headband 12
# White_kiteshield 12
# White_lily_seed 6
# White_longsword 11
# White_mace 12
# White_magic_staff 12
# White_med_helm 12
# White_partyhat 12
# White_platebody 12
# White_platelegs 12
# White_plateskirt 12
# White_scimitar 11
# White_sq_shield 12
# White_sword 13
# White_toy_horsey 13
# White_unicorn_mask 10
# White_warhammer 11
# Whiteberry_seed 13
# Wild_pie 12
# Wildblood_hops 13
# Wildblood_seed 13
# Willow_bird_house 9
# Willow_blackjack 13
# Willow_blackjack(d) 13
# Willow_blackjack(o) 13
# Willow_branch 12
# Willow_comp_bow 12
# Willow_logs 10
# Willow_longbow 12
# Willow_longbow_(u) 12
# Willow_pyre_logs 12
# Willow_roots 12
# Willow_sapling 12
# Willow_seed 13
# Willow_shield 9
# Willow_shortbow 12
# Willow_shortbow_(u) 12
# Willow_stock 12
# Wine_of_zamorak 12
# Wizard_blizzard 11
# Wizard_boots 12
# Wizard_hat 12
# Wizard's_mind_bomb 12
# Woad_leaf 12
# Woad_seed 13
# Wolf_bones 12
# Wolfbone_arrowtips 12
# Wood_camo_legs 12
# Wood_camo_top 12
# Wood_dining_table 14
# Wooden_bed 14
# Wooden_bench 13
# Wooden_cat 12
# Wooden_chair 14
# Wooden_shield 12
# Wooden_shield_(g) 11
# Wooden_spoon 12
# Wooden_stock 12
# Wool 12
# Worm_batta 12
# Worm_crunchies 12
# Worm_hole 12
# Wrapped_oomlie 12
# Wrath_rune 9
# Wrath_talisman 8
# Wrath_tiara 8
# Wyrm_bones 6
# Wyvern_bones 12
# Wyvern_visage 9
# Xerician_fabric 11
# Xerician_hat 12
# Xerician_robe 13
# Xerician_top 13
# Yak-hide 13
# Yak-hide_armour 21
# Yanillian_hops 13
# Yanillian_seed 14
# Yellow_bead 13
# Yellow_boots 14
# Yellow_cape 14
# Yellow_dark_bow_paint 13
# Yellow_dye 13
# Yellow_feather 12
# Yellow_flowers 14
# Yellow_gloves 13
# Yellow_hat 14
# Yellow_partyhat 13
# Yellow_robe_bottoms 14
# Yellow_robe_top 14
# Yew_bird_house 10
# Yew_comp_bow 13
# Yew_logs 13
# Yew_longbow 13
# Yew_longbow_(u) 12
# Yew_pyre_logs 13
# Yew_roots 13
# Yew_sapling 13
# Yew_seed 14
# Yew_shield 9
# Yew_shortbow 13
# Yew_shortbow_(u) 13
# Yew_stock 13
# Young_impling_jar 13
# Zamorak_armour_set_(lg) 12
# Zamorak_armour_set_(sk) 12
# Zamorak_bracers 12
# Zamorak_brew(1) 14
# Zamorak_brew(2) 14
# Zamorak_brew(3) 13
# Zamorak_brew(4) 14
# Zamorak_chaps 12
# Zamorak_cloak 13
# Zamorak_coif 13
# Zamorak_crozier 13
# Zamorak_d'hide 13
# Zamorak_d'hide_boots 12
# Zamorak_dragonhide_set 13
# Zamorak_full_helm 13
# Zamorak_godsword 13
# Zamorak_godsword_ornament_kit 11
# Zamorak_hilt 13
# Zamorak_kiteshield 13
# Zamorak_mitre 13
# Zamorak_mix(1) 14
# Zamorak_mix(2) 14
# Zamorak_mjolnir 13
# Zamorak_monk_bottom 9
# Zamorak_monk_top 22
# Zamorak_page_1 13
# Zamorak_page_2 12
# Zamorak_page_3 13
# Zamorak_page_4 13
# Zamorak_platebody 13
# Zamorak_platelegs 13
# Zamorak_plateskirt 13
# Zamorak_robe_legs 13
# Zamorak_robe_top 13
# Zamorak_stole 12
# Zamorak's_grapes 10
# Zamorakian_hasta 13
# Zamorakian_spear 13
# Zenyte 13
# Zenyte_amulet 14
# Zenyte_amulet_(u) 12
# Zenyte_bracelet 14
# Zenyte_necklace 14
# Zenyte_ring 14
# Zenyte_shard 12
# Zogre_bones 13
# Zombie_head 12
# Zul-andra_teleport 13
# Zulrah's_scales 13
# Zuriel's_staff 7

# %%
data['Dragon_bones']
# Out:
# [415, 1026, 1246, 1249, 1253, 1346, 1376, 1391, 1393, 1399, 1403]

# %%
print(itemPrices['Dragon_bones'][414:417])
# Out:
# [(1463961600, 3175, -1), (1463961600, 3175, -1), (1464048000, 3143, -1)]

# %%
# fix duplicate dates
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    seen = []
    repeats = []
    for d in range(len(dates)):
        if dates[d] not in seen:
            seen.append(dates[d])
        else:
            repeats.append(d)
    for index in sorted(repeats, reverse=True):
        del itemPrices[item][index]

# %%
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check if it worked

data = {}
for item in itemPrices:
    #print(item)
    dates = [a[0] for a in itemPrices[item]]
    data[item] = checkDates(dates)
for d in data:
    if len(data[d])>0:
        print(d,len(data[d]))

# %%
#itemPrices = scraper.loadItemPrices()
# just throw out first 90 days of data?
toPop = []
for item in itemPrices:
    if len(itemPrices[item])<30:
        print(item)
        toPop.append(item)
for item in toPop:
    itemPrices.pop(item)
# Out:
# Dragon_hasta(kp)

# %%
# Find missing dates
item = 'Dragon_legs/skirt_ornament_kit'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
# Out:
# 179 5232.0 2015-09-22 00:00:00
# 203 72.0 2016-05-20 00:00:00
# 261 120.0 2016-07-19 00:00:00
# 296 48.0 2016-08-27 00:00:00
# 297 72.0 2016-08-29 00:00:00
# 374 528.0 2016-11-16 00:00:00
# 422 96.0 2017-01-24 00:00:00
# 443 48.0 2017-02-17 00:00:00
# 489 192.0 2017-04-05 00:00:00
# 577 120.0 2017-07-09 00:00:00
# 602 72.0 2017-08-07 00:00:00
# 626 48.0 2017-09-02 00:00:00
# 769 48.0 2018-01-24 00:00:00
# 822 48.0 2018-03-19 00:00:00
# 824 48.0 2018-03-22 00:00:00
# 864 48.0 2018-05-02 00:00:00
# 867 48.0 2018-05-06 00:00:00
# 965 48.0 2018-08-13 00:00:00
# 966 48.0 2018-08-15 00:00:00
# 1044 48.0 2018-11-02 00:00:00
# 1071 48.0 2018-11-30 00:00:00
# 1074 48.0 2018-12-04 00:00:00
# 1075 48.0 2018-12-06 00:00:00
# 1076 48.0 2018-12-08 00:00:00
# 1105 48.0 2019-01-07 00:00:00
# 1106 48.0 2019-01-09 00:00:00
# 1137 48.0 2019-02-10 00:00:00
# 1141 48.0 2019-02-15 00:00:00
# 1152 48.0 2019-02-27 00:00:00
# 1181 72.0 2019-03-29 00:00:00
# 0.23986486486486486

# %%
# Find missing dates
total = []
for item in itemPrices:
    if len(itemPrices[item])>0:
        dates = [a[0] for a in itemPrices[item]]
        day = 86400
        hour = 3600
        missing = 0
        for i in range(len(dates)-1):
            diff = dates[i+1]-dates[i]
            if diff<23*hour or diff>25*hour:
                #print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
                missing += int(diff/day)-1
        missRate = missing/len(itemPrices[item])
        total.append(missRate)
        if missing/len(itemPrices[item])>.1:
            print(item,missRate)
# Out:
# Dragon_legs/skirt_ornament_kit 0.23986486486486486

# %%
# Find missing dates
'''
item = 'Dragon_knife'
dates = [a[0] for a in itemPrices[item]]
day = 86400
hour = 3600
missing = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))
        missing += int(diff/day)-1
print(missing/len(itemPrices[item]))
'''
# Out:
# "\nitem = 'Dragon_knife'\ndates = [a[0] for a in itemPrices[item]]\nday = 86400\nhour = 3600\nmissing = 0\nfor i in range(len(dates)-1):\n    diff = dates[i+1]-dates[i]\n    if diff<23*hour or diff>25*hour:\n        print(i,diff/hour,datetime.utcfromtimestamp(dates[i]).strftime('%Y-%m-%d %H:%M:%S'))\n        missing += int(diff/day)-1\nprint(missing/len(itemPrices[item]))\n"

# %%
print(len(total),max(total),min(total),np.mean(total),np.std(total))
# Out:
# 3393 0.23986486486486486 0.005372733378106112 0.058134228883860016 0.00969633305705063

# %%
plt.hist(total,30)
# Out:
# (array([2.00e+00, 0.00e+00, 1.60e+01, 2.70e+01, 1.65e+02, 7.53e+02,
#         1.18e+03, 6.43e+02, 5.11e+02, 8.90e+01, 3.00e+00, 3.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00]),
#  array([0.00537273, 0.01318914, 0.02100554, 0.02882195, 0.03663835,
#         0.04445476, 0.05227116, 0.06008756, 0.06790397, 0.07572037,
#         0.08353678, 0.09135318, 0.09916959, 0.10698599, 0.11480239,
#         0.1226188 , 0.1304352 , 0.13825161, 0.14606801, 0.15388442,
#         0.16170082, 0.16951723, 0.17733363, 0.18515003, 0.19296644,
#         0.20078284, 0.20859925, 0.21641565, 0.22423206, 0.23204846,
#         0.23986486]),
#  <a list of 30 Patch objects>)

# %%
itemPrices.pop('Dragon_legs/skirt_ornament_kit',None)
# Out:
# [(1427414400, 548136, -1),
#  (1427500800, 548136, -1),
#  (1427587200, 550260, -1),
#  (1427673600, 550739, -1),
#  (1427760000, 559735, -1),
#  (1427846400, 562314, -1),
#  (1427932800, 562314, -1),
#  (1428019200, 560119, -1),
#  (1428105600, 567325, -1),
#  (1428192000, 582044, -1),
#  (1428278400, 582044, -1),
#  (1428364800, 583804, -1),
#  (1428451200, 599196, -1),
#  (1428537600, 599196, -1),
#  (1428624000, 620725, -1),
#  (1428710400, 640672, -1),
#  (1428796800, 660230, -1),
#  (1428883200, 660230, -1),
#  (1428969600, 661343, -1),
#  (1429056000, 661343, -1),
#  (1429142400, 659002, -1),
#  (1429228800, 659002, -1),
#  (1429315200, 647765, -1),
#  (1429401600, 629985, -1),
#  (1429488000, 620478, -1),
#  (1429574400, 620478, -1),
#  (1429660800, 601037, -1),
#  (1429747200, 601037, -1),
#  (1429833600, 581792, -1),
#  (1429920000, 581792, -1),
#  (1430006400, 566326, -1),
#  (1430092800, 566326, -1),
#  (1430179200, 558572, -1),
#  (1430265600, 547349, -1),
#  (1430352000, 547349, -1),
#  (1430438400, 539409, -1),
#  (1430524800, 523118, -1),
#  (1430611200, 507298, -1),
#  (1430697600, 507298, -1),
#  (1430784000, 485618, -1),
#  (1430870400, 466270, -1),
#  (1430956800, 444772, -1),
#  (1431043200, 433866, -1),
#  (1431129600, 423110, -1),
#  (1431216000, 415124, -1),
#  (1431302400, 418969, -1),
#  (1431388800, 418969, -1),
#  (1431475200, 434450, -1),
#  (1431561600, 443798, -1),
#  (1431648000, 428257, -1),
#  (1431734400, 412726, -1),
#  (1431820800, 395009, -1),
#  (1431907200, 375258, -1),
#  (1431993600, 356495, -1),
#  (1432080000, 338670, -1),
#  (1432166400, 338670, -1),
#  (1530662400, 100420, -1),
#  (1530748800, 100420, -1),
#  (1530835200, 102611, -1),
#  (1530921600, 107069, -1),
#  (1531008000, 112174, -1),
#  (1531094400, 113694, -1),
#  (1531180800, 110963, -1),
#  (1531267200, 110003, -1),
#  (1531353600, 110117, -1),
#  (1531440000, 109523, -1),
#  (1531526400, 105208, -1),
#  (1531612800, 100635, -1),
#  (1531699200, 97264, -1),
#  (1531785600, 95992, -1),
#  (1531872000, 94018, -1),
#  (1531958400, 92273, -1),
#  (1532044800, 90560, -1),
#  (1532131200, 88392, -1),
#  (1532217600, 85260, -1),
#  (1532304000, 84744, -1),
#  (1532390400, 81577, -1),
#  (1532476800, 80475, -1),
#  (1532563200, 79491, -1),
#  (1532649600, 77980, -1),
#  (1532736000, 78353, -1),
#  (1532822400, 80881, -1),
#  (1532908800, 82524, -1),
#  (1532995200, 84946, -1),
#  (1533081600, 84687, -1),
#  (1533168000, 84687, -1),
#  (1533254400, 83565, -1),
#  (1533340800, 82991, -1),
#  (1533427200, 81885, -1),
#  (1533513600, 81039, -1),
#  (1533600000, 78895, -1),
#  (1533686400, 78508, -1),
#  (1533772800, 77142, -1),
#  (1533859200, 74665, -1),
#  (1533945600, 72015, -1),
#  (1534032000, 69691, -1),
#  (1534118400, 69758, -1),
#  (1534291200, 71727, -1),
#  (1534464000, 78263, -1),
#  (1534550400, 82118, -1),
#  (1534636800, 85623, -1),
#  (1534723200, 89316, -1),
#  (1534809600, 93394, -1),
#  (1534896000, 96134, -1),
#  (1534982400, 98216, -1),
#  (1535068800, 97717, -1),
#  (1535155200, 97236, -1),
#  (1535241600, 99106, -1),
#  (1535328000, 102305, -1),
#  (1535414400, 105969, -1),
#  (1535500800, 109327, -1),
#  (1535587200, 112323, -1),
#  (1535673600, 111558, -1),
#  (1535760000, 112546, -1),
#  (1535846400, 114546, -1),
#  (1535932800, 116346, -1),
#  (1536019200, 118430, -1),
#  (1536105600, 118059, -1),
#  (1536192000, 117440, -1),
#  (1536278400, 117440, -1),
#  (1536364800, 117088, -1),
#  (1536451200, 117809, -1),
#  (1536537600, 117793, -1),
#  (1536624000, 116399, -1),
#  (1536710400, 116399, -1),
#  (1536796800, 118781, -1),
#  (1536883200, 117281, -1),
#  (1536969600, 117936, -1),
#  (1537056000, 117934, -1),
#  (1537142400, 119570, -1),
#  (1537228800, 120373, -1),
#  ...]

# %%
item = 'Abyssal_whip'
prices = [a[1] for a in itemPrices[item]]
plt.plot(prices)

# %%
def interPolateMissingDates(info):
    dates = [a[0] for a in info]
    prices = [a[1] for a in info]
    quants = [a[2] for a in info]
    fixed = []
    for i in range(len(dates)-1):
        fixed.append(info[i])
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            daysToAdd = int(diff/day)-1
            d = []
            p = []
            q = []
            pToAdd = (prices[i+1]-prices[i])/(daysToAdd+1)
            qToAdd = (quants[i+1]-quants[i])/(daysToAdd+1)
            for j in range(daysToAdd):
                d.append(dates[i]+day*(j+1))
                p.append(prices[i]+(j+1)*pToAdd)
                q.append(quants[i]+(j+1)*qToAdd)
            for j in range(daysToAdd):
                fixed.append((d[j],p[j],q[j]))
    return fixed

# %%
# interpolate dates, prices, and quantities
#for item in itemPrices:
item = 'Abyssal_whip'
dates = [a[0] for a in itemPrices[item]]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("Before:",total)
fixed = interPolateMissingDates(itemPrices[item])
dates = [a[0] for a in fixed]
total = 0
for i in range(len(dates)-1):
    diff = dates[i+1]-dates[i]
    if diff<23*hour or diff>25*hour:
        total += int(diff/day)-1
print("After:",total)
prices = [a[1] for a in fixed]
plt.plot(prices)
# Out:
# Before: 60
# After: 0

# %%
# fix all items
toPop = []
for item in itemPrices:
    try:
        itemPrices[item] = interPolateMissingDates(itemPrices[item])
    except ZeroDivisionError:
        print(item)
        toPop.append(item)
# Out:
# Bottled_dragonbreath_(unpowered)
# Bottled_dragonbreath
# Bottomless_compost_bucket
# Celastrus_sapling
# Dragon_hasta
# Dragon_hasta(p)
# Dragon_hasta(p+)
# Dragon_hasta(p++)
# Dragon_hunter_lance
# Dragon_knife
# Dragon_knife(p)
# Dragon_knife(p+)
# Dragon_knife(p++)
# Dragonfruit
# Dragonfruit_pie
# Dragonfruit_sapling
# Dragonfruit_tree_seed
# Drake_bones
# Drake's_claw
# Drake's_tooth
# Hydra_bones
# Potato_cactus_seed
# Redwood_sapling
# Redwood_tree_seed
# Snape_grass_seed
# Uncooked_dragonfruit_pie
# White_lily_seed
# Wyrm_bones

# %%
for item in toPop:
    itemPrices.pop(item,None)

# %%
for item in itemPrices:
    dates = [a[0] for a in itemPrices[item]]
    total = 0
    for i in range(len(dates)-1):
        diff = dates[i+1]-dates[i]
        if diff<23*hour or diff>25*hour:
            total += int(diff/day)-1
    if total>0:
        print(item,total)

# %%
def checkOutliers(prices):
    outliers = []
    manualAdjust = []
    for i in range(len(prices)-2):
        diff1 = abs(prices[i+1]-prices[i])
        diff2 = abs(prices[i+2]-prices[i+1])
        if diff1>100 and diff2>100 and diff1>prices[i]*0.15 and diff2>prices[i+1]*0.15:
            outliers.append(i+1)
        if diff1>100 and diff2>100 and diff1>prices[i]*0.17 and diff2<prices[i+1]*0.15:
            manualAdjust.append(i+1)
    return outliers,manualAdjust

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
# Out:
# 130
# 13

# %%
print(outlier)
#print(adjust)
# Out:
# {'Amulet_of_bounty': [65, 66, 67, 68, 69], 'Antipoison(1)': [181], 'Antipoison(2)': [181], 'Antipoison(3)': [181], 'Arceuus_banner': [276, 277, 278, 279], 'Arceuus_hood': [276, 277, 278, 279], 'Arceuus_scarf': [275, 276, 277, 278, 279], 'Attack_potion(2)': [181], 'Attack_potion(3)': [181], 'Black_cape': [181], 'Black_robe': [181], "Blacksmith's_helm": [276, 277, 278, 279], 'Blue_boots': [181], 'Blue_cape': [181], 'Blue_halloween_mask': [181], 'Blue_hat': [181], 'Blue_robe_bottoms': [181], 'Blue_robe_top': [181], 'Blue_wizard_robe': [181], 'Bones_to_bananas': [745, 746, 747], 'Boots_of_darkness': [275, 276, 277, 278, 279], 'Bowl_wig': [275, 276, 277, 278, 279], 'Bucket_helm_(g)': [278, 279], 'Cream_boots': [181], 'Cream_hat': [181], 'Cream_robe_bottoms': [181], 'Cream_robe_top': [181], 'Cyclops_head': [259, 260], 'Defence_potion(2)': [181], 'Dragon_impling_jar': [1133], 'Empty_oil_lantern': [765, 766, 767, 768, 769], 'Enchant_diamond': [744, 745, 746, 747], 'Enchant_emerald_or_jade': [745, 746, 747], 'Enchant_onyx': [747], 'Fishing_potion(1)': [181], 'Fishing_potion(2)': [181, 1375], 'Fishing_potion(3)': [181], 'Gilded_hasta': [278, 279], 'Gilded_spear': [277, 278, 279], 'Gloves_of_darkness': [276, 277, 278, 279], 'Greater_demon_mask': [276, 277, 278, 279], 'Green_boots': [181], 'Green_halloween_mask': [181], 'Green_hat': [181], 'Green_robe_bottoms': [181], 'Green_robe_top': [181], 'Hosidius_banner': [275, 276, 277, 278, 279], 'Hosidius_hood': [276, 277, 278, 279], 'Hosidius_scarf': [275, 276, 277, 278, 279], 'Incomplete_heavy_ballista': [337, 338, 339, 340, 341], 'Incomplete_light_ballista': [338, 339, 340, 341], 'Iron_hasta(p)': [765, 766, 767, 768], 'Iron_hasta(p+)': [764, 765, 766, 767, 768], 'Iron_hasta(p++)': [764, 765, 766, 767, 768], 'Jade_amulet': [65, 66, 67, 68, 69], 'Jade_amulet_(u)': [66, 67, 68, 69], 'Jungle_demon_mask': [277, 278, 279], 'Left_eye_patch': [275, 276, 277, 278, 279], 'Lesser_demon_mask': [275, 276, 277, 278, 279], 'Lovakengj_banner': [275, 276, 277, 278, 279], 'Lovakengj_hood': [276, 277, 278, 279], 'Lovakengj_scarf': [275, 276, 277, 278, 279], 'Mith_grapple_tip': [743, 744, 745, 746, 747], 'Mithril_dagger(p)': [1063], 'Mithril_limbs': [745, 746, 747], "Monk's_robe": [180], "Monk's_robe_top": [180], 'Monkey_tail': [340, 341], "Mummy's_body": [277, 278, 279], "Mummy's_feet": [277, 278, 279], "Mummy's_hands": [277, 278, 279], "Mummy's_head": [278, 279], "Mummy's_legs": [277, 278, 279], 'Old_demon_mask': [278, 279], 'Opal_amulet': [65, 66, 67, 68, 69], 'Opal_amulet_(u)': [66, 67, 68, 69], 'Orange_cape': [181], 'Pink_boots': [181], 'Pink_hat': [181], 'Pink_robe_bottoms': [181], 'Pink_robe_top': [181], 'Piscarilius_banner': [275, 276, 277, 278, 279], 'Piscarilius_hood': [275, 276, 277, 278, 279], 'Piscarilius_scarf': [275, 276, 277, 278, 279], 'Prayer_potion(1)': [181], 'Prayer_potion(2)': [181], 'Prayer_potion(3)': [181], 'Purple_cape': [181], 'Ranging_potion(1)': [181], 'Ranging_potion(2)': [181], 'Ranging_potion(3)': [181], 'Red_halloween_mask': [181], 'Restore_mix(1)': [1372, 1373, 1374], 'Restore_mix(2)': [1374], 'Restore_potion(1)': [181], 'Restore_potion(2)': [181], 'Restore_potion(3)': [181], 'Robe_bottom_of_darkness': [277, 278, 279], 'Robe_top_of_darkness': [278, 279], 'Samurai_boots': [277, 278, 279], 'Shayzien_banner': [275, 276, 277, 278, 279], 'Shayzien_hood': [278, 279], 'Spider_on_shaft': [744, 745, 746, 747], 'Spider_on_stick': [744, 745, 746, 747], 'Strength_mix(1)': [1374], 'Strength_potion(4)': [181], 'Super_attack(1)': [181], 'Super_attack(2)': [181], 'Super_attack(3)': [181], 'Super_defence(1)': [181], 'Super_defence(2)': [181], 'Super_defence(3)': [181], 'Super_strength(2)': [181], 'Super_strength(3)': [181], 'Superantipoison(1)': [181], 'Superantipoison(2)': [181], 'Topaz_amulet': [66, 67, 68, 69], 'Topaz_amulet_(u)': [68, 69], 'Turquoise_boots': [181], 'Turquoise_hat': [181], 'Turquoise_robe_bottoms': [181], 'Turquoise_robe_top': [181], 'Unstrung_light_ballista': [339, 340, 341], ...

# %%
item = 'Fishing_potion(1)'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [181]
# [1228, 1228, 1228, 54, 1228, 1228.0, 1228.0]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# adjust items that were revalued on 2017-04-11
week = 7 * 86400
checkPoint = 1491868800
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Amulet_of_bounty
# Arceuus_banner
# Arceuus_hood
# Arceuus_scarf
# Blacksmith's_helm
# Bones_to_bananas
# Boots_of_darkness
# Bowl_wig
# Bucket_helm_(g)
# Cyclops_head
# Empty_oil_lantern
# Enchant_diamond
# Enchant_emerald_or_jade
# Enchant_onyx
# Gilded_hasta
# Gilded_spear
# Gloves_of_darkness
# Greater_demon_mask
# Hosidius_banner
# Hosidius_hood
# Hosidius_scarf
# Incomplete_heavy_ballista
# Incomplete_light_ballista
# Iron_hasta(p)
# Iron_hasta(p+)
# Iron_hasta(p++)
# Jade_amulet
# Jade_amulet_(u)
# Jungle_demon_mask
# Left_eye_patch
# Lesser_demon_mask
# Lovakengj_banner
# Lovakengj_hood
# Lovakengj_scarf
# Mith_grapple_tip
# Mithril_limbs
# Monkey_tail
# Mummy's_body
# Mummy's_feet
# Mummy's_hands
# Mummy's_head
# Mummy's_legs
# Old_demon_mask
# Opal_amulet
# Opal_amulet_(u)
# Piscarilius_banner
# Piscarilius_hood
# Piscarilius_scarf
# Robe_bottom_of_darkness
# Robe_top_of_darkness
# Samurai_boots
# Shayzien_banner
# Shayzien_hood
# Spider_on_shaft
# Spider_on_stick
# Topaz_amulet
# Topaz_amulet_(u)
# Unstrung_light_ballista
# Zombie_head

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 71
# 13
# {'Antipoison(1)': [181], 'Antipoison(2)': [181], 'Antipoison(3)': [181], 'Attack_potion(2)': [181], 'Attack_potion(3)': [181], 'Black_cape': [181], 'Black_robe': [181], 'Blue_boots': [181], 'Blue_cape': [181], 'Blue_halloween_mask': [181], 'Blue_hat': [181], 'Blue_robe_bottoms': [181], 'Blue_robe_top': [181], 'Blue_wizard_robe': [181], 'Cream_boots': [181], 'Cream_hat': [181], 'Cream_robe_bottoms': [181], 'Cream_robe_top': [181], 'Defence_potion(2)': [181], 'Dragon_impling_jar': [1133], 'Fishing_potion(1)': [181], 'Fishing_potion(2)': [181, 1375], 'Fishing_potion(3)': [181], 'Green_boots': [181], 'Green_halloween_mask': [181], 'Green_hat': [181], 'Green_robe_bottoms': [181], 'Green_robe_top': [181], 'Mithril_dagger(p)': [1063], "Monk's_robe": [180], "Monk's_robe_top": [180], 'Orange_cape': [181], 'Pink_boots': [181], 'Pink_hat': [181], 'Pink_robe_bottoms': [181], 'Pink_robe_top': [181], 'Prayer_potion(1)': [181], 'Prayer_potion(2)': [181], 'Prayer_potion(3)': [181], 'Purple_cape': [181], 'Ranging_potion(1)': [181], 'Ranging_potion(2)': [181], 'Ranging_potion(3)': [181], 'Red_halloween_mask': [181], 'Restore_mix(1)': [1372, 1373, 1374], 'Restore_mix(2)': [1374], 'Restore_potion(1)': [181], 'Restore_potion(2)': [181], 'Restore_potion(3)': [181], 'Strength_mix(1)': [1374], 'Strength_potion(4)': [181], 'Super_attack(1)': [181], 'Super_attack(2)': [181], 'Super_attack(3)': [181], 'Super_defence(1)': [181], 'Super_defence(2)': [181], 'Super_defence(3)': [181], 'Super_strength(2)': [181], 'Super_strength(3)': [181], 'Superantipoison(1)': [181], 'Superantipoison(2)': [181], 'Turquoise_boots': [181], 'Turquoise_hat': [181], 'Turquoise_robe_bottoms': [181], 'Turquoise_robe_top': [181], 'Wizard_hat': [181], 'Yellow_cape': [181], 'Zamorak_brew(1)': [181], 'Zamorak_brew(2)': [181], 'Zamorak_brew(3)': [181], 'Zamorak_monk_top': [181]}

# %%
item = 'Turquoise_robe_bottoms'
print(outlier[item])
prices = [a[1] for a in itemPrices[item]]
dates = [a[0] for a in itemPrices[item]]
print(prices[outlier[item][0]-3:outlier[item][0]+4])
print(dates[outlier[item][0]],[datetime.utcfromtimestamp(dates[outlier[item][0]]).strftime('%Y-%m-%d %H:%M:%S')])
plt.plot(prices)
plt.show()
# Out:
# [181]
# [2865, 2865, 2865, 83, 2865, 2837.2, 2809.4]
# 1441152000 ['2015-09-02 00:00:00']

# %%
# fix outliers caused by misread on 2015-09-02 00:00:00
week = 7 * 86400
checkPoint = 1441152000
for item in outlier:
    i = outlier[item][0]
    date = itemPrices[item][i][0]
    if date > checkPoint-week and date < checkPoint+week:
        print(item)
        itemPrices[item] = itemPrices[item][i+7:]
# Out:
# Antipoison(1)
# Antipoison(2)
# Antipoison(3)
# Attack_potion(2)
# Attack_potion(3)
# Black_cape
# Black_robe
# Blue_boots
# Blue_cape
# Blue_halloween_mask
# Blue_hat
# Blue_robe_bottoms
# Blue_robe_top
# Blue_wizard_robe
# Cream_boots
# Cream_hat
# Cream_robe_bottoms
# Cream_robe_top
# Defence_potion(2)
# Fishing_potion(1)
# Fishing_potion(2)
# Fishing_potion(3)
# Green_boots
# Green_halloween_mask
# Green_hat
# Green_robe_bottoms
# Green_robe_top
# Monk's_robe
# Monk's_robe_top
# Orange_cape
# Pink_boots
# Pink_hat
# Pink_robe_bottoms
# Pink_robe_top
# Prayer_potion(1)
# Prayer_potion(2)
# Prayer_potion(3)
# Purple_cape
# Ranging_potion(1)
# Ranging_potion(2)
# Ranging_potion(3)
# Red_halloween_mask
# Restore_potion(1)
# Restore_potion(2)
# Restore_potion(3)
# Strength_potion(4)
# Super_attack(1)
# Super_attack(2)
# Super_attack(3)
# Super_defence(1)
# Super_defence(2)
# Super_defence(3)
# Super_strength(2)
# Super_strength(3)
# Superantipoison(1)
# Superantipoison(2)
# Turquoise_boots
# Turquoise_hat
# Turquoise_robe_bottoms
# Turquoise_robe_top
# Wizard_hat
# Yellow_cape
# Zamorak_brew(1)
# Zamorak_brew(2)
# Zamorak_brew(3)
# Zamorak_monk_top

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]

# %%
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 6
# 9
# {'Dragon_impling_jar': [1133], 'Fishing_potion(2)': [1187], 'Mithril_dagger(p)': [1063], 'Restore_mix(1)': [1372, 1373, 1374], 'Restore_mix(2)': [1374], 'Strength_mix(1)': [1374]}

# %%
for item in outlier:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Dragon_impling_jar
# Fishing_potion(2)
# Mithril_dagger(p)
# Restore_mix(1)
# Restore_mix(2)
# Strength_mix(1)

# %%
# guess I'll just get rid of these ones
for item in outlier:
    itemPrices.pop(item,None)

# %%
outlier = {}
adjust = {}
for item in itemPrices:
    #print(item)
    prices = [a[1] for a in itemPrices[item]]
    data = checkOutliers(prices)
    if len(data[0])>0:
        outlier[item] = data[0]
    if len(data[1])>0:
        adjust[item] = data[1]
print(len(outlier))
print(len(adjust))
print(outlier)
# Out:
# 0
# 8
# {}

# %%
for item in adjust:
    print(item)
    prices = [a[1] for a in itemPrices[item]]
    dates = [a[0] for a in itemPrices[item]]
    plt.plot(prices)
    plt.show()
# Out:
# Craw's_bow_(u)
# Disk_of_returning
# Dragon_harpoon
# Dragon_sword
# Dragonbone_necklace
# Heavy_ballista
# Thammaron's_sceptre_(u)
# Viggora's_chainmace_(u)

# %%
# noticed that dragon sword price was changed after an update on january 10th
# and that information was stored on its wiki page, should probably scrape that as well

# %%
# save results back to itemPrices
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1496: 2
# 1489: 272
# 1488: 526
# 1467: 2016
# 1301: 65
# 1274: 6
# 1180: 6
# 1179: 26
# 1164: 1
# 1131: 1
# 1061: 31
# 1054: 10
# 1040: 4
# 1033: 2
# 1020: 1
# 1005: 1
# 999: 84
# 998: 3
# 997: 1
# 991: 1
# 982: 6
# 971: 1
# 964: 1
# 936: 2
# 929: 6
# 915: 1
# 908: 1
# 887: 1
# 817: 14
# 809: 2
# 803: 1
# 797: 1
# 794: 1
# 789: 20
# 782: 1
# 761: 1
# 719: 1
# 717: 21
# 716: 16
# 715: 12
# 714: 9
# 713: 1
# 697: 1
# 669: 3
# 668: 1
# 649: 13
# 621: 1
# 571: 24
# 523: 6
# 517: 1
# 494: 7
# 480: 1
# 453: 51
# 439: 5
# 432: 1
# 431: 9
# 425: 10
# 424: 2
# 418: 6
# 334: 2
# 313: 1
# 299: 18
# 249: 4
# 208: 12

# %%
# probably 1306
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l].append(item)
    else:
        sizes[l] = [item]

# %%
s = 1496
print(sizes[s][0])
print(datetime.utcfromtimestamp(itemPrices[sizes[s][0]][0][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Karambwan_vessel
# 2015-02-26 00:00:00

# %%
for item in itemPrices:
    prices = [a[1] for a in itemPrices[item]]
    ma7 = util.items.sma(prices,7)
    for i in range(1,len(ma7)):
        if ma7[i]<ma7[i-1]:
            itemPrices[item] = itemPrices[item][i:]
            break
    prices = [a[1] for a in itemPrices[item]]
    ma7 = util.items.sma(prices,7)
    for i in range(1,len(ma7)):
        if ma7[i]>ma7[i-1]:
            itemPrices[item] = itemPrices[item][i:]
            break

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l]+=1
    else:
        sizes[l] = 1
cumSum = 0
cumSums = []
keys = []
for key in sorted(sizes,reverse=True):
    print("%s: %s" % (key, sizes[key]))
    keys.append(key)
    cumSum += sizes[key]
    cumSums.append(cumSum)
cumSums = np.array(cumSums)/cumSum
# Out:
# 1489: 2
# 352: 1
# 351: 2
# 350: 1
# 348: 1
# 346: 1
# 345: 1
# 343: 1
# 342: 1
# 341: 1
# 337: 2
# 335: 2
# 333: 3
# 332: 2
# 331: 1
# 330: 1
# 324: 1
# 323: 1
# 321: 1
# 319: 1
# 318: 2
# 316: 1
# 312: 1
# 311: 3
# 310: 1
# 306: 2
# 302: 1
# 301: 2
# 298: 1
# 296: 1
# 295: 1
# 294: 3
# 293: 1
# 291: 1
# 290: 1
# 289: 2
# 285: 1
# 284: 1
# 281: 1
# 280: 1
# 278: 2
# 277: 1
# 273: 2
# 271: 2
# 270: 1
# 269: 1
# 267: 1
# 266: 2
# 264: 1
# 260: 1
# 257: 1
# 255: 2
# 250: 1
# 248: 2
# 246: 1
# 242: 1
# 240: 2
# 238: 1
# 236: 1
# 235: 1
# 233: 2
# 231: 2
# 226: 1
# 225: 1
# 224: 2
# 223: 1
# 222: 1
# 221: 1
# 220: 1
# 217: 1
# 216: 1
# 212: 1
# 211: 1
# 210: 1
# 208: 7
# 207: 1
# 204: 2
# 203: 1
# 200: 2
# 198: 1
# 195: 1
# 194: 1
# 193: 1
# 192: 1
# 191: 1
# 188: 1
# 187: 1
# 186: 4
# 184: 1
# 183: 2
# 182: 1
# 181: 2
# 178: 1
# 176: 2
# 175: 1
# 174: 2
# 173: 1
# 172: 2
# 167: 3
# 166: 1
# 162: 2
# 161: 2
# 160: 2
# 157: 1
# 156: 1
# 155: 1
# 153: 1
# 152: 1
# 151: 1
# 150: 2
# 149: 1
# 148: 2
# 147: 2
# 146: 1
# 145: 1
# 144: 1
# 143: 2
# 142: 2
# 141: 1
# 140: 3
# 138: 1
# 134: 2
# 132: 2
# 131: 1
# 130: 2
# 129: 2
# 128: 2
# 126: 1
# 124: 3
# 123: 3
# 122: 2
# 117: 1
# 116: 2
# 114: 2
# 113: 1
# 112: 1
# 110: 2
# 109: 2
# 105: 1
# 104: 1
# 103: 1
# 102: 1
# 101: 3
# 100: 1
# 99: 2
# 94: 1
# 90: 1
# 85: 2
# 84: 2
# 83: 1
# 82: 1
# 81: 1
# 80: 1
# 78: 1
# 77: 1
# 75: 2
# 68: 1
# 65: 3
# 64: 1
# 63: 3
# 60: 1
# 59: 2
# 58: 1
# 56: 1
# 54: 2
# 50: 1
# 49: 1
# 48: 1
# 45: 1
# 40: 1
# 33: 1
# 31: 1
# 28: 2
# 27: 1
# 24: 1
# 22: 2
# 19: 2
# 12: 1
# 11: 1
# 10: 1
# 9: 1

# %%
# probably 1306
plt.plot(keys,cumSums)
plt.gca().invert_xaxis()

# %%
# check length of available datasets
sizes = {}
for item in itemPrices:
    l = len(itemPrices[item])
    if l in sizes:
        sizes[l].append(item)
    else:
        sizes[l] = [item]

# %%
s = 50
print(sizes[s][0])
print(datetime.utcfromtimestamp(itemPrices[sizes[s][0]][0][0]).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Dragon_metal_lump
# 2019-02-11 00:00:00

# %%
for item in itemPrices:
    itemPrices[item].sort(key=lambda tup: tup[0])
with open('itemPrices.pickle', 'wb') as f:
    pickle.dump(itemPrices,f)
